# %%
import pandas as pd
import numpy as np
import io
import boto3
from pymongo import MongoClient

# %% [markdown]
# # s3 client & bucket_list

# %%
s3_client = boto3.client(service_name="s3",
                         aws_access_key_id="AKIA5SHMC74H2QMNG2FB",
                         aws_secret_access_key="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")
s3 = boto3.resource('s3')
bucket = s3.Bucket('elice-team5-bucket')
for obj in bucket.objects.all():
    print(obj)
# Out:
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-변화지표/')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-변화지표/서울시 우리마을가게 상권분석서비스(상권-상권변화지표).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-변화지표/서울시 우리마을가게 상권분석서비스(자치구별 상권변화지표).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-변화지표/서울시 우리마을가게 상권분석서비스(행정동별 상권변화지표).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-영역/')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-영역/서울시 우리마을가게 상권분석서비스(상권영역)-위도,경도 추가.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-영역/서울시 우리마을가게 상권분석서비스(상권영역).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-점포/서울시_우리마을가게_상권분석서비스(상권-점포)_2014년.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-점포/서울시_우리마을가게_상권분석서비스(상권-점포)_2015년.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-점포/서울시_우리마을가게_상권분석서비스(상권-점포)_2016년.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-점포/서울시_우리마을가게_상권분석서비스(상권-점포)_2017년.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-점포/서울시_우리마을가게_상권분석서비스(상권-점포)_2018년.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-점포/서울시_우리마을가게_상권분석서비스(상권-점포)_2019년.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-점포/서울시_우리마을가게_상권분석서비스(상권-점포)_2020년.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-추정매출/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2016.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-추정매출/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2017.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-추정매출/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2018.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-추정매출/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2019.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-추정매출/서울시우리마을가게상권분석서비스(상권-추정매출)_2020.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권-추정매출/서울시우리마을가게상권분석서비스(상권-추정매출)_2021.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권배후지-소득소비/')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권배후지-소득소비/서울시 우리마을가게 상권분석서비스(상권배후지-소득소비).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권배후지-추정매출/2016년_우리마을가게_상권서비스_상권배후지-추정매출.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권배후지-추정매출/2017년_우리마을가게_상권서비스_상권배후지-추정매출.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권배후지-추정매출/2018년_우리마을가게_상권서비스_상권배후지-추정매출.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권배후지-추정매출/2019년_우리마을가게_상권서비스_상권배후지-추정매출.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권배후지-추정매출/2020년_우리마을가게_상권서비스_상권배후지-추정매출.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='상권배후지-추정매출/2021년_우리마을가게_상권서비스_상권배후지-추정매출.csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='인구/')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='인구/서울시 우리마을가게 상권분석서비스(상권-생활인구).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='인구/서울시 우리마을가게 상권분석서비스(상권-직장인구).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='인구/서울시 우리마을가게 상권분석서비스(상권_상주인구).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='인구/서울시 우리마을가게 상권분석서비스(상권배후지-상주인구).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='인구/서울시 우리마을가게 상권분석서비스(상권배후지-생활인구).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='인구/서울시 우리마을가게 상권분석서비스(상권배후지-직장인구).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='주변시설/')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='주변시설/서울시 우리마을가게 상권분석서비스(상권-아파트).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='주변시설/서울시 우리마을가게 상권분석서비스(상권-집객시설).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='주변시설/서울시 우리마을가게 상권분석서비스(상권배후지-아파트).csv')
# s3.ObjectSummary(bucket_name='elice-team5-bucket', key='주변시설/서울시 우리마을가게 상권분석서비스(상권배후지-집객시설).csv')

# %% [markdown]
# # 연도별 (상권-추정매출).csv 파일 불러오기 함수

# %%
def csv_into_df(year):
    if year < 2020:
        csv_title = '상권-추정매출/서울시 우리마을가게 상권분석서비스(상권-추정매출)_' + str(year) + '.csv'
    else:
        csv_title = '상권-추정매출/서울시우리마을가게상권분석서비스(상권-추정매출)_' + str(year) + '.csv'
    obj = s3_client.get_object(Bucket="elice-team5-bucket", Key=csv_title)
    df = pd.read_csv(io.BytesIO(obj["Body"].read()), encoding='cp949', low_memory=False)
    return df

# %% [markdown]
# # 서울시 서비스 업종 코드별 추정 월별 평균 매출 함수

# %%
def monthly_sales_df(df):
    grouped_df = df.groupby(['서비스_업종_코드_명']).sum()
    grouped_df["월별_평균_매출"] = grouped_df['분기당_매출_금액']/grouped_df['점포수']/4
    result_df = grouped_df.loc[:,['분기당_매출_금액', '점포수', '월별_평균_매출']].sort_values('월별_평균_매출', ascending=False)
    return result_df

# %% [markdown]
# # value 소숫점 표현식

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %% [markdown]
# # csv 파일 concat 으로 df에 넣기

# %%
df = pd.DataFrame()
for year in range(2016, 2021):
    df = pd.concat([df, csv_into_df(year)])
df
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0          2016         1        A       골목상권  1000013       율곡로10길  CS300011
# 1          2016         1        R       전통시장  1001271         동묘시장  CS300017
# 2          2016         1        A       골목상권  1000447       증가로10길  CS300006
# 3          2016         1        R       전통시장  1001420       고척근린시장  CS300035
# 4          2016         1        A       골목상권  1000936       학동로38길  CS300014
# ...         ...       ...      ...        ...      ...          ...       ...
# 132316     2020         2        R       전통시장  1001477         마천시장  CS100008
# 132317     2020         2        R       전통시장  1001487         천호시장  CS200028
# 132318     2020         2        R       전통시장  1001488       성내골목시장  CS200030
# 132319     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS200030
# 132320     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300043
#
#        서비스_업종_코드_명  분기당_매출_금액  분기당_매출_건수  ...  시간대_건수~24_매출_건수  남성_매출_건수  \
# 0             일반의류   27000000         21  ...                0         0
# 1           시계및귀금속     649744         17  ...                0         8
# 2             미곡판매    1856535         40  ...                0        20
# 3             인테리어     152749          5  ...                0         5
# 4               신발    1000000          4  ...                0         4
# ...            ...        ...        ...  ...              ...       ...
# 132316       분식전문점   28919831       2653  ...                0      1293
# 132317         미용실   59125109         78  ...                0        78
# 132318       피부관리실    6928058         32  ...                0         0
# 132319       피부관리실   17953355         95  ...                0        67
# 132320      전자상거래업    6415600        169  ...                0        63
#
#         여성_매출_건수  연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  \
# 0             11             0             0             0             0
# 1              9             0             0             0             0
# 2             20             0             0             0             0
# 3              0             0             0             0             5
# 4              0             0             4             0             0
# ...          ...           ...           ...           ...           ...
# 132316       971             0             0           388           323
# 132317         0             0             0             0             0
# 132318        32             0             0            19             6
# 132319        10             0             0            10            38
# 132320       106             0            10           139            10
#
#         연령대_50_매출_건수  연령대_60_이상_매출_건수  점포수
# 0                  4                7    2
# 1                  8                9    1
# 2                 20               20    2
# 3                  0                0    2
# 4                  0                0    2
# ...              ...              ...  ...
# 132316           711              842    8
# 132317             0               78    1
# 132318             0                7    1
# 132319            19               10    3
# 132320             5                5    8
#
# [763749 rows x 80 columns]

# %% [markdown]
# # '기준_년_코드', '서비스_업종_코드_명' 그룹화

# %%
grouped_df = df.groupby(['기준_년_코드','서비스_업종_코드_명']).sum()
grouped_df
# Out:
#                      기준_분기_코드       상권_코드     분기당_매출_금액  분기당_매출_건수  주중_매출_비율  \
# 기준_년_코드 서비스_업종_코드_명
# 2016    PC방              3474  1345109214  125911277203   26880348     89397
#         가구               2537  1014835611  557598716973    1435527     71127
#         가방               2199   876812985  422277852340    7503515     63079
#         가전제품             2155   863708894  829311372953    3997598     68415
#         가전제품수리           1554   609423562   39408821705     501559     51496
# ...                       ...         ...           ...        ...       ...
# 2020    한의원              7558  3029456518  689294200034   17781184    255272
#         핸드폰              2758  1117921602  292277806448    9634679     91514
#         호프-간이주점         11373  4560362371 1718303182556   47840610    331232
#         화장품              7935  3192618903 2116487593745   33626350    254788
#         화초               4960  1992668950  237079869373    5287841    153766
#
#                      주말_매출_비율  월요일_매출_비율  화요일_매출_비율  수요일_매출_비율  목요일_매출_비율  \
# 기준_년_코드 서비스_업종_코드_명
# 2016    PC방             45137      17596      17101      17429      17914
#         가구              30347      15015      13675      13980      14094
#         가방              24590      10968      12090      12991      13305
#         가전제품            17952      14083      13097      13952      13486
#         가전제품수리           9442      11989      10096      10084      10339
# ...                       ...        ...        ...        ...        ...
# 2020    한의원             47739      57705      50889      49693      45870
#         핸드폰             20231      19538      19478      17608      18240
#         호프-간이주점        124939      56993      65020      67514      68288
#         화장품             64457      50121      50104      50594      52640
#         화초              45506      24623      27873      29659      33783
#
#                      ...  시간대_건수~24_매출_건수  남성_매출_건수  여성_매출_건수  연령대_10_매출_건수  \
# 기준_년_코드 서비스_업종_코드_명  ...
# 2016    PC방          ...          5609803  21917004   4932549       3882997
#         가구           ...            14114    534103    750618          7236
#         가방           ...           710247   2031076   5156341        185792
#         가전제품         ...           104877   2139759   1487256         76476
#         가전제품수리       ...             2420    251570    190253          2811
# ...                  ...              ...       ...       ...           ...
# 2020    한의원          ...            19624   8147865   9585069         39408
#         핸드폰          ...           465453   4456514   4957578        611454
#         호프-간이주점      ...         16938794  27653940  17737310        802143
#         화장품          ...          2344470   8212617  25025918        695293
#         화초           ...           164262   2141016   2581335         68069
#
#                      연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  \
# 기준_년_코드 서비스_업종_코드_명
# 2016    PC방              17663768       2867776       1281590       1005663
#         가구                 195003        328370        318164        276703
#         가방                2598730       1764684       1325894        844220
#         가전제품               822119        733419        786575        713892
#         가전제품수리              42191         92634        115707        104704
# ...                           ...           ...           ...           ...
# 2020    한의원               1344985       2572045       3567599       4455787
#         핸드폰               2618957       1873641       2094075       1521235
#         호프-간이주점          17192826      11058782       7500382       6173179
#         화장품              11890732       7485460       5053780       4856416
#         화초                1366890       1302066        802225        704465
#
#                      연령대_60_이상_매출_건수    점포수
# 기준_년_코드 서비스_업종_코드_명
# 2016    PC방                   147811   3860
#         가구                    159902   5367
#         가방                    468384   7910
#         가전제품                  495580   6479
#         가전제품수리                 83961   1529
# ...                              ...    ...
# 2020    한의원                  5753023   9240
#         핸드폰                   694442   7365
#         호프-간이주점              2663777  42705
#         화장품                  3256788  43978
#         화초                    478628   9348
#
# [369 rows x 74 columns]

# %% [markdown]
# # 필요한 데이터 index 만들기

# %%
grouped_df['월별_평균_매출'] = grouped_df['분기당_매출_금액']/grouped_df['점포수']/4
grouped_df['전년도비_매출_증감'] = np.nan
grouped_df['전년도비_매출_증감률'] = np.nan
grouped_df['전년도비_점포수_증감'] = np.nan
grouped_df['전년도비_점포수_증감률'] = np.nan

# %% [markdown]
# # 전년도비_매출_증감

# %%
for year in range(2017, 2021):
    grouped_df.loc[year, '전년도비_매출_증감'] = grouped_df.loc[year, '월별_평균_매출'].sub(grouped_df.loc[(year-1), '월별_평균_매출']).dropna().values
grouped_df.loc[2019]
# Out:
#              기준_분기_코드       상권_코드     분기당_매출_금액  분기당_매출_건수  주중_매출_비율  \
# 서비스_업종_코드_명
# PC방              4110  1630293699  452236221391   97310629    106177
# 가구               1956   778670519  501158000153     956272     54736
# 가방               1307   527506120  202009823699    3290667     37895
# 가전제품             1471   597485475  761034837681    2225432     47748
# 가전제품수리           1166   477312185   32346577272     487194     40463
# ...               ...         ...           ...        ...       ...
# 한의원              7692  3087496453  759454136903   19877249    259146
# 핸드폰              3086  1253020894  335359887797    9846368    102441
# 호프-간이주점         11464  4613395234 2094046998139   53249872    332151
# 화장품              8145  3265645037 2683386001237   79142430    254869
# 화초               5122  2070707288  240233122436    4912570    158631
#
#              주말_매출_비율  월요일_매출_비율  화요일_매출_비율  수요일_매출_비율  목요일_매출_비율  ...  \
# 서비스_업종_코드_명                                                        ...
# PC방             56863      20519      20558      20589      21044  ...
# 가구              23115      11645      11336      10897      10613  ...
# 가방              14841       6758       8413       7593       7407  ...
# 가전제품            11987      10690       9577       9082       8649  ...
# 가전제품수리           7261       9074       8747       7271       7807  ...
# ...               ...        ...        ...        ...        ...  ...
# 한의원             49699      59089      51660      49511      44917  ...
# 핸드폰             22817      21500      21053      20350      19148  ...
# 호프-간이주점        129307      56878      65969      66828      67492  ...
# 화장품             71712      49083      49745      49840      52729  ...
# 화초              48443      27868      32936      32375      31032  ...
#
#              연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  연령대_60_이상_매출_건수    점포수  \
# 서비스_업종_코드_명
# PC방              12777069       5880406       4323256           710250   4244
# 가구                 178881        205949        247460           169187   4338
# 가방                 632361        610346        567206           462493   6225
# 가전제품               395118        433609        471764           416461   5292
# 가전제품수리              78038        107560        106037           100092   1295
# ...                   ...           ...           ...              ...    ...
# 한의원               3051565       4322410       4952560          5913783   9347
# 핸드폰               1806616       2197939       1540093           745894   7355
# 호프-간이주점          11647432       8170811       6450054          2630943  43820
# 화장품              17405870      11766467       9230955          4458950  43502
# 화초                1169628        759039        617053           399439   9272
#
#              월별_평균_매출  전년도비_매출_증감  전년도비_매출_증감률  전년도비_점포수_증감  전년도비_점포수_증감률
# 서비스_업종_코드_명
# PC방          26639740    -1463302          NaN          NaN           NaN
# 가구           28881858    -1930030          NaN          NaN           NaN
# 가방            8112844    -3782846          NaN          NaN           NaN
# 가전제품         35952137    -2802406          NaN          NaN           NaN
# 가전제품수리        6244513    -1557177          NaN          NaN           NaN
# ...               ...         ...          ...          ...           ...
# 한의원          20312778    -1320832          NaN          NaN           NaN
# 핸드폰          11399044    -2163804          NaN          NaN           NaN
# 호프-간이주점      11946868    -4698952          NaN          NaN           NaN
# 화장품          15421050    -1937715          NaN          NaN           NaN
# 화초            6477381     -283958          NaN          NaN           NaN
#
# [63 rows x 79 columns]

# %% [markdown]
# # 전년도비_매출_증감률

# %%
for year in range(2017, 2021):
    grouped_df.loc[year, '전년도비_매출_증감률'] = grouped_df.loc[year, '월별_평균_매출'].values / grouped_df.loc[year-1, '월별_평균_매출'].filter(items=grouped_df.loc[year].index, axis=0).values * 100 - 100
grouped_df.loc[2018]
# Out:
#              기준_분기_코드       상권_코드     분기당_매출_금액  분기당_매출_건수  주중_매출_비율  \
# 서비스_업종_코드_명
# PC방              4455  1779420539  527662712740  115481290    117176
# 가구               2363   948793707  609089405881    1445355     66455
# 가방               2009   800760460  344070950759    6651772     57784
# 가전제품             1958   790637761  897400193926    3430956     63907
# 가전제품수리           1614   641428096   49025817671     679392     53759
# ...               ...         ...           ...        ...       ...
# 핸드폰              5889  2364884327  635121080933   13872525    191861
# 호프-간이주점         12221  4888574399 3356263434270   90177045    354598
# 화장품             10124  4056176495 3373085651261  106079354    316590
# 화초               5781  2326900579  260284511992    5560722    177064
# 회계사사무소            287   119110240   27227384577      52948     11789
#
#              주말_매출_비율  월요일_매출_비율  화요일_매출_비율  수요일_매출_비율  목요일_매출_비율  ...  \
# 서비스_업종_코드_명                                                        ...
# PC방             60815      23430      22696      22868      22811  ...
# 가구              28415      14318      12909      13642      12860  ...
# 가방              22278      11320      11334      11176      11403  ...
# 가전제품            15146      12803      13515      11919      13067  ...
# 가전제품수리          10376      11074      11189      10566      10111  ...
# ...               ...        ...        ...        ...        ...  ...
# 핸드폰             44624      42320      38115      38305      35978  ...
# 호프-간이주점        134339      63338      69978      71279      71683  ...
# 화장품             89075      60491      61958      63104      64162  ...
# 화초              55639      35058      36010      34138      32853  ...
# 회계사사무소            112       2802       2256       1839       2441  ...
#
#              연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  연령대_60_이상_매출_건수    점포수  \
# 서비스_업종_코드_명
# PC방              13001074       5265453       3878832           666128   4694
# 가구                 278974        302253        329389           217543   4942
# 가방                1392960       1159172        880998           587414   7231
# 가전제품               475802        558937        601047           492633   5789
# 가전제품수리             112026        149681        134768           117471   1571
# ...                   ...           ...           ...              ...    ...
# 핸드폰               2778705       2679446       2153892          1178363  11707
# 호프-간이주점          18782739      12421217       9164425          3761216  50407
# 화장품              22033285      14362315      11346492          5697048  48579
# 화초                1219666        779014        613833           377543   9624
# 회계사사무소               6289         14964         11419            13081    676
#
#              월별_평균_매출  전년도비_매출_증감  전년도비_매출_증감률  전년도비_점포수_증감  전년도비_점포수_증감률
# 서비스_업종_코드_명
# PC방          28103042    11469700           69          NaN           NaN
# 가구           30811888     4718637           18          NaN           NaN
# 가방           11895690     -116644           -1          NaN           NaN
# 가전제품         38754543     3943605           11          NaN           NaN
# 가전제품수리        7801690      -82018           -1          NaN           NaN
# ...               ...         ...          ...          ...           ...
# 핸드폰          13562849     1084730            9          NaN           NaN
# 호프-간이주점      16645820     3245831           24          NaN           NaN
# 화장품          17358764     -320798           -2          NaN           NaN
# 화초            6761339      540694            9          NaN           NaN
# 회계사사무소       10069299    -2276360          -18          NaN           NaN
#
# [81 rows x 79 columns]

# %% [markdown]
# # 전년도비_점포수_증감

# %%
for year in range(2017, 2021):
    grouped_df.loc[year, '전년도비_점포수_증감'] = grouped_df.loc[year, '점포수'].sub(grouped_df.loc[(year-1), '점포수']).dropna().values
grouped_df.loc[2019]
# Out:
#              기준_분기_코드       상권_코드     분기당_매출_금액  분기당_매출_건수  주중_매출_비율  \
# 서비스_업종_코드_명
# PC방              4110  1630293699  452236221391   97310629    106177
# 가구               1956   778670519  501158000153     956272     54736
# 가방               1307   527506120  202009823699    3290667     37895
# 가전제품             1471   597485475  761034837681    2225432     47748
# 가전제품수리           1166   477312185   32346577272     487194     40463
# ...               ...         ...           ...        ...       ...
# 한의원              7692  3087496453  759454136903   19877249    259146
# 핸드폰              3086  1253020894  335359887797    9846368    102441
# 호프-간이주점         11464  4613395234 2094046998139   53249872    332151
# 화장품              8145  3265645037 2683386001237   79142430    254869
# 화초               5122  2070707288  240233122436    4912570    158631
#
#              주말_매출_비율  월요일_매출_비율  화요일_매출_비율  수요일_매출_비율  목요일_매출_비율  ...  \
# 서비스_업종_코드_명                                                        ...
# PC방             56863      20519      20558      20589      21044  ...
# 가구              23115      11645      11336      10897      10613  ...
# 가방              14841       6758       8413       7593       7407  ...
# 가전제품            11987      10690       9577       9082       8649  ...
# 가전제품수리           7261       9074       8747       7271       7807  ...
# ...               ...        ...        ...        ...        ...  ...
# 한의원             49699      59089      51660      49511      44917  ...
# 핸드폰             22817      21500      21053      20350      19148  ...
# 호프-간이주점        129307      56878      65969      66828      67492  ...
# 화장품             71712      49083      49745      49840      52729  ...
# 화초              48443      27868      32936      32375      31032  ...
#
#              연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  연령대_60_이상_매출_건수    점포수  \
# 서비스_업종_코드_명
# PC방              12777069       5880406       4323256           710250   4244
# 가구                 178881        205949        247460           169187   4338
# 가방                 632361        610346        567206           462493   6225
# 가전제품               395118        433609        471764           416461   5292
# 가전제품수리              78038        107560        106037           100092   1295
# ...                   ...           ...           ...              ...    ...
# 한의원               3051565       4322410       4952560          5913783   9347
# 핸드폰               1806616       2197939       1540093           745894   7355
# 호프-간이주점          11647432       8170811       6450054          2630943  43820
# 화장품              17405870      11766467       9230955          4458950  43502
# 화초                1169628        759039        617053           399439   9272
#
#              월별_평균_매출  전년도비_매출_증감  전년도비_매출_증감률  전년도비_점포수_증감  전년도비_점포수_증감률
# 서비스_업종_코드_명
# PC방          26639740    -1463302           -5         -450           NaN
# 가구           28881858    -1930030           -6         -604           NaN
# 가방            8112844    -3782846          -32        -1006           NaN
# 가전제품         35952137    -2802406           -7         -497           NaN
# 가전제품수리        6244513    -1557177          -20         -276           NaN
# ...               ...         ...          ...          ...           ...
# 한의원          20312778    -1320832           -6         -283           NaN
# 핸드폰          11399044    -2163804          -16        -4352           NaN
# 호프-간이주점      11946868    -4698952          -28        -6587           NaN
# 화장품          15421050    -1937715          -11        -5077           NaN
# 화초            6477381     -283958           -4         -352           NaN
#
# [63 rows x 79 columns]

# %% [markdown]
# # 전년도비_점포수_증감률

# %%
for year in range(2017, 2021):
    grouped_df.loc[year, '전년도비_점포수_증감률'] = grouped_df.loc[year, '점포수'].values / grouped_df.loc[year-1, '점포수'].filter(items=grouped_df.loc[year].index, axis=0).values * 100 - 100
grouped_df.loc[2018]
# Out:
#              기준_분기_코드       상권_코드     분기당_매출_금액  분기당_매출_건수  주중_매출_비율  \
# 서비스_업종_코드_명
# PC방              4455  1779420539  527662712740  115481290    117176
# 가구               2363   948793707  609089405881    1445355     66455
# 가방               2009   800760460  344070950759    6651772     57784
# 가전제품             1958   790637761  897400193926    3430956     63907
# 가전제품수리           1614   641428096   49025817671     679392     53759
# ...               ...         ...           ...        ...       ...
# 핸드폰              5889  2364884327  635121080933   13872525    191861
# 호프-간이주점         12221  4888574399 3356263434270   90177045    354598
# 화장품             10124  4056176495 3373085651261  106079354    316590
# 화초               5781  2326900579  260284511992    5560722    177064
# 회계사사무소            287   119110240   27227384577      52948     11789
#
#              주말_매출_비율  월요일_매출_비율  화요일_매출_비율  수요일_매출_비율  목요일_매출_비율  ...  \
# 서비스_업종_코드_명                                                        ...
# PC방             60815      23430      22696      22868      22811  ...
# 가구              28415      14318      12909      13642      12860  ...
# 가방              22278      11320      11334      11176      11403  ...
# 가전제품            15146      12803      13515      11919      13067  ...
# 가전제품수리          10376      11074      11189      10566      10111  ...
# ...               ...        ...        ...        ...        ...  ...
# 핸드폰             44624      42320      38115      38305      35978  ...
# 호프-간이주점        134339      63338      69978      71279      71683  ...
# 화장품             89075      60491      61958      63104      64162  ...
# 화초              55639      35058      36010      34138      32853  ...
# 회계사사무소            112       2802       2256       1839       2441  ...
#
#              연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  연령대_60_이상_매출_건수    점포수  \
# 서비스_업종_코드_명
# PC방              13001074       5265453       3878832           666128   4694
# 가구                 278974        302253        329389           217543   4942
# 가방                1392960       1159172        880998           587414   7231
# 가전제품               475802        558937        601047           492633   5789
# 가전제품수리             112026        149681        134768           117471   1571
# ...                   ...           ...           ...              ...    ...
# 핸드폰               2778705       2679446       2153892          1178363  11707
# 호프-간이주점          18782739      12421217       9164425          3761216  50407
# 화장품              22033285      14362315      11346492          5697048  48579
# 화초                1219666        779014        613833           377543   9624
# 회계사사무소               6289         14964         11419            13081    676
#
#              월별_평균_매출  전년도비_매출_증감  전년도비_매출_증감률  전년도비_점포수_증감  전년도비_점포수_증감률
# 서비스_업종_코드_명
# PC방          28103042    11469700           69           67             1
# 가구           30811888     4718637           18         -337            -6
# 가방           11895690     -116644           -1         -475            -6
# 가전제품         38754543     3943605           11         -305            -5
# 가전제품수리        7801690      -82018           -1           27             2
# ...               ...         ...          ...          ...           ...
# 핸드폰          13562849     1084730            9         -809            -6
# 호프-간이주점      16645820     3245831           24        -5496           -10
# 화장품          17358764     -320798           -2        -3172            -6
# 화초            6761339      540694            9          -82            -1
# 회계사사무소       10069299    -2276360          -18            1             0
#
# [81 rows x 79 columns]

# %% [markdown]
# # pivot_table 생성

# %%
pivot_df = pd.pivot_table(grouped_df, index=['기준_년_코드', '서비스_업종_코드_명'], values=['분기당_매출_금액', '점포수', '월별_평균_매출', '전년도비_매출_증감', '전년도비_매출_증감률', '전년도비_점포수_증감', '전년도비_점포수_증감률'])
# 연도별 필터링 및 정렬
pivot_df.loc[2019].sort_values(by='전년도비_점포수_증감률', ascending=False)
# Out:
#                  분기당_매출_금액  월별_평균_매출  전년도비_매출_증감  전년도비_매출_증감률  전년도비_점포수_증감  \
# 서비스_업종_코드_명
# 외국어학원         504156356997  15715597    -2429196          -13          899
# 분식전문점        1697104792589  10027563     -669880           -6         3958
# 커피-음료        2255213047104  11788389    -3159190          -21         3176
# 피부관리실         213941571586   3831606    -1264880          -25          657
# 스포츠 강습        239763061493   6796005    -1676829          -20          164
# ...                    ...       ...         ...          ...          ...
# 인테리어          175089154468   7296598     -550849           -7        -2170
# 자전거 및 기타운송장비   41281110621  27520740    -4373190          -14         -148
# 육류판매         1611034668032  34916226    -6025010          -15        -6167
# 핸드폰           335359887797  11399044    -2163804          -16        -4352
# 부동산중개업         11110365599    901815    -3720412          -80       -14990
#
#               전년도비_점포수_증감률    점포수
# 서비스_업종_코드_명
# 외국어학원                   13   8020
# 분식전문점                   10  42311
# 커피-음료                    7  47827
# 피부관리실                    5  13959
# 스포츠 강습                   2   8820
# ...                    ...    ...
# 인테리어                   -27   5999
# 자전거 및 기타운송장비           -28    375
# 육류판매                   -35  11535
# 핸드폰                    -37   7355
# 부동산중개업                 -83   3080
#
# [63 rows x 7 columns]

# %%
mongo_df = pivot_df.dropna()

# %%
mongo_df.reset_index().to_dict('records')
# Out:
# [{'기준_년_코드': 2017,
#   '서비스_업종_코드_명': 'PC방',
#   '분기당_매출_금액': 307849882518.0,
#   '월별_평균_매출': 16633341.393883726,
#   '전년도비_매출_증감': 8478465.927368183,
#   '전년도비_매출_증감률': 103.96806134172522,
#   '전년도비_점포수_증감': 767.0,
#   '전년도비_점포수_증감률': 19.870466321243512,
#   '점포수': 4627},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '가구',
#   '분기당_매출_금액': 550985083342.0,
#   '월별_평균_매출': 26093250.773915514,
#   '전년도비_매출_증감': 119768.52251808718,
#   '전년도비_매출_증감률': 0.4611184644355717,
#   '전년도비_점포수_증감': -88.0,
#   '전년도비_점포수_증감률': -1.6396497111980608,
#   '점포수': 5279},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '가방',
#   '분기당_매출_금액': 370268192661.0,
#   '월별_평균_매출': 12012334.306417078,
#   '전년도비_매출_증감': -1333994.7814463861,
#   '전년도비_매출_증감률': -9.995218705190325,
#   '전년도비_점포수_증감': -204.0,
#   '전년도비_점포수_증감률': -2.5790139064475426,
#   '점포수': 7706},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '가전제품',
#   '분기당_매출_금액': 848551424071.0,
#   '월별_평균_매출': 34810937.97468822,
#   '전년도비_매출_증감': 2810962.1700501554,
#   '전년도비_매출_증감률': 8.784263423232773,
#   '전년도비_점포수_증감': -385.0,
#   '전년도비_점포수_증감률': -5.94227504244482,
#   '점포수': 6094},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '가전제품수리',
#   '분기당_매출_금액': 48689781381.0,
#   '월별_평균_매출': 7883708.125161917,
#   '전년도비_매출_증감': 1440146.695305802,
#   '전년도비_매출_증감률': 22.35016630140143,
#   '전년도비_점포수_증감': 15.0,
#   '전년도비_점포수_증감률': 0.9810333551340591,
#   '점포수': 1544},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '건축물청소',
#   '분기당_매출_금액': 14125410795.0,
#   '월별_평균_매출': 141254107.95,
#   '전년도비_매출_증감': 139834639.2,
#   '전년도비_매출_증감률': 9851.19532923849,
#   '전년도비_점포수_증감': 18.0,
#   '전년도비_점포수_증감률': 257.14285714285717,
#   '점포수': 25},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '고시원',
#   '분기당_매출_금액': 98390852176.0,
#   '월별_평균_매출': 18834389.77335375,
#   '전년도비_매출_증감': 7977399.711692246,
#   '전년도비_매출_증감률': 73.47708403880972,
#   '전년도비_점포수_증감': -632.0,
#   '전년도비_점포수_증감률': -32.6109391124871,
#   '점포수': 1306},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '골프연습장',
#   '분기당_매출_금액': 159165247706.0,
#   '월별_평균_매출': 14453800.191245914,
#   '전년도비_매출_증감': 1154566.7896760833,
#   '전년도비_매출_증감률': 8.68145369596867,
#   '전년도비_점포수_증감': -18.0,
#   '전년도비_점포수_증감률': -0.649584987369181,
#   '점포수': 2753},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '네일숍',
#   '분기당_매출_금액': 117433469984.0,
#   '월별_평균_매출': 4850217.6600033045,
#   '전년도비_매출_증감': -611739.3710881853,
#   '전년도비_매출_증감률': -11.200003361541249,
#   '전년도비_점포수_증감': 730.0,
#   '전년도비_점포수_증감률': 13.714071012586885,
#   '점포수': 6053},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '노래방',
#   '분기당_매출_금액': 505851289243.0,
#   '월별_평균_매출': 5741524.666791519,
#   '전년도비_매출_증감': -284791.4395369636,
#   '전년도비_매출_증감률': -4.725796564801712,
#   '전년도비_점포수_증감': -33.0,
#   '전년도비_점포수_증감률': -0.14959880320957097,
#   '점포수': 22026},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '당구장',
#   '분기당_매출_금액': 104063779503.0,
#   '월별_평균_매출': 2856070.3563234163,
#   '전년도비_매출_증감': 256037.3417786043,
#   '전년도비_매출_증감률': 9.847465026263478,
#   '전년도비_점포수_증감': 618.0,
#   '전년도비_점포수_증감률': 7.278294664939338,
#   '점포수': 9109},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '독서실',
#   '분기당_매출_금액': 68302924055.0,
#   '월별_평균_매출': 6291721.08096905,
#   '전년도비_매출_증감': 114293.48083174042,
#   '전년도비_매출_증감률': 1.8501792045154843,
#   '전년도비_점포수_증감': 165.0,
#   '전년도비_점포수_증감률': 6.47312671635936,
#   '점포수': 2714},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '문구',
#   '분기당_매출_금액': 957509048228.0,
#   '월별_평균_매출': 23422432.68659491,
#   '전년도비_매출_증감': 99601.2650105469,
#   '전년도비_매출_증감률': 0.42705477396869185,
#   '전년도비_점포수_증감': -371.0,
#   '전년도비_점포수_증감률': -3.5029742233972314,
#   '점포수': 10220},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '미곡판매',
#   '분기당_매출_금액': 189274348589.0,
#   '월별_평균_매출': 16305509.010079255,
#   '전년도비_매출_증감': 645807.249425143,
#   '전년도비_매출_증감률': 4.124007336128017,
#   '전년도비_점포수_증감': -125.0,
#   '전년도비_점포수_증감률': -4.129501156260332,
#   '점포수': 2902},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '미용실',
#   '분기당_매출_금액': 1039527697439.0,
#   '월별_평균_매출': 5716967.846358176,
#   '전년도비_매출_증감': 111207.16755487863,
#   '전년도비_매출_증감률': 1.9838015556992872,
#   '전년도비_점포수_증감': 944.0,
#   '전년도비_점포수_증감률': 2.1206811340252614,
#   '점포수': 45458},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '반찬가게',
#   '분기당_매출_금액': 982449546272.0,
#   '월별_평균_매출': 15785872.264798509,
#   '전년도비_매출_증감': 3268612.817672411,
#   '전년도비_매출_증감률': 26.11284707710415,
#   '전년도비_점포수_증감': 301.0,
#   '전년도비_점포수_증감률': 1.9727356141040673,
#   '점포수': 15559},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '법무사사무소',
#   '분기당_매출_금액': 211649016067.0,
#   '월별_평균_매출': 9198931.504998261,
#   '전년도비_매출_증감': 206430.33227332123,
#   '전년도비_매출_증감률': 2.295583045342738,
#   '전년도비_점포수_증감': -94.0,
#   '전년도비_점포수_증감률': -1.6079370509750248,
#   '점포수': 5752},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '변호사사무소',
#   '분기당_매출_금액': 838309396985.0,
#   '월별_평균_매출': 24329852.478087995,
#   '전년도비_매출_증감': -1086905.6342412643,
#   '전년도비_매출_증감률': -4.276334650696555,
#   '전년도비_점포수_증감': 268.0,
#   '전년도비_점포수_증감률': 3.2111190989695615,
#   '점포수': 8614},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '볼링장',
#   '분기당_매출_금액': 52899375249.0,
#   '월별_평균_매출': 58517008.01880531,
#   '전년도비_매출_증감': 16788466.426357396,
#   '전년도비_매출_증감률': 40.23257412235034,
#   '전년도비_점포수_증감': 34.0,
#   '전년도비_점포수_증감률': 17.70833333333333,
#   '점포수': 226},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '부동산중개업',
#   '분기당_매출_금액': 246704599446.0,
#   '월별_평균_매출': 3365316.192584711,
#   '전년도비_매출_증감': 724126.4045569822,
#   '전년도비_매출_증감률': 27.41667440330798,
#   '전년도비_점포수_증감': 728.0,
#   '전년도비_점포수_증감률': 4.136598670378987,
#   '점포수': 18327},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '분식전문점',
#   '분기당_매출_금액': 1522678851385.0,
#   '월별_평균_매출': 10552760.037874587,
#   '전년도비_매출_증감': 1255560.8995873313,
#   '전년도비_매출_증감률': 13.504722023396738,
#   '전년도비_점포수_증감': -1002.0,
#   '전년도비_점포수_증감률': -2.7026298044504387,
#   '점포수': 36073},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '비디오/서적임대',
#   '분기당_매출_금액': 5347575168.0,
#   '월별_평균_매출': 12494334.504672898,
#   '전년도비_매출_증감': 5690280.450618844,
#   '전년도비_매출_증감률': 83.63073552051529,
#   '전년도비_점포수_증감': 70.0,
#   '전년도비_점포수_증감률': 189.18918918918922,
#   '점포수': 107},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '사진관',
#   '분기당_매출_금액': 228291429346.0,
#   '월별_평균_매출': 7667991.043463657,
#   '전년도비_매출_증감': 52896.26664865203,
#   '전년도비_매출_증감률': 0.6946238779548963,
#   '전년도비_점포수_증감': 432.0,
#   '전년도비_점포수_증감률': 6.161745827984589,
#   '점포수': 7443},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '서적',
#   '분기당_매출_금액': 462381847164.0,
#   '월별_평균_매출': 21566317.498320896,
#   '전년도비_매출_증감': -1153254.6517704278,
#   '전년도비_매출_증감률': -5.076040359174598,
#   '전년도비_점포수_증감': -115.0,
#   '전년도비_점포수_증감률': -2.100456621004568,
#   '점포수': 5360},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '섬유제품',
#   '분기당_매출_금액': 344440658674.0,
#   '월별_평균_매출': 10454068.795495933,
#   '전년도비_매출_증감': 1541454.9529790469,
#   '전년도비_매출_증감률': 17.295206324609993,
#   '전년도비_점포수_증감': -202.0,
#   '전년도비_점포수_증감률': -2.393648536556455,
#   '점포수': 8237},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '세무사사무소',
#   '분기당_매출_금액': 402848545964.0,
#   '월별_평균_매출': 16889508.048130136,
#   '전년도비_매출_증감': 1248721.0375331454,
#   '전년도비_매출_증감률': 7.983748111185889,
#   '전년도비_점포수_증감': -218.0,
#   '전년도비_점포수_증감률': -3.5269373887720405,
#   '점포수': 5963},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '세탁소',
#   '분기당_매출_금액': 90164348890.0,
#   '월별_평균_매출': 2696947.502093802,
#   '전년도비_매출_증감': 361192.88424705155,
#   '전년도비_매출_증감률': 15.463648513730547,
#   '전년도비_점포수_증감': 110.0,
#   '전년도비_점포수_증감률': 1.3336566440349031,
#   '점포수': 8358},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '수산물판매',
#   '분기당_매출_금액': 573312356222.0,
#   '월별_평균_매출': 29382552.08189832,
#   '전년도비_매출_증감': 4387210.653414462,
#   '전년도비_매출_증감률': 17.552113324665157,
#   '전년도비_점포수_증감': -16.0,
#   '전년도비_점포수_증감률': -0.3269309358398118,
#   '점포수': 4878},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '슈퍼마켓',
#   '분기당_매출_금액': 3871604365452.0,
#   '월별_평균_매출': 25645878.258737184,
#   '전년도비_매출_증감': 1866479.201162912,
#   '전년도비_매출_증감률': 7.849143692167431,
#   '전년도비_점포수_증감': -2012.0,
#   '전년도비_점포수_증감률': -5.0612532387492735,
#   '점포수': 37741},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '스포츠 강습',
#   '분기당_매출_금액': 274543333908.0,
#   '월별_평균_매출': 8268381.336826888,
#   '전년도비_매출_증감': 894693.1920749797,
#   '전년도비_매출_증감률': 12.13359142007873,
#   '전년도비_점포수_증감': 441.0,
#   '전년도비_점포수_증감률': 5.610687022900777,
#   '점포수': 8301},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '스포츠클럽',
#   '분기당_매출_금액': 393906812408.0,
#   '월별_평균_매출': 23418954.36432818,
#   '전년도비_매출_증감': 1576230.888199482,
#   '전년도비_매출_증감률': 7.216274517791248,
#   '전년도비_점포수_증감': 351.0,
#   '전년도비_점포수_증감률': 9.107420861442648,
#   '점포수': 4205},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '시계및귀금속',
#   '분기당_매출_금액': 1061720262513.0,
#   '월별_평균_매출': 14086401.614830442,
#   '전년도비_매출_증감': 2335421.3207166195,
#   '전년도비_매출_증감률': 19.874268037760686,
#   '전년도비_점포수_증감': -380.0,
#   '전년도비_점포수_증감률': -1.976798626645163,
#   '점포수': 18843},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '신발',
#   '분기당_매출_금액': 607054928091.0,
#   '월별_평균_매출': 8638645.948471652,
#   '전년도비_매출_증감': -967760.7887719627,
#   '전년도비_매출_증감률': -10.074118400795967,
#   '전년도비_점포수_증감': -325.0,
#   '전년도비_점포수_증감률': -1.8163527636505847,
#   '점포수': 17568},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '악기',
#   '분기당_매출_금액': 204778193606.0,
#   '월별_평균_매출': 27944622.489901748,
#   '전년도비_매출_증감': 500909.30404207855,
#   '전년도비_매출_증감률': 1.825224234963116,
#   '전년도비_점포수_증감': -35.0,
#   '전년도비_점포수_증감률': -1.874665238350289,
#   '점포수': 1832},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '안경',
#   '분기당_매출_금액': 625462976525.0,
#   '월별_평균_매출': 21666307.902348623,
#   '전년도비_매출_증감': 763476.4408535585,
#   '전년도비_매출_증감률': 3.6525024959415333,
#   '전년도비_점포수_증감': 127.0,
#   '전년도비_점포수_증감률': 1.7912552891396416,
#   '점포수': 7217},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '애완동물',
#   '분기당_매출_금액': 102373396036.0,
#   '월별_평균_매출': 11324490.711946903,
#   '전년도비_매출_증감': 249626.12903638557,
#   '전년도비_매출_증감률': 2.253988093196014,
#   '전년도비_점포수_증감': 92.0,
#   '전년도비_점포수_증감률': 4.243542435424359,
#   '점포수': 2260},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '양식음식점',
#   '분기당_매출_금액': 1779285822529.0,
#   '월별_평균_매출': 22276715.52645483,
#   '전년도비_매출_증감': 554180.6158226728,
#   '전년도비_매출_증감률': 2.5511783873410963,
#   '전년도비_점포수_증감': 400.0,
#   '전년도비_점포수_증감률': 2.0441537203597733,
#   '점포수': 19968},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '여관',
#   '분기당_매출_금액': 555202438025.0,
#   '월별_평균_매출': 12866204.069915647,
#   '전년도비_매출_증감': -619713.068833001,
#   '전년도비_매출_증감률': -4.595260837339708,
#   '전년도비_점포수_증감': -304.0,
#   '전년도비_점포수_증감률': -2.74071402812838,
#   '점포수': 10788},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '여행사',
#   '분기당_매출_금액': 1070768667364.0,
#   '월별_평균_매출': 16461208.144201206,
#   '전년도비_매출_증감': -819986.5760494191,
#   '전년도비_매출_증감률': -4.744964623820451,
#   '전년도비_점포수_증감': 1060.0,
#   '전년도비_점포수_증감률': 6.972766741218251,
#   '점포수': 16262},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '예술품',
#   '분기당_매출_금액': 56998788252.0,
#   '월별_평균_매출': 5927494.618552413,
#   '전년도비_매출_증감': 860944.7718146201,
#   '전년도비_매출_증감률': 16.992722816473574,
#   '전년도비_점포수_증감': -33.0,
#   '전년도비_점포수_증감률': -1.3541239228559618,
#   '점포수': 2404},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '예술학원',
#   '분기당_매출_금액': 356801558624.0,
#   '월별_평균_매출': 7395157.490963356,
#   '전년도비_매출_증감': 973784.2871658346,
#   '전년도비_매출_증감률': 15.164735894651798,
#   '전년도비_점포수_증감': 120.0,
#   '전년도비_점포수_증감률': 1.004856807904872,
#   '점포수': 12062},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '완구',
#   '분기당_매출_금액': 143075658486.0,
#   '월별_평균_매출': 29080418.391463414,
#   '전년도비_매출_증감': 30832.316995330155,
#   '전년도비_매출_증감률': 0.10613685481195034,
#   '전년도비_점포수_증감': -39.0,
#   '전년도비_점포수_증감률': -3.0732860520094647,
#   '점포수': 1230},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '외국어학원',
#   '분기당_매출_금액': 518854204216.0,
#   '월별_평균_매출': 21105361.382037096,
#   '전년도비_매출_증감': 1218095.6189303733,
#   '전년도비_매출_증감률': 6.125002971449646,
#   '전년도비_점포수_증감': -282.0,
#   '전년도비_점포수_증감률': -4.38705662725576,
#   '점포수': 6146},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '운동/경기용품',
#   '분기당_매출_금액': 979713894748.0,
#   '월별_평균_매출': 31380970.363484945,
#   '전년도비_매출_증감': 2244604.1235089004,
#   '전년도비_매출_증감률': 7.70378881505556,
#   '전년도비_점포수_증감': -126.0,
#   '전년도비_점포수_증감률': -1.5887025595763475,
#   '점포수': 7805},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '유아의류',
#   '분기당_매출_금액': 82917385243.0,
#   '월별_평균_매출': 5759751.684009447,
#   '전년도비_매출_증감': -1672275.581224339,
#   '전년도비_매출_증감률': -22.500934422658304,
#   '전년도비_점포수_증감': 284.0,
#   '전년도비_점포수_증감률': 8.567119155354447,
#   '점포수': 3599},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '육류판매',
#   '분기당_매출_금액': 2759354814127.0,
#   '월별_평균_매출': 37178049.233724065,
#   '전년도비_매출_증감': 4849713.088475052,
#   '전년도비_매출_증감률': 15.001431149087367,
#   '전년도비_점포수_증감': -199.0,
#   '전년도비_점포수_증감률': -1.0611069638477204,
#   '점포수': 18555},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '의료기기',
#   '분기당_매출_금액': 248538203828.0,
#   '월별_평균_매출': 19392806.166354556,
#   '전년도비_매출_증감': 1409832.6872781962,
#   '전년도비_매출_증감률': 7.839819643389731,
#   '전년도비_점포수_증감': 205.0,
#   '전년도비_점포수_증감률': 6.835611870623538,
#   '점포수': 3204},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '의약품',
#   '분기당_매출_금액': 2912953087281.0,
#   '월별_평균_매출': 38496499.01254163,
#   '전년도비_매출_증감': 2698123.997880891,
#   '전년도비_매출_증감률': 7.537001321361416,
#   '전년도비_점포수_증감': 23.0,
#   '전년도비_점포수_증감률': 0.12173176669843144,
#   '점포수': 18917},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '인테리어',
#   '분기당_매출_금액': 234807681841.0,
#   '월별_평균_매출': 7079344.001477327,
#   '전년도비_매출_증감': 1075785.480705726,
#   '전년도비_매출_증감률': 17.919130412132006,
#   '전년도비_점포수_증감': -145.0,
#   '전년도비_점포수_증감률': -1.7186203626881564,
#   '점포수': 8292},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '일반교습학원',
#   '분기당_매출_금액': 1089530923889.0,
#   '월별_평균_매출': 12650723.652977103,
#   '전년도비_매출_증감': 245205.7618185524,
#   '전년도비_매출_증감률': 1.976586257582298,
#   '전년도비_점포수_증감': 358.0,
#   '전년도비_점포수_증감률': 1.690832664242194,
#   '점포수': 21531},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '일반의류',
#   '분기당_매출_금액': 6533130811377.0,
#   '월별_평균_매출': 7896625.310488413,
#   '전년도비_매출_증감': -33733.443883066066,
#   '전년도비_매출_증감률': -0.42537096905573435,
#   '전년도비_점포수_증감': -2078.0,
#   '전년도비_점포수_증감률': -0.9946819459004104,
#   '점포수': 206833},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '일반의원',
#   '분기당_매출_금액': 2937746328005.0,
#   '월별_평균_매출': 35481742.20982898,
#   '전년도비_매출_증감': 3000604.7190264687,
#   '전년도비_매출_증감률': 9.237991495452192,
#   '전년도비_점포수_증감': 313.0,
#   '전년도비_점포수_증감률': 1.5353674090061702,
#   '점포수': 20699},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '일식음식점',
#   '분기당_매출_금액': 1314890997314.0,
#   '월별_평균_매출': 21629342.632484537,
#   '전년도비_매출_증감': 382070.66657313704,
#   '전년도비_매출_증감률': 1.7982104581996339,
#   '전년도비_점포수_증감': 435.0,
#   '전년도비_점포수_증감률': 2.9465555781345216,
#   '점포수': 15198},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '자동차미용',
#   '분기당_매출_금액': 38315452050.0,
#   '월별_평균_매출': 7743624.100646726,
#   '전년도비_매출_증감': 766841.207586661,
#   '전년도비_매출_증감률': 10.991329662120506,
#   '전년도비_점포수_증감': 5.0,
#   '전년도비_점포수_증감률': 0.4058441558441501,
#   '점포수': 1237},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '자동차부품',
#   '분기당_매출_금액': 283156700721.0,
#   '월별_평균_매출': 27523007.457328927,
#   '전년도비_매출_증감': 1374658.724186182,
#   '전년도비_매출_증감률': 5.257153092974548,
#   '전년도비_점포수_증감': 36.0,
#   '전년도비_점포수_증감률': 1.4195583596214476,
#   '점포수': 2572},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '자동차수리',
#   '분기당_매출_금액': 475008753020.0,
#   '월별_평균_매출': 13951149.935972745,
#   '전년도비_매출_증감': 983951.1457523741,
#   '전년도비_매출_증감률': 7.58800078313331,
#   '전년도비_점포수_증감': -246.0,
#   '전년도비_점포수_증감률': -2.8088604704270494,
#   '점포수': 8512},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '자전거 및 기타운송장비',
#   '분기당_매출_금액': 75446959573.0,
#   '월별_평균_매출': 31700403.181932773,
#   '전년도비_매출_증감': -101979.04254170135,
#   '전년도비_매출_증감률': -0.32066479115272273,
#   '전년도비_점포수_증감': -71.0,
#   '전년도비_점포수_증감률': -10.660660660660653,
#   '점포수': 595},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '전자상거래업',
#   '분기당_매출_금액': 841539189919.0,
#   '월별_평균_매출': 10855208.57952376,
#   '전년도비_매출_증감': 475328.5240386259,
#   '전년도비_매출_증감률': 4.57932578698194,
#   '전년도비_점포수_증감': 2025.0,
#   '전년도비_점포수_증감률': 11.667434892832446,
#   '점포수': 19381},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '제과점',
#   '분기당_매출_금액': 1044718137080.0,
#   '월별_평균_매출': 21203079.580289006,
#   '전년도비_매출_증감': 785217.6906391121,
#   '전년도비_매출_증감률': 3.8457390635850572,
#   '전년도비_점포수_증감': 236.0,
#   '전년도비_점포수_증감률': 1.95331898692271,
#   '점포수': 12318},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '조명용품',
#   '분기당_매출_금액': 393017272777.0,
#   '월별_평균_매출': 8448350.661586415,
#   '전년도비_매출_증감': -387744.05189176835,
#   '전년도비_매출_증감률': -4.388183518453246,
#   '전년도비_점포수_증감': 308.0,
#   '전년도비_점포수_증감률': 2.7203674262497657,
#   '점포수': 11630},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '주유소',
#   '분기당_매출_금액': 595044007691.0,
#   '월별_평균_매출': 153046298.27443415,
#   '전년도비_매출_증감': 9343286.419198006,
#   '전년도비_매출_증감률': 6.501802779617634,
#   '전년도비_점포수_증감': -2.0,
#   '전년도비_점포수_증감률': -0.20533880903489887,
#   '점포수': 972},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '중고차판매',
#   '분기당_매출_금액': 384545863779.0,
#   '월별_평균_매출': 89763273.5245098,
#   '전년도비_매출_증감': 14248857.03223452,
#   '전년도비_매출_증감률': 18.86905533288747,
#   '전년도비_점포수_증감': 3.0,
#   '전년도비_점포수_증감률': 0.28089887640450684,
#   '점포수': 1071},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '중식음식점',
#   '분기당_매출_금액': 1015745047206.0,
#   '월별_평균_매출': 18338720.43052647,
#   '전년도비_매출_증감': 799850.7632432096,
#   '전년도비_매출_증감률': 4.560446473556041,
#   '전년도비_점포수_증감': 467.0,
#   '전년도비_점포수_증감률': 3.4902840059790776,
#   '점포수': 13847},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '철물점',
#   '분기당_매출_금액': 132726730845.0,
#   '월별_평균_매출': 6590205.106504469,
#   '전년도비_매출_증감': 993748.8651268873,
#   '전년도비_매출_증감률': 17.756752170767868,
#   '전년도비_점포수_증감': 48.0,
#   '전년도비_점포수_증감률': 0.9625025065169552,
#   '점포수': 5035},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '청과상',
#   '분기당_매출_금액': 2438956087131.0,
#   '월별_평균_매출': 55939359.79658257,
#   '전년도비_매출_증감': 4988521.842207909,
#   '전년도비_매출_증감률': 9.790853384344757,
#   '전년도비_점포수_증감': -278.0,
#   '전년도비_점포수_증감률': -2.487028090892835,
#   '점포수': 10900},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '치과의원',
#   '분기당_매출_금액': 1613015212887.0,
#   '월별_평균_매출': 33918227.20344436,
#   '전년도비_매출_증감': 1562581.2905780487,
#   '전년도비_매출_증감률': 4.829392974524694,
#   '전년도비_점포수_증감': 48.0,
#   '전년도비_점포수_증감률': 0.4053711679756731,
#   '점포수': 11889},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '치킨전문점',
#   '분기당_매출_금액': 817938942603.0,
#   '월별_평균_매출': 13887852.190352486,
#   '전년도비_매출_증감': 684114.390404908,
#   '전년도비_매출_증감률': 5.181217627690415,
#   '전년도비_점포수_증감': -537.0,
#   '전년도비_점포수_증감률': -3.5187733438175712,
#   '점포수': 14724},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '커피-음료',
#   '분기당_매출_금액': 2567513742055.0,
#   '월별_평균_매출': 14937131.981610117,
#   '전년도비_매출_증감': 618695.0098670609,
#   '전년도비_매출_증감률': 4.3209675126414595,
#   '전년도비_점포수_증감': 885.0,
#   '전년도비_점포수_증감률': 2.1027870838976384,
#   '점포수': 42972},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '컴퓨터및주변장치판매',
#   '분기당_매출_금액': 3364021086319.0,
#   '월별_평균_매출': 34518357.88785709,
#   '전년도비_매출_증감': 2785417.008482311,
#   '전년도비_매출_증감률': 8.7776831623341,
#   '전년도비_점포수_증감': -923.0,
#   '전년도비_점포수_증감률': -3.650096887728864,
#   '점포수': 24364},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '통신기기수리',
#   '분기당_매출_금액': 17466341751.0,
#   '월별_평균_매출': 3843825.209286972,
#   '전년도비_매출_증감': 557066.9093392733,
#   '전년도비_매출_증감률': 16.948824905930508,
#   '전년도비_점포수_증감': 180.0,
#   '전년도비_점포수_증감률': 18.828451882845187,
#   '점포수': 1136},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '패스트푸드점',
#   '분기당_매출_금액': 867712678075.0,
#   '월별_평균_매출': 19588962.391073685,
#   '전년도비_매출_증감': 535632.863152884,
#   '전년도비_매출_증감률': 2.8112297242745257,
#   '전년도비_점포수_증감': 392.0,
#   '전년도비_점포수_증감률': 3.6697247706422047,
#   '점포수': 11074},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '편의점',
#   '분기당_매출_금액': 4726208763058.0,
#   '월별_평균_매출': 51376301.88557701,
#   '전년도비_매출_증감': 2476695.4032186717,
#   '전년도비_매출_증감률': 5.064857534410223,
#   '전년도비_점포수_증감': 1203.0,
#   '전년도비_점포수_증감률': 5.519614590502414,
#   '점포수': 22998},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '피부관리실',
#   '분기당_매출_금액': 256532292769.0,
#   '월별_평균_매출': 5353345.007700334,
#   '전년도비_매출_증감': 398185.43302697595,
#   '전년도비_매출_증감률': 8.035774166833448,
#   '전년도비_점포수_증감': 423.0,
#   '전년도비_점포수_증감률': 3.6601194081508908,
#   '점포수': 11980},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '한복점',
#   '분기당_매출_금액': 16870442685.0,
#   '월별_평균_매출': 3229410.92745023,
#   '전년도비_매출_증감': 238685.32676633913,
#   '전년도비_매출_증감률': 7.98085008908069,
#   '전년도비_점포수_증감': -10.0,
#   '전년도비_점포수_증감률': -0.7598784194528889,
#   '점포수': 1306},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '한식음식점',
#   '분기당_매출_금액': 10743910629506.0,
#   '월별_평균_매출': 16904210.71517175,
#   '전년도비_매출_증감': 1031090.3527569361,
#   '전년도비_매출_증감률': 6.495826461433538,
#   '전년도비_점포수_증감': -3251.0,
#   '전년도비_점포수_증감률': -2.004995528693456,
#   '점포수': 158894},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '한의원',
#   '분기당_매출_금액': 812149573051.0,
#   '월별_평균_매출': 20745621.054740984,
#   '전년도비_매출_증감': 318863.69750676677,
#   '전년도비_매출_증감률': 1.561009865297308,
#   '전년도비_점포수_증감': 14.0,
#   '전년도비_점포수_증감률': 0.14325181622838556,
#   '점포수': 9787},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '핸드폰',
#   '분기당_매출_금액': 624704530415.0,
#   '월별_평균_매출': 12478118.616470918,
#   '전년도비_매출_증감': 86309.3713002801,
#   '전년도비_매출_증감률': 0.6965033885904575,
#   '전년도비_점포수_증감': 92.0,
#   '전년도비_점포수_증감률': 0.7405022537025019,
#   '점포수': 12516},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '호프-간이주점',
#   '분기당_매출_금액': 2996398361599.0,
#   '월별_평균_매출': 13399989.095392913,
#   '전년도비_매출_증감': 799622.9036475681,
#   '전년도비_매출_증감률': 6.34602908740392,
#   '전년도비_점포수_증감': -1822.0,
#   '전년도비_점포수_증감률': -3.1563447379818115,
#   '점포수': 55903},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '화장품',
#   '분기당_매출_금액': 3659740225363.0,
#   '월별_평균_매출': 17679562.836288188,
#   '전년도비_매출_증감': -457342.8398716934,
#   '전년도비_매출_증감률': -2.5216144806489638,
#   '전년도비_점포수_증감': -1401.0,
#   '전년도비_점포수_증감률': -2.6358368452739285,
#   '점포수': 51751},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '화초',
#   '분기당_매출_금액': 241510339908.0,
#   '월별_평균_매출': 6220645.474654852,
#   '전년도비_매출_증감': 265336.15900042467,
#   '전년도비_매출_증감률': 4.455455542887549,
#   '전년도비_점포수_증감': 255.0,
#   '전년도비_점포수_증감률': 2.6981271823087525,
#   '점포수': 9706},
#  {'기준_년_코드': 2017,
#   '서비스_업종_코드_명': '회계사사무소',
#   '분기당_매출_금액': 33333280219.0,
#   '월별_평균_매출': 12345659.34037037,
#   '전년도비_매출_증감': 2004924.947705498,
#   '전년도비_매출_증감률': 19.388612757790952,
#   '전년도비_점포수_증감': -68.0,
#   '전년도비_점포수_증감률': -9.152086137281287,
#   '점포수': 675},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': 'PC방',
#   '분기당_매출_금액': 527662712740.0,
#   '월별_평균_매출': 28103041.794844482,
#   '전년도비_매출_증감': 11469700.400960756,
#   '전년도비_매출_증감률': 68.95608121876401,
#   '전년도비_점포수_증감': 67.0,
#   '전년도비_점포수_증감률': 1.448022476766809,
#   '점포수': 4694},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '가구',
#   '분기당_매출_금액': 609089405881.0,
#   '월별_평균_매출': 30811888.197136786,
#   '전년도비_매출_증감': 4718637.4232212715,
#   '전년도비_매출_증감률': 18.08374688192673,
#   '전년도비_점포수_증감': -337.0,
#   '전년도비_점포수_증감률': -6.3837848077287305,
#   '점포수': 4942},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '가방',
#   '분기당_매출_금액': 344070950759.0,
#   '월별_평균_매출': 11895690.45633384,
#   '전년도비_매출_증감': -116643.85008323751,
#   '전년도비_매출_증감률': -0.9710339981208023,
#   '전년도비_점포수_증감': -475.0,
#   '전년도비_점포수_증감률': -6.164028030106408,
#   '점포수': 7231},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '가전제품',
#   '분기당_매출_금액': 897400193926.0,
#   '월별_평균_매출': 38754542.836673,
#   '전년도비_매출_증감': 3943604.861984782,
#   '전년도비_매출_증감률': 11.32863717964814,
#   '전년도비_점포수_증감': -305.0,
#   '전년도비_점포수_증감률': -5.004922874958979,
#   '점포수': 5789},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '가전제품수리',
#   '분기당_매출_금액': 49025817671.0,
#   '월별_평균_매출': 7801689.635741566,
#   '전년도비_매출_증감': -82018.48942035064,
#   '전년도비_매출_증감률': -1.0403542104581192,
#   '전년도비_점포수_증감': 27.0,
#   '전년도비_점포수_증감률': 1.7487046632124361,
#   '점포수': 1571},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '건축물청소',
#   '분기당_매출_금액': 22115972353.0,
#   '월별_평균_매출': 157971231.09285715,
#   '전년도비_매출_증감': 16717123.142857164,
#   '전년도비_매출_증감률': 11.834787239444083,
#   '전년도비_점포수_증감': 10.0,
#   '전년도비_점포수_증감률': 40.0,
#   '점포수': 35},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '고시원',
#   '분기당_매출_금액': 81829905015.0,
#   '월별_평균_매출': 17560065.45386266,
#   '전년도비_매출_증감': -1274324.319491092,
#   '전년도비_매출_증감률': -6.76594429034256,
#   '전년도비_점포수_증감': -141.0,
#   '전년도비_점포수_증감률': -10.79632465543645,
#   '점포수': 1165},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '골프연습장',
#   '분기당_매출_금액': 150457459560.0,
#   '월별_평균_매출': 14146056.74689733,
#   '전년도비_매출_증감': -307743.444348583,
#   '전년도비_매출_증감률': -2.1291524739284142,
#   '전년도비_점포수_증감': -94.0,
#   '전년도비_점포수_증감률': -3.4144569560479567,
#   '점포수': 2659},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '네일숍',
#   '분기당_매출_금액': 105267205921.0,
#   '월별_평균_매출': 4696074.496832619,
#   '전년도비_매출_증감': -154143.16317068506,
#   '전년도비_매출_증감률': -3.178066923507515,
#   '전년도비_점포수_증감': -449.0,
#   '전년도비_점포수_증감률': -7.417809350735169,
#   '점포수': 5604},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '노래방',
#   '분기당_매출_금액': 489211972246.0,
#   '월별_평균_매출': 5757060.490562041,
#   '전년도비_매출_증감': 15535.82377052214,
#   '전년도비_매출_증감률': 0.2705870769898411,
#   '전년도비_점포수_증감': -782.0,
#   '전년도비_점포수_증감률': -3.550349586851894,
#   '점포수': 21244},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '당구장',
#   '분기당_매출_금액': 94479739344.0,
#   '월별_평균_매출': 2552126.940680713,
#   '전년도비_매출_증감': -303943.4156427034,
#   '전년도비_매출_증감률': -10.642014296663405,
#   '전년도비_점포수_증감': 146.0,
#   '전년도비_점포수_증감률': 1.6028104072894962,
#   '점포수': 9255},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '독서실',
#   '분기당_매출_금액': 60647841370.0,
#   '월별_평균_매출': 5477586.828937861,
#   '전년도비_매출_증감': -814134.2520311885,
#   '전년도비_매출_증감률': -12.939770240193099,
#   '전년도비_점포수_증감': 54.0,
#   '전년도비_점포수_증감률': 1.9896831245394253,
#   '점포수': 2768},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '문구',
#   '분기당_매출_금액': 974933457692.0,
#   '월별_평균_매출': 25008553.706443667,
#   '전년도비_매출_증감': 1586121.0198487565,
#   '전년도비_매출_증감률': 6.771803087544043,
#   '전년도비_점포수_증감': -474.0,
#   '전년도비_점포수_증감률': -4.637964774951072,
#   '점포수': 9746},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '미곡판매',
#   '분기당_매출_금액': 255103841032.0,
#   '월별_평균_매출': 24491536.197388634,
#   '전년도비_매출_증감': 8186027.187309379,
#   '전년도비_매출_증감률': 50.20405791839545,
#   '전년도비_점포수_증감': -298.0,
#   '전년도비_점포수_증감률': -10.268780151619566,
#   '점포수': 2604},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '미용실',
#   '분기당_매출_금액': 1012126826996.0,
#   '월별_평균_매출': 5511712.702557288,
#   '전년도비_매출_증감': -205255.1438008882,
#   '전년도비_매출_증감률': -3.5902798356936643,
#   '전년도비_점포수_증감': 450.0,
#   '전년도비_점포수_증감률': 0.9899247657178023,
#   '점포수': 45908},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '반찬가게',
#   '분기당_매출_금액': 1328784551592.0,
#   '월별_평균_매출': 20912567.698961284,
#   '전년도비_매출_증감': 5126695.434162775,
#   '전년도비_매출_증감률': 32.476478639669324,
#   '전년도비_점포수_증감': 326.0,
#   '전년도비_점포수_증감률': 2.095250337425284,
#   '점포수': 15885},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '법무사사무소',
#   '분기당_매출_금액': 224232509835.0,
#   '월별_평균_매출': 9646898.547367062,
#   '전년도비_매출_증감': 447967.0423688013,
#   '전년도비_매출_증감률': 4.869772561361032,
#   '전년도비_점포수_증감': 59.0,
#   '전년도비_점포수_증감률': 1.0257301808066757,
#   '점포수': 5811},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '변호사사무소',
#   '분기당_매출_금액': 1214138062160.0,
#   '월별_평균_매출': 35659600.039943606,
#   '전년도비_매출_증감': 11329747.56185561,
#   '전년도비_매출_증감률': 46.56726781249262,
#   '전년도비_점포수_증감': -102.0,
#   '전년도비_점포수_증감률': -1.1841188762479646,
#   '점포수': 8512},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '볼링장',
#   '분기당_매출_금액': 39532511910.0,
#   '월별_평균_매출': 41877660.92161017,
#   '전년도비_매출_증감': -16639347.097195141,
#   '전년도비_매출_증감률': -28.435061293372755,
#   '전년도비_점포수_증감': 10.0,
#   '전년도비_점포수_증감률': 4.424778761061958,
#   '점포수': 236},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '부동산중개업',
#   '분기당_매출_금액': 334094566913.0,
#   '월별_평균_매출': 4622226.991048699,
#   '전년도비_매출_증감': 1256910.7984639881,
#   '전년도비_매출_증감률': 37.348965937688774,
#   '전년도비_점포수_증감': -257.0,
#   '전년도비_점포수_증감률': -1.4023026136301695,
#   '점포수': 18070},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '분식전문점',
#   '분기당_매출_금액': 1641116015580.0,
#   '월별_평균_매출': 10697442.283393737,
#   '전년도비_매출_증감': 144682.24551915005,
#   '전년도비_매출_증감률': 1.3710370083265104,
#   '전년도비_점포수_증감': 2280.0,
#   '전년도비_점포수_증감률': 6.3205167299642255,
#   '점포수': 38353},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '비디오/서적임대',
#   '분기당_매출_금액': 6832863645.0,
#   '월별_평균_매출': 11945565.812937062,
#   '전년도비_매출_증감': -548768.6917358357,
#   '전년도비_매출_증감률': -4.392140225880752,
#   '전년도비_점포수_증감': 36.0,
#   '전년도비_점포수_증감률': 33.64485981308411,
#   '점포수': 143},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '사진관',
#   '분기당_매출_금액': 216930137214.0,
#   '월별_평균_매출': 7371555.566603235,
#   '전년도비_매출_증감': -296435.4768604217,
#   '전년도비_매출_증감률': -3.8658818871874985,
#   '전년도비_점포수_증감': -86.0,
#   '전년도비_점포수_증감률': -1.1554480720139821,
#   '점포수': 7357},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '서적',
#   '분기당_매출_금액': 481989114817.0,
#   '월별_평균_매출': 22995663.87485687,
#   '전년도비_매출_증감': 1429346.3765359744,
#   '전년도비_매출_증감률': 6.6276793738535105,
#   '전년도비_점포수_증감': -120.0,
#   '전년도비_점포수_증감률': -2.2388059701492438,
#   '점포수': 5240},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '섬유제품',
#   '분기당_매출_금액': 373201691845.0,
#   '월별_평균_매출': 11831146.710784934,
#   '전년도비_매출_증감': 1377077.9152890015,
#   '전년도비_매출_증감률': 13.172650211392394,
#   '전년도비_점포수_증감': -351.0,
#   '전년도비_점포수_증감률': -4.261260167536733,
#   '점포수': 7886},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '세무사사무소',
#   '분기당_매출_금액': 418442694128.0,
#   '월별_평균_매출': 16414667.116271771,
#   '전년도비_매출_증감': -474840.9318583645,
#   '전년도비_매출_증감률': -2.8114550791248973,
#   '전년도비_점포수_증감': 410.0,
#   '전년도비_점포수_증감률': 6.875733691095093,
#   '점포수': 6373},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '세탁소',
#   '분기당_매출_금액': 100475776237.0,
#   '월별_평균_매출': 3043244.97931306,
#   '전년도비_매출_증감': 346297.47721925797,
#   '전년도비_매출_증감률': 12.84034920777681,
#   '전년도비_점포수_증감': -104.0,
#   '전년도비_점포수_증감률': -1.2443168222062724,
#   '점포수': 8254},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '수산물판매',
#   '분기당_매출_금액': 562364013185.0,
#   '월별_평균_매출': 29523520.221808065,
#   '전년도비_매출_증감': 140968.13990974426,
#   '전년도비_매출_증감률': 0.47976819548152605,
#   '전년도비_점포수_증감': -116.0,
#   '전년도비_점포수_증감률': -2.378023780237797,
#   '점포수': 4762},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '슈퍼마켓',
#   '분기당_매출_금액': 3867959055116.0,
#   '월별_평균_매출': 25880945.42137944,
#   '전년도비_매출_증감': 235067.16264225543,
#   '전년도비_매출_증감률': 0.9165884680208762,
#   '전년도비_점포수_증감': -378.0,
#   '전년도비_점포수_증감률': -1.001563286611372,
#   '점포수': 37363},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '스포츠 강습',
#   '분기당_매출_금액': 293363423372.0,
#   '월별_평균_매출': 8472834.547481516,
#   '전년도비_매출_증감': 204453.21065462846,
#   '전년도비_매출_증감률': 2.4727114331798674,
#   '전년도비_점포수_증감': 355.0,
#   '전년도비_점포수_증감률': 4.276593181544385,
#   '점포수': 8656},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '스포츠클럽',
#   '분기당_매출_금액': 552059663095.0,
#   '월별_평균_매출': 35145127.52069009,
#   '전년도비_매출_증감': 11726173.156361911,
#   '전년도비_매출_증감률': 50.07129256899384,
#   '전년도비_점포수_증감': -278.0,
#   '전년도비_점포수_증감률': -6.611177170035674,
#   '점포수': 3927},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '시계및귀금속',
#   '분기당_매출_금액': 1127988465734.0,
#   '월별_평균_매출': 15387816.02278184,
#   '전년도비_매출_증감': 1301414.4079513978,
#   '전년도비_매출_증감률': 9.238799542540676,
#   '전년도비_점포수_증감': -517.0,
#   '전년도비_점포수_증감률': -2.743724460011677,
#   '점포수': 18326},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '신발',
#   '분기당_매출_금액': 561946322422.0,
#   '월별_평균_매출': 8678975.75866436,
#   '전년도비_매출_증감': 40329.810192707926,
#   '전년도비_매출_증감률': 0.46685337532375115,
#   '전년도비_점포수_증감': -1381.0,
#   '전년도비_점포수_증감률': -7.860883424408016,
#   '점포수': 16187},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '악기',
#   '분기당_매출_금액': 197347892399.0,
#   '월별_평균_매출': 27905527.77135181,
#   '전년도비_매출_증감': -39094.71854993701,
#   '전년도비_매출_증감률': -0.13990068595151683,
#   '전년도비_점포수_증감': -64.0,
#   '전년도비_점포수_증감률': -3.493449781659379,
#   '점포수': 1768},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '안경',
#   '분기당_매출_금액': 586896202796.0,
#   '월별_평균_매출': 20429413.909635197,
#   '전년도비_매출_증감': -1236893.9927134253,
#   '전년도비_매출_증감률': -5.708836033754267,
#   '전년도비_점포수_증감': -35.0,
#   '전년도비_점포수_증감률': -0.48496605237633617,
#   '점포수': 7182},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '애완동물',
#   '분기당_매출_금액': 90055632644.0,
#   '월별_평균_매출': 10041885.888046388,
#   '전년도비_매출_증감': -1282604.8239005152,
#   '전년도비_매출_증감률': -11.325938238859763,
#   '전년도비_점포수_증감': -18.0,
#   '전년도비_점포수_증감률': -0.796460176991161,
#   '점포수': 2242},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '양식음식점',
#   '분기당_매출_금액': 1760791871807.0,
#   '월별_평균_매출': 22506159.208126694,
#   '전년도비_매출_증감': 229443.68167186528,
#   '전년도비_매출_증감률': 1.0299708742942357,
#   '전년도비_점포수_증감': -409.0,
#   '전년도비_점포수_증감률': -2.0482772435897516,
#   '점포수': 19559},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '여관',
#   '분기당_매출_금액': 518407564047.0,
#   '월별_평균_매출': 12279883.552373508,
#   '전년도비_매출_증감': -586320.5175421387,
#   '전년도비_매출_증감률': -4.557059054527983,
#   '전년도비_점포수_증감': -234.0,
#   '전년도비_점포수_증감률': -2.169076751946605,
#   '점포수': 10554},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '여행사',
#   '분기당_매출_금액': 987966001905.0,
#   '월별_평균_매출': 15613597.602645554,
#   '전년도비_매출_증감': -847610.5415556524,
#   '전년도비_매출_증감률': -5.149139322767397,
#   '전년도비_점포수_증감': -443.0,
#   '전년도비_점포수_증감률': -2.7241421719345738,
#   '점포수': 15819},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '예술품',
#   '분기당_매출_금액': 48592938199.0,
#   '월별_평균_매출': 5106445.796448087,
#   '전년도비_매출_증감': -821048.8221043255,
#   '전년도비_매출_증감률': -13.851532138629565,
#   '전년도비_점포수_증감': -25.0,
#   '전년도비_점포수_증감률': -1.0399334442595602,
#   '점포수': 2379},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '예술학원',
#   '분기당_매출_금액': 395938543880.0,
#   '월별_평균_매출': 8386396.337371855,
#   '전년도비_매출_증감': 991238.8464084994,
#   '전년도비_매출_증감률': 13.403890959993234,
#   '전년도비_점포수_증감': -259.0,
#   '전년도비_점포수_증감률': -2.1472392638036837,
#   '점포수': 11803},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '완구',
#   '분기당_매출_금액': 133737173684.0,
#   '월별_평균_매출': 28262293.677937448,
#   '전년도비_매출_증감': -818124.7135259658,
#   '전년도비_매출_증감률': -2.8133182353598016,
#   '전년도비_점포수_증감': -47.0,
#   '전년도비_점포수_증감률': -3.82113821138212,
#   '점포수': 1183},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '외국어학원',
#   '분기당_매출_금액': 516836295270.0,
#   '월별_평균_매출': 18144793.40226092,
#   '전년도비_매출_증감': -2960567.9797761776,
#   '전년도비_매출_증감률': -14.027563547411873,
#   '전년도비_점포수_증감': 975.0,
#   '전년도비_점포수_증감률': 15.863976570126908,
#   '점포수': 7121},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '운동/경기용품',
#   '분기당_매출_금액': 1013524582174.0,
#   '월별_평균_매출': 33811201.70049373,
#   '전년도비_매출_증감': 2430231.3370087855,
#   '전년도비_매출_증감률': 7.744283586069784,
#   '전년도비_점포수_증감': -311.0,
#   '전년도비_점포수_증감률': -3.9846252402306277,
#   '점포수': 7494},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '유아의류',
#   '분기당_매출_금액': 66715993996.0,
#   '월별_평균_매출': 4565835.88803723,
#   '전년도비_매출_증감': -1193915.7959722169,
#   '전년도비_매출_증감률': -20.728598409664684,
#   '전년도비_점포수_증감': 54.0,
#   '전년도비_점포수_증감률': 1.5004167824395722,
#   '점포수': 3653},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '육류판매',
#   '분기당_매출_금액': 2898967026807.0,
#   '월별_평균_매출': 40941235.83220822,
#   '전년도비_매출_증감': 3763186.5984841585,
#   '전년도비_매출_증감률': 10.122065778186624,
#   '전년도비_점포수_증감': -853.0,
#   '전년도비_점포수_증감률': -4.597143627054706,
#   '점포수': 17702},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '의료기기',
#   '분기당_매출_금액': 217733433391.0,
#   '월별_평균_매출': 18272359.297667004,
#   '전년도비_매출_증감': -1120446.8686875515,
#   '전년도비_매출_증감률': -5.7776417661073936,
#   '전년도비_점포수_증감': -225.0,
#   '전년도비_점포수_증감률': -7.022471910112358,
#   '점포수': 2979},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '의약품',
#   '분기당_매출_금액': 3070591194480.0,
#   '월별_평균_매출': 40247879.128611125,
#   '전년도비_매출_증감': 1751380.1160694957,
#   '전년도비_매출_증감률': 4.54945296583702,
#   '전년도비_점포수_증감': 156.0,
#   '전년도비_점포수_증감률': 0.8246550721573271,
#   '점포수': 19073},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '인테리어',
#   '분기당_매출_금액': 256423150798.0,
#   '월별_평균_매출': 7847446.162259762,
#   '전년도비_매출_증감': 768102.160782435,
#   '전년도비_매출_증감률': 10.849905875772478,
#   '전년도비_점포수_증감': -123.0,
#   '전년도비_점포수_증감률': -1.4833574529667146,
#   '점포수': 8169},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '일반교습학원',
#   '분기당_매출_금액': 1318036572758.0,
#   '월별_평균_매출': 16383708.392477129,
#   '전년도비_매출_증감': 3732984.7395000253,
#   '전년도비_매출_증감률': 29.508072754569582,
#   '전년도비_점포수_증감': -1419.0,
#   '전년도비_점포수_증감률': -6.590497422321306,
#   '점포수': 20112},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '일반의류',
#   '분기당_매출_금액': 6463821814076.0,
#   '월별_평균_매출': 8340673.535794657,
#   '전년도비_매출_증감': 444048.22530624364,
#   '전년도비_매출_증감률': 5.623265735002676,
#   '전년도비_점포수_증감': -13089.0,
#   '전년도비_점포수_증감률': -6.3282938409248,
#   '점포수': 193744},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '일반의원',
#   '분기당_매출_금액': 3392287829715.0,
#   '월별_평균_매출': 40573722.9656851,
#   '전년도비_매출_증감': 5091980.755856119,
#   '전년도비_매출_증감률': 14.350988533042113,
#   '전년도비_점포수_증감': 203.0,
#   '전년도비_점포수_증감률': 0.9807237064592584,
#   '점포수': 20902},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '일식음식점',
#   '분기당_매출_금액': 1371525341055.0,
#   '월별_평균_매출': 22122803.746290084,
#   '전년도비_매출_증감': 493461.11380554736,
#   '전년도비_매출_증감률': 2.2814429554804576,
#   '전년도비_점포수_증감': 301.0,
#   '전년도비_점포수_증감률': 1.9805237531254107,
#   '점포수': 15499},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '자동차미용',
#   '분기당_매출_금액': 38868994367.0,
#   '월별_평균_매출': 8348151.71112543,
#   '전년도비_매출_증감': 604527.6104787039,
#   '전년도비_매출_증감률': 7.806778875387494,
#   '전년도비_점포수_증감': -73.0,
#   '전년도비_점포수_증감률': -5.901374292643496,
#   '점포수': 1164},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '자동차부품',
#   '분기당_매출_금액': 281709857346.0,
#   '월별_평균_매출': 29455233.93412798,
#   '전년도비_매출_증감': 1932226.4767990522,
#   '전년도비_매출_증감률': 7.020404582583268,
#   '전년도비_점포수_증감': -181.0,
#   '전년도비_점포수_증감률': -7.037325038880255,
#   '점포수': 2391},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '자동차수리',
#   '분기당_매출_금액': 487810266528.0,
#   '월별_평균_매출': 14739251.466279913,
#   '전년도비_매출_증감': 788101.5303071681,
#   '전년도비_매출_증감률': 5.649007672658328,
#   '전년도비_점포수_증감': -238.0,
#   '전년도비_점포수_증감률': -2.796052631578945,
#   '점포수': 8274},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '자전거 및 기타운송장비',
#   '분기당_매출_금액': 66722101480.0,
#   '월별_평균_매출': 31893929.961759083,
#   '전년도비_매출_증감': 193526.77982630953,
#   '전년도비_매출_증감률': 0.6104868090025093,
#   '전년도비_점포수_증감': -72.0,
#   '전년도비_점포수_증감률': -12.100840336134453,
#   '점포수': 523},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '전자상거래업',
#   '분기당_매출_금액': 960977774970.0,
#   '월별_평균_매출': 13149668.513546798,
#   '전년도비_매출_증감': 2294459.9340230376,
#   '전년도비_매출_증감률': 21.13694930147257,
#   '전년도비_점포수_증감': -1111.0,
#   '전년도비_점포수_증감률': -5.7324183478664565,
#   '점포수': 18270},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '제과점',
#   '분기당_매출_금액': 1109753742287.0,
#   '월별_평균_매출': 23150737.280686747,
#   '전년도비_매출_증감': 1947657.700397741,
#   '전년도비_매출_증감률': 9.18573027574891,
#   '전년도비_점포수_증감': -334.0,
#   '전년도비_점포수_증감률': -2.711479136223417,
#   '점포수': 11984},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '조명용품',
#   '분기당_매출_금액': 376462920104.0,
#   '월별_평균_매출': 8166223.863427332,
#   '전년도비_매출_증감': -282126.79815908335,
#   '전년도비_매출_증감률': -3.3394304931242687,
#   '전년도비_점포수_증감': -105.0,
#   '전년도비_점포수_증감률': -0.9028374892519366,
#   '점포수': 11525},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '주유소',
#   '분기당_매출_금액': 567948297689.0,
#   '월별_평균_매출': 157065347.81222346,
#   '전년도비_매출_증감': 4019049.537789315,
#   '전년도비_매출_증감률': 2.6260351168916145,
#   '전년도비_점포수_증감': -68.0,
#   '전년도비_점포수_증감률': -6.995884773662553,
#   '점포수': 904},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '중고차판매',
#   '분기당_매출_금액': 291576922966.0,
#   '월별_평균_매출': 69688557.11424474,
#   '전년도비_매출_증감': -20074716.41026506,
#   '전년도비_매출_증감률': -22.364064524433445,
#   '전년도비_점포수_증감': -25.0,
#   '전년도비_점포수_증감률': -2.334267040149399,
#   '점포수': 1046},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '중식음식점',
#   '분기당_매출_금액': 1063576605974.0,
#   '월별_평균_매출': 19538110.918766994,
#   '전년도비_매출_증감': 1199390.4882405251,
#   '전년도비_매출_증감률': 6.5402081502045775,
#   '전년도비_점포수_증감': -238.0,
#   '전년도비_점포수_증감률': -1.7187838520979284,
#   '점포수': 13609},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '철물점',
#   '분기당_매출_금액': 143606510852.0,
#   '월별_평균_매출': 7007930.453445247,
#   '전년도비_매출_증감': 417725.3469407782,
#   '전년도비_매출_증감률': 6.338578848304536,
#   '전년도비_점포수_증감': 88.0,
#   '전년도비_점포수_증감률': 1.747765640516377,
#   '점포수': 5123},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '청과상',
#   '분기당_매출_금액': 2592221185735.0,
#   '월별_평균_매출': 62074262.11051245,
#   '전년도비_매출_증감': 6134902.313929878,
#   '전년도비_매출_증감률': 10.967058500917389,
#   '전년도비_점포수_증감': -460.0,
#   '전년도비_점포수_증감률': -4.2201834862385255,
#   '점포수': 10440},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '치과의원',
#   '분기당_매출_금액': 1650064173619.0,
#   '월별_평균_매출': 34920514.97542961,
#   '전년도비_매출_증감': 1002287.7719852477,
#   '전년도비_매출_증감률': 2.9550122592594334,
#   '전년도비_점포수_증감': -76.0,
#   '전년도비_점포수_증감률': -0.6392463621835276,
#   '점포수': 11813},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '치킨전문점',
#   '분기당_매출_금액': 788101963195.0,
#   '월별_평균_매출': 14014189.543975389,
#   '전년도비_매출_증감': 126337.35362290218,
#   '전년도비_매출_증감률': 0.9096968479450425,
#   '전년도비_점포수_증감': -665.0,
#   '전년도비_점포수_증감률': -4.5164357511545745,
#   '점포수': 14059},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '커피-음료',
#   '분기당_매출_금액': 2669697367624.0,
#   '월별_평균_매출': 14947578.820317574,
#   '전년도비_매출_증감': 10446.838707456365,
#   '전년도비_매출_증감률': 0.06993871862628964,
#   '전년도비_점포수_증감': 1679.0,
#   '전년도비_점포수_증감률': 3.9071953830401185,
#   '점포수': 44651},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '컴퓨터및주변장치판매',
#   '분기당_매출_금액': 3384638054344.0,
#   '월별_평균_매출': 36311183.69248594,
#   '전년도비_매출_증감': 1792825.8046288565,
#   '전년도비_매출_증감률': 5.193832830789262,
#   '전년도비_점포수_증감': -1061.0,
#   '전년도비_점포수_증감률': -4.35478574946643,
#   '점포수': 23303},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '통신기기수리',
#   '분기당_매출_금액': 13003786176.0,
#   '월별_평균_매출': 2979786.0164986253,
#   '전년도비_매출_증감': -864039.1927883467,
#   '전년도비_매출_증감률': -22.478628598947807,
#   '전년도비_점포수_증감': -45.0,
#   '전년도비_점포수_증감률': -3.961267605633793,
#   '점포수': 1091},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '패스트푸드점',
#   '분기당_매출_금액': 832708694448.0,
#   '월별_평균_매출': 19576563.251081437,
#   '전년도비_매출_증감': -12399.139992248267,
#   '전년도비_매출_증감률': -0.06329656336416178,
#   '전년도비_점포수_증감': -440.0,
#   '전년도비_점포수_증감률': -3.9732707242188923,
#   '점포수': 10634},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '편의점',
#   '분기당_매출_금액': 4787610230000.0,
#   '월별_평균_매출': 52255077.82143637,
#   '전년도비_매출_증감': 878775.9358593598,
#   '전년도비_매출_증감률': 1.7104694257997153,
#   '전년도비_점포수_증감': -93.0,
#   '전년도비_점포수_증감률': -0.4043829898252085,
#   '점포수': 22905},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '피부관리실',
#   '분기당_매출_금액': 271173843248.0,
#   '월별_평균_매출': 5096486.303713727,
#   '전년도비_매출_증감': -256858.7039866075,
#   '전년도비_매출_증감률': -4.7980973319884725,
#   '전년도비_점포수_증감': 1322.0,
#   '전년도비_점포수_증감률': 11.035058430717854,
#   '점포수': 13302},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '한복점',
#   '분기당_매출_금액': 14856427301.0,
#   '월별_평균_매출': 3054364.165501645,
#   '전년도비_매출_증감': -175046.76194858504,
#   '전년도비_매출_증감률': -5.420392941036852,
#   '전년도비_점포수_증감': -90.0,
#   '전년도비_점포수_증감률': -6.891271056661566,
#   '점포수': 1216},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '한식음식점',
#   '분기당_매출_금액': 11115393195257.0,
#   '월별_평균_매출': 17952840.042473156,
#   '전년도비_매출_증감': 1048629.3273014054,
#   '전년도비_매출_증감률': 6.203361665151547,
#   '전년도비_점포수_증감': -4108.0,
#   '전년도비_점포수_증감률': -2.5853713796619218,
#   '점포수': 154786},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '한의원',
#   '분기당_매출_금액': 833326648248.0,
#   '월별_평균_매출': 21633609.767601248,
#   '전년도비_매출_증감': 887988.7128602639,
#   '전년도비_매출_증감률': 4.280366977287159,
#   '전년도비_점포수_증감': -157.0,
#   '전년도비_점포수_증감률': -1.6041687953407546,
#   '점포수': 9630},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '핸드폰',
#   '분기당_매출_금액': 635121080933.0,
#   '월별_평균_매출': 13562848.742910225,
#   '전년도비_매출_증감': 1084730.126439307,
#   '전년도비_매출_증감률': 8.693058302935825,
#   '전년도비_점포수_증감': -809.0,
#   '전년도비_점포수_증감률': -6.4637264301693875,
#   '점포수': 11707},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '호프-간이주점',
#   '분기당_매출_금액': 3356263434270.0,
#   '월별_평균_매출': 16645820.194963,
#   '전년도비_매출_증감': 3245831.099570088,
#   '전년도비_매출_증감률': 24.22263985786411,
#   '전년도비_점포수_증감': -5496.0,
#   '전년도비_점포수_증감률': -9.831314956263526,
#   '점포수': 50407},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '화장품',
#   '분기당_매출_금액': 3373085651261.0,
#   '월별_평균_매출': 17358764.3388141,
#   '전년도비_매출_증감': -320798.49747408926,
#   '전년도비_매출_증감률': -1.8145160061064018,
#   '전년도비_점포수_증감': -3172.0,
#   '전년도비_점포수_증감률': -6.129350157484879,
#   '점포수': 48579},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '화초',
#   '분기당_매출_금액': 260284511992.0,
#   '월별_평균_매출': 6761339.151911887,
#   '전년도비_매출_증감': 540693.6772570349,
#   '전년도비_매출_증감률': 8.69192239712126,
#   '전년도비_점포수_증감': -82.0,
#   '전년도비_점포수_증감률': -0.844838244384917,
#   '점포수': 9624},
#  {'기준_년_코드': 2018,
#   '서비스_업종_코드_명': '회계사사무소',
#   '분기당_매출_금액': 27227384577.0,
#   '월별_평균_매출': 10069299.029955622,
#   '전년도비_매출_증감': -2276360.3104147483,
#   '전년도비_매출_증감률': -18.438547894894825,
#   '전년도비_점포수_증감': 1.0,
#   '전년도비_점포수_증감률': 0.14814814814813815,
#   '점포수': 676},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': 'PC방',
#   '분기당_매출_금액': 452236221391.0,
#   '월별_평균_매출': 26639739.71436145,
#   '전년도비_매출_증감': -1463302.0804830305,
#   '전년도비_매출_증감률': -5.206917070277683,
#   '전년도비_점포수_증감': -450.0,
#   '전년도비_점포수_증감률': -9.586706433745206,
#   '점포수': 4244},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '가구',
#   '분기당_매출_금액': 501158000153.0,
#   '월별_평균_매출': 28881858.007895343,
#   '전년도비_매출_증감': -1930030.1892414428,
#   '전년도비_매출_증감률': -6.263914035040514,
#   '전년도비_점포수_증감': -604.0,
#   '전년도비_점포수_증감률': -12.221772561715909,
#   '점포수': 4338},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '가방',
#   '분기당_매출_금액': 202009823699.0,
#   '월별_평균_매출': 8112844.325261044,
#   '전년도비_매출_증감': -3782846.131072796,
#   '전년도비_매출_증감률': -31.80013926016902,
#   '전년도비_점포수_증감': -1006.0,
#   '전년도비_점포수_증감률': -13.912321947171904,
#   '점포수': 6225},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '가전제품',
#   '분기당_매출_금액': 761034837681.0,
#   '월별_평균_매출': 35952137.078656465,
#   '전년도비_매출_증감': -2802405.758016534,
#   '전년도비_매출_증감률': -7.231167117173811,
#   '전년도비_점포수_증감': -497.0,
#   '전년도비_점포수_증감률': -8.585247883917773,
#   '점포수': 5292},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '가전제품수리',
#   '분기당_매출_금액': 32346577272.0,
#   '월별_평균_매출': 6244512.986872586,
#   '전년도비_매출_증감': -1557176.64886898,
#   '전년도비_매출_증감률': -19.95947956882506,
#   '전년도비_점포수_증감': -276.0,
#   '전년도비_점포수_증감률': -17.568427753023556,
#   '점포수': 1295},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '고시원',
#   '분기당_매출_금액': 64283930154.0,
#   '월별_평균_매출': 14636596.118852459,
#   '전년도비_매출_증감': -2923469.3350102007,
#   '전년도비_매출_증감률': -16.648396571706,
#   '전년도비_점포수_증감': -67.0,
#   '전년도비_점포수_증감률': -5.751072961373396,
#   '점포수': 1098},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '골프연습장',
#   '분기당_매출_금액': 124079729995.0,
#   '월별_평균_매출': 12619988.811533768,
#   '전년도비_매출_증감': -1526067.9353635628,
#   '전년도비_매출_증감률': -10.787938735635834,
#   '전년도비_점포수_증감': -201.0,
#   '전년도비_점포수_증감률': -7.5592327942835595,
#   '점포수': 2458},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '네일숍',
#   '분기당_매출_금액': 66618357814.0,
#   '월별_평균_매출': 3630032.574869224,
#   '전년도비_매출_증감': -1066041.9219633956,
#   '전년도비_매출_증감률': -22.70070295269832,
#   '전년도비_점포수_증감': -1016.0,
#   '전년도비_점포수_증감률': -18.129907209136334,
#   '점포수': 4588},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '노래방',
#   '분기당_매출_금액': 412988523986.0,
#   '월별_평균_매출': 5171147.500575979,
#   '전년도비_매출_증감': -585912.989986062,
#   '전년도비_매출_증감률': -10.177294314461193,
#   '전년도비_점포수_증감': -1278.0,
#   '전년도비_점포수_증감률': -6.015816230465077,
#   '점포수': 19966},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '당구장',
#   '분기당_매출_금액': 82096285136.0,
#   '월별_평균_매출': 2326464.6660621176,
#   '전년도비_매출_증감': -225662.27461859537,
#   '전년도비_매출_증감률': -8.84212579795917,
#   '전년도비_점포수_증감': -433.0,
#   '전년도비_점포수_증감률': -4.678552133981626,
#   '점포수': 8822},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '문구',
#   '분기당_매출_금액': 1006212115461.0,
#   '월별_평균_매출': 29744948.42914154,
#   '전년도비_매출_증감': 4736394.722697873,
#   '전년도비_매출_증감률': 18.93909891109577,
#   '전년도비_점포수_증감': -1289.0,
#   '전년도비_점포수_증감률': -13.225938846706342,
#   '점포수': 8457},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '미곡판매',
#   '분기당_매출_금액': 226679969744.0,
#   '월별_평균_매출': 29623623.855723992,
#   '전년도비_매출_증감': 5132087.658335358,
#   '전년도비_매출_증감률': 20.95453554637605,
#   '전년도비_점포수_증감': -691.0,
#   '전년도비_점포수_증감률': -26.536098310291862,
#   '점포수': 1913},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '미용실',
#   '분기당_매출_금액': 879292308425.0,
#   '월별_평균_매출': 4800154.538841576,
#   '전년도비_매출_증감': -711558.1637157118,
#   '전년도비_매출_증감률': -12.909928403662391,
#   '전년도비_점포수_증감': -113.0,
#   '전년도비_점포수_증감률': -0.24614446283871416,
#   '점포수': 45795},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '반찬가게',
#   '분기당_매출_금액': 1347307865372.0,
#   '월별_평균_매출': 24607463.9350526,
#   '전년도비_매출_증감': 3694896.2360913157,
#   '전년도비_매출_증감률': 17.668304960346106,
#   '전년도비_점포수_증감': -2197.0,
#   '전년도비_점포수_증감률': -13.830657853320744,
#   '점포수': 13688},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '부동산중개업',
#   '분기당_매출_금액': 11110365599.0,
#   '월별_평균_매출': 901815.3895292208,
#   '전년도비_매출_증감': -3720411.6015194785,
#   '전년도비_매출_증감률': -80.48959102883401,
#   '전년도비_점포수_증감': -14990.0,
#   '전년도비_점포수_증감률': -82.9551743220808,
#   '점포수': 3080},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '분식전문점',
#   '분기당_매출_금액': 1697104792589.0,
#   '월별_평균_매출': 10027562.528591856,
#   '전년도비_매출_증감': -669879.7548018806,
#   '전년도비_매출_증감률': -6.2620553311306395,
#   '전년도비_점포수_증감': 3958.0,
#   '전년도비_점포수_증감률': 10.319922822204262,
#   '점포수': 42311},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '서적',
#   '분기당_매출_금액': 408560600234.0,
#   '월별_평균_매출': 26263859.61905374,
#   '전년도비_매출_증감': 3268195.7441968694,
#   '전년도비_매출_증감률': 14.212226104810426,
#   '전년도비_점포수_증감': -1351.0,
#   '전년도비_점포수_증감률': -25.78244274809161,
#   '점포수': 3889},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '섬유제품',
#   '분기당_매출_금액': 278078356531.0,
#   '월별_평균_매출': 10072383.241487974,
#   '전년도비_매출_증감': -1758763.4692969602,
#   '전년도비_매출_증감률': -14.865536809662942,
#   '전년도비_점포수_증감': -984.0,
#   '전년도비_점포수_증감률': -12.47780877504438,
#   '점포수': 6902},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '세탁소',
#   '분기당_매출_금액': 90167385059.0,
#   '월별_평균_매출': 2897782.011151819,
#   '전년도비_매출_증감': -145462.96816124115,
#   '전년도비_매출_증감률': -4.779863900213371,
#   '전년도비_점포수_증감': -475.0,
#   '전년도비_점포수_증감률': -5.754785558517085,
#   '점포수': 7779},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '수산물판매',
#   '분기당_매출_금액': 1194932763729.0,
#   '월별_평균_매출': 68359997.925,
#   '전년도비_매출_증감': 38836477.703191936,
#   '전년도비_매출_증감률': 131.54419734305495,
#   '전년도비_점포수_증감': -392.0,
#   '전년도비_점포수_증감률': -8.231835363292745,
#   '점포수': 4370},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '슈퍼마켓',
#   '분기당_매출_금액': 3293315408338.0,
#   '월별_평균_매출': 22170639.05871661,
#   '전년도비_매출_증감': -3710306.3626628295,
#   '전년도비_매출_증감률': -14.336054198382811,
#   '전년도비_점포수_증감': -227.0,
#   '전년도비_점포수_증감률': -0.6075529266921791,
#   '점포수': 37136},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '스포츠 강습',
#   '분기당_매출_금액': 239763061493.0,
#   '월별_평균_매출': 6796005.144359411,
#   '전년도비_매출_증감': -1676829.4031221056,
#   '전년도비_매출_증감률': -19.790654399365437,
#   '전년도비_점포수_증감': 164.0,
#   '전년도비_점포수_증감률': 1.8946395563770722,
#   '점포수': 8820},
#  {'기준_년_코드': 2019,
#   '서비스_업종_코드_명': '스포츠클럽',
#   '분기당_매출_금액': 252039695074.0,
#   '월별_평균_매출': 21330373.652166553,
# ...
#   '전년도비_매출_증감률': 53.97907376951673,
#   '전년도비_점포수_증감': -22.0,
#   '전년도비_점포수_증감률': -0.5071461502996755,
#   '점포수': 4316},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '가방',
#   '분기당_매출_금액': 204161551347.0,
#   '월별_평균_매출': 8190049.396140886,
#   '전년도비_매출_증감': 77205.07087984122,
#   '전년도비_매출_증감률': 0.9516399894356198,
#   '전년도비_점포수_증감': 7.0,
#   '전년도비_점포수_증감률': 0.11244979919678144,
#   '점포수': 6232},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '가전제품',
#   '분기당_매출_금액': 1213880331068.0,
#   '월별_평균_매출': 58755098.30919652,
#   '전년도비_매출_증감': 22802961.230540052,
#   '전년도비_매출_증감률': 63.425885311494824,
#   '전년도비_점포수_증감': -127.0,
#   '전년도비_점포수_증감률': -2.399848828420261,
#   '점포수': 5165},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '가전제품수리',
#   '분기당_매출_금액': 40446137266.0,
#   '월별_평균_매출': 6978284.552449966,
#   '전년도비_매출_증감': 733771.5655773794,
#   '전년도비_매출_증감률': 11.750661214412347,
#   '전년도비_점포수_증감': 154.0,
#   '전년도비_점포수_증감률': 11.891891891891888,
#   '점포수': 1449},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '고시원',
#   '분기당_매출_금액': 14131659720.0,
#   '월별_평균_매출': 5520179.578125,
#   '전년도비_매출_증감': -9116416.540727459,
#   '전년도비_매출_증감률': -62.28508641421887,
#   '전년도비_점포수_증감': -458.0,
#   '전년도비_점포수_증감률': -41.71220400728597,
#   '점포수': 640},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '골프연습장',
#   '분기당_매출_금액': 130251546612.0,
#   '월별_평균_매출': 13670397.419395465,
#   '전년도비_매출_증감': 1050408.6078616977,
#   '전년도비_매출_증감률': 8.323371942308697,
#   '전년도비_점포수_증감': -76.0,
#   '전년도비_점포수_증감률': -3.091944670463789,
#   '점포수': 2382},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '네일숍',
#   '분기당_매출_금액': 51244858345.0,
#   '월별_평균_매출': 2703358.2161320955,
#   '전년도비_매출_증감': -926674.3587371283,
#   '전년도비_매출_증감률': -25.52799016605279,
#   '전년도비_점포수_증감': 151.0,
#   '전년도비_점포수_증감률': 3.291194420226674,
#   '점포수': 4739},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '노래방',
#   '분기당_매출_금액': 244253082412.0,
#   '월별_평균_매출': 3154420.4258187828,
#   '전년도비_매출_증감': -2016727.0747571965,
#   '전년도비_매출_증감률': -38.99960452747803,
#   '전년도비_점포수_증감': -608.0,
#   '전년도비_점포수_증감률': -3.0451768005609523,
#   '점포수': 19358},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '당구장',
#   '분기당_매출_금액': 82655754673.0,
#   '월별_평균_매출': 2396652.594322663,
#   '전년도비_매출_증감': 70187.92826054525,
#   '전년도비_매출_증감률': 3.016935063937538,
#   '전년도비_점포수_증감': -200.0,
#   '전년도비_점포수_증감률': -2.2670596236681035,
#   '점포수': 8622},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '문구',
#   '분기당_매출_금액': 1340168905572.0,
#   '월별_평균_매출': 38634943.080373615,
#   '전년도비_매출_증감': 8889994.651232075,
#   '전년도비_매출_증감률': 29.88740986527455,
#   '전년도비_점포수_증감': 215.0,
#   '전년도비_점포수_증감률': 2.5422726735248915,
#   '점포수': 8672},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '미곡판매',
#   '분기당_매출_금액': 378703017723.0,
#   '월별_평균_매출': 45803461.26306241,
#   '전년도비_매출_증감': 16179837.407338418,
#   '전년도비_매출_증감률': 54.61802204260735,
#   '전년도비_점포수_증감': 154.0,
#   '전년도비_점포수_증감률': 8.050182958703616,
#   '점포수': 2067},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '미용실',
#   '분기당_매출_금액': 832348862295.0,
#   '월별_평균_매출': 4492674.732252737,
#   '전년도비_매출_증감': -307479.80658883974,
#   '전년도비_매출_증감률': -6.405623071107286,
#   '전년도비_점포수_증감': 522.0,
#   '전년도비_점포수_증감률': 1.1398624303963203,
#   '점포수': 46317},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '반찬가게',
#   '분기당_매출_금액': 2537305699548.0,
#   '월별_평균_매출': 39411396.38937558,
#   '전년도비_매출_증감': 14803932.454322983,
#   '전년도비_매출_증감률': 60.1603338458427,
#   '전년도비_점포수_증감': 2407.0,
#   '전년도비_점포수_증감률': 17.584745762711876,
#   '점포수': 16095},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '부동산중개업',
#   '분기당_매출_금액': 9578477722.0,
#   '월별_평균_매출': 826015.6710934805,
#   '전년도비_매출_증감': -75799.71843574021,
#   '전년도비_매출_증감률': -8.405236738675569,
#   '전년도비_점포수_증감': -181.0,
#   '전년도비_점포수_증감률': -5.876623376623385,
#   '점포수': 2899},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '분식전문점',
#   '분기당_매출_금액': 1431511505006.0,
#   '월별_평균_매출': 8327776.708044399,
#   '전년도비_매출_증감': -1699785.8205474578,
#   '전년도비_매출_증감률': -16.951136586790795,
#   '전년도비_점포수_증감': 663.0,
#   '전년도비_점포수_증감률': 1.5669684006523141,
#   '점포수': 42974},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '서적',
#   '분기당_매출_금액': 366363339796.0,
#   '월별_평균_매출': 22070080.71060241,
#   '전년도비_매출_증감': -4193778.90845133,
#   '전년도비_매출_증감률': -15.967869800099194,
#   '전년도비_점포수_증감': 261.0,
#   '전년도비_점포수_증감률': 6.711236821805102,
#   '점포수': 4150},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '섬유제품',
#   '분기당_매출_금액': 333872982046.0,
#   '월별_평균_매출': 12827454.3586138,
#   '전년도비_매출_증감': 2755071.117125826,
#   '전년도비_매출_증감률': 27.352723293706063,
#   '전년도비_점포수_증감': -395.0,
#   '전년도비_점포수_증감률': -5.722978846711101,
#   '점포수': 6507},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '세탁소',
#   '분기당_매출_금액': 87297557689.0,
#   '월별_평균_매출': 2696033.2825509575,
#   '전년도비_매출_증감': -201748.7286008615,
#   '전년도비_매출_증감률': -6.96217754905139,
#   '전년도비_점포수_증감': 316.0,
#   '전년도비_점포수_증감률': 4.062218794189491,
#   '점포수': 8095},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '수산물판매',
#   '분기당_매출_금액': 2031924940526.0,
#   '월별_평균_매출': 107304865.8917406,
#   '전년도비_매출_증감': 38944867.96674061,
#   '전년도비_매출_증감률': 56.97025914112564,
#   '전년도비_점포수_증감': 364.0,
#   '전년도비_점포수_증감률': 8.329519450800916,
#   '점포수': 4734},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '슈퍼마켓',
#   '분기당_매출_금액': 3078085289980.0,
#   '월별_평균_매출': 22234074.617018204,
#   '전년도비_매출_증감': 63435.55830159411,
#   '전년도비_매출_증감률': 0.2861241759138693,
#   '전년도비_점포수_증감': -2526.0,
#   '전년도비_점포수_증감률': -6.802024989228784,
#   '점포수': 34610},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '스포츠 강습',
#   '분기당_매출_금액': 209958748944.0,
#   '월별_평균_매출': 5491127.4438748825,
#   '전년도비_매출_증감': -1304877.7004845282,
#   '전년도비_매출_증감률': -19.200657927217108,
#   '전년도비_점포수_증감': 739.0,
#   '전년도비_점포수_증감률': 8.378684807256235,
#   '점포수': 9559},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '스포츠클럽',
#   '분기당_매출_금액': 193177636469.0,
#   '월별_평균_매출': 16130397.166750167,
#   '전년도비_매출_증감': -5199976.485416386,
#   '전년도비_매출_증감률': -24.378271896274157,
#   '전년도비_점포수_증감': 40.0,
#   '전년도비_점포수_증감률': 1.3540961408260017,
#   '점포수': 2994},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '시계및귀금속',
#   '분기당_매출_금액': 1095047589012.0,
#   '월별_평균_매출': 15736155.501120882,
#   '전년도비_매출_증감': 2376786.9146754146,
#   '전년도비_매출_증감률': 17.791162054521976,
#   '전년도비_점포수_증감': 233.0,
#   '전년도비_점포수_증감률': 1.357492426007937,
#   '점포수': 17397},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '신발',
#   '분기당_매출_금액': 576149211472.0,
#   '월별_평균_매출': 10180034.127358824,
#   '전년도비_매출_증감': 1985186.0635865824,
#   '전년도비_매출_증감률': 24.2248062213952,
#   '전년도비_점포수_증감': 99.0,
#   '전년도비_점포수_증감률': 0.704626334519574,
#   '점포수': 14149},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '안경',
#   '분기당_매출_금액': 415234048961.0,
#   '월별_평균_매출': 15117010.66553808,
#   '전년도비_매출_증감': -3302640.4273699746,
#   '전년도비_매출_증감률': -17.92998363927512,
#   '전년도비_점포수_증감': -148.0,
#   '전년도비_점포수_증감률': -2.109764789736275,
#   '점포수': 6867},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '애완동물',
#   '분기당_매출_금액': 65640081795.0,
#   '월별_평균_매출': 8515838.32317073,
#   '전년도비_매출_증감': 1312310.2439874643,
#   '전년도비_매출_증감률': 18.217604340014645,
#   '전년도비_점포수_증감': -81.0,
#   '전년도비_점포수_증감률': -4.033864541832671,
#   '점포수': 1927},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '양식음식점',
#   '분기당_매출_금액': 943277796188.0,
#   '월별_평균_매출': 13189744.898875777,
#   '전년도비_매출_증감': -4059163.8316770457,
#   '전년도비_매출_증감률': -23.532873268017752,
#   '전년도비_점포수_증감': -427.0,
#   '전년도비_점포수_증감률': -2.3325685567573515,
#   '점포수': 17879},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '여관',
#   '분기당_매출_금액': 237487050873.0,
#   '월별_평균_매출': 6179409.10889363,
#   '전년도비_매출_증감': -3377581.4516803576,
#   '전년도비_매출_증감률': -35.34147522980814,
#   '전년도비_점포수_증감': -549.0,
#   '전년도비_점포수_증감률': -5.405139312789203,
#   '점포수': 9608},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '예술학원',
#   '분기당_매출_금액': 244527022638.0,
#   '월별_평균_매출': 5707913.693697479,
#   '전년도비_매출_증감': -1072885.297611828,
#   '전년도비_매출_증감률': -15.822402330269696,
#   '전년도비_점포수_증감': -250.0,
#   '전년도비_점포수_증감률': -2.28102189781022,
#   '점포수': 10710},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '완구',
#   '분기당_매출_금액': 87938825389.0,
#   '월별_평균_매출': 21681169.96770217,
#   '전년도비_매출_증감': 1142811.100593295,
#   '전년도비_매출_증감률': 5.564276620092798,
#   '전년도비_점포수_증감': -79.0,
#   '전년도비_점포수_증감률': -7.227813357731023,
#   '점포수': 1014},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '외국어학원',
#   '분기당_매출_금액': 435932322349.0,
#   '월별_평균_매출': 13663876.7035168,
#   '전년도비_매출_증감': -2051720.4597313292,
#   '전년도비_매출_증감률': -13.055313383378149,
#   '전년도비_점포수_증감': -44.0,
#   '전년도비_점포수_증감률': -0.548628428927671,
#   '점포수': 7976},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '운동/경기용품',
#   '분기당_매출_금액': 935554738263.0,
#   '월별_평균_매출': 37888981.786125064,
#   '전년도비_매출_증감': 8218329.443971489,
#   '전년도비_매출_증감률': 27.69851282405267,
#   '전년도비_점포수_증감': -91.0,
#   '전년도비_점포수_증감률': -1.4527458492975711,
#   '점포수': 6173},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '육류판매',
#   '분기당_매출_금액': 2784865447683.0,
#   '월별_평균_매출': 59480253.04747971,
#   '전년도비_매출_증감': 24564027.03898383,
#   '전년도비_매출_증감률': 70.35132328736461,
#   '전년도비_점포수_증감': 170.0,
#   '전년도비_점포수_증감률': 1.4737754659731195,
#   '점포수': 11705},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '의료기기',
#   '분기당_매출_금액': 1094924378834.0,
#   '월별_평균_매출': 83531002.35230394,
#   '전년도비_매출_증감': 44115914.69391885,
#   '전년도비_매출_증감률': 111.92646601797853,
#   '전년도비_점포수_증감': 540.0,
#   '전년도비_점포수_증감률': 19.729630982827913,
#   '점포수': 3277},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '의약품',
#   '분기당_매출_금액': 4032398746309.0,
#   '월별_평균_매출': 51673570.48425086,
#   '전년도비_매출_증감': 12424175.599074833,
#   '전년도비_매출_증감률': 31.654438585414425,
#   '전년도비_점포수_증감': 506.0,
#   '전년도비_점포수_증감률': 2.662737462505916,
#   '점포수': 19509},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '인테리어',
#   '분기당_매출_금액': 191013300833.0,
#   '월별_평균_매출': 8085561.328860481,
#   '전년도비_매출_증감': 788963.7931045219,
#   '전년도비_매출_증감률': 10.812762924614034,
#   '전년도비_점포수_증감': -93.0,
#   '전년도비_점포수_증감률': -1.5502583763960587,
#   '점포수': 5906},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '일반교습학원',
#   '분기당_매출_금액': 960095699346.0,
#   '월별_평균_매출': 13771525.895719778,
#   '전년도비_매출_증감': 792855.7019399442,
#   '전년도비_매출_증감률': 6.10891324074116,
#   '전년도비_점포수_증감': 460.0,
#   '전년도비_점포수_증감률': 2.710825623195248,
#   '점포수': 17429},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '일반의류',
#   '분기당_매출_금액': 5292616764081.0,
#   '월별_평균_매출': 7499386.125316689,
#   '전년도비_매출_증감': -84983.89701034129,
#   '전년도비_매출_증감률': -1.1205135925615934,
#   '전년도비_점포수_증감': 1882.0,
#   '전년도비_점포수_증감률': 1.0781825577331716,
#   '점포수': 176435},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '일반의원',
#   '분기당_매출_금액': 3973334750153.0,
#   '월별_평균_매출': 46000448.62175836,
#   '전년도비_매출_증감': 977073.2678681016,
#   '전년도비_매출_증감률': 2.1701466409129893,
#   '전년도비_점포수_증감': 490.0,
#   '전년도비_점포수_증감률': 2.3218347232752024,
#   '점포수': 21594},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '일식음식점',
#   '분기당_매출_금액': 898921628673.0,
#   '월별_평균_매출': 15411494.113856124,
#   '전년도비_매출_증감': -995381.7585713863,
#   '전년도비_매출_증감률': -6.0668573731588396,
#   '전년도비_점포수_증감': -627.0,
#   '전년도비_점포수_증감률': -4.122559011111832,
#   '점포수': 14582},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '자동차미용',
#   '분기당_매출_금액': 36336848289.0,
#   '월별_평균_매출': 9633310.787115589,
#   '전년도비_매출_증감': 1262037.6664970322,
#   '전년도비_매출_증감률': 15.075815211292266,
#   '전년도비_점포수_증감': -27.0,
#   '전년도비_점포수_증감률': -2.7835051546391725,
#   '점포수': 943},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '자동차수리',
#   '분기당_매출_금액': 399582511281.0,
#   '월별_평균_매출': 12913085.292172957,
#   '전년도비_매출_증감': 589970.9901765529,
#   '전년도비_매출_증감률': 4.7875153611208106,
#   '전년도비_점포수_증감': -53.0,
#   '전년도비_점포수_증감률': -0.680446783926044,
#   '점포수': 7736},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '자전거 및 기타운송장비',
#   '분기당_매출_금액': 12076196702.0,
#   '월별_평균_매출': 26482887.504385963,
#   '전년도비_매출_증감': -1037852.9096140377,
#   '전년도비_매출_증감률': -3.7711663785254643,
#   '전년도비_점포수_증감': -261.0,
#   '전년도비_점포수_증감률': -69.6,
#   '점포수': 114},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '전자상거래업',
#   '분기당_매출_금액': 752243985027.0,
#   '월별_평균_매출': 12400171.18928854,
#   '전년도비_매출_증감': -529294.7198301256,
#   '전년도비_매출_증감률': -4.093709079327354,
#   '전년도비_점포수_증감': 427.0,
#   '전년도비_점포수_증감률': 2.897075785331424,
#   '점포수': 15166},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '제과점',
#   '분기당_매출_금액': 901675399934.0,
#   '월별_평균_매출': 18702302.33000083,
#   '전년도비_매출_증감': -1446653.8049750924,
#   '전년도비_매출_증감률': -7.179795297007445,
#   '전년도비_점포수_증감': 425.0,
#   '전년도비_점포수_증감률': 3.6549707602339083,
#   '점포수': 12053},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '조명용품',
#   '분기당_매출_금액': 1009027236618.0,
#   '월별_평균_매출': 26875858.635680802,
#   '전년도비_매출_증감': 15105836.103906944,
#   '전년도비_매출_증감률': 128.3416073599508,
#   '전년도비_점포수_증감': 259.0,
#   '전년도비_점포수_증감률': 2.837734195244863,
#   '점포수': 9386},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '중식음식점',
#   '분기당_매출_금액': 795230735422.0,
#   '월별_평균_매출': 14076873.458578207,
#   '전년도비_매출_증감': -2711369.8490312807,
#   '전년도비_매출_증감률': -16.15040835036217,
#   '전년도비_점포수_증감': 423.0,
#   '전년도비_점포수_증감률': 3.0875912408759234,
#   '점포수': 14123},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '철물점',
#   '분기당_매출_금액': 127308311651.0,
#   '월별_평균_매출': 6863721.784073754,
#   '전년도비_매출_증감': 868741.0580122294,
#   '전년도비_매출_증감률': 14.491140133872605,
#   '전년도비_점포수_증감': 21.0,
#   '전년도비_점포수_증감률': 0.454939341421138,
#   '점포수': 4637},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '청과상',
#   '분기당_매출_금액': 2352935718404.0,
#   '월별_평균_매출': 62644720.937273696,
#   '전년도비_매출_증감': 28357574.9888269,
#   '전년도비_매출_증감률': 82.70614017120167,
#   '전년도비_점포수_증감': 312.0,
#   '전년도비_점포수_증감률': 3.4368803701255786,
#   '점포수': 9390},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '치과의원',
#   '분기당_매출_금액': 1663707162265.0,
#   '월별_평균_매출': 35437231.879206784,
#   '전년도비_매출_증감': -345880.66480895877,
#   '전년도비_매출_증감률': -0.9666030711652098,
#   '전년도비_점포수_증감': 48.0,
#   '전년도비_점포수_증감률': 0.4106424843870258,
#   '점포수': 11737},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '치킨전문점',
#   '분기당_매출_금액': 481939646144.0,
#   '월별_평균_매출': 8745366.30151702,
#   '전년도비_매출_증감': -2047248.7184057161,
#   '전년도비_매출_증감률': -18.96897753349468,
#   '전년도비_점포수_증감': 187.0,
#   '전년도비_점포수_증감률': 1.3760117733627766,
#   '점포수': 13777},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '커피-음료',
#   '분기당_매출_금액': 2033490522606.0,
#   '월별_평균_매출': 9523296.816370687,
#   '전년도비_매출_증감': -2265091.787890505,
#   '전년도비_매출_증감률': -19.214600603442392,
#   '전년도비_점포수_증감': 5555.0,
#   '전년도비_점포수_증감률': 11.61477826332407,
#   '점포수': 53382},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '컴퓨터및주변장치판매',
#   '분기당_매출_금액': 5164442554558.0,
#   '월별_평균_매출': 71434692.85379551,
#   '전년도비_매출_증감': 20446546.775414698,
#   '전년도비_매출_증감률': 40.10058876034347,
#   '전년도비_점포수_증감': 911.0,
#   '전년도비_점포수_증감률': 5.307929849093981,
#   '점포수': 18074},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '패스트푸드점',
#   '분기당_매출_금액': 500321766888.0,
#   '월별_평균_매출': 11516475.621213516,
#   '전년도비_매출_증감': -4985226.055141905,
#   '전년도비_매출_증감률': -30.210375589840055,
#   '전년도비_점포수_증감': 901.0,
#   '전년도비_점포수_증감률': 9.046184738955816,
#   '점포수': 10861},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '편의점',
#   '분기당_매출_금액': 4021862568041.0,
#   '월별_평균_매출': 45698829.28871239,
#   '전년도비_매출_증감': -1679440.3978530914,
#   '전년도비_매출_증감률': -3.544748275873218,
#   '전년도비_점포수_증감': -202.0,
#   '전년도비_점포수_증감률': -0.9097459917132085,
#   '점포수': 22002},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '피부관리실',
#   '분기당_매출_금액': 194001516338.0,
#   '월별_평균_매출': 3534497.8198877713,
#   '전년도비_매출_증감': -297108.51985719614,
#   '전년도비_매출_증감률': -7.754150440125116,
#   '전년도비_점포수_증감': -237.0,
#   '전년도비_점포수_증감률': -1.697829357403819,
#   '점포수': 13722},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '한식음식점',
#   '분기당_매출_금액': 8748664481235.0,
#   '월별_평균_매출': 14390860.295616943,
#   '전년도비_매출_증감': -2636111.2518138625,
#   '전년도비_매출_증감률': -15.481973670248038,
#   '전년도비_점포수_증감': -808.0,
#   '전년도비_점포수_증감률': -0.5288269597031245,
#   '점포수': 151983},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '한의원',
#   '분기당_매출_금액': 689294200034.0,
#   '월별_평균_매출': 18649734.849404763,
#   '전년도비_매출_증감': -1663042.964412503,
#   '전년도비_매출_증감률': -8.187176464270976,
#   '전년도비_점포수_증감': -107.0,
#   '전년도비_점포수_증감률': -1.1447523269498276,
#   '점포수': 9240},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '핸드폰',
#   '분기당_매출_금액': 292277806448.0,
#   '월별_평균_매출': 9921174.692735912,
#   '전년도비_매출_증감': -1477869.7599153463,
#   '전년도비_매출_증감률': -12.964856537353128,
#   '전년도비_점포수_증감': 10.0,
#   '전년도비_점포수_증감률': 0.13596193065940554,
#   '점포수': 7365},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '호프-간이주점',
#   '분기당_매출_금액': 1718303182556.0,
#   '월별_평균_매출': 10059145.19702611,
#   '전년도비_매출_증감': -1887722.6609097645,
#   '전년도비_매출_증감률': -15.800983850807555,
#   '전년도비_점포수_증감': -1115.0,
#   '전년도비_점포수_증감률': -2.544500228206303,
#   '점포수': 42705},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '화장품',
#   '분기당_매출_금액': 2116487593745.0,
#   '월별_평균_매출': 12031513.448457183,
#   '전년도비_매출_증감': -3389536.1655663103,
#   '전년도비_매출_증감률': -21.97993165448321,
#   '전년도비_점포수_증감': 476.0,
#   '전년도비_점포수_증감률': 1.0942025653993,
#   '점포수': 43978},
#  {'기준_년_코드': 2020,
#   '서비스_업종_코드_명': '화초',
#   '분기당_매출_금액': 237079869373.0,
#   '월별_평균_매출': 6340390.1736467695,
#   '전년도비_매출_증감': -136991.2552790288,
#   '전년도비_매출_증감률': -2.114917220518649,
#   '전년도비_점포수_증감': 76.0,
#   '전년도비_점포수_증감률': 0.8196721311475272,
#   '점포수': 9348}]

# %% [markdown]
# # Mongo db 전송

# %%
mongo_df = pivot_df.dropna()

# %%
! pip install certifi
import certifi
ca = certifi.where()
import pymongo
connection = pymongo.MongoClient(f"mongodb+srv://user1:uZGuuMyRngM3izgG@cluster0.cu0c3.mongodb.net/myFirstDatabase?retryWrites=true&w=majority", tlsCAFile=ca)
# Out:
# Requirement already satisfied: certifi in c:\users\chsr1\appdata\local\programs\python\python39\lib\site-packages (2021.5.30)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\chsr1\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
db = connection['elice']
collection = db.get_collection('sales_info')
collection.insert_many(mongo_df.reset_index().to_dict('records'))

# %%
print(list(collection.find()))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
