# %%
# !pip install pyspark
# !pip install Koalas

import os
os.environ["PYARROW_IGNORE_TIMEZONE"] = "1"

import databricks.koalas as ks
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()
# Out:
# ...
# WARNING:root:Found numpy version "1.21.2" installed with pyspark version "2.4.8". Some functions will not work well with this combination of numpy version "1.21.2" and pyspark version "2.4.8". Please try to upgrade pyspark version to 3.1 or above, or downgrade numpy version to below 1.20.
# WARNING:root:'ARROW_PRE_0_15_IPC_FORMAT' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=0.15 and pyspark<3.0. Koalas will set it for you but it does not work if there is a Spark context already launched.

# %%
import pyspark.sql.functions as F
import pyspark.sql.types as T

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.10:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.8</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_2016 = spark.read.format("csv").option("header", True).load("./data/상권-추정매출/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2016.csv")
df_2017 = spark.read.format("csv").option("header", True).load("./data/상권-추정매출/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2017.csv")
df_2018 = spark.read.format("csv").option("header", True).load("./data/상권-추정매출/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2018.csv")
df_2019 = spark.read.format("csv").option("header", True).load("./data/상권-추정매출/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2019.csv")
df_2020 = spark.read.format("csv").option("header", True).load("./data/상권-추정매출/서울시우리마을가게상권분석서비스(상권-추정매출)_2020.csv")

# %% [markdown]
# ## 데이터 타입 확인, 변경

# %% [markdown]
# ### 2016

# %%
df_2016.printSchema()
# Out:
# root
#  |-- 기준_년_코드: string (nullable = true)
#  |-- 기준_분기_코드: string (nullable = true)
#  |-- 상권_구분_코드: string (nullable = true)
#  |-- 상권_구분_코드_명: string (nullable = true)
#  |-- 상권_코드: string (nullable = true)
#  |-- 상권_코드_명: string (nullable = true)
#  |-- 서비스_업종_코드: string (nullable = true)
#  |-- 서비스_업종_코드_명: string (nullable = true)
#  |-- 분기당_매출_금액: string (nullable = true)
#  |-- 분기당_매출_건수: string (nullable = true)
#  |-- 주중_매출_비율: string (nullable = true)
#  |-- 주말_매출_비율: string (nullable = true)
#  |-- 월요일_매출_비율: string (nullable = true)
#  |-- 화요일_매출_비율: string (nullable = true)
#  |-- 수요일_매출_비율: string (nullable = true)
#  |-- 목요일_매출_비율: string (nullable = true)
#  |-- 금요일_매출_비율: string (nullable = true)
#  |-- 토요일_매출_비율: string (nullable = true)
#  |-- 일요일_매출_비율: string (nullable = true)
#  |-- 시간대_00~06_매출_비율: string (nullable = true)
#  |-- 시간대_06~11_매출_비율: string (nullable = true)
#  |-- 시간대_11~14_매출_비율: string (nullable = true)
# ...

# %%
# 매출 비율
df_2016 = df_2016 \
.withColumn('분기당_매출_금액', F.col('분기당_매출_금액').cast(T.IntegerType())) \
.withColumn('분기당_매출_건수', F.col('분기당_매출_건수').cast(T.IntegerType())) \
.withColumn('주중_매출_비율', F.col('주중_매출_비율').cast(T.IntegerType())) \
.withColumn('주말_매출_비율', F.col('주말_매출_비율').cast(T.IntegerType())) \
.withColumn('월요일_매출_비율', F.col('월요일_매출_비율').cast(T.IntegerType())) \
.withColumn('화요일_매출_비율', F.col('화요일_매출_비율').cast(T.IntegerType())) \
.withColumn('수요일_매출_비율', F.col('수요일_매출_비율').cast(T.IntegerType())) \
.withColumn('목요일_매출_비율', F.col('목요일_매출_비율').cast(T.IntegerType())) \
.withColumn('금요일_매출_비율', F.col('금요일_매출_비율').cast(T.IntegerType())) \
.withColumn('토요일_매출_비율', F.col('토요일_매출_비율').cast(T.IntegerType())) \
.withColumn('일요일_매출_비율', F.col('일요일_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_00~06_매출_비율', F.col('시간대_00~06_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_06~11_매출_비율', F.col('시간대_06~11_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_11~14_매출_비율', F.col('시간대_11~14_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_14~17_매출_비율', F.col('시간대_14~17_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_17~21_매출_비율', F.col('시간대_17~21_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_21~24_매출_비율', F.col('시간대_21~24_매출_비율').cast(T.IntegerType())) \
.withColumn('남성_매출_비율', F.col('남성_매출_비율').cast(T.IntegerType())) \
.withColumn('여성_매출_비율', F.col('여성_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_비율', F.col('연령대_10_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_비율', F.col('연령대_20_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_비율', F.col('연령대_30_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_비율', F.col('연령대_40_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_비율', F.col('연령대_50_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_비율', F.col('연령대_60_이상_매출_비율').cast(T.IntegerType()))

# 매출 금액
df_2016 = df_2016 \
.withColumn('주중_매출_금액', F.col('주중_매출_금액').cast(T.IntegerType())) \
.withColumn('주말_매출_금액', F.col('주말_매출_금액').cast(T.IntegerType())) \
.withColumn('월요일_매출_금액', F.col('월요일_매출_금액').cast(T.IntegerType())) \
.withColumn('화요일_매출_금액', F.col('화요일_매출_금액').cast(T.IntegerType())) \
.withColumn('수요일_매출_금액', F.col('수요일_매출_금액').cast(T.IntegerType())) \
.withColumn('목요일_매출_금액', F.col('목요일_매출_금액').cast(T.IntegerType())) \
.withColumn('금요일_매출_금액', F.col('금요일_매출_금액').cast(T.IntegerType())) \
.withColumn('토요일_매출_금액', F.col('토요일_매출_금액').cast(T.IntegerType())) \
.withColumn('일요일_매출_금액', F.col('일요일_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_00~06_매출_금액', F.col('시간대_00~06_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_06~11_매출_금액', F.col('시간대_06~11_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_11~14_매출_금액', F.col('시간대_11~14_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_14~17_매출_금액', F.col('시간대_14~17_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_17~21_매출_금액', F.col('시간대_17~21_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_21~24_매출_금액', F.col('시간대_21~24_매출_금액').cast(T.IntegerType())) \
.withColumn('남성_매출_금액', F.col('남성_매출_금액').cast(T.IntegerType())) \
.withColumn('여성_매출_금액', F.col('여성_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_금액', F.col('연령대_10_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_금액', F.col('연령대_20_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_금액', F.col('연령대_30_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_금액', F.col('연령대_40_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_금액', F.col('연령대_50_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_금액', F.col('연령대_60_이상_매출_금액').cast(T.IntegerType()))

# 매출 건수
df_2016 = df_2016 \
.withColumn('주중_매출_건수', F.col('주중_매출_건수').cast(T.IntegerType())) \
.withColumn('주말_매출_건수', F.col('주말_매출_건수').cast(T.IntegerType())) \
.withColumn('월요일_매출_건수', F.col('월요일_매출_건수').cast(T.IntegerType())) \
.withColumn('화요일_매출_건수', F.col('화요일_매출_건수').cast(T.IntegerType())) \
.withColumn('수요일_매출_건수', F.col('수요일_매출_건수').cast(T.IntegerType())) \
.withColumn('목요일_매출_건수', F.col('목요일_매출_건수').cast(T.IntegerType())) \
.withColumn('금요일_매출_건수', F.col('금요일_매출_건수').cast(T.IntegerType())) \
.withColumn('토요일_매출_건수', F.col('토요일_매출_건수').cast(T.IntegerType())) \
.withColumn('일요일_매출_건수', F.col('일요일_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~06_매출_건수', F.col('시간대_건수~06_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~11_매출_건수', F.col('시간대_건수~11_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~14_매출_건수', F.col('시간대_건수~14_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~17_매출_건수', F.col('시간대_건수~17_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~21_매출_건수', F.col('시간대_건수~21_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~24_매출_건수', F.col('시간대_건수~24_매출_건수').cast(T.IntegerType())) \
.withColumn('남성_매출_건수', F.col('남성_매출_건수').cast(T.IntegerType())) \
.withColumn('여성_매출_건수', F.col('여성_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_건수', F.col('연령대_10_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_건수', F.col('연령대_20_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_건수', F.col('연령대_30_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_건수', F.col('연령대_40_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_건수', F.col('연령대_50_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_건수', F.col('연령대_60_이상_매출_건수').cast(T.IntegerType()))

df_2016 = df_2016.withColumn('점포수', F.col('점포수').cast(T.IntegerType()))

# %%
df_2016.printSchema()
# Out:
# root
#  |-- 기준_년_코드: string (nullable = true)
#  |-- 기준_분기_코드: string (nullable = true)
#  |-- 상권_구분_코드: string (nullable = true)
#  |-- 상권_구분_코드_명: string (nullable = true)
#  |-- 상권_코드: string (nullable = true)
#  |-- 상권_코드_명: string (nullable = true)
#  |-- 서비스_업종_코드: string (nullable = true)
#  |-- 서비스_업종_코드_명: string (nullable = true)
#  |-- 분기당_매출_금액: integer (nullable = true)
#  |-- 분기당_매출_건수: integer (nullable = true)
#  |-- 주중_매출_비율: integer (nullable = true)
#  |-- 주말_매출_비율: integer (nullable = true)
#  |-- 월요일_매출_비율: integer (nullable = true)
#  |-- 화요일_매출_비율: integer (nullable = true)
#  |-- 수요일_매출_비율: integer (nullable = true)
#  |-- 목요일_매출_비율: integer (nullable = true)
#  |-- 금요일_매출_비율: integer (nullable = true)
#  |-- 토요일_매출_비율: integer (nullable = true)
#  |-- 일요일_매출_비율: integer (nullable = true)
#  |-- 시간대_00~06_매출_비율: integer (nullable = true)
#  |-- 시간대_06~11_매출_비율: integer (nullable = true)
#  |-- 시간대_11~14_매출_비율: integer (nullable = true)
# ...

# %% [markdown]
# ## 2017

# %%
df_2017.printSchema()
# Out:
# root
#  |-- 기준_년_코드: string (nullable = true)
#  |-- 기준_분기_코드: string (nullable = true)
#  |-- 상권_구분_코드: string (nullable = true)
#  |-- 상권_구분_코드_명: string (nullable = true)
#  |-- 상권_코드: string (nullable = true)
#  |-- 상권_코드_명: string (nullable = true)
#  |-- 서비스_업종_코드: string (nullable = true)
#  |-- 서비스_업종_코드_명: string (nullable = true)
#  |-- 분기당_매출_금액: string (nullable = true)
#  |-- 분기당_매출_건수: string (nullable = true)
#  |-- 주중_매출_비율: string (nullable = true)
#  |-- 주말_매출_비율: string (nullable = true)
#  |-- 월요일_매출_비율: string (nullable = true)
#  |-- 화요일_매출_비율: string (nullable = true)
#  |-- 수요일_매출_비율: string (nullable = true)
#  |-- 목요일_매출_비율: string (nullable = true)
#  |-- 금요일_매출_비율: string (nullable = true)
#  |-- 토요일_매출_비율: string (nullable = true)
#  |-- 일요일_매출_비율: string (nullable = true)
#  |-- 시간대_00~06_매출_비율: string (nullable = true)
#  |-- 시간대_06~11_매출_비율: string (nullable = true)
#  |-- 시간대_11~14_매출_비율: string (nullable = true)
# ...

# %%
# 매출 비율
df_2017 = df_2017 \
.withColumn('분기당_매출_금액', F.col('분기당_매출_금액').cast(T.IntegerType())) \
.withColumn('분기당_매출_건수', F.col('분기당_매출_건수').cast(T.IntegerType())) \
.withColumn('주중_매출_비율', F.col('주중_매출_비율').cast(T.IntegerType())) \
.withColumn('주말_매출_비율', F.col('주말_매출_비율').cast(T.IntegerType())) \
.withColumn('월요일_매출_비율', F.col('월요일_매출_비율').cast(T.IntegerType())) \
.withColumn('화요일_매출_비율', F.col('화요일_매출_비율').cast(T.IntegerType())) \
.withColumn('수요일_매출_비율', F.col('수요일_매출_비율').cast(T.IntegerType())) \
.withColumn('목요일_매출_비율', F.col('목요일_매출_비율').cast(T.IntegerType())) \
.withColumn('금요일_매출_비율', F.col('금요일_매출_비율').cast(T.IntegerType())) \
.withColumn('토요일_매출_비율', F.col('토요일_매출_비율').cast(T.IntegerType())) \
.withColumn('일요일_매출_비율', F.col('일요일_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_00~06_매출_비율', F.col('시간대_00~06_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_06~11_매출_비율', F.col('시간대_06~11_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_11~14_매출_비율', F.col('시간대_11~14_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_14~17_매출_비율', F.col('시간대_14~17_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_17~21_매출_비율', F.col('시간대_17~21_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_21~24_매출_비율', F.col('시간대_21~24_매출_비율').cast(T.IntegerType())) \
.withColumn('남성_매출_비율', F.col('남성_매출_비율').cast(T.IntegerType())) \
.withColumn('여성_매출_비율', F.col('여성_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_비율', F.col('연령대_10_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_비율', F.col('연령대_20_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_비율', F.col('연령대_30_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_비율', F.col('연령대_40_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_비율', F.col('연령대_50_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_비율', F.col('연령대_60_이상_매출_비율').cast(T.IntegerType()))

# 매출 금액
df_2017 = df_2017 \
.withColumn('주중_매출_금액', F.col('주중_매출_금액').cast(T.IntegerType())) \
.withColumn('주말_매출_금액', F.col('주말_매출_금액').cast(T.IntegerType())) \
.withColumn('월요일_매출_금액', F.col('월요일_매출_금액').cast(T.IntegerType())) \
.withColumn('화요일_매출_금액', F.col('화요일_매출_금액').cast(T.IntegerType())) \
.withColumn('수요일_매출_금액', F.col('수요일_매출_금액').cast(T.IntegerType())) \
.withColumn('목요일_매출_금액', F.col('목요일_매출_금액').cast(T.IntegerType())) \
.withColumn('금요일_매출_금액', F.col('금요일_매출_금액').cast(T.IntegerType())) \
.withColumn('토요일_매출_금액', F.col('토요일_매출_금액').cast(T.IntegerType())) \
.withColumn('일요일_매출_금액', F.col('일요일_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_00~06_매출_금액', F.col('시간대_00~06_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_06~11_매출_금액', F.col('시간대_06~11_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_11~14_매출_금액', F.col('시간대_11~14_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_14~17_매출_금액', F.col('시간대_14~17_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_17~21_매출_금액', F.col('시간대_17~21_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_21~24_매출_금액', F.col('시간대_21~24_매출_금액').cast(T.IntegerType())) \
.withColumn('남성_매출_금액', F.col('남성_매출_금액').cast(T.IntegerType())) \
.withColumn('여성_매출_금액', F.col('여성_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_금액', F.col('연령대_10_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_금액', F.col('연령대_20_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_금액', F.col('연령대_30_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_금액', F.col('연령대_40_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_금액', F.col('연령대_50_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_금액', F.col('연령대_60_이상_매출_금액').cast(T.IntegerType()))

# 매출 건수
df_2017 = df_2017 \
.withColumn('주중_매출_건수', F.col('주중_매출_건수').cast(T.IntegerType())) \
.withColumn('주말_매출_건수', F.col('주말_매출_건수').cast(T.IntegerType())) \
.withColumn('월요일_매출_건수', F.col('월요일_매출_건수').cast(T.IntegerType())) \
.withColumn('화요일_매출_건수', F.col('화요일_매출_건수').cast(T.IntegerType())) \
.withColumn('수요일_매출_건수', F.col('수요일_매출_건수').cast(T.IntegerType())) \
.withColumn('목요일_매출_건수', F.col('목요일_매출_건수').cast(T.IntegerType())) \
.withColumn('금요일_매출_건수', F.col('금요일_매출_건수').cast(T.IntegerType())) \
.withColumn('토요일_매출_건수', F.col('토요일_매출_건수').cast(T.IntegerType())) \
.withColumn('일요일_매출_건수', F.col('일요일_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~06_매출_건수', F.col('시간대_건수~06_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~11_매출_건수', F.col('시간대_건수~11_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~14_매출_건수', F.col('시간대_건수~14_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~17_매출_건수', F.col('시간대_건수~17_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~21_매출_건수', F.col('시간대_건수~21_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~24_매출_건수', F.col('시간대_건수~24_매출_건수').cast(T.IntegerType())) \
.withColumn('남성_매출_건수', F.col('남성_매출_건수').cast(T.IntegerType())) \
.withColumn('여성_매출_건수', F.col('여성_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_건수', F.col('연령대_10_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_건수', F.col('연령대_20_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_건수', F.col('연령대_30_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_건수', F.col('연령대_40_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_건수', F.col('연령대_50_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_건수', F.col('연령대_60_이상_매출_건수').cast(T.IntegerType()))

df_2017 = df_2017.withColumn('점포수', F.col('점포수').cast(T.IntegerType()))

# %%
df_2017.printSchema()
# Out:
# root
#  |-- 기준_년_코드: string (nullable = true)
#  |-- 기준_분기_코드: string (nullable = true)
#  |-- 상권_구분_코드: string (nullable = true)
#  |-- 상권_구분_코드_명: string (nullable = true)
#  |-- 상권_코드: string (nullable = true)
#  |-- 상권_코드_명: string (nullable = true)
#  |-- 서비스_업종_코드: string (nullable = true)
#  |-- 서비스_업종_코드_명: string (nullable = true)
#  |-- 분기당_매출_금액: integer (nullable = true)
#  |-- 분기당_매출_건수: integer (nullable = true)
#  |-- 주중_매출_비율: integer (nullable = true)
#  |-- 주말_매출_비율: integer (nullable = true)
#  |-- 월요일_매출_비율: integer (nullable = true)
#  |-- 화요일_매출_비율: integer (nullable = true)
#  |-- 수요일_매출_비율: integer (nullable = true)
#  |-- 목요일_매출_비율: integer (nullable = true)
#  |-- 금요일_매출_비율: integer (nullable = true)
#  |-- 토요일_매출_비율: integer (nullable = true)
#  |-- 일요일_매출_비율: integer (nullable = true)
#  |-- 시간대_00~06_매출_비율: integer (nullable = true)
#  |-- 시간대_06~11_매출_비율: integer (nullable = true)
#  |-- 시간대_11~14_매출_비율: integer (nullable = true)
# ...

# %% [markdown]
# ## 2018

# %%
df_2018.printSchema()
# Out:
# root
#  |-- 기준_년_코드: string (nullable = true)
#  |-- 기준_분기_코드: string (nullable = true)
#  |-- 상권_구분_코드: string (nullable = true)
#  |-- 상권_구분_코드_명: string (nullable = true)
#  |-- 상권_코드: string (nullable = true)
#  |-- 상권_코드_명: string (nullable = true)
#  |-- 서비스_업종_코드: string (nullable = true)
#  |-- 서비스_업종_코드_명: string (nullable = true)
#  |-- 분기당_매출_금액: string (nullable = true)
#  |-- 분기당_매출_건수: string (nullable = true)
#  |-- 주중_매출_비율: string (nullable = true)
#  |-- 주말_매출_비율: string (nullable = true)
#  |-- 월요일_매출_비율: string (nullable = true)
#  |-- 화요일_매출_비율: string (nullable = true)
#  |-- 수요일_매출_비율: string (nullable = true)
#  |-- 목요일_매출_비율: string (nullable = true)
#  |-- 금요일_매출_비율: string (nullable = true)
#  |-- 토요일_매출_비율: string (nullable = true)
#  |-- 일요일_매출_비율: string (nullable = true)
#  |-- 시간대_00~06_매출_비율: string (nullable = true)
#  |-- 시간대_06~11_매출_비율: string (nullable = true)
#  |-- 시간대_11~14_매출_비율: string (nullable = true)
# ...

# %%
# 매출 비율
df_2018 = df_2018 \
.withColumn('분기당_매출_금액', F.col('분기당_매출_금액').cast(T.IntegerType())) \
.withColumn('분기당_매출_건수', F.col('분기당_매출_건수').cast(T.IntegerType())) \
.withColumn('주중_매출_비율', F.col('주중_매출_비율').cast(T.IntegerType())) \
.withColumn('주말_매출_비율', F.col('주말_매출_비율').cast(T.IntegerType())) \
.withColumn('월요일_매출_비율', F.col('월요일_매출_비율').cast(T.IntegerType())) \
.withColumn('화요일_매출_비율', F.col('화요일_매출_비율').cast(T.IntegerType())) \
.withColumn('수요일_매출_비율', F.col('수요일_매출_비율').cast(T.IntegerType())) \
.withColumn('목요일_매출_비율', F.col('목요일_매출_비율').cast(T.IntegerType())) \
.withColumn('금요일_매출_비율', F.col('금요일_매출_비율').cast(T.IntegerType())) \
.withColumn('토요일_매출_비율', F.col('토요일_매출_비율').cast(T.IntegerType())) \
.withColumn('일요일_매출_비율', F.col('일요일_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_00~06_매출_비율', F.col('시간대_00~06_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_06~11_매출_비율', F.col('시간대_06~11_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_11~14_매출_비율', F.col('시간대_11~14_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_14~17_매출_비율', F.col('시간대_14~17_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_17~21_매출_비율', F.col('시간대_17~21_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_21~24_매출_비율', F.col('시간대_21~24_매출_비율').cast(T.IntegerType())) \
.withColumn('남성_매출_비율', F.col('남성_매출_비율').cast(T.IntegerType())) \
.withColumn('여성_매출_비율', F.col('여성_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_비율', F.col('연령대_10_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_비율', F.col('연령대_20_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_비율', F.col('연령대_30_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_비율', F.col('연령대_40_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_비율', F.col('연령대_50_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_비율', F.col('연령대_60_이상_매출_비율').cast(T.IntegerType()))

# 매출 금액
df_2018 = df_2018 \
.withColumn('주중_매출_금액', F.col('주중_매출_금액').cast(T.IntegerType())) \
.withColumn('주말_매출_금액', F.col('주말_매출_금액').cast(T.IntegerType())) \
.withColumn('월요일_매출_금액', F.col('월요일_매출_금액').cast(T.IntegerType())) \
.withColumn('화요일_매출_금액', F.col('화요일_매출_금액').cast(T.IntegerType())) \
.withColumn('수요일_매출_금액', F.col('수요일_매출_금액').cast(T.IntegerType())) \
.withColumn('목요일_매출_금액', F.col('목요일_매출_금액').cast(T.IntegerType())) \
.withColumn('금요일_매출_금액', F.col('금요일_매출_금액').cast(T.IntegerType())) \
.withColumn('토요일_매출_금액', F.col('토요일_매출_금액').cast(T.IntegerType())) \
.withColumn('일요일_매출_금액', F.col('일요일_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_00~06_매출_금액', F.col('시간대_00~06_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_06~11_매출_금액', F.col('시간대_06~11_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_11~14_매출_금액', F.col('시간대_11~14_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_14~17_매출_금액', F.col('시간대_14~17_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_17~21_매출_금액', F.col('시간대_17~21_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_21~24_매출_금액', F.col('시간대_21~24_매출_금액').cast(T.IntegerType())) \
.withColumn('남성_매출_금액', F.col('남성_매출_금액').cast(T.IntegerType())) \
.withColumn('여성_매출_금액', F.col('여성_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_금액', F.col('연령대_10_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_금액', F.col('연령대_20_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_금액', F.col('연령대_30_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_금액', F.col('연령대_40_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_금액', F.col('연령대_50_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_금액', F.col('연령대_60_이상_매출_금액').cast(T.IntegerType()))

# 매출 건수
df_2018 = df_2018 \
.withColumn('주중_매출_건수', F.col('주중_매출_건수').cast(T.IntegerType())) \
.withColumn('주말_매출_건수', F.col('주말_매출_건수').cast(T.IntegerType())) \
.withColumn('월요일_매출_건수', F.col('월요일_매출_건수').cast(T.IntegerType())) \
.withColumn('화요일_매출_건수', F.col('화요일_매출_건수').cast(T.IntegerType())) \
.withColumn('수요일_매출_건수', F.col('수요일_매출_건수').cast(T.IntegerType())) \
.withColumn('목요일_매출_건수', F.col('목요일_매출_건수').cast(T.IntegerType())) \
.withColumn('금요일_매출_건수', F.col('금요일_매출_건수').cast(T.IntegerType())) \
.withColumn('토요일_매출_건수', F.col('토요일_매출_건수').cast(T.IntegerType())) \
.withColumn('일요일_매출_건수', F.col('일요일_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~06_매출_건수', F.col('시간대_건수~06_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~11_매출_건수', F.col('시간대_건수~11_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~14_매출_건수', F.col('시간대_건수~14_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~17_매출_건수', F.col('시간대_건수~17_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~21_매출_건수', F.col('시간대_건수~21_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~24_매출_건수', F.col('시간대_건수~24_매출_건수').cast(T.IntegerType())) \
.withColumn('남성_매출_건수', F.col('남성_매출_건수').cast(T.IntegerType())) \
.withColumn('여성_매출_건수', F.col('여성_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_건수', F.col('연령대_10_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_건수', F.col('연령대_20_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_건수', F.col('연령대_30_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_건수', F.col('연령대_40_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_건수', F.col('연령대_50_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_건수', F.col('연령대_60_이상_매출_건수').cast(T.IntegerType()))

df_2018 = df_2018.withColumn('점포수', F.col('점포수').cast(T.IntegerType()))

# %%
df_2018.printSchema()
# Out:
# root
#  |-- 기준_년_코드: string (nullable = true)
#  |-- 기준_분기_코드: string (nullable = true)
#  |-- 상권_구분_코드: string (nullable = true)
#  |-- 상권_구분_코드_명: string (nullable = true)
#  |-- 상권_코드: string (nullable = true)
#  |-- 상권_코드_명: string (nullable = true)
#  |-- 서비스_업종_코드: string (nullable = true)
#  |-- 서비스_업종_코드_명: string (nullable = true)
#  |-- 분기당_매출_금액: integer (nullable = true)
#  |-- 분기당_매출_건수: integer (nullable = true)
#  |-- 주중_매출_비율: integer (nullable = true)
#  |-- 주말_매출_비율: integer (nullable = true)
#  |-- 월요일_매출_비율: integer (nullable = true)
#  |-- 화요일_매출_비율: integer (nullable = true)
#  |-- 수요일_매출_비율: integer (nullable = true)
#  |-- 목요일_매출_비율: integer (nullable = true)
#  |-- 금요일_매출_비율: integer (nullable = true)
#  |-- 토요일_매출_비율: integer (nullable = true)
#  |-- 일요일_매출_비율: integer (nullable = true)
#  |-- 시간대_00~06_매출_비율: integer (nullable = true)
#  |-- 시간대_06~11_매출_비율: integer (nullable = true)
#  |-- 시간대_11~14_매출_비율: integer (nullable = true)
# ...

# %% [markdown]
# ## 2019

# %%
df_2019.printSchema()
# Out:
# root
#  |-- 기준_년_코드: string (nullable = true)
#  |-- 기준_분기_코드: string (nullable = true)
#  |-- 상권_구분_코드: string (nullable = true)
#  |-- 상권_구분_코드_명: string (nullable = true)
#  |-- 상권_코드: string (nullable = true)
#  |-- 상권_코드_명: string (nullable = true)
#  |-- 서비스_업종_코드: string (nullable = true)
#  |-- 서비스_업종_코드_명: string (nullable = true)
#  |-- 분기당_매출_금액: string (nullable = true)
#  |-- 분기당_매출_건수: string (nullable = true)
#  |-- 주중_매출_비율: string (nullable = true)
#  |-- 주말_매출_비율: string (nullable = true)
#  |-- 월요일_매출_비율: string (nullable = true)
#  |-- 화요일_매출_비율: string (nullable = true)
#  |-- 수요일_매출_비율: string (nullable = true)
#  |-- 목요일_매출_비율: string (nullable = true)
#  |-- 금요일_매출_비율: string (nullable = true)
#  |-- 토요일_매출_비율: string (nullable = true)
#  |-- 일요일_매출_비율: string (nullable = true)
#  |-- 시간대_00~06_매출_비율: string (nullable = true)
#  |-- 시간대_06~11_매출_비율: string (nullable = true)
#  |-- 시간대_11~14_매출_비율: string (nullable = true)
# ...

# %%
# 매출 비율
df_2019 = df_2019 \
.withColumn('분기당_매출_금액', F.col('분기당_매출_금액').cast(T.IntegerType())) \
.withColumn('분기당_매출_건수', F.col('분기당_매출_건수').cast(T.IntegerType())) \
.withColumn('주중_매출_비율', F.col('주중_매출_비율').cast(T.IntegerType())) \
.withColumn('주말_매출_비율', F.col('주말_매출_비율').cast(T.IntegerType())) \
.withColumn('월요일_매출_비율', F.col('월요일_매출_비율').cast(T.IntegerType())) \
.withColumn('화요일_매출_비율', F.col('화요일_매출_비율').cast(T.IntegerType())) \
.withColumn('수요일_매출_비율', F.col('수요일_매출_비율').cast(T.IntegerType())) \
.withColumn('목요일_매출_비율', F.col('목요일_매출_비율').cast(T.IntegerType())) \
.withColumn('금요일_매출_비율', F.col('금요일_매출_비율').cast(T.IntegerType())) \
.withColumn('토요일_매출_비율', F.col('토요일_매출_비율').cast(T.IntegerType())) \
.withColumn('일요일_매출_비율', F.col('일요일_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_00~06_매출_비율', F.col('시간대_00~06_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_06~11_매출_비율', F.col('시간대_06~11_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_11~14_매출_비율', F.col('시간대_11~14_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_14~17_매출_비율', F.col('시간대_14~17_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_17~21_매출_비율', F.col('시간대_17~21_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_21~24_매출_비율', F.col('시간대_21~24_매출_비율').cast(T.IntegerType())) \
.withColumn('남성_매출_비율', F.col('남성_매출_비율').cast(T.IntegerType())) \
.withColumn('여성_매출_비율', F.col('여성_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_비율', F.col('연령대_10_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_비율', F.col('연령대_20_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_비율', F.col('연령대_30_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_비율', F.col('연령대_40_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_비율', F.col('연령대_50_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_비율', F.col('연령대_60_이상_매출_비율').cast(T.IntegerType()))


# 매출 금액
df_2019 = df_2019 \
.withColumn('주중_매출_금액', F.col('주중_매출_금액').cast(T.IntegerType())) \
.withColumn('주말_매출_금액', F.col('주말_매출_금액').cast(T.IntegerType())) \
.withColumn('월요일_매출_금액', F.col('월요일_매출_금액').cast(T.IntegerType())) \
.withColumn('화요일_매출_금액', F.col('화요일_매출_금액').cast(T.IntegerType())) \
.withColumn('수요일_매출_금액', F.col('수요일_매출_금액').cast(T.IntegerType())) \
.withColumn('목요일_매출_금액', F.col('목요일_매출_금액').cast(T.IntegerType())) \
.withColumn('금요일_매출_금액', F.col('금요일_매출_금액').cast(T.IntegerType())) \
.withColumn('토요일_매출_금액', F.col('토요일_매출_금액').cast(T.IntegerType())) \
.withColumn('일요일_매출_금액', F.col('일요일_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_00~06_매출_금액', F.col('시간대_00~06_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_06~11_매출_금액', F.col('시간대_06~11_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_11~14_매출_금액', F.col('시간대_11~14_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_14~17_매출_금액', F.col('시간대_14~17_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_17~21_매출_금액', F.col('시간대_17~21_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_21~24_매출_금액', F.col('시간대_21~24_매출_금액').cast(T.IntegerType())) \
.withColumn('남성_매출_금액', F.col('남성_매출_금액').cast(T.IntegerType())) \
.withColumn('여성_매출_금액', F.col('여성_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_금액', F.col('연령대_10_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_금액', F.col('연령대_20_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_금액', F.col('연령대_30_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_금액', F.col('연령대_40_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_금액', F.col('연령대_50_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_금액', F.col('연령대_60_이상_매출_금액').cast(T.IntegerType()))


# 매출 건수
df_2019 = df_2019 \
.withColumn('주중_매출_건수', F.col('주중_매출_건수').cast(T.IntegerType())) \
.withColumn('주말_매출_건수', F.col('주말_매출_건수').cast(T.IntegerType())) \
.withColumn('월요일_매출_건수', F.col('월요일_매출_건수').cast(T.IntegerType())) \
.withColumn('화요일_매출_건수', F.col('화요일_매출_건수').cast(T.IntegerType())) \
.withColumn('수요일_매출_건수', F.col('수요일_매출_건수').cast(T.IntegerType())) \
.withColumn('목요일_매출_건수', F.col('목요일_매출_건수').cast(T.IntegerType())) \
.withColumn('금요일_매출_건수', F.col('금요일_매출_건수').cast(T.IntegerType())) \
.withColumn('토요일_매출_건수', F.col('토요일_매출_건수').cast(T.IntegerType())) \
.withColumn('일요일_매출_건수', F.col('일요일_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~06_매출_건수', F.col('시간대_건수~06_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~11_매출_건수', F.col('시간대_건수~11_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~14_매출_건수', F.col('시간대_건수~14_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~17_매출_건수', F.col('시간대_건수~17_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~21_매출_건수', F.col('시간대_건수~21_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~24_매출_건수', F.col('시간대_건수~24_매출_건수').cast(T.IntegerType())) \
.withColumn('남성_매출_건수', F.col('남성_매출_건수').cast(T.IntegerType())) \
.withColumn('여성_매출_건수', F.col('여성_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_건수', F.col('연령대_10_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_건수', F.col('연령대_20_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_건수', F.col('연령대_30_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_건수', F.col('연령대_40_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_건수', F.col('연령대_50_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_건수', F.col('연령대_60_이상_매출_건수').cast(T.IntegerType()))

df_2019 = df_2019.withColumn('점포수', F.col('점포수').cast(T.IntegerType()))

# %%
df_2019.printSchema()
# Out:
# root
#  |-- 기준_년_코드: string (nullable = true)
#  |-- 기준_분기_코드: string (nullable = true)
#  |-- 상권_구분_코드: string (nullable = true)
#  |-- 상권_구분_코드_명: string (nullable = true)
#  |-- 상권_코드: string (nullable = true)
#  |-- 상권_코드_명: string (nullable = true)
#  |-- 서비스_업종_코드: string (nullable = true)
#  |-- 서비스_업종_코드_명: string (nullable = true)
#  |-- 분기당_매출_금액: integer (nullable = true)
#  |-- 분기당_매출_건수: integer (nullable = true)
#  |-- 주중_매출_비율: integer (nullable = true)
#  |-- 주말_매출_비율: integer (nullable = true)
#  |-- 월요일_매출_비율: integer (nullable = true)
#  |-- 화요일_매출_비율: integer (nullable = true)
#  |-- 수요일_매출_비율: integer (nullable = true)
#  |-- 목요일_매출_비율: integer (nullable = true)
#  |-- 금요일_매출_비율: integer (nullable = true)
#  |-- 토요일_매출_비율: integer (nullable = true)
#  |-- 일요일_매출_비율: integer (nullable = true)
#  |-- 시간대_00~06_매출_비율: integer (nullable = true)
#  |-- 시간대_06~11_매출_비율: integer (nullable = true)
#  |-- 시간대_11~14_매출_비율: integer (nullable = true)
# ...

# %% [markdown]
# ## 2020

# %%
# 매출 비율
df_2020 = df_2020 \
.withColumn('분기당_매출_금액', F.col('분기당_매출_금액').cast(T.IntegerType())) \
.withColumn('분기당_매출_건수', F.col('분기당_매출_건수').cast(T.IntegerType())) \
.withColumn('주중_매출_비율', F.col('주중_매출_비율').cast(T.IntegerType())) \
.withColumn('주말_매출_비율', F.col('주말_매출_비율').cast(T.IntegerType())) \
.withColumn('월요일_매출_비율', F.col('월요일_매출_비율').cast(T.IntegerType())) \
.withColumn('화요일_매출_비율', F.col('화요일_매출_비율').cast(T.IntegerType())) \
.withColumn('수요일_매출_비율', F.col('수요일_매출_비율').cast(T.IntegerType())) \
.withColumn('목요일_매출_비율', F.col('목요일_매출_비율').cast(T.IntegerType())) \
.withColumn('금요일_매출_비율', F.col('금요일_매출_비율').cast(T.IntegerType())) \
.withColumn('토요일_매출_비율', F.col('토요일_매출_비율').cast(T.IntegerType())) \
.withColumn('일요일_매출_비율', F.col('일요일_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_00~06_매출_비율', F.col('시간대_00~06_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_06~11_매출_비율', F.col('시간대_06~11_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_11~14_매출_비율', F.col('시간대_11~14_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_14~17_매출_비율', F.col('시간대_14~17_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_17~21_매출_비율', F.col('시간대_17~21_매출_비율').cast(T.IntegerType())) \
.withColumn('시간대_21~24_매출_비율', F.col('시간대_21~24_매출_비율').cast(T.IntegerType())) \
.withColumn('남성_매출_비율', F.col('남성_매출_비율').cast(T.IntegerType())) \
.withColumn('여성_매출_비율', F.col('여성_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_비율', F.col('연령대_10_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_비율', F.col('연령대_20_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_비율', F.col('연령대_30_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_비율', F.col('연령대_40_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_비율', F.col('연령대_50_매출_비율').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_비율', F.col('연령대_60_이상_매출_비율').cast(T.IntegerType()))


# 매출 금액
df_2020 = df_2020 \
.withColumn('주중_매출_금액', F.col('주중_매출_금액').cast(T.IntegerType())) \
.withColumn('주말_매출_금액', F.col('주말_매출_금액').cast(T.IntegerType())) \
.withColumn('월요일_매출_금액', F.col('월요일_매출_금액').cast(T.IntegerType())) \
.withColumn('화요일_매출_금액', F.col('화요일_매출_금액').cast(T.IntegerType())) \
.withColumn('수요일_매출_금액', F.col('수요일_매출_금액').cast(T.IntegerType())) \
.withColumn('목요일_매출_금액', F.col('목요일_매출_금액').cast(T.IntegerType())) \
.withColumn('금요일_매출_금액', F.col('금요일_매출_금액').cast(T.IntegerType())) \
.withColumn('토요일_매출_금액', F.col('토요일_매출_금액').cast(T.IntegerType())) \
.withColumn('일요일_매출_금액', F.col('일요일_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_00~06_매출_금액', F.col('시간대_00~06_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_06~11_매출_금액', F.col('시간대_06~11_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_11~14_매출_금액', F.col('시간대_11~14_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_14~17_매출_금액', F.col('시간대_14~17_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_17~21_매출_금액', F.col('시간대_17~21_매출_금액').cast(T.IntegerType())) \
.withColumn('시간대_21~24_매출_금액', F.col('시간대_21~24_매출_금액').cast(T.IntegerType())) \
.withColumn('남성_매출_금액', F.col('남성_매출_금액').cast(T.IntegerType())) \
.withColumn('여성_매출_금액', F.col('여성_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_금액', F.col('연령대_10_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_금액', F.col('연령대_20_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_금액', F.col('연령대_30_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_금액', F.col('연령대_40_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_금액', F.col('연령대_50_매출_금액').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_금액', F.col('연령대_60_이상_매출_금액').cast(T.IntegerType()))


# 매출 건수
df_2020 = df_2020 \
.withColumn('주중_매출_건수', F.col('주중_매출_건수').cast(T.IntegerType())) \
.withColumn('주말_매출_건수', F.col('주말_매출_건수').cast(T.IntegerType())) \
.withColumn('월요일_매출_건수', F.col('월요일_매출_건수').cast(T.IntegerType())) \
.withColumn('화요일_매출_건수', F.col('화요일_매출_건수').cast(T.IntegerType())) \
.withColumn('수요일_매출_건수', F.col('수요일_매출_건수').cast(T.IntegerType())) \
.withColumn('목요일_매출_건수', F.col('목요일_매출_건수').cast(T.IntegerType())) \
.withColumn('금요일_매출_건수', F.col('금요일_매출_건수').cast(T.IntegerType())) \
.withColumn('토요일_매출_건수', F.col('토요일_매출_건수').cast(T.IntegerType())) \
.withColumn('일요일_매출_건수', F.col('일요일_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~06_매출_건수', F.col('시간대_건수~06_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~11_매출_건수', F.col('시간대_건수~11_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~14_매출_건수', F.col('시간대_건수~14_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~17_매출_건수', F.col('시간대_건수~17_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~21_매출_건수', F.col('시간대_건수~21_매출_건수').cast(T.IntegerType())) \
.withColumn('시간대_건수~24_매출_건수', F.col('시간대_건수~24_매출_건수').cast(T.IntegerType())) \
.withColumn('남성_매출_건수', F.col('남성_매출_건수').cast(T.IntegerType())) \
.withColumn('여성_매출_건수', F.col('여성_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_10_매출_건수', F.col('연령대_10_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_20_매출_건수', F.col('연령대_20_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_30_매출_건수', F.col('연령대_30_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_40_매출_건수', F.col('연령대_40_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_50_매출_건수', F.col('연령대_50_매출_건수').cast(T.IntegerType())) \
.withColumn('연령대_60_이상_매출_건수', F.col('연령대_60_이상_매출_건수').cast(T.IntegerType()))

df_2020 = df_2020.withColumn('점포수', F.col('점포수').cast(T.IntegerType()))

# %%
df_2020.printSchema()
# Out:
# root
#  |-- 기준_년_코드: string (nullable = true)
#  |-- 기준_분기_코드: string (nullable = true)
#  |-- 상권_구분_코드: string (nullable = true)
#  |-- 상권_구분_코드_명: string (nullable = true)
#  |-- 상권_코드: string (nullable = true)
#  |-- 상권_코드_명: string (nullable = true)
#  |-- 서비스_업종_코드: string (nullable = true)
#  |-- 서비스_업종_코드_명: string (nullable = true)
#  |-- 분기당_매출_금액: integer (nullable = true)
#  |-- 분기당_매출_건수: integer (nullable = true)
#  |-- 주중_매출_비율: integer (nullable = true)
#  |-- 주말_매출_비율: integer (nullable = true)
#  |-- 월요일_매출_비율: integer (nullable = true)
#  |-- 화요일_매출_비율: integer (nullable = true)
#  |-- 수요일_매출_비율: integer (nullable = true)
#  |-- 목요일_매출_비율: integer (nullable = true)
#  |-- 금요일_매출_비율: integer (nullable = true)
#  |-- 토요일_매출_비율: integer (nullable = true)
#  |-- 일요일_매출_비율: integer (nullable = true)
#  |-- 시간대_00~06_매출_비율: integer (nullable = true)
#  |-- 시간대_06~11_매출_비율: integer (nullable = true)
#  |-- 시간대_11~14_매출_비율: integer (nullable = true)
# ...

# %% [markdown]
# # Null 값 확인

# %% [markdown]
# * 상권_구분_코드_명
# * 상권_코드_명
# * 서비스_업종_코드_명

# %%
df_2016.where(F.col('상권_구분_코드_명').isNull()==True).count()
df_2017.where(F.col('상권_구분_코드_명').isNull()==True).count()
df_2018.where(F.col('상권_구분_코드_명').isNull()==True).count()
df_2019.where(F.col('상권_구분_코드_명').isNull()==True).count()
df_2020.where(F.col('상권_구분_코드_명').isNull()==True).count()
# Out:
# 21/11/16 21:29:03 WARN Utils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.debug.maxToStringFields' in SparkEnv.conf.
# 0

# %%
df_2016.where(F.col('상권_코드_명').isNull()==True).count()
df_2017.where(F.col('상권_코드_명').isNull()==True).count()
df_2018.where(F.col('상권_코드_명').isNull()==True).count()
df_2019.where(F.col('상권_코드_명').isNull()==True).count()
df_2020.where(F.col('상권_코드_명').isNull()==True).count()
# Out:
# 0

# %%
df_2016.where(F.col('서비스_업종_코드_명').isNull()==True).count()
df_2017.where(F.col('서비스_업종_코드_명').isNull()==True).count()
df_2018.where(F.col('서비스_업종_코드_명').isNull()==True).count()
df_2019.where(F.col('서비스_업종_코드_명').isNull()==True).count()
df_2020.where(F.col('서비스_업종_코드_명').isNull()==True).count()
# Out:
# 0

# %%
# df_2016.where(F.col('분기당_매출_금액').isNull()==True).count()
# df_2017.where(F.col('분기당_매출_금액').isNull()).count()
# df_2018.where(F.col('분기당_매출_금액').isNull()).count()
# df_2019.where(F.col('분기당_매출_금액').isNull()).count()
df_2020.where(F.col('분기당_매출_금액').isNull()).count()
# Out:
# 5680

# %%
df_2016.where(F.col('분기당_매출_건수').isNull()==True).count()
df_2017.where(F.col('분기당_매출_건수').isNull()==True).count()
df_2018.where(F.col('분기당_매출_건수').isNull()==True).count()
df_2019.where(F.col('분기당_매출_건수').isNull()==True).count()
df_2020.where(F.col('분기당_매출_건수').isNull()==True).count()
# Out:
# 0

# %% [markdown]
# # 상권, 업종별 알바 시간

# %%
# 주중 매출 비율, 주말 매출 비율
df_sales_mean = df_2016.groupby('서비스_업종_코드_명')\
    .agg(F.round(F.mean('주중_매출_비율'), 3).alias('2016_주중_평균_매출_비율'),\
        F.round(F.mean('주말_매출_비율'), 3).alias('2016_주말_평균_매출_비율'))

tmp = df_2017.groupby('서비스_업종_코드_명')\
    .agg(F.round(F.mean('주중_매출_비율'), 3).alias('2017_주중_평균_매출_비율'),\
        F.round(F.mean('주말_매출_비율'), 3).alias('2017_주말_평균_매출_비율'))

df_sales_mean = df_sales_mean.join(tmp, how='outer', on='서비스_업종_코드_명')

df_sales_mean.show()
# Out:
# +----------------------+------------------------+------------------------+------------------------+------------------------+
# |   서비스_업종_코드_명|2016_주중_평균_매출_비율|2016_주말_평균_매출_비율|2017_주중_평균_매출_비율|2017_주말_평균_매출_비율|
# +----------------------+------------------------+------------------------+------------------------+------------------------+
# |                  악기|                  78.996|                  21.078|                  79.146|                  20.912|
# |          일반교습학원|                  87.956|                  12.121|                  87.793|                  12.279|
# |                  완구|                  62.981|                  37.117|                  59.858|                  40.239|
# |자전거 및 기타운송장비|                  64.282|                  35.791|                  65.356|                  34.737|
# |             커피-음료|                  74.412|                  25.693|                  74.373|                  25.723|
# ...

# %%
tmp = df_2018.groupby('서비스_업종_코드_명')\
    .agg(F.round(F.mean('주중_매출_비율'), 3).alias('2018_주중_평균_매출_비율'),\
        F.round(F.mean('주말_매출_비율'), 3).alias('2018_주말_평균_매출_비율'))

df_sales_mean = df_sales_mean.join(tmp, how='outer', on='서비스_업종_코드_명')

df_sales_mean.show()
# Out:
# +----------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+
# |   서비스_업종_코드_명|2016_주중_평균_매출_비율|2016_주말_평균_매출_비율|2017_주중_평균_매출_비율|2017_주말_평균_매출_비율|2018_주중_평균_매출_비율|2018_주말_평균_매출_비율|
# +----------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+
# |                  악기|                  78.996|                  21.078|                  79.146|                  20.912|                  79.385|                  20.668|
# |          일반교습학원|                  87.956|                  12.121|                  87.793|                  12.279|                  87.609|                  12.459|
# |                  완구|                  62.981|                  37.117|                  59.858|                  40.239|                  62.463|                  37.618|
# ...

# %%
tmp = df_2019.groupby('서비스_업종_코드_명')\
    .agg(F.round(F.mean('주중_매출_비율'), 3).alias('2019_주중_평균_매출_비율'),\
        F.round(F.mean('주말_매출_비율'), 3).alias('2019_주말_평균_매출_비율'))

df_sales_mean = df_sales_mean.join(tmp, how='outer', on='서비스_업종_코드_명')

df_sales_mean.show()
# Out:
# +----------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+
# |   서비스_업종_코드_명|2016_주중_평균_매출_비율|2016_주말_평균_매출_비율|2017_주중_평균_매출_비율|2017_주말_평균_매출_비율|2018_주중_평균_매출_비율|2018_주말_평균_매출_비율|2019_주중_평균_매출_비율|2019_주말_평균_매출_비율|
# +----------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+
# |                  악기|                  78.996|                  21.078|                  79.146|                  20.912|                  79.385|                  20.668|                    null|                    null|
# ...

# %%
# null인 데이터 -> 2019년에만 존재
df_sales_mean.where(F.col('2019_주중_평균_매출_비율').isNull()).count()
# Out:
# 18

# %%
# null인 데이터 -> 일단 0으로 대체
df_sales_mean = df_sales_mean.fillna(0, subset=['2019_주중_평균_매출_비율', '2019_주말_평균_매출_비율'])
df_sales_mean.show()

df_sales_mean.where(F.col('2019_주중_평균_매출_비율').isNull()).count()
# Out:
# +----------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+
# |   서비스_업종_코드_명|2016_주중_평균_매출_비율|2016_주말_평균_매출_비율|2017_주중_평균_매출_비율|2017_주말_평균_매출_비율|2018_주중_평균_매출_비율|2018_주말_평균_매출_비율|2019_주중_평균_매출_비율|2019_주말_평균_매출_비율|
# +----------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+
# |                  악기|                  78.996|                  21.078|                  79.146|                  20.912|                  79.385|                  20.668|                     0.0|                     0.0|
# ...

# %%
df_sales_mean = df_sales_mean.withColumn('주중_평균_매출_비율', \
                         (F.col('2016_주중_평균_매출_비율') + F.col('2017_주중_평균_매출_비율') +\
                         F.col('2018_주중_평균_매출_비율') + F.col('2019_주중_평균_매출_비율'))/4)
# Out:
# [Stage 176:========================================>            (153 + 9) / 200]
# +----------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+-------------------+
# |   서비스_업종_코드_명|2016_주중_평균_매출_비율|2016_주말_평균_매출_비율|2017_주중_평균_매출_비율|2017_주말_평균_매출_비율|2018_주중_평균_매출_비율|2018_주말_평균_매출_비율|2019_주중_평균_매출_비율|2019_주말_평균_매출_비율|주중_평균_매출_비율|
# +----------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+-------------------+
# |                  악기|                  78.996|                  21.078|                  79.146|                  20.912|                  79.385|                  20.668|                     0.0|                     0.0|           59.38175|
# ...

# %%
df_sales_mean = df_sales_mean.withColumn('주말_평균_매출_비율', \
                         (F.col('2016_주말_평균_매출_비율') + F.col('2017_주말_평균_매출_비율') +\
                         F.col('2018_주말_평균_매출_비율') + F.col('2019_주말_평균_매출_비율'))/4)

# %%
df_sales_mean.select('서비스_업종_코드_명', '주중_평균_매출_비율', '주말_평균_매출_비율').show()
# Out:
# [Stage 232:===============================================>     (179 + 8) / 200]
# +----------------------+-------------------+-------------------+
# |   서비스_업종_코드_명|주중_평균_매출_비율|주말_평균_매출_비율|
# +----------------------+-------------------+-------------------+
# |                  악기|           59.38175| 15.664499999999999|
# |          일반교습학원|            87.9945|           12.07275|
# |                  완구|           62.06375| 38.028999999999996|
# |자전거 및 기타운송장비|           65.03425|             35.053|
# |             커피-음료|           74.51675| 25.583999999999996|
# |              육류판매|  71.06949999999999|             29.028|
# |                  문구|            85.6025|           14.48225|
# |            스포츠클럽|  89.35549999999999| 10.713000000000001|
# |            자동차수리|             80.555|           19.53975|
# |                  신발|  72.96424999999999| 27.127000000000002|
# |                  안경|  73.60775000000001|           26.49125|
# ...
