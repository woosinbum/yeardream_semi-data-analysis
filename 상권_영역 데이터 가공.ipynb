# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
def read_files_spark(local_dir,header):
    df = spark.read.csv(local_dir,encoding='cp949',header=header)
    return df

# %%
from pyspark.sql import SparkSession
import databricks.koalas as ks

spark = SparkSession.builder.getOrCreate()
# Out:
# WARNING:root:Found numpy version "1.20.1" installed with pyspark version "2.4.8". Some functions will not work well with this combination of numpy version "1.20.1" and pyspark version "2.4.8". Please try to upgrade pyspark version to 3.1 or above, or downgrade numpy version to below 1.20.
# WARNING:root:'ARROW_PRE_0_15_IPC_FORMAT' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=0.15 and pyspark<3.0. Koalas will set it for you but it does not work if there is a Spark context already launched.
# WARNING:root:'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. Koalas will set it for you but it does not work if there is a Spark context already launched.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://host.docker.internal:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.8</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ----------------

# %% [markdown]
# ### 상권-영역 데이터 API호출 및 CSV생성

# %%
auth_key = '6f666551526a6f6132345a62664e58'
change_keys = {"TRDAR_SE_CD":"상권_구분_코드","TRDAR_SE_CD_NM":"상권_구분_코드_명","TRDAR_CD":"상권_코드","TRDAR_CD_NM":"상권_코드_명","XCNTS_VALUE":"엑스좌표_값","YDNTS_VALUE":"와이좌표_값","SIGNGU_CD":"시군구_코드","ADSTRD_CD":"행정동_코드","STDR_YM_CD":"기준_년월_코드"}

start, end  = 1, 1000
df = pd.DataFrame()
for i in range(2):
    url = f'http://openapi.seoul.go.kr:8088/{auth_key}/json/TbgisTrdarRelm/{start}/{end}/'
    res = requests.get(url)
    data = res.json()['TbgisTrdarRelm']['row']
    data = [{change_keys[k]:v for k,v in row.items()} for row in data]

    df = pd.concat([df,pd.json_normalize(data)])
            
    start += 1000
    end += 1000

df.to_csv("./상권-영역/서울시 우리마을가게 상권분석서비스(상권영역).csv", index=None, encoding='cp949')

# %%
df
# Out:
#     상권_구분_코드 상권_구분_코드_명    상권_코드       상권_코드_명  엑스좌표_값  와이좌표_값 시군구_코드  \
# 0          A       골목상권  1000275        보문로26길  201886  454183  11290
# 1          A       골목상권  1000276        보문로31길  201385  454290  11290
# 2          D       발달상권  1001045  동작구 총신대입구역_1  198304  442948  11590
# 3          D       발달상권  1001046  서울 관악구 신림역_4  193828  443001  11620
# 4          D       발달상권  1001047       뱅뱅사거리_1  202960  443242  11680
# ..       ...        ...      ...           ...     ...     ...    ...
# 491        D       발달상권  1001153         당산역_1  191112  448327  11560
# 492        D       발달상권  1001154     용산 전자상가_4  196450  448406  11170
# 493        D       발달상권  1001155     용산 전자상가_5  196870  448350  11170
# 494        D       발달상권  1001156    서울 강동구 길동역  212214  448512  11740
# 495        D       발달상권  1001120     도산공원사거리_1  202754  446796  11680
#
#        행정동_코드 기준_년월_코드
# 0    11290600   201810
# 1    11290555   201810
# 2    11590630   201810
# 3    11620695   201810
# 4    11680655   201810
# ..        ...      ...
# 491  11560620   201810
# 492  11170560   201810
# 493  11170560   201810
# 494  11740685   201810
# 495  11680545   201810
#
# [1496 rows x 9 columns]

# %% [markdown]
# ### 좌표 변환 모듈 설치 및 import

# %%
# !pip install pyproj
# Out:
# Requirement already satisfied: pyproj in c:\users\joach\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: certifi in c:\users\joach\anaconda3\lib\site-packages (from pyproj) (2020.12.5)

# %%
from pyproj import Transformer

# %% [markdown]
# #### 도로명 주소에서 위도,경도 좌표로 변환

# %%
# from EPSG5181(GR80) to EPSG4326(WGS84)
transformer = Transformer.from_crs("EPSG:5181", "EPSG:4326")

# %%
DataFrame = df.copy()

long_list = []
lat_list = []

for idx, row in DataFrame.iterrows():
    x, y = row['엑스좌표_값'], row['와이좌표_값']
    latitude, longitude = transformer.transform(y, x)
    long_list.append(longitude)
    lat_list.append(latitude)

# %%
df['위도'] = lat_list
df['경도'] = long_list

# %%
df = df.drop(columns=['기준_년월_코드','상권_구분_코드'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-f2e99842a437> in <module>
# ----> 1 df = df.drop(columns=['기준_년월_코드','상권_구분_코드'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['기준_년월_코드' '상권_구분_코드'] not found in axis"

# %%
df
# Out:
#     상권_구분_코드_명    상권_코드       상권_코드_명  엑스좌표_값  와이좌표_값 시군구_코드    행정동_코드  \
# 0         골목상권  1000275        보문로26길  201886  454183  11290  11290600
# 1         골목상권  1000276        보문로31길  201385  454290  11290  11290555
# 2         발달상권  1001045  동작구 총신대입구역_1  198304  442948  11590  11590630
# 3         발달상권  1001046  서울 관악구 신림역_4  193828  443001  11620  11620695
# 4         발달상권  1001047       뱅뱅사거리_1  202960  443242  11680  11680655
# ..         ...      ...           ...     ...     ...    ...       ...
# 491       발달상권  1001153         당산역_1  191112  448327  11560  11560620
# 492       발달상권  1001154     용산 전자상가_4  196450  448406  11170  11170560
# 493       발달상권  1001155     용산 전자상가_5  196870  448350  11170  11170560
# 494       발달상권  1001156    서울 강동구 길동역  212214  448512  11740  11740685
# 495       발달상권  1001120     도산공원사거리_1  202754  446796  11680  11680545
#
#             위도          경도
# 0    37.587205  127.021354
# 1    37.588170  127.015681
# 2    37.485978  126.980824
# 3    37.486436  126.930214
# 4    37.488623  127.033469
# ..         ...         ...
# 491  37.534401  126.899440
# 492  37.535149  126.959834
# 493  37.534646  126.964587
# 494  37.536030  127.138194
# 495  37.520646  127.031153
#
# [1496 rows x 9 columns]

# %%
df.to_csv("./상권-영역/서울시 우리마을가게 상권분석서비스(상권영역)-위도,경도 추가.csv", index=None, encoding='cp949')

# %%
df = df.astype({"상권_구분_코드_명":str,"상권_코드":int,"상권_코드_명":str,"엑스좌표_값":int,"와이좌표_값":int,"시군구_코드":int,"행정동_코드":int,"위도":float,"경도":float})

# %%
df.dtypes
# Out:
# 상권_구분_코드_명     object
# 상권_코드           int32
# 상권_코드_명        object
# 엑스좌표_값          int32
# 와이좌표_값          int32
# 시군구_코드          int32
# 행정동_코드          int32
# 위도            float64
# 경도            float64
# dtype: object

# %%
import pymongo

# %%
connection = pymongo.MongoClient("mongodb+srv://user1:uZGuuMyRngM3izgG@cluster0.cu0c3.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
connection.list_database_names()
# Out:
# ['elice', 'admin', 'local']

# %%
db = connection.get_database("elice")

# %%
collection = db.get_collection("area_info")

# %%
df.to_dict('records')
# Out:
# [{'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000275,
#   '상권_코드_명': '보문로26길',
#   '엑스좌표_값': 201886,
#   '와이좌표_값': 454183,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290600,
#   '위도': 37.58720469334632,
#   '경도': 127.02135356029717},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000276,
#   '상권_코드_명': '보문로31길',
#   '엑스좌표_값': 201385,
#   '와이좌표_값': 454290,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290555,
#   '위도': 37.58816964537452,
#   '경도': 127.01568136950489},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001045,
#   '상권_코드_명': '동작구 총신대입구역_1',
#   '엑스좌표_값': 198304,
#   '와이좌표_값': 442948,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590630,
#   '위도': 37.48597765914372,
#   '경도': 126.9808235857054},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001046,
#   '상권_코드_명': '서울 관악구 신림역_4',
#   '엑스좌표_값': 193828,
#   '와이좌표_값': 443001,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620695,
#   '위도': 37.486436139402514,
#   '경도': 126.9302137115341},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001047,
#   '상권_코드_명': '뱅뱅사거리_1',
#   '엑스좌표_값': 202960,
#   '와이좌표_값': 443242,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680655,
#   '위도': 37.48862343831305,
#   '경도': 127.03346945025531},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001048,
#   '상권_코드_명': '뱅뱅사거리',
#   '엑스좌표_값': 202638,
#   '와이좌표_값': 443504,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650520,
#   '위도': 37.49098505346684,
#   '경도': 127.02982945599554},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001049,
#   '상권_코드_명': '개봉동 현대아파트 인근',
#   '엑스좌표_값': 187247,
#   '와이좌표_값': 443356,
#   '시군구_코드': 11530,
#   '행정동_코드': 11530760,
#   '위도': 37.48956732297291,
#   '경도': 126.85579690602577},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001050,
#   '상권_코드_명': '교대역_1',
#   '엑스좌표_값': 201023,
#   '와이좌표_값': 443482,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650530,
#   '위도': 37.490790031276504,
#   '경도': 127.01156764763162},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001260,
#   '상권_코드_명': '창동역',
#   '엑스좌표_값': 204324,
#   '와이좌표_값': 461465,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320514,
#   '위도': 37.652806377355745,
#   '경도': 127.04899997749135},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001261,
#   '상권_코드_명': '서울 노원구 노원역_1',
#   '엑스좌표_값': 205532,
#   '와이좌표_값': 461611,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350695,
#   '위도': 37.65411533094399,
#   '경도': 127.0626902470538},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001262,
#   '상권_코드_명': '서울 노원구 노원역_2',
#   '엑스좌표_값': 205198,
#   '와이좌표_값': 461669,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350695,
#   '위도': 37.654639851230215,
#   '경도': 127.05890567576205},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001263,
#   '상권_코드_명': '서울 노원구 노원역_3',
#   '엑스좌표_값': 205516,
#   '와이좌표_값': 461822,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350640,
#   '위도': 37.65601649888629,
#   '경도': 127.0625105241541},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001217,
#   '상권_코드_명': '서울 종로구 종로5가역_1',
#   '엑스좌표_값': 200123,
#   '와이좌표_값': 452320,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110630,
#   '위도': 37.570421097077954,
#   '경도': 127.0013923109485},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001255,
#   '상권_코드_명': '서울 은평구 연신내역_3',
#   '엑스좌표_값': 192979,
#   '와이좌표_값': 457903,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380530,
#   '위도': 37.62069666168165,
#   '경도': 126.92047159847978},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001259,
#   '상권_코드_명': '서울 강북구 수유역_3',
#   '엑스좌표_값': 202401,
#   '와이좌표_값': 460138,
#   '시군구_코드': 11305,
#   '행정동_코드': 11305630,
#   '위도': 37.64085736435166,
#   '경도': 127.0272040015457},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001310,
#   '상권_코드_명': '구의시장',
#   '엑스좌표_값': 207818,
#   '와이좌표_값': 449558,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215860,
#   '위도': 37.54550242151623,
#   '경도': 127.08846716777747},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001322,
#   '상권_코드_명': '동부시장',
#   '엑스좌표_값': 204647,
#   '와이좌표_값': 451975,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230600,
#   '위도': 37.56730095286713,
#   '경도': 127.05259999071382},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001323,
#   '상권_코드_명': '답십리시장',
#   '엑스좌표_값': 205141,
#   '와이좌표_값': 452679,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230610,
#   '위도': 37.57364133312369,
#   '경도': 127.05819657291528},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001324,
#   '상권_코드_명': '전곡시장',
#   '엑스좌표_값': 206080,
#   '와이좌표_값': 453173,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230660,
#   '위도': 37.57808652423727,
#   '경도': 127.06883022580342},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001325,
#   '상권_코드_명': '청량리청과물시장',
#   '엑스좌표_값': 203815,
#   '와이좌표_값': 453397,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 37.58011691623963,
#   '경도': 127.04318987696023},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001451,
#   '상권_코드_명': '사당시장',
#   '엑스좌표_값': 197801,
#   '와이좌표_값': 442618,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590650,
#   '위도': 37.483003271393486,
#   '경도': 126.97513722688751},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001468,
#   '상권_코드_명': '남부종합시장',
#   '엑스좌표_값': 198664,
#   '와이좌표_값': 443924,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650590,
#   '위도': 37.49477208354063,
#   '경도': 126.98489227985215},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001469,
#   '상권_코드_명': '양재시장',
#   '엑스좌표_값': 203388,
#   '와이좌표_값': 442737,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650651,
#   '위도': 37.4840718777507,
#   '경도': 127.0383066275842},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001407,
#   '상권_코드_명': '등마루시장',
#   '엑스좌표_값': 187644,
#   '와이좌표_값': 450807,
#   '시군구_코드': 11500,
#   '행정동_코드': 11500520,
#   '위도': 37.556706219310875,
#   '경도': 126.86016068133681},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001408,
#   '상권_코드_명': '신월중앙시장',
#   '엑스좌표_값': 186247,
#   '와이좌표_값': 451047,
#   '시군구_코드': 11500,
#   '행정동_코드': 11500535,
#   '위도': 37.5588488207642,
#   '경도': 126.84434565394928},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001450,
#   '상권_코드_명': '남성역골목시장',
#   '엑스좌표_값': 197564,
#   '와이좌표_값': 442672,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590650,
#   '위도': 37.48348922176638,
#   '경도': 126.97245743180964},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001042,
#   '상권_코드_명': '서울 서초구 남부터미널역_3',
#   '엑스좌표_값': 201432,
#   '와이좌표_값': 443037,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650510,
#   '위도': 37.48678000320049,
#   '경도': 127.0161915795939},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001043,
#   '상권_코드_명': '동작구 총신대입구역_2',
#   '엑스좌표_값': 198499,
#   '와이좌표_값': 442941,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650621,
#   '위도': 37.48591492585732,
#   '경도': 126.98302843524853},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001044,
#   '상권_코드_명': '양재역_3',
#   '엑스좌표_값': 202755,
#   '와이좌표_값': 443008,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650520,
#   '위도': 37.48651571376833,
#   '경도': 127.03115058953671},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001030,
#   '상권_코드_명': '양재역_2',
#   '엑스좌표_값': 203216,
#   '와이좌표_값': 442691,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650651,
#   '위도': 37.48365802839606,
#   '경도': 127.0363616986534},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001031,
#   '상권_코드_명': '서울 관악구 신림역_1',
#   '엑스좌표_값': 193706,
#   '와이좌표_값': 442615,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620645,
#   '위도': 37.4829574265654,
#   '경도': 126.92883756748512},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001032,
#   '상권_코드_명': '서울 관악구 신림역_2',
#   '엑스좌표_값': 193880,
#   '와이좌표_값': 442602,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620645,
#   '위도': 37.482841464045244,
#   '경도': 126.93080498641467},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001033,
#   '상권_코드_명': '서울 서초구 남부터미널역_1',
#   '엑스좌표_값': 201661,
#   '와이좌표_값': 442764,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650510,
#   '위도': 37.48431986735238,
#   '경도': 127.01878025964147},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000379,
#   '상권_코드_명': '동일로173가길',
#   '엑스좌표_값': 206395,
#   '와이좌표_값': 458052,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350595,
#   '위도': 37.622043697935894,
#   '경도': 127.07243887072359},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000380,
#   '상권_코드_명': '동일로192길',
#   '엑스좌표_값': 206671,
#   '와이좌표_값': 458471,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350595,
#   '위도': 37.62581687022158,
#   '경도': 127.0755690585679},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000381,
#   '상권_코드_명': '동일로242길',
#   '엑스좌표_값': 205175,
#   '와이좌표_값': 463916,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350630,
#   '위도': 37.67488501157822,
#   '경도': 127.05866096147015},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000071,
#   '상권_코드_명': '이태원로54길',
#   '엑스좌표_값': 200121,
#   '와이좌표_값': 448560,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170685,
#   '위도': 37.536543574586496,
#   '경도': 127.00136905188955},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000072,
#   '상권_코드_명': '장문로45길',
#   '엑스좌표_값': 200041,
#   '와이좌표_값': 447690,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170700,
#   '위도': 37.52870487172285,
#   '경도': 127.00046384506732},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000073,
#   '상권_코드_명': '청파로47길',
#   '엑스좌표_값': 197165,
#   '와이좌표_값': 449449,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170555,
#   '위도': 37.544549114266864,
#   '경도': 126.96792002437306},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001490,
#   '상권_코드_명': '길동복조리시장',
#   '엑스좌표_값': 212698,
#   '와이좌표_값': 448781,
#   '시군구_코드': 11740,
#   '행정동_코드': 11740685,
#   '위도': 37.538447392541784,
#   '경도': 127.14367486055193},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001332,
#   '상권_코드_명': '사가정시장',
#   '엑스좌표_값': 207989,
#   '와이좌표_값': 453527,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260575,
#   '위도': 37.58126145968097,
#   '경도': 127.09044539460683},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001333,
#   '상권_코드_명': '중화제일시장',
#   '엑스좌표_값': 206662,
#   '와이좌표_값': 456140,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260630,
#   '위도': 37.604814912176174,
#   '경도': 127.07544588440813},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001334,
#   '상권_코드_명': '태능시장',
#   '엑스좌표_값': 206759,
#   '와이좌표_값': 455413,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260610,
#   '위도': 37.59826400907771,
#   '경도': 127.07653767941356},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001335,
#   '상권_코드_명': '묵1동도깨비시장',
#   '엑스좌표_값': 207147,
#   '와이좌표_값': 457479,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260620,
#   '위도': 37.616875506063934,
#   '경도': 127.0809514877725},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001336,
#   '상권_코드_명': '우림골목시장',
#   '엑스좌표_값': 208659,
#   '와이좌표_값': 455348,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260655,
#   '위도': 37.59766245247334,
#   '경도': 127.09805213757389},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001337,
#   '상권_코드_명': '유영시장',
#   '엑스좌표_값': 208553,
#   '와이좌표_값': 454672,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260660,
#   '위도': 37.591572748702255,
#   '경도': 127.09684393083963},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001338,
#   '상권_코드_명': '돈암제일시장',
#   '엑스좌표_값': 201402,
#   '와이좌표_값': 454703,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290555,
#   '위도': 37.59189071792463,
#   '경도': 127.01587463871735},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001377,
#   '상권_코드_명': '영천시장',
#   '엑스좌표_값': 196581,
#   '와이좌표_값': 452325,
#   '시군구_코드': 11410,
#   '행정동_코드': 11410520,
#   '위도': 37.5704598113684,
#   '경도': 126.96129826420189},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001057,
#   '상권_코드_명': '교대역_2',
#   '엑스좌표_값': 201412,
#   '와이좌표_값': 443757,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650510,
#   '위도': 37.493267288811936,
#   '경도': 127.01596682099772},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001058,
#   '상권_코드_명': '역삼역_1',
#   '엑스좌표_값': 203292,
#   '와이좌표_값': 443852,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680640,
#   '위도': 37.494118459450675,
#   '경도': 127.03722618303436},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001059,
#   '상권_코드_명': '교대역_3',
#   '엑스좌표_값': 201065,
#   '와이좌표_값': 443865,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650530,
#   '위도': 37.494240841590305,
#   '경도': 127.01204311976798},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001060,
#   '상권_코드_명': '가락시장',
#   '엑스좌표_값': 210036,
#   '와이좌표_값': 443852,
#   '시군구_코드': 11710,
#   '행정동_코드': 11710631,
#   '위도': 37.49406981478419,
#   '경도': 127.113487750174},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001061,
#   '상권_코드_명': '방배동카페골목',
#   '엑스좌표_값': 198796,
#   '와이좌표_값': 443913,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650590,
#   '위도': 37.49467315423672,
#   '경도': 126.98638497674007},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001062,
#   '상권_코드_명': '서울 강남구 강남역_1',
#   '엑스좌표_값': 202416,
#   '와이좌표_값': 443988,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650520,
#   '위도': 37.495346534821586,
#   '경도': 127.02732075688415},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001181,
#   '상권_코드_명': '서울 광진구 군자역',
#   '엑스좌표_값': 206935,
#   '와이좌표_값': 450796,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215730,
#   '위도': 37.55666383323358,
#   '경도': 127.07848699391494},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001123,
#   '상권_코드_명': '학동사거리_1',
#   '엑스좌표_값': 203226,
#   '와이좌표_값': 446892,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680531,
#   '위도': 37.52150923659847,
#   '경도': 127.036493181618},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001017,
#   '상권_코드_명': '관악구 사당역_3',
#   '엑스좌표_값': 198317,
#   '와이좌표_값': 441788,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620630,
#   '위도': 37.47552597828984,
#   '경도': 126.98097322504685},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001018,
#   '상권_코드_명': '포이사거리_2',
#   '엑스좌표_값': 203907,
#   '와이좌표_값': 441907,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 37.47659145589457,
#   '경도': 127.04417032889133},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001019,
#   '상권_코드_명': '포이사거리_1',
#   '엑스좌표_값': 204078,
#   '와이좌표_값': 441953,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680690,
#   '위도': 37.477005181709146,
#   '경도': 127.04610381207898},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001020,
#   '상권_코드_명': '장지역',
#   '엑스좌표_값': 210795,
#   '와이좌표_값': 441986,
#   '시군구_코드': 11710,
#   '행정동_코드': 11710642,
#   '위도': 37.477248481146304,
#   '경도': 127.12204320261074},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001021,
#   '상권_코드_명': '가산디지털단지역_1',
#   '엑스좌표_값': 189789,
#   '와이좌표_값': 441401,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545510,
#   '위도': 37.47198421841353,
#   '경도': 126.88456732142473},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001038,
#   '상권_코드_명': '구로디지탈1단지',
#   '엑스좌표_값': 190721,
#   '와이좌표_값': 442712,
#   '시군구_코드': 11530,
#   '행정동_코드': 11530540,
#   '위도': 37.48380625597272,
#   '경도': 126.89508680818014},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001039,
#   '상권_코드_명': '서울 서초구 남부터미널역_2',
#   '엑스좌표_값': 201211,
#   '와이좌표_값': 442998,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650530,
#   '위도': 37.48642892605263,
#   '경도': 127.01369267538392},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001040,
#   '상권_코드_명': '서울 관악구 신림역_3',
#   '엑스좌표_값': 193679,
#   '와이좌표_값': 442896,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620695,
#   '위도': 37.48548907432291,
#   '경도': 126.92852988341207},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001041,
#   '상권_코드_명': '서울 강남구 수서역',
#   '엑스좌표_값': 209143,
#   '와이좌표_값': 443137,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680750,
#   '위도': 37.48763689043684,
#   '경도': 127.10338078395336},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000377,
#   '상권_코드_명': '해등로16길',
#   '엑스좌표_값': 203765,
#   '와이좌표_값': 461761,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320515,
#   '위도': 37.65547574605313,
#   '경도': 127.0426668642167},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000378,
#   '상권_코드_명': '공릉로58길',
#   '엑스좌표_값': 206529,
#   '와이좌표_값': 459618,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350611,
#   '위도': 37.63615219120443,
#   '경도': 127.07397072659852},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000298,
#   '상권_코드_명': '정릉로27길',
#   '엑스좌표_값': 201136,
#   '와이좌표_값': 456377,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290630,
#   '위도': 37.60697367210774,
#   '경도': 127.01286535692006},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000299,
#   '상권_코드_명': '정릉로8길',
#   '엑스좌표_값': 199817,
#   '와이좌표_값': 456396,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290640,
#   '위도': 37.6071455432061,
#   '경도': 126.99792749494841},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000376,
#   '상권_코드_명': '우이천로4다길',
#   '엑스좌표_값': 203558,
#   '와이좌표_값': 459512,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320513,
#   '위도': 37.63521344861366,
#   '경도': 127.04031008537356},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001292,
#   '상권_코드_명': '이태원제일시장',
#   '엑스좌표_값': 198921,
#   '와이좌표_값': 448849,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170660,
#   '위도': 37.53914684239876,
#   '경도': 126.98779125338027},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001293,
#   '상권_코드_명': '보광시장',
#   '엑스좌표_값': 200033,
#   '와이좌표_값': 447503,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170700,
#   '위도': 37.52701999855625,
#   '경도': 127.00037333031572},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001278,
#   '상권_코드_명': '남평화시장',
#   '엑스좌표_값': 200955,
#   '와이좌표_값': 452181,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140615,
#   '위도': 37.56916822669786,
#   '경도': 127.010810038063},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001279,
#   '상권_코드_명': '동평화시장',
#   '엑스좌표_값': 201155,
#   '와이좌표_값': 452190,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140615,
#   '위도': 37.56924908729413,
#   '경도': 127.01307393450413},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001280,
#   '상권_코드_명': '제일평화시장',
#   '엑스좌표_값': 201022,
#   '와이좌표_값': 452093,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140615,
#   '위도': 37.568375278700614,
#   '경도': 127.01156831600028},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000300,
#   '상권_코드_명': '종암로16길',
#   '엑스좌표_값': 203263,
#   '와이좌표_값': 455409,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290705,
#   '위도': 37.59824700224238,
#   '경도': 127.03694960878664},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001281,
#   '상권_코드_명': '청평화시장',
#   '엑스좌표_값': 201326,
#   '와이좌표_값': 452228,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140615,
#   '위도': 37.569591235352874,
#   '경도': 127.01500962462404},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001282,
#   '상권_코드_명': '약수시장',
#   '엑스좌표_값': 200933,
#   '와이좌표_값': 450362,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140635,
#   '위도': 37.552779117727084,
#   '경도': 127.01055869791927},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001283,
#   '상권_코드_명': '백학시장',
#   '엑스좌표_값': 201714,
#   '와이좌표_값': 451574,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140650,
#   '위도': 37.563698082212916,
#   '경도': 127.019400052715},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001284,
#   '상권_코드_명': '서울중앙시장',
#   '엑스좌표_값': 201735,
#   '와이좌표_값': 451936,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140670,
#   '위도': 37.566959648728094,
#   '경도': 127.01963859917295},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001309,
#   '상권_코드_명': '조양시장',
#   '엑스좌표_값': 205964,
#   '와이좌표_값': 448825,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215847,
#   '위도': 37.538911952569784,
#   '경도': 127.06748167951677},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001368,
#   '상권_코드_명': '연서시장',
#   '엑스좌표_값': 193085,
#   '와이좌표_값': 457778,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380530,
#   '위도': 37.619571231155106,
#   '경도': 126.92167346415707},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001369,
#   '상권_코드_명': '갈현시장',
#   '엑스좌표_값': 192709,
#   '와이좌표_값': 458241,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380551,
#   '위도': 37.623739895187256,
#   '경도': 126.91740988335779},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001370,
#   '상권_코드_명': '역촌중앙시장',
#   '엑스좌표_값': 192603,
#   '와이좌표_값': 457080,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380552,
#   '위도': 37.613278589249596,
#   '경도': 126.91622088862053},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001371,
#   '상권_코드_명': '대조시장',
#   '엑스좌표_값': 193542,
#   '와이좌표_값': 456660,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380570,
#   '위도': 37.60950150921935,
#   '경도': 126.92685978763448},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001098,
#   '상권_코드_명': '포스코사거리_1',
#   '엑스좌표_값': 204775,
#   '와이좌표_값': 445500,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680590,
#   '위도': 37.50896055541883,
#   '경도': 127.05400674639628},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001099,
#   '상권_코드_명': '포스코사거리_2',
#   '엑스좌표_값': 204973,
#   '와이좌표_값': 445586,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680580,
#   '위도': 37.50973437396545,
#   '경도': 127.05624676889406},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001100,
#   '상권_코드_명': '강남구 논현역_3',
#   '엑스좌표_값': 201931,
#   '와이좌표_값': 445848,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680521,
#   '위도': 37.51210637798919,
#   '경도': 127.02184113245826},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001101,
#   '상권_코드_명': '선정릉역_2',
#   '엑스좌표_값': 204085,
#   '와이좌표_값': 445833,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680590,
#   '위도': 37.511964209812604,
#   '경도': 127.04620448208236},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001102,
#   '상권_코드_명': '서울 강남구 학동역_1',
#   '엑스좌표_값': 202606,
#   '와이좌표_값': 445905,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680521,
#   '위도': 37.512618291870304,
#   '경도': 127.02947611581212},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001103,
#   '상권_코드_명': '코엑스',
#   '엑스좌표_값': 205283,
#   '와이좌표_값': 445735,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680580,
#   '위도': 37.51107514837405,
#   '경도': 127.05975407071885},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001104,
#   '상권_코드_명': '삼성역_3',
#   '엑스좌표_값': 205648,
#   '와이좌표_값': 445805,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680580,
#   '위도': 37.51170369047007,
#   '경도': 127.06388298678927},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001055,
#   '상권_코드_명': '서울 서초구 서초역',
#   '엑스좌표_값': 200791,
#   '와이좌표_값': 443762,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650530,
#   '위도': 37.49331307953432,
#   '경도': 127.00894459146538},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001056,
#   '상권_코드_명': '서울 송파구 가락시장역',
#   '엑스좌표_값': 210540,
#   '와이좌표_값': 443838,
#   '시군구_코드': 11710,
#   '행정동_코드': 11710620,
#   '위도': 37.49393806173699,
#   '경도': 127.11918680395776},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001027,
#   '상권_코드_명': '가산디지털단지역_3',
#   '엑스좌표_값': 189955,
#   '와이좌표_값': 442117,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545510,
#   '위도': 37.47843725502126,
#   '경도': 126.8864341433713},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001028,
#   '상권_코드_명': '서울 관악구 서울대입구역_2',
#   '엑스좌표_값': 196006,
#   '와이좌표_값': 442715,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620575,
#   '위도': 37.48387123577071,
#   '경도': 126.95484171774832},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001029,
#   '상권_코드_명': '양재역_1',
#   '엑스좌표_값': 202809,
#   '와이좌표_값': 442502,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650651,
#   '위도': 37.48195644871718,
#   '경도': 127.0317592337244},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001011,
#   '상권_코드_명': '서울 금천구 시흥1동_4',
#   '엑스좌표_값': 191286,
#   '와이좌표_값': 439286,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545670,
#   '위도': 37.452943165976684,
#   '경도': 126.90151548643851},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001054,
#   '상권_코드_명': '서울 강남구 대치역_2',
#   '엑스좌표_값': 205280,
#   '와이좌표_값': 443785,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680600,
#   '위도': 37.49350556247691,
#   '경도': 127.05970614658726},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001012,
#   '상권_코드_명': '양재 화물트럭터미널앞_1',
#   '엑스좌표_값': 203161,
#   '와이좌표_값': 440282,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 37.46195288464275,
#   '경도': 127.03572950785127},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001013,
#   '상권_코드_명': '양재 화물트럭터미널앞_2',
#   '엑스좌표_값': 203269,
#   '와이좌표_값': 440563,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 37.46448435173673,
#   '경도': 127.0369515023419},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001014,
#   '상권_코드_명': '양재동 꽃시장',
#   '엑스좌표_값': 203547,
#   '와이좌표_값': 440820,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 37.466798926021674,
#   '경도': 127.04009514194523},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001015,
#   '상권_코드_명': '서울 금천구 독산1동_1',
#   '엑스좌표_값': 190842,
#   '와이좌표_값': 441181,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545610,
#   '위도': 37.470013027610726,
#   '경도': 126.89647392543884},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001016,
#   '상권_코드_명': '서울 관악구 대학동_1',
#   '엑스좌표_값': 194671,
#   '와이좌표_값': 441227,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620735,
#   '위도': 37.47045748675511,
#   '경도': 126.9397582692801},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000155,
#   '상권_코드_명': '아차산로78길',
#   '엑스좌표_값': 209529,
#   '와이좌표_값': 449647,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215810,
#   '위도': 37.54628821661367,
#   '경도': 127.10782968128034},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000156,
#   '상권_코드_명': '용마산로21길',
#   '엑스좌표_값': 207516,
#   '와이좌표_값': 451467,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215750,
#   '위도': 37.562704962308366,
#   '경도': 127.08506933925977},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000157,
#   '상권_코드_명': '용마산로3길',
#   '엑스좌표_값': 207500,
#   '와이좌표_값': 450785,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215750,
#   '위도': 37.55656029984123,
#   '경도': 127.0848812735163},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000158,
#   '상권_코드_명': '자양로11길',
#   '엑스좌표_값': 207326,
#   '와이좌표_값': 448272,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215820,
#   '위도': 37.53391961280386,
#   '경도': 127.08288695723225},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000295,
#   '상권_코드_명': '장월로1길',
#   '엑스좌표_값': 203962,
#   '와이좌표_값': 456285,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290725,
#   '위도': 37.606136933117284,
#   '경도': 127.04486969357842},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000296,
#   '상권_코드_명': '장위로50길',
#   '엑스좌표_값': 205038,
#   '와이좌표_값': 457231,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290780,
#   '위도': 37.61465502502365,
#   '경도': 127.05706191208294},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000297,
#   '상권_코드_명': '정릉로26길',
#   '엑스좌표_값': 201022,
#   '와이좌표_값': 456027,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290630,
#   '위도': 37.60382034084607,
#   '경도': 127.01157380260076},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001277,
#   '상권_코드_명': '방산종합시장',
#   '엑스좌표_값': 200011,
#   '와이좌표_값': 452055,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140605,
#   '위도': 37.56803346704921,
#   '경도': 127.0001245116387},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001264,
#   '상권_코드_명': '통인시장',
#   '엑스좌표_값': 197342,
#   '와이좌표_값': 453459,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110515,
#   '위도': 37.58067959801362,
#   '경도': 126.96990837264661},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001265,
#   '상권_코드_명': '광장시장',
#   '엑스좌표_값': 199948,
#   '와이좌표_값': 452270,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110615,
#   '위도': 37.569970606126326,
#   '경도': 126.99941138428245},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001266,
#   '상권_코드_명': '동대문종합시장',
#   '엑스좌표_값': 200715,
#   '와이좌표_값': 452320,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110630,
#   '위도': 37.57042082785713,
#   '경도': 127.00809351482725},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001267,
#   '상권_코드_명': '종로신진시장',
#   '엑스좌표_값': 200468,
#   '와이좌표_값': 452314,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110630,
#   '위도': 37.570366926707166,
#   '경도': 127.00529756952639},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001268,
#   '상권_코드_명': '충신시장',
#   '엑스좌표_값': 200505,
#   '와이좌표_값': 452729,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110630,
#   '위도': 37.57410603671966,
#   '경도': 127.00571668026423},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001269,
#   '상권_코드_명': '동문시장',
#   '엑스좌표_값': 200983,
#   '와이좌표_값': 452333,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110670,
#   '위도': 37.570537710296215,
#   '경도': 127.01112718531732},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001270,
#   '상권_코드_명': '창신골목시장',
#   '엑스좌표_값': 201018,
#   '와이좌표_값': 452590,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110680,
#   '위도': 37.57285322980232,
#   '경도': 127.0115237287406},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001272,
#   '상권_코드_명': '신설종합시장',
#   '엑스좌표_값': 201854,
#   '와이좌표_값': 452569,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110710,
#   '위도': 37.57266271778433,
#   '경도': 127.02098716952338},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001286,
#   '상권_코드_명': '후암시장',
#   '엑스좌표_값': 197904,
#   '와이좌표_값': 450124,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170510,
#   '위도': 37.550632831653395,
#   '경도': 126.97628039005014},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001287,
#   '상권_코드_명': '신흥시장',
#   '엑스좌표_값': 198680,
#   '와이좌표_값': 449527,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170520,
#   '위도': 37.54525530656243,
#   '경도': 126.98506315071423},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001289,
#   '상권_코드_명': '용문전통시장',
#   '엑스좌표_값': 196488,
#   '와이좌표_값': 448561,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170590,
#   '위도': 37.53654590718111,
#   '경도': 126.96026355135787},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001290,
#   '상권_코드_명': '이촌종합시장',
#   '엑스좌표_값': 197769,
#   '와이좌표_값': 446791,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170630,
#   '위도': 37.520602165174964,
#   '경도': 126.97476277019915},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001291,
#   '상권_코드_명': '이태원시장',
#   '엑스좌표_값': 199063,
#   '와이좌표_값': 448266,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170650,
#   '위도': 37.53389416451648,
#   '경도': 126.98939870878053},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001092,
#   '상권_코드_명': '강남구 논현역_1',
#   '엑스좌표_값': 201940,
#   '와이좌표_값': 445256,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650560,
#   '위도': 37.506772411794465,
#   '경도': 127.02194136821261},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001093,
#   '상권_코드_명': '신천역',
#   '엑스좌표_값': 207224,
#   '와이좌표_값': 445640,
#   '시군구_코드': 11710,
#   '행정동_코드': 11710650,
#   '위도': 37.510206048895434,
#   '경도': 127.08170705738294},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001094,
#   '상권_코드_명': '선정릉역_1',
#   '엑스좌표_값': 204141,
#   '와이좌표_값': 445689,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680590,
#   '위도': 37.51066651445342,
#   '경도': 127.04683707408867},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001095,
#   '상권_코드_명': '강남구 논현역_2',
#   '엑스좌표_값': 202208,
#   '와이좌표_값': 445400,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680521,
#   '위도': 37.50806925695847,
#   '경도': 127.02497287577978},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001288,
#   '상권_코드_명': '만리시장',
#   '엑스좌표_값': 196790,
#   '와이좌표_값': 450197,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170555,
#   '위도': 37.55128735486901,
#   '경도': 126.96367337165762},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001096,
#   '상권_코드_명': '신도림역',
#   '엑스좌표_값': 190279,
#   '와이좌표_값': 445432,
#   '시군구_코드': 11530,
#   '행정동_코드': 11530510,
#   '위도': 37.50830905050998,
#   '경도': 126.89005341254958},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001052,
#   '상권_코드_명': '뱅뱅사거리_2',
#   '엑스좌표_값': 202873,
#   '와이좌표_값': 443583,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680640,
#   '위도': 37.491696148423806,
#   '경도': 127.03248705054254},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001053,
#   '상권_코드_명': '서울 강남구 대치역_1',
#   '엑스좌표_값': 205462,
#   '와이좌표_값': 443761,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680600,
#   '위도': 37.493288262855124,
#   '경도': 127.06176402022076},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001022,
#   '상권_코드_명': '관악구 사당역_2',
#   '엑스좌표_값': 198281,
#   '와이좌표_값': 442081,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590620,
#   '위도': 37.47816587022181,
#   '경도': 126.98056555160662},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001023,
#   '상권_코드_명': '가산디지털단지역_2',
#   '엑스좌표_값': 189388,
#   '와이좌표_값': 442499,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545510,
#   '위도': 37.481872767274155,
#   '경도': 126.88001831527892},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001024,
#   '상권_코드_명': '관악구 사당역_1',
#   '엑스좌표_값': 198513,
#   '와이좌표_값': 442082,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650610,
#   '위도': 37.47817528262151,
#   '경도': 126.98318846514128},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001025,
#   '상권_코드_명': '서울 관악구 서울대입구역_1',
#   '엑스좌표_값': 195788,
#   '와이좌표_값': 442367,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620595,
#   '위도': 37.48073475833174,
#   '경도': 126.95237888491067},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001026,
#   '상권_코드_명': '구로디지털단지역',
#   '엑스좌표_값': 190126,
#   '와이좌표_값': 442380,
#   '시군구_코드': 11530,
#   '행정동_코드': 11530595,
#   '위도': 37.48080874716509,
#   '경도': 126.88836389120875},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001097,
#   '상권_코드_명': '잠실역 롯데월드',
#   '엑스좌표_값': 208671,
#   '와이좌표_값': 445771,
#   '시군구_코드': 11710,
#   '행정동_코드': 11710680,
#   '위도': 37.51137390833691,
#   '경도': 127.09807487617543},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001051,
#   '상권_코드_명': '보라매공원',
#   '엑스좌표_값': 193371,
#   '와이좌표_값': 443527,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590680,
#   '위도': 37.49117227142047,
#   '경도': 126.92504171914183},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000067,
#   '상권_코드_명': '원효로53길',
#   '엑스좌표_값': 196681,
#   '와이좌표_값': 448648,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170590,
#   '위도': 37.53733049201621,
#   '경도': 126.962446852187},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000068,
#   '상권_코드_명': '원효로89길',
#   '엑스좌표_값': 197234,
#   '와이좌표_값': 449086,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170560,
#   '위도': 37.54127869587753,
#   '경도': 126.96870217399656},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000069,
#   '상권_코드_명': '이촌로22길',
#   '엑스좌표_값': 196081,
#   '와이좌표_값': 447371,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170640,
#   '위도': 37.52582235495916,
#   '경도': 126.9556649066854},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000070,
#   '상권_코드_명': '이태원로27길',
#   '엑스좌표_값': 199453,
#   '와이좌표_값': 448497,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170650,
#   '위도': 37.53597578998269,
#   '경도': 126.9938110272278},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000152,
#   '상권_코드_명': '아차산로51길',
#   '엑스좌표_값': 207482,
#   '와이좌표_값': 448936,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215850,
#   '위도': 37.53990099747857,
#   '경도': 127.08465871524909},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000153,
#   '상권_코드_명': '아차산로55길',
#   '엑스좌표_값': 207733,
#   '와이좌표_값': 448875,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215850,
#   '위도': 37.53934931787935,
#   '경도': 127.08749813117429},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000154,
#   '상권_코드_명': '아차산로65길',
#   '엑스좌표_값': 208193,
#   '와이좌표_값': 449251,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215870,
#   '위도': 37.54273310165684,
#   '경도': 127.09270717418437},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001300,
#   '상권_코드_명': '화양제일골목시장',
#   '엑스좌표_값': 206096,
#   '와이좌표_값': 449274,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215710,
#   '위도': 37.54295657610216,
#   '경도': 127.06897896366658},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001301,
#   '상권_코드_명': '중곡제일시장',
#   '엑스좌표_값': 207176,
#   '와이좌표_값': 451590,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215740,
#   '위도': 37.56381589690654,
#   '경도': 127.08122227894687},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001302,
#   '상권_코드_명': '면곡골목시장',
#   '엑스좌표_값': 207134,
#   '와이좌표_값': 452395,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215760,
#   '위도': 37.571069232038916,
#   '경도': 127.08075472787203},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001303,
#   '상권_코드_명': '신성골목시장',
#   '엑스좌표_값': 207808,
#   '와이좌표_값': 450932,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215770,
#   '위도': 37.557882207018466,
#   '경도': 127.08836862482477},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001304,
#   '상권_코드_명': '자양골목시장',
#   '엑스좌표_값': 207042,
#   '와이좌표_값': 448309,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215820,
#   '위도': 37.53425519432588,
#   '경도': 127.0796741157871},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001305,
#   '상권_코드_명': '자양종합시장',
#   '엑스좌표_값': 206753,
#   '와이좌표_값': 448042,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215830,
#   '위도': 37.531851684331734,
#   '경도': 127.07640188035896},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001306,
#   '상권_코드_명': '노룬산골목시장',
#   '엑스좌표_값': 205742,
#   '와이좌표_값': 448568,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215847,
#   '위도': 37.53659779184103,
#   '경도': 127.06496777853715},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001307,
#   '상권_코드_명': '능동로골목시장',
#   '엑스좌표_값': 205899,
#   '와이좌표_값': 448403,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215840,
#   '위도': 37.535110151175616,
#   '경도': 127.06674282679104},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001308,
#   '상권_코드_명': '영동교골목시장',
#   '엑스좌표_값': 205654,
#   '와이좌표_값': 448727,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215847,
#   '위도': 37.53803092517618,
#   '경도': 127.06397332818047},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001273,
#   '상권_코드_명': '남대문시장',
#   '엑스좌표_값': 198091,
#   '와이좌표_값': 451149,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140540,
#   '위도': 37.55986846331072,
#   '경도': 126.97839392940769},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001274,
#   '상권_코드_명': '신중부시장',
#   '엑스좌표_값': 200023,
#   '와이좌표_값': 451785,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140590,
#   '위도': 37.56560077788206,
#   '경도': 127.00026033405094},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001275,
#   '상권_코드_명': '인현시장',
#   '엑스좌표_값': 199564,
#   '와이좌표_값': 451525,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140590,
#   '위도': 37.56325808472952,
#   '경도': 126.9950651264428},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001276,
#   '상권_코드_명': '평화시장',
#   '엑스좌표_값': 200710,
#   '와이좌표_값': 452148,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140590,
#   '위도': 37.56887111952541,
#   '경도': 127.00803675030764},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001069,
#   '상권_코드_명': '은마아파트입구사거리_3',
#   '엑스좌표_값': 205282,
#   '와이좌표_값': 444402,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680630,
#   '위도': 37.49906475931724,
#   '경도': 127.0597331901952},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001070,
#   '상권_코드_명': '은마아파트입구사거리_4',
#   '엑스좌표_값': 205466,
#   '와이좌표_값': 444479,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680610,
#   '위도': 37.49975746322555,
#   '경도': 127.06181458398488},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001071,
#   '상권_코드_명': '서울 강남구 한티역',
#   '엑스좌표_값': 204738,
#   '와이좌표_값': 444303,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680630,
#   '위도': 37.49817571394421,
#   '경도': 127.05358055707585},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001165,
#   '상권_코드_명': '서울 광진구 건대입구역_2',
#   '엑스좌표_값': 206151,
#   '와이좌표_값': 449134,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215710,
#   '위도': 37.54169481234147,
#   '경도': 127.06960014021577},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001166,
#   '상권_코드_명': '서울 마포구 마포역_2',
#   '엑스좌표_값': 195156,
#   '와이좌표_값': 449005,
#   '시군구_코드': 11440,
#   '행정동_코드': 11440590,
#   '위도': 37.54054031359572,
#   '경도': 126.94518974329746},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001167,
#   '상권_코드_명': '서울 마포구 공덕역_1',
#   '엑스좌표_값': 195722,
#   '와이좌표_값': 449271,
#   '시군구_코드': 11440,
#   '행정동_코드': 11440565,
#   '위도': 37.542939770927525,
#   '경도': 126.95159252793033},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001089,
#   '상권_코드_명': '삼정역_1',
#   '엑스좌표_값': 203222,
#   '와이좌표_값': 445342,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680640,
#   '위도': 37.50754369288381,
#   '경도': 127.03644114171418},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001090,
#   '상권_코드_명': '삼정역_2',
#   '엑스좌표_값': 203114,
#   '와이좌표_값': 445442,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680531,
#   '위도': 37.50844506812788,
#   '경도': 127.03522007445697},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001091,
#   '상권_코드_명': '삼성역_2',
#   '엑스좌표_값': 205759,
#   '와이좌표_값': 445433,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680610,
#   '위도': 37.50835126987693,
#   '경도': 127.06513556420268},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000277,
#   '상권_코드_명': '보문로32길',
#   '엑스좌표_값': 201778,
#   '와이좌표_값': 454576,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290575,
#   '위도': 37.590745808586,
#   '경도': 127.0201317226878},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000278,
#   '상권_코드_명': '삼선교로10길',
#   '엑스좌표_값': 200854,
#   '와이좌표_값': 454139,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290555,
#   '위도': 37.58680979195958,
#   '경도': 127.00966905845232},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000279,
#   '상권_코드_명': '삼선교로10다길',
#   '엑스좌표_값': 200773,
#   '와이좌표_값': 453904,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290555,
#   '위도': 37.58469252997415,
#   '경도': 127.00875172189099},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000280,
#   '상권_코드_명': '삼선교로16가길',
#   '엑스좌표_값': 201020,
#   '와이좌표_값': 453872,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290555,
#   '위도': 37.58440397169849,
#   '경도': 127.01154815247764},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000064,
#   '상권_코드_명': '우사단로4길',
#   '엑스좌표_값': 199868,
#   '와이좌표_값': 447913,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170700,
#   '위도': 37.53071409672035,
#   '경도': 126.99850660509166},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000065,
#   '상권_코드_명': '원효로19길',
#   '엑스좌표_값': 195898,
#   '와이좌표_값': 448189,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170570,
#   '위도': 37.533191750440004,
#   '경도': 126.95359008797688},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000066,
#   '상권_코드_명': '원효로41길',
#   '엑스좌표_값': 196180,
#   '와이좌표_값': 448370,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170570,
#   '위도': 37.53482377237657,
#   '경도': 126.95677968602872},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001298,
#   '상권_코드_명': '성동용답상가시장',
#   '엑스좌표_값': 204625,
#   '와이좌표_값': 451565,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200790,
#   '위도': 37.563606981029494,
#   '경도': 127.05234838492093},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001311,
#   '상권_코드_명': '동부청과시장',
#   '엑스좌표_값': 203796,
#   '와이좌표_값': 453091,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230536,
#   '위도': 37.57735995363058,
#   '경도': 127.042973192155},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001314,
#   '상권_코드_명': '경동시장',
#   '엑스좌표_값': 203447,
#   '와이좌표_값': 453307,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 37.57930747265717,
#   '경도': 127.03902330140541},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001315,
#   '상권_코드_명': '동서시장',
#   '엑스좌표_값': 203658,
#   '와이좌표_값': 453368,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 37.57985626500525,
#   '경도': 127.0414123248943},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001316,
#   '상권_코드_명': '서울약령시장',
#   '엑스좌표_값': 203313,
#   '와이좌표_값': 453621,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 37.58213708424979,
#   '경도': 127.03750771415709},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001317,
#   '상권_코드_명': '청량리농수산물시장',
#   '엑스좌표_값': 203638,
#   '와이좌표_값': 453503,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 37.58107268555848,
#   '경도': 127.04118657439247},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001318,
#   '상권_코드_명': '청량리전통시장',
#   '엑스좌표_값': 203766,
#   '와이좌표_값': 453471,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 37.5807838531397,
#   '경도': 127.04263552493434},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001319,
#   '상권_코드_명': '청량리종합시장',
#   '엑스좌표_값': 203566,
#   '와이좌표_값': 453322,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 37.57944216868575,
#   '경도': 127.04037056666714},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001320,
#   '상권_코드_명': '전농로터리시장',
#   '엑스좌표_값': 205011,
#   '와이좌표_값': 453130,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230560,
#   '위도': 37.57770553283901,
#   '경도': 127.05672804457532},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001312,
#   '상권_코드_명': '용두시장',
#   '엑스좌표_값': 202629,
#   '와이좌표_값': 453215,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230536,
#   '위도': 37.578481256301714,
#   '경도': 127.02976243882634},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001313,
#   '상권_코드_명': '청량리수산시장',
#   '엑스좌표_값': 203666,
#   '와이좌표_값': 453187,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230536,
#   '위도': 37.57822543442258,
#   '경도': 127.04150198792094},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001321,
#   '상권_코드_명': '답십리현대시장',
#   '엑스좌표_값': 205255,
#   '와이좌표_값': 451917,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230610,
#   '위도': 37.56677510875752,
#   '경도': 127.0594816021787},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001299,
#   '상권_코드_명': '한아름시장',
#   '엑스좌표_값': 206177,
#   '와이좌표_값': 449338,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215710,
#   '위도': 37.54353267640729,
#   '경도': 127.06989605257513},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001085,
#   '상권_코드_명': '서울 서초구 강남역',
#   '엑스좌표_값': 202701,
#   '와이좌표_값': 444730,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680640,
#   '위도': 37.50203121152806,
#   '경도': 127.03054633381461},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001086,
#   '상권_코드_명': '고속터미널역',
#   '엑스좌표_값': 200518,
#   '와이좌표_값': 445031,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650581,
#   '위도': 37.50474704248736,
#   '경도': 127.00585841327658},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001087,
#   '상권_코드_명': '서울 강남구 선릉역_2',
#   '엑스좌표_값': 204007,
#   '와이좌표_값': 445054,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680640,
#   '위도': 37.50494572617329,
#   '경도': 127.04531799918914},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001088,
#   '상권_코드_명': '삼성역_1',
#   '엑스좌표_값': 205337,
#   '와이좌표_값': 445247,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680610,
#   '위도': 37.50667793699713,
#   '경도': 127.06036130395252},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001066,
#   '상권_코드_명': '서울 강남구 강남역',
#   '엑스좌표_값': 202696,
#   '와이좌표_값': 444064,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680640,
#   '위도': 37.49603052520305,
#   '경도': 127.03048734774165},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001067,
#   '상권_코드_명': '오류동역',
#   '엑스좌표_값': 186098,
#   '와이좌표_값': 444015,
#   '시군구_코드': 11530,
#   '행정동_코드': 11530770,
#   '위도': 37.49548836626892,
#   '경도': 126.84279231806514},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001068,
#   '상권_코드_명': '은마아파트입구사거리_2',
#   '엑스좌표_값': 205514,
#   '와이좌표_값': 444398,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680610,
#   '위도': 37.49902736333294,
#   '경도': 127.06235680520315},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000293,
#   '상권_코드_명': '인촌로5길',
#   '엑스좌표_값': 201816,
#   '와이좌표_값': 454390,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290600,
#   '위도': 37.589069888712466,
#   '경도': 127.02056152342301},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000294,
#   '상권_코드_명': '인촌로6길',
#   '엑스좌표_값': 201886,
#   '와이좌표_값': 453709,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290610,
#   '위도': 37.58293398628817,
#   '경도': 127.02135234042038},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000212,
#   '상권_코드_명': '천호대로77길',
#   '엑스좌표_값': 205537,
#   '와이좌표_값': 451598,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230650,
#   '위도': 37.56389928147714,
#   '경도': 127.06267116438009},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000213,
#   '상권_코드_명': '천호대로97길',
#   '엑스좌표_값': 206223,
#   '와이좌표_값': 451471,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230650,
#   '위도': 37.56275063990482,
#   '경도': 127.07043465104928},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000214,
#   '상권_코드_명': '한천로14길',
#   '엑스좌표_값': 205777,
#   '와이좌표_값': 451945,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230650,
#   '위도': 37.56702426272566,
#   '경도': 127.06539036288811},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000215,
#   '상권_코드_명': '한천로33길',
#   '엑스좌표_값': 205926,
#   '와이좌표_값': 453093,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230570,
#   '위도': 37.577366732991294,
#   '경도': 127.06708618306541},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000273,
#   '상권_코드_명': '보국문로16길',
#   '엑스좌표_값': 200903,
#   '와이좌표_값': 456997,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290650,
#   '위도': 37.61256006404193,
#   '경도': 127.01022736468003},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000274,
#   '상권_코드_명': '보문로13길',
#   '엑스좌표_값': 201841,
#   '와이좌표_값': 453388,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290610,
#   '위도': 37.58004188788442,
#   '경도': 127.02084206689122},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000370,
#   '상권_코드_명': '방학로15길',
#   '엑스좌표_값': 202133,
#   '와이좌표_값': 462195,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320710,
#   '위도': 37.659391247274804,
#   '경도': 127.02417349329981},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000371,
#   '상권_코드_명': '방학로5길',
#   '엑스좌표_값': 203319,
#   '와이좌표_값': 462234,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320670,
#   '위도': 37.6597391098479,
#   '경도': 127.0376147199963},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000372,
#   '상권_코드_명': '방학로6가길',
#   '엑스좌표_값': 203292,
#   '와이좌표_값': 462755,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320690,
#   '위도': 37.664433318720725,
#   '경도': 127.03731107439158},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000373,
#   '상권_코드_명': '삼양로144길',
#   '엑스좌표_값': 201226,
#   '와이좌표_값': 461253,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320660,
#   '위도': 37.65090565207283,
#   '경도': 127.0138927944061},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000374,
#   '상권_코드_명': '시루봉로23길',
#   '엑스좌표_값': 203746,
#   '와이좌표_값': 463694,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320521,
#   '위도': 37.67289178170676,
#   '경도': 127.04246146636115},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000369,
#   '상권_코드_명': '방학로10길',
#   '엑스좌표_값': 202981,
#   '와이좌표_값': 462736,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320700,
#   '위도': 37.66426319465528,
#   '경도': 127.03378616624471},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000375,
#   '상권_코드_명': '우이천로32길',
#   '엑스좌표_값': 202238,
#   '와이좌표_값': 461174,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320660,
#   '위도': 37.65019196760325,
#   '경도': 127.02536033944621},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001326,
#   '상권_코드_명': '회기시장',
#   '엑스좌표_값': 204908,
#   '와이좌표_값': 454618,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230710,
#   '위도': 37.59111286011739,
#   '경도': 127.05557197790903},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001327,
#   '상권_코드_명': '이경시장',
#   '엑스좌표_값': 205837,
#   '와이좌표_값': 455017,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230720,
#   '위도': 37.59470239435596,
#   '경도': 127.0660939710493},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001328,
#   '상권_코드_명': '이문제일시장',
#   '엑스좌표_값': 205511,
#   '와이좌표_값': 456110,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230750,
#   '위도': 37.60455222823275,
#   '경도': 127.06241081007137},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001329,
#   '상권_코드_명': '동부골목시장',
#   '엑스좌표_값': 206792,
#   '와이좌표_값': 454766,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260590,
#   '위도': 37.59243435616141,
#   '경도': 127.07690536552167},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001330,
#   '상권_코드_명': '동원시장',
#   '엑스좌표_값': 208013,
#   '와이좌표_값': 454486,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260565,
#   '위도': 37.58990176352666,
#   '경도': 127.09072759033637},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001331,
#   '상권_코드_명': '면목골목시장',
#   '엑스좌표_값': 207494,
#   '와이좌표_값': 453154,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260570,
#   '위도': 37.57790491668717,
#   '경도': 127.08483757281584},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001285,
#   '상권_코드_명': '합동(새벽)시장',
#   '엑스좌표_값': 197137,
#   '와이좌표_값': 451173,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140680,
#   '위도': 37.56008223294128,
#   '경도': 126.9675964607861},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001294,
#   '상권_코드_명': '마장축산물시장',
#   '엑스좌표_값': 203566,
#   '와이좌표_값': 452297,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200540,
#   '위도': 37.570206975507475,
#   '경도': 127.04036558148313},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001295,
#   '상권_코드_명': '행당시장',
#   '엑스좌표_값': 202951,
#   '와이좌표_값': 451270,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200560,
#   '위도': 37.5609559222069,
#   '경도': 127.03339991642562},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001296,
#   '상권_코드_명': '금남시장',
#   '엑스좌표_값': 201970,
#   '와이좌표_값': 449892,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200615,
#   '위도': 37.54854279302089,
#   '경도': 127.02229309489861},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001297,
#   '상권_코드_명': '뚝도시장',
#   '엑스좌표_값': 204817,
#   '와이좌표_값': 448747,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200670,
#   '위도': 37.53821587578757,
#   '경도': 127.05450305757522},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001115,
#   '상권_코드_명': '서울 강남구 강남구청역_2',
#   '엑스좌표_값': 203357,
#   '와이좌표_값': 446378,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680531,
#   '위도': 37.51687761404692,
#   '경도': 127.03797273360779},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001116,
#   '상권_코드_명': '영등포역_1',
#   '엑스좌표_값': 192076,
#   '와이좌표_값': 446422,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560535,
#   '위도': 37.51724614982384,
#   '경도': 126.91036717468776},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001117,
#   '상권_코드_명': '강남구 신사역_2',
#   '엑스좌표_값': 202085,
#   '와이좌표_값': 446380,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680521,
#   '위도': 37.51689938344783,
#   '경도': 127.02358450208524},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001118,
#   '상권_코드_명': '문래동 주민센터',
#   '엑스좌표_값': 191040,
#   '와이좌표_값': 446252,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560605,
#   '위도': 37.51570497175982,
#   '경도': 126.89865048270202},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001119,
#   '상권_코드_명': '영등포역_2',
#   '엑스좌표_값': 191929,
#   '와이좌표_값': 446538,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560535,
#   '위도': 37.51829003889983,
#   '경도': 126.90870310352355},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001082,
#   '상권_코드_명': '선릉역_2',
#   '엑스좌표_값': 204689,
#   '와이좌표_값': 444957,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680630,
#   '위도': 37.50406854038104,
#   '경도': 127.05303059892454},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001083,
#   '상권_코드_명': '서울 송파구 석촌역_2',
#   '엑스좌표_값': 209524,
#   '와이좌표_값': 445199,
#   '시군구_코드': 11710,
#   '행정동_코드': 11710580,
#   '위도': 37.506211765399414,
#   '경도': 127.10771546251011},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001084,
#   '상권_코드_명': '서울 강남구 선릉역_1',
#   '엑스좌표_값': 204433,
#   '와이좌표_값': 445167,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680590,
#   '위도': 37.505961915174254,
#   '경도': 127.0501366139763},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000210,
#   '상권_코드_명': '천호대로17길',
#   '엑스좌표_값': 202858,
#   '와이좌표_값': 452970,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230536,
#   '위도': 37.57627313855811,
#   '경도': 127.03235395138553},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000211,
#   '상권_코드_명': '천호대로45길',
#   '엑스좌표_값': 203787,
#   '와이좌표_값': 452855,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230536,
#   '위도': 37.57523364435813,
#   '경도': 127.0428700872885},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000221,
#   '상권_코드_명': '휘경로3길',
#   '엑스좌표_값': 205568,
#   '와이좌표_값': 455328,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230740,
#   '위도': 37.59750614234382,
#   '경도': 127.06305037536431},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000289,
#   '상권_코드_명': '인촌로17가길',
#   '엑스좌표_값': 202091,
#   '와이좌표_값': 454230,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290600,
#   '위도': 37.587627717199915,
# ...
#   '행정동_코드': 11290705,
#   '위도': 37.600175550324316,
#   '경도': 127.03555769735354},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000304,
#   '상권_코드_명': '종암로5길',
#   '엑스좌표_값': 203019,
#   '와이좌표_값': 454873,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290705,
#   '위도': 37.593418521501405,
#   '경도': 127.03418438906162},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000305,
#   '상권_코드_명': '지봉로20길',
#   '엑스좌표_값': 201697,
#   '와이좌표_값': 453727,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290610,
#   '위도': 37.58309653275608,
#   '경도': 127.01921261957447},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000309,
#   '상권_코드_명': '화랑로13길',
#   '엑스좌표_값': 203678,
#   '와이좌표_값': 456195,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290725,
#   '위도': 37.6053272213694,
#   '경도': 127.04165293910224},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000311,
#   '상권_코드_명': '화랑로19길',
#   '엑스좌표_값': 204416,
#   '와이좌표_값': 456562,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290770,
#   '위도': 37.60863060684104,
#   '경도': 127.05001291789686},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000312,
#   '상권_코드_명': '화랑로1길',
#   '엑스좌표_값': 202972,
#   '와이좌표_값': 456141,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290715,
#   '위도': 37.60484323784302,
#   '경도': 127.03365735017576},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000041,
#   '상권_코드_명': '장충단로8길',
#   '엑스좌표_값': 200741,
#   '와이좌표_값': 451402,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140580,
#   '위도': 37.56214966423963,
#   '경도': 127.00838689708328},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000042,
#   '상권_코드_명': '청구로17길',
#   '엑스좌표_값': 201034,
#   '와이좌표_값': 451013,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140625,
#   '위도': 37.5586445042682,
#   '경도': 127.01170262527664},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000043,
#   '상권_코드_명': '청구로1길',
#   '엑스좌표_값': 201360,
#   '와이좌표_값': 450951,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140645,
#   '위도': 37.5580854626735,
#   '경도': 127.01539211939027},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000310,
#   '상권_코드_명': '화랑로14길',
#   '엑스좌표_값': 203729,
#   '와이좌표_값': 455749,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290725,
#   '위도': 37.60130860037792,
#   '경도': 127.0422282367505},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000389,
#   '상권_코드_명': '가좌로7길',
#   '엑스좌표_값': 192862,
#   '와이좌표_값': 453934,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380600,
#   '위도': 37.58493548788187,
#   '경도': 126.91918500828997},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000390,
#   '상권_코드_명': '갈현로1길',
#   '엑스좌표_값': 191901,
#   '와이좌표_값': 455542,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380631,
#   '위도': 37.599415470604995,
#   '경도': 126.90828699545541},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000352,
#   '상권_코드_명': '노해로60길',
#   '엑스좌표_값': 203002,
#   '와이좌표_값': 461043,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320680,
#   '위도': 37.64900950100889,
#   '경도': 127.03401721691714},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000353,
#   '상권_코드_명': '노해로63다길',
#   '엑스좌표_값': 204014,
#   '와이좌표_값': 461657,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320515,
#   '위도': 37.65453767028034,
#   '경도': 127.0454880844189},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000529,
#   '상권_코드_명': '목동중앙서로7길',
#   '엑스좌표_값': 188084,
#   '와이좌표_값': 448328,
#   '시군구_코드': 11470,
#   '행정동_코드': 11470540,
#   '위도': 37.53437630492295,
#   '경도': 126.86518060911823},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000530,
#   '상권_코드_명': '목동중앙서로8가길',
#   '엑스좌표_값': 188068,
#   '와이좌표_값': 447995,
#   '시군구_코드': 11470,
#   '행정동_코드': 11470540,
#   '위도': 37.531375772815636,
#   '경도': 126.86500499115456},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000531,
#   '상권_코드_명': '신목로2길',
#   '엑스좌표_값': 189014,
#   '와이좌표_값': 446703,
#   '시군구_코드': 11470,
#   '행정동_코드': 11470630,
#   '위도': 37.5197466006671,
#   '경도': 126.87572703427178},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000118,
#   '상권_코드_명': '왕십리로26길',
#   '엑스좌표_값': 202889,
#   '와이좌표_값': 451635,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200535,
#   '위도': 37.56424475550748,
#   '경도': 127.03269962738138},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000095,
#   '상권_코드_명': '마조로16길',
#   '엑스좌표_값': 203961,
#   '와이좌표_값': 451778,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200540,
#   '위도': 37.5655291955643,
#   '경도': 127.04483400702887},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000096,
#   '상권_코드_명': '마조로1길',
#   '엑스좌표_값': 203530,
#   '와이좌표_값': 451337,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200550,
#   '위도': 37.561557554176645,
#   '경도': 127.03995345723395},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000097,
#   '상권_코드_명': '매봉길',
#   '엑스좌표_값': 201211,
#   '와이좌표_값': 449778,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200645,
#   '위도': 37.54751696364525,
#   '경도': 127.0137038416579},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000098,
#   '상권_코드_명': '무수막길',
#   '엑스좌표_값': 201844,
#   '와이좌표_값': 450369,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200615,
#   '위도': 37.55284081556082,
#   '경도': 127.02086844044004},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000099,
#   '상권_코드_명': '무학로6길',
#   '엑스좌표_값': 202959,
#   '와이좌표_값': 451797,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200535,
#   '위도': 37.56570414697989,
#   '경도': 127.03349258737882},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000100,
#   '상권_코드_명': '무학봉28길',
#   '엑스좌표_값': 202825,
#   '와이좌표_값': 451396,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200520,
#   '위도': 37.562091572705945,
#   '경도': 127.031974312506},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000101,
#   '상권_코드_명': '무학봉길',
#   '엑스좌표_값': 202542,
#   '와이좌표_값': 451232,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200520,
#   '위도': 37.56061476224366,
#   '경도': 127.02877065426908},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000678,
#   '상권_코드_명': '시흥대로62가길',
#   '엑스좌표_값': 191516,
#   '와이좌표_값': 439656,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545670,
#   '위도': 37.45627904718531,
#   '경도': 126.90411065768251},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000679,
#   '상권_코드_명': '시흥대로63길',
#   '엑스좌표_값': 190993,
#   '와이좌표_값': 439529,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545670,
#   '위도': 37.45512981860987,
#   '경도': 126.89820107525821},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000714,
#   '상권_코드_명': '신길로17길',
#   '엑스좌표_값': 191729,
#   '와이좌표_값': 444251,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560670,
#   '위도': 37.497682313890735,
#   '경도': 126.90646647588949},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000715,
#   '상권_코드_명': '신길로39길',
#   '엑스좌표_값': 191864,
#   '와이좌표_값': 445355,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560650,
#   '위도': 37.507630603042216,
#   '경도': 126.90798092965898},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000716,
#   '상권_코드_명': '신길로42가길',
#   '엑스좌표_값': 192439,
#   '와이좌표_값': 445537,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560630,
#   '위도': 37.509275317074035,
#   '경도': 126.91448236642141},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000717,
#   '상권_코드_명': '신길로42길',
#   '엑스좌표_값': 192317,
#   '와이좌표_값': 445241,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560660,
#   '위도': 37.50660733856764,
#   '경도': 126.91310559537058},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000808,
#   '상권_코드_명': '법원단지9길',
#   '엑스좌표_값': 193119,
#   '와이좌표_값': 441729,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620775,
#   '위도': 37.4749703074004,
#   '경도': 126.92220899630287},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000812,
#   '상권_코드_명': '봉천로33길',
#   '엑스좌표_값': 195052,
#   '와이좌표_값': 442764,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620605,
#   '위도': 37.48430811470407,
#   '경도': 126.94405496284341},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000813,
#   '상권_코드_명': '서림7길',
#   '엑스좌표_값': 194723,
#   '와이좌표_값': 441441,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620665,
#   '위도': 37.472385946388286,
#   '경도': 126.94034457112895},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000814,
#   '상권_코드_명': '승방길',
#   '엑스좌표_값': 198228,
#   '와이좌표_값': 441524,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620630,
#   '위도': 37.47314714560136,
#   '경도': 126.9799676906516},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000928,
#   '상권_코드_명': '선릉로18길',
#   '엑스좌표_값': 205444,
#   '와이좌표_값': 442663,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680670,
#   '위도': 37.4833953079835,
#   '경도': 127.06155235940356},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000929,
#   '상권_코드_명': '압구정로2길',
#   '엑스좌표_값': 201728,
#   '와이좌표_값': 446846,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680510,
#   '위도': 37.52109879550894,
#   '경도': 127.01954738784833},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000930,
#   '상권_코드_명': '언주로81길',
#   '엑스좌표_값': 203657,
#   '와이좌표_값': 444381,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680650,
#   '위도': 37.49888341076538,
#   '경도': 127.04135625779246},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000499,
#   '상권_코드_명': '월드컵로16길',
#   '엑스좌표_값': 192138,
#   '와이좌표_값': 450868,
#   '시군구_코드': 11440,
#   '행정동_코드': 11440660,
#   '위도': 37.55730511043558,
#   '경도': 126.91102090556349},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000867,
#   '상권_코드_명': '사평대로26길',
#   '엑스좌표_값': 199919,
#   '와이좌표_값': 444457,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650581,
#   '위도': 37.499575410941276,
#   '경도': 126.99908397925343},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000868,
#   '상권_코드_명': '사평대로57길',
#   '엑스좌표_값': 201876,
#   '와이좌표_값': 445325,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650560,
#   '위도': 37.50739423746393,
#   '경도': 127.02121770526344},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000869,
#   '상권_코드_명': '서초대로15길',
#   '엑스좌표_값': 199030,
#   '와이좌표_값': 443314,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650621,
#   '위도': 37.489276395611654,
#   '경도': 126.98903187507891},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000552,
#   '상권_코드_명': '가로공원로76가길',
#   '엑스좌표_값': 185909,
#   '와이좌표_값': 448257,
#   '시군구_코드': 11500,
#   '행정동_코드': 11500540,
#   '위도': 37.53370593974615,
#   '경도': 126.84057377888907},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000553,
#   '상권_코드_명': '가로공원로80길',
#   '엑스좌표_값': 185846,
#   '와이좌표_값': 448560,
#   '시군구_코드': 11500,
#   '행정동_코드': 11500540,
#   '위도': 37.53643499697612,
#   '경도': 126.83985515881274},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000624,
#   '상권_코드_명': '고척로52길',
#   '엑스좌표_값': 187266,
#   '와이좌표_값': 444683,
#   '시군구_코드': 11530,
#   '행정동_코드': 11530720,
#   '위도': 37.50152390747052,
#   '경도': 126.85598878903117},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000006,
#   '상권_코드_명': '북촌로11길',
#   '엑스좌표_값': 198602,
#   '와이좌표_값': 453529,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110600,
#   '위도': 37.58131306801902,
#   '경도': 126.98417289246329},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000007,
#   '상권_코드_명': '북촌로5길',
#   '엑스좌표_값': 198383,
#   '와이좌표_값': 453422,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110540,
#   '위도': 37.58034864628062,
#   '경도': 126.9816937748628},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000137,
#   '상권_코드_명': '능동로13길',
#   '엑스좌표_값': 206086,
#   '와이좌표_값': 449515,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215710,
#   '위도': 37.545128049103546,
#   '경도': 127.06886780666939},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000138,
#   '상권_코드_명': '능동로19길',
#   '엑스좌표_값': 206369,
#   '와이좌표_값': 449653,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215710,
#   '위도': 37.546369515836325,
#   '경도': 127.07207136574804},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000139,
#   '상권_코드_명': '능동로34길',
#   '엑스좌표_값': 207316,
#   '와이좌표_값': 450510,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215780,
#   '위도': 37.554084037542566,
#   '경도': 127.082796113612},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000231,
#   '상권_코드_명': '동일로123길',
#   '엑스좌표_값': 206965,
#   '와이좌표_값': 455458,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260610,
#   '위도': 37.5986679189065,
#   '경도': 127.07887081170279},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000831,
#   '상권_코드_명': '조원중앙로2길',
#   '엑스좌표_값': 191933,
#   '와이좌표_값': 442499,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620725,
#   '위도': 37.4818984832819,
#   '경도': 126.90879262527073},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000832,
#   '상권_코드_명': '중앙길',
#   '엑스좌표_값': 195647,
#   '와이좌표_값': 442864,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620615,
#   '위도': 37.48521211679205,
#   '경도': 126.95078179399408},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000833,
#   '상권_코드_명': '청룡8길',
#   '엑스좌표_값': 194960,
#   '와이좌표_값': 442335,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620595,
#   '위도': 37.48044229165424,
#   '경도': 126.94301769195768},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000809,
#   '상권_코드_명': '법원단지길',
#   '엑스좌표_값': 192885,
#   '와이좌표_값': 441644,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620775,
#   '위도': 37.47420267842053,
#   '경도': 126.91956440524902},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000810,
#   '상권_코드_명': '복은길',
#   '엑스좌표_값': 194616,
#   '와이좌표_값': 441668,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620665,
#   '위도': 37.47443062149265,
#   '경도': 126.93913329960627},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000855,
#   '상권_코드_명': '동광로39길',
#   '엑스좌표_값': 199980,
#   '와이좌표_값': 444218,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650581,
#   '위도': 37.497422009086804,
#   '경도': 126.99977382853267},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000856,
#   '상권_코드_명': '동산로10길',
#   '엑스좌표_값': 204021,
#   '와이좌표_값': 441216,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 37.47036498869084,
#   '경도': 127.04545537732939},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000857,
#   '상권_코드_명': '동산로19길',
#   '엑스좌표_값': 204097,
#   '와이좌표_값': 441586,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 37.47369839247095,
#   '경도': 127.04631657576508},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000858,
#   '상권_코드_명': '방배천로4안길',
#   '엑스좌표_값': 198534,
#   '와이좌표_값': 442403,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650610,
#   '위도': 37.48106755570759,
#   '경도': 126.98342524544262},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000859,
#   '상권_코드_명': '마방로2길',
#   '엑스좌표_값': 203516,
#   '와이좌표_값': 441384,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 37.47188074416293,
#   '경도': 127.03974740984224},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000549,
#   '상권_코드_명': '지양로7길',
#   '엑스좌표_값': 185169,
#   '와이좌표_값': 446879,
#   '시군구_코드': 11470,
#   '행정동_코드': 11470611,
#   '위도': 37.5212785873856,
#   '경도': 126.83222922554914},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000500,
#   '상권_코드_명': '월드컵로19길',
#   '엑스좌표_값': 191895,
#   '와이좌표_값': 450786,
#   '시군구_코드': 11440,
#   '행정동_코드': 11440690,
#   '위도': 37.55656418891049,
#   '경도': 126.90827163378137},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000576,
#   '상권_코드_명': '공항대로55길',
#   '엑스좌표_값': 187636,
#   '와이좌표_값': 450546,
#   '시군구_코드': 11500,
#   '행정동_코드': 11500520,
#   '위도': 37.554354515253934,
#   '경도': 126.86007453844135},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000577,
#   '상권_코드_명': '공항대로59길',
#   '엑스좌표_값': 187993,
#   '와이좌표_값': 450371,
#   '시군구_코드': 11500,
#   '행정동_코드': 11500520,
#   '위도': 37.55278249214008,
#   '경도': 126.86411761955507},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000674,
#   '상권_코드_명': '시흥대로150길',
#   '엑스좌표_값': 191260,
#   '와이좌표_값': 441898,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545630,
#   '위도': 37.47647730659402,
#   '경도': 126.90119067131354},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000675,
#   '상권_코드_명': '시흥대로153길',
#   '엑스좌표_값': 190698,
#   '와이좌표_값': 441839,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545510,
#   '위도': 37.47594022771477,
#   '경도': 126.89483778236263},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000676,
#   '상권_코드_명': '시흥대로22길',
#   '엑스좌표_값': 191610,
#   '와이좌표_값': 437964,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545690,
#   '위도': 37.4410347689175,
#   '경도': 126.90519232063028},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000677,
#   '상권_코드_명': '시흥대로36길',
#   '엑스좌표_값': 191609,
#   '와이좌표_값': 438262,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545690,
#   '위도': 37.44371978067097,
#   '경도': 126.90517763240933},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000821,
#   '상권_코드_명': '신림로65길',
#   '엑스좌표_값': 193516,
#   '와이좌표_값': 442877,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620695,
#   '위도': 37.48531675363689,
#   '경도': 126.92668704794538},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000008,
#   '상권_코드_명': '북촌로5나길',
#   '엑스좌표_값': 198500,
#   '와이좌표_값': 454026,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110540,
#   '위도': 37.585790844270974,
#   '경도': 126.98301710779458},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000009,
#   '상권_코드_명': '삼청로5길',
#   '엑스좌표_값': 198284,
#   '와이좌표_값': 453968,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110540,
#   '위도': 37.58526789115327,
#   '경도': 126.9805717072538},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000762,
#   '상권_코드_명': '서달로10길',
#   '엑스좌표_값': 196733,
#   '와이좌표_값': 444897,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590605,
#   '위도': 37.50353406212093,
#   '경도': 126.9630518799391},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000763,
#   '상권_코드_명': '서달로14길',
#   '엑스좌표_값': 196881,
#   '와이좌표_값': 445277,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590605,
#   '위도': 37.50695839337092,
#   '경도': 126.96472407394903},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000764,
#   '상권_코드_명': '서달로15길',
#   '엑스좌표_값': 196677,
#   '와이좌표_값': 445447,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590605,
#   '위도': 37.50848938989847,
#   '경도': 126.96241606411337},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000765,
#   '상권_코드_명': '서달로8가길',
#   '엑스좌표_값': 196640,
#   '와이좌표_값': 445137,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590605,
#   '위도': 37.5056961409957,
#   '경도': 126.96199900109328},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000326,
#   '상권_코드_명': '도봉로99길',
#   '엑스좌표_값': 202431,
#   '와이좌표_값': 460456,
#   '시군구_코드': 11305,
#   '행정동_코드': 11305630,
#   '위도': 37.64372241540077,
#   '경도': 127.02754496778088},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000327,
#   '상권_코드_명': '삼각산로28길',
#   '엑스좌표_값': 201827,
#   '와이좌표_값': 459865,
#   '시군구_코드': 11305,
#   '행정동_코드': 11305630,
#   '위도': 37.63839899645745,
#   '경도': 127.02069973900537},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000037,
#   '상권_코드_명': '동호로20길',
#   '엑스좌표_값': 200833,
#   '와이좌표_값': 451152,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140580,
#   '위도': 37.55989709372857,
#   '경도': 127.00942790140374},
#  ...]

# %%
collection.insert_many(df.to_dict('records'))

# %%
for item in collection.find():
    print(item)
# Out:
# {'_id': ObjectId('6194a480a04fa6007b69102e'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000275, '상권_코드_명': '보문로26길', '엑스좌표_값': 201886, '와이좌표_값': 454183, '시군구_코드': 11290, '행정동_코드': 11290600, '위도': 37.58720469334632, '경도': 127.02135356029717}
# {'_id': ObjectId('6194a480a04fa6007b69102f'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000276, '상권_코드_명': '보문로31길', '엑스좌표_값': 201385, '와이좌표_값': 454290, '시군구_코드': 11290, '행정동_코드': 11290555, '위도': 37.58816964537452, '경도': 127.01568136950489}
# {'_id': ObjectId('6194a480a04fa6007b691030'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001045, '상권_코드_명': '동작구 총신대입구역_1', '엑스좌표_값': 198304, '와이좌표_값': 442948, '시군구_코드': 11590, '행정동_코드': 11590630, '위도': 37.48597765914372, '경도': 126.9808235857054}
# {'_id': ObjectId('6194a480a04fa6007b691031'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001046, '상권_코드_명': '서울 관악구 신림역_4', '엑스좌표_값': 193828, '와이좌표_값': 443001, '시군구_코드': 11620, '행정동_코드': 11620695, '위도': 37.486436139402514, '경도': 126.9302137115341}
# {'_id': ObjectId('6194a480a04fa6007b691032'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001047, '상권_코드_명': '뱅뱅사거리_1', '엑스좌표_값': 202960, '와이좌표_값': 443242, '시군구_코드': 11680, '행정동_코드': 11680655, '위도': 37.48862343831305, '경도': 127.03346945025531}
# {'_id': ObjectId('6194a480a04fa6007b691033'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001048, '상권_코드_명': '뱅뱅사거리', '엑스좌표_값': 202638, '와이좌표_값': 443504, '시군구_코드': 11650, '행정동_코드': 11650520, '위도': 37.49098505346684, '경도': 127.02982945599554}
# {'_id': ObjectId('6194a480a04fa6007b691034'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001049, '상권_코드_명': '개봉동 현대아파트 인근', '엑스좌표_값': 187247, '와이좌표_값': 443356, '시군구_코드': 11530, '행정동_코드': 11530760, '위도': 37.48956732297291, '경도': 126.85579690602577}
# {'_id': ObjectId('6194a480a04fa6007b691035'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001050, '상권_코드_명': '교대역_1', '엑스좌표_값': 201023, '와이좌표_값': 443482, '시군구_코드': 11650, '행정동_코드': 11650530, '위도': 37.490790031276504, '경도': 127.01156764763162}
# {'_id': ObjectId('6194a480a04fa6007b691036'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001260, '상권_코드_명': '창동역', '엑스좌표_값': 204324, '와이좌표_값': 461465, '시군구_코드': 11320, '행정동_코드': 11320514, '위도': 37.652806377355745, '경도': 127.04899997749135}
# {'_id': ObjectId('6194a480a04fa6007b691037'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001261, '상권_코드_명': '서울 노원구 노원역_1', '엑스좌표_값': 205532, '와이좌표_값': 461611, '시군구_코드': 11350, '행정동_코드': 11350695, '위도': 37.65411533094399, '경도': 127.0626902470538}
# {'_id': ObjectId('6194a480a04fa6007b691038'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001262, '상권_코드_명': '서울 노원구 노원역_2', '엑스좌표_값': 205198, '와이좌표_값': 461669, '시군구_코드': 11350, '행정동_코드': 11350695, '위도': 37.654639851230215, '경도': 127.05890567576205}
# {'_id': ObjectId('6194a480a04fa6007b691039'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001263, '상권_코드_명': '서울 노원구 노원역_3', '엑스좌표_값': 205516, '와이좌표_값': 461822, '시군구_코드': 11350, '행정동_코드': 11350640, '위도': 37.65601649888629, '경도': 127.0625105241541}
# {'_id': ObjectId('6194a480a04fa6007b69103a'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001217, '상권_코드_명': '서울 종로구 종로5가역_1', '엑스좌표_값': 200123, '와이좌표_값': 452320, '시군구_코드': 11110, '행정동_코드': 11110630, '위도': 37.570421097077954, '경도': 127.0013923109485}
# {'_id': ObjectId('6194a480a04fa6007b69103b'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001255, '상권_코드_명': '서울 은평구 연신내역_3', '엑스좌표_값': 192979, '와이좌표_값': 457903, '시군구_코드': 11380, '행정동_코드': 11380530, '위도': 37.62069666168165, '경도': 126.92047159847978}
# {'_id': ObjectId('6194a480a04fa6007b69103c'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001259, '상권_코드_명': '서울 강북구 수유역_3', '엑스좌표_값': 202401, '와이좌표_값': 460138, '시군구_코드': 11305, '행정동_코드': 11305630, '위도': 37.64085736435166, '경도': 127.0272040015457}
# {'_id': ObjectId('6194a480a04fa6007b69103d'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001310, '상권_코드_명': '구의시장', '엑스좌표_값': 207818, '와이좌표_값': 449558, '시군구_코드': 11215, '행정동_코드': 11215860, '위도': 37.54550242151623, '경도': 127.08846716777747}
# {'_id': ObjectId('6194a480a04fa6007b69103e'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001322, '상권_코드_명': '동부시장', '엑스좌표_값': 204647, '와이좌표_값': 451975, '시군구_코드': 11230, '행정동_코드': 11230600, '위도': 37.56730095286713, '경도': 127.05259999071382}
# {'_id': ObjectId('6194a480a04fa6007b69103f'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001323, '상권_코드_명': '답십리시장', '엑스좌표_값': 205141, '와이좌표_값': 452679, '시군구_코드': 11230, '행정동_코드': 11230610, '위도': 37.57364133312369, '경도': 127.05819657291528}
# {'_id': ObjectId('6194a480a04fa6007b691040'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001324, '상권_코드_명': '전곡시장', '엑스좌표_값': 206080, '와이좌표_값': 453173, '시군구_코드': 11230, '행정동_코드': 11230660, '위도': 37.57808652423727, '경도': 127.06883022580342}
# {'_id': ObjectId('6194a480a04fa6007b691041'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001325, '상권_코드_명': '청량리청과물시장', '엑스좌표_값': 203815, '와이좌표_값': 453397, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 37.58011691623963, '경도': 127.04318987696023}
# {'_id': ObjectId('6194a480a04fa6007b691042'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001451, '상권_코드_명': '사당시장', '엑스좌표_값': 197801, '와이좌표_값': 442618, '시군구_코드': 11590, '행정동_코드': 11590650, '위도': 37.483003271393486, '경도': 126.97513722688751}
# {'_id': ObjectId('6194a480a04fa6007b691043'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001468, '상권_코드_명': '남부종합시장', '엑스좌표_값': 198664, '와이좌표_값': 443924, '시군구_코드': 11650, '행정동_코드': 11650590, '위도': 37.49477208354063, '경도': 126.98489227985215}
# {'_id': ObjectId('6194a480a04fa6007b691044'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001469, '상권_코드_명': '양재시장', '엑스좌표_값': 203388, '와이좌표_값': 442737, '시군구_코드': 11650, '행정동_코드': 11650651, '위도': 37.4840718777507, '경도': 127.0383066275842}
# {'_id': ObjectId('6194a480a04fa6007b691045'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001407, '상권_코드_명': '등마루시장', '엑스좌표_값': 187644, '와이좌표_값': 450807, '시군구_코드': 11500, '행정동_코드': 11500520, '위도': 37.556706219310875, '경도': 126.86016068133681}
# {'_id': ObjectId('6194a480a04fa6007b691046'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001408, '상권_코드_명': '신월중앙시장', '엑스좌표_값': 186247, '와이좌표_값': 451047, '시군구_코드': 11500, '행정동_코드': 11500535, '위도': 37.5588488207642, '경도': 126.84434565394928}
# {'_id': ObjectId('6194a480a04fa6007b691047'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001450, '상권_코드_명': '남성역골목시장', '엑스좌표_값': 197564, '와이좌표_값': 442672, '시군구_코드': 11590, '행정동_코드': 11590650, '위도': 37.48348922176638, '경도': 126.97245743180964}
# {'_id': ObjectId('6194a480a04fa6007b691048'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001042, '상권_코드_명': '서울 서초구 남부터미널역_3', '엑스좌표_값': 201432, '와이좌표_값': 443037, '시군구_코드': 11650, '행정동_코드': 11650510, '위도': 37.48678000320049, '경도': 127.0161915795939}
# {'_id': ObjectId('6194a480a04fa6007b691049'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001043, '상권_코드_명': '동작구 총신대입구역_2', '엑스좌표_값': 198499, '와이좌표_값': 442941, '시군구_코드': 11650, '행정동_코드': 11650621, '위도': 37.48591492585732, '경도': 126.98302843524853}
# {'_id': ObjectId('6194a480a04fa6007b69104a'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001044, '상권_코드_명': '양재역_3', '엑스좌표_값': 202755, '와이좌표_값': 443008, '시군구_코드': 11650, '행정동_코드': 11650520, '위도': 37.48651571376833, '경도': 127.03115058953671}
# {'_id': ObjectId('6194a480a04fa6007b69104b'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001030, '상권_코드_명': '양재역_2', '엑스좌표_값': 203216, '와이좌표_값': 442691, '시군구_코드': 11650, '행정동_코드': 11650651, '위도': 37.48365802839606, '경도': 127.0363616986534}
# {'_id': ObjectId('6194a480a04fa6007b69104c'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001031, '상권_코드_명': '서울 관악구 신림역_1', '엑스좌표_값': 193706, '와이좌표_값': 442615, '시군구_코드': 11620, '행정동_코드': 11620645, '위도': 37.4829574265654, '경도': 126.92883756748512}
# {'_id': ObjectId('6194a480a04fa6007b69104d'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001032, '상권_코드_명': '서울 관악구 신림역_2', '엑스좌표_값': 193880, '와이좌표_값': 442602, '시군구_코드': 11620, '행정동_코드': 11620645, '위도': 37.482841464045244, '경도': 126.93080498641467}
# {'_id': ObjectId('6194a480a04fa6007b69104e'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001033, '상권_코드_명': '서울 서초구 남부터미널역_1', '엑스좌표_값': 201661, '와이좌표_값': 442764, '시군구_코드': 11650, '행정동_코드': 11650510, '위도': 37.48431986735238, '경도': 127.01878025964147}
# {'_id': ObjectId('6194a480a04fa6007b69104f'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000379, '상권_코드_명': '동일로173가길', '엑스좌표_값': 206395, '와이좌표_값': 458052, '시군구_코드': 11350, '행정동_코드': 11350595, '위도': 37.622043697935894, '경도': 127.07243887072359}
# {'_id': ObjectId('6194a480a04fa6007b691050'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000380, '상권_코드_명': '동일로192길', '엑스좌표_값': 206671, '와이좌표_값': 458471, '시군구_코드': 11350, '행정동_코드': 11350595, '위도': 37.62581687022158, '경도': 127.0755690585679}
# {'_id': ObjectId('6194a480a04fa6007b691051'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000381, '상권_코드_명': '동일로242길', '엑스좌표_값': 205175, '와이좌표_값': 463916, '시군구_코드': 11350, '행정동_코드': 11350630, '위도': 37.67488501157822, '경도': 127.05866096147015}
# {'_id': ObjectId('6194a480a04fa6007b691052'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000071, '상권_코드_명': '이태원로54길', '엑스좌표_값': 200121, '와이좌표_값': 448560, '시군구_코드': 11170, '행정동_코드': 11170685, '위도': 37.536543574586496, '경도': 127.00136905188955}
# {'_id': ObjectId('6194a480a04fa6007b691053'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000072, '상권_코드_명': '장문로45길', '엑스좌표_값': 200041, '와이좌표_값': 447690, '시군구_코드': 11170, '행정동_코드': 11170700, '위도': 37.52870487172285, '경도': 127.00046384506732}
# {'_id': ObjectId('6194a480a04fa6007b691054'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000073, '상권_코드_명': '청파로47길', '엑스좌표_값': 197165, '와이좌표_값': 449449, '시군구_코드': 11170, '행정동_코드': 11170555, '위도': 37.544549114266864, '경도': 126.96792002437306}
# {'_id': ObjectId('6194a480a04fa6007b691055'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001490, '상권_코드_명': '길동복조리시장', '엑스좌표_값': 212698, '와이좌표_값': 448781, '시군구_코드': 11740, '행정동_코드': 11740685, '위도': 37.538447392541784, '경도': 127.14367486055193}
# {'_id': ObjectId('6194a480a04fa6007b691056'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001332, '상권_코드_명': '사가정시장', '엑스좌표_값': 207989, '와이좌표_값': 453527, '시군구_코드': 11260, '행정동_코드': 11260575, '위도': 37.58126145968097, '경도': 127.09044539460683}
# {'_id': ObjectId('6194a480a04fa6007b691057'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001333, '상권_코드_명': '중화제일시장', '엑스좌표_값': 206662, '와이좌표_값': 456140, '시군구_코드': 11260, '행정동_코드': 11260630, '위도': 37.604814912176174, '경도': 127.07544588440813}
# {'_id': ObjectId('6194a480a04fa6007b691058'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001334, '상권_코드_명': '태능시장', '엑스좌표_값': 206759, '와이좌표_값': 455413, '시군구_코드': 11260, '행정동_코드': 11260610, '위도': 37.59826400907771, '경도': 127.07653767941356}
# {'_id': ObjectId('6194a480a04fa6007b691059'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001335, '상권_코드_명': '묵1동도깨비시장', '엑스좌표_값': 207147, '와이좌표_값': 457479, '시군구_코드': 11260, '행정동_코드': 11260620, '위도': 37.616875506063934, '경도': 127.0809514877725}
# {'_id': ObjectId('6194a480a04fa6007b69105a'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001336, '상권_코드_명': '우림골목시장', '엑스좌표_값': 208659, '와이좌표_값': 455348, '시군구_코드': 11260, '행정동_코드': 11260655, '위도': 37.59766245247334, '경도': 127.09805213757389}
# {'_id': ObjectId('6194a480a04fa6007b69105b'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001337, '상권_코드_명': '유영시장', '엑스좌표_값': 208553, '와이좌표_값': 454672, '시군구_코드': 11260, '행정동_코드': 11260660, '위도': 37.591572748702255, '경도': 127.09684393083963}
# {'_id': ObjectId('6194a480a04fa6007b69105c'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001338, '상권_코드_명': '돈암제일시장', '엑스좌표_값': 201402, '와이좌표_값': 454703, '시군구_코드': 11290, '행정동_코드': 11290555, '위도': 37.59189071792463, '경도': 127.01587463871735}
# {'_id': ObjectId('6194a480a04fa6007b69105d'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001377, '상권_코드_명': '영천시장', '엑스좌표_값': 196581, '와이좌표_값': 452325, '시군구_코드': 11410, '행정동_코드': 11410520, '위도': 37.5704598113684, '경도': 126.96129826420189}
# {'_id': ObjectId('6194a480a04fa6007b69105e'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001057, '상권_코드_명': '교대역_2', '엑스좌표_값': 201412, '와이좌표_값': 443757, '시군구_코드': 11650, '행정동_코드': 11650510, '위도': 37.493267288811936, '경도': 127.01596682099772}
# {'_id': ObjectId('6194a480a04fa6007b69105f'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001058, '상권_코드_명': '역삼역_1', '엑스좌표_값': 203292, '와이좌표_값': 443852, '시군구_코드': 11680, '행정동_코드': 11680640, '위도': 37.494118459450675, '경도': 127.03722618303436}
# {'_id': ObjectId('6194a480a04fa6007b691060'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001059, '상권_코드_명': '교대역_3', '엑스좌표_값': 201065, '와이좌표_값': 443865, '시군구_코드': 11650, '행정동_코드': 11650530, '위도': 37.494240841590305, '경도': 127.01204311976798}
# {'_id': ObjectId('6194a480a04fa6007b691061'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001060, '상권_코드_명': '가락시장', '엑스좌표_값': 210036, '와이좌표_값': 443852, '시군구_코드': 11710, '행정동_코드': 11710631, '위도': 37.49406981478419, '경도': 127.113487750174}
# {'_id': ObjectId('6194a480a04fa6007b691062'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001061, '상권_코드_명': '방배동카페골목', '엑스좌표_값': 198796, '와이좌표_값': 443913, '시군구_코드': 11650, '행정동_코드': 11650590, '위도': 37.49467315423672, '경도': 126.98638497674007}
# {'_id': ObjectId('6194a480a04fa6007b691063'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001062, '상권_코드_명': '서울 강남구 강남역_1', '엑스좌표_값': 202416, '와이좌표_값': 443988, '시군구_코드': 11650, '행정동_코드': 11650520, '위도': 37.495346534821586, '경도': 127.02732075688415}
# {'_id': ObjectId('6194a480a04fa6007b691064'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001181, '상권_코드_명': '서울 광진구 군자역', '엑스좌표_값': 206935, '와이좌표_값': 450796, '시군구_코드': 11215, '행정동_코드': 11215730, '위도': 37.55666383323358, '경도': 127.07848699391494}
# {'_id': ObjectId('6194a480a04fa6007b691065'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001123, '상권_코드_명': '학동사거리_1', '엑스좌표_값': 203226, '와이좌표_값': 446892, '시군구_코드': 11680, '행정동_코드': 11680531, '위도': 37.52150923659847, '경도': 127.036493181618}
# {'_id': ObjectId('6194a480a04fa6007b691066'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001017, '상권_코드_명': '관악구 사당역_3', '엑스좌표_값': 198317, '와이좌표_값': 441788, '시군구_코드': 11620, '행정동_코드': 11620630, '위도': 37.47552597828984, '경도': 126.98097322504685}
# {'_id': ObjectId('6194a480a04fa6007b691067'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001018, '상권_코드_명': '포이사거리_2', '엑스좌표_값': 203907, '와이좌표_값': 441907, '시군구_코드': 11650, '행정동_코드': 11650652, '위도': 37.47659145589457, '경도': 127.04417032889133}
# {'_id': ObjectId('6194a480a04fa6007b691068'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001019, '상권_코드_명': '포이사거리_1', '엑스좌표_값': 204078, '와이좌표_값': 441953, '시군구_코드': 11680, '행정동_코드': 11680690, '위도': 37.477005181709146, '경도': 127.04610381207898}
# {'_id': ObjectId('6194a480a04fa6007b691069'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001020, '상권_코드_명': '장지역', '엑스좌표_값': 210795, '와이좌표_값': 441986, '시군구_코드': 11710, '행정동_코드': 11710642, '위도': 37.477248481146304, '경도': 127.12204320261074}
# {'_id': ObjectId('6194a480a04fa6007b69106a'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001021, '상권_코드_명': '가산디지털단지역_1', '엑스좌표_값': 189789, '와이좌표_값': 441401, '시군구_코드': 11545, '행정동_코드': 11545510, '위도': 37.47198421841353, '경도': 126.88456732142473}
# {'_id': ObjectId('6194a480a04fa6007b69106b'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001038, '상권_코드_명': '구로디지탈1단지', '엑스좌표_값': 190721, '와이좌표_값': 442712, '시군구_코드': 11530, '행정동_코드': 11530540, '위도': 37.48380625597272, '경도': 126.89508680818014}
# {'_id': ObjectId('6194a480a04fa6007b69106c'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001039, '상권_코드_명': '서울 서초구 남부터미널역_2', '엑스좌표_값': 201211, '와이좌표_값': 442998, '시군구_코드': 11650, '행정동_코드': 11650530, '위도': 37.48642892605263, '경도': 127.01369267538392}
# {'_id': ObjectId('6194a480a04fa6007b69106d'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001040, '상권_코드_명': '서울 관악구 신림역_3', '엑스좌표_값': 193679, '와이좌표_값': 442896, '시군구_코드': 11620, '행정동_코드': 11620695, '위도': 37.48548907432291, '경도': 126.92852988341207}
# {'_id': ObjectId('6194a480a04fa6007b69106e'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001041, '상권_코드_명': '서울 강남구 수서역', '엑스좌표_값': 209143, '와이좌표_값': 443137, '시군구_코드': 11680, '행정동_코드': 11680750, '위도': 37.48763689043684, '경도': 127.10338078395336}
# {'_id': ObjectId('6194a480a04fa6007b69106f'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000377, '상권_코드_명': '해등로16길', '엑스좌표_값': 203765, '와이좌표_값': 461761, '시군구_코드': 11320, '행정동_코드': 11320515, '위도': 37.65547574605313, '경도': 127.0426668642167}
# {'_id': ObjectId('6194a480a04fa6007b691070'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000378, '상권_코드_명': '공릉로58길', '엑스좌표_값': 206529, '와이좌표_값': 459618, '시군구_코드': 11350, '행정동_코드': 11350611, '위도': 37.63615219120443, '경도': 127.07397072659852}
# {'_id': ObjectId('6194a480a04fa6007b691071'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000298, '상권_코드_명': '정릉로27길', '엑스좌표_값': 201136, '와이좌표_값': 456377, '시군구_코드': 11290, '행정동_코드': 11290630, '위도': 37.60697367210774, '경도': 127.01286535692006}
# {'_id': ObjectId('6194a480a04fa6007b691072'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000299, '상권_코드_명': '정릉로8길', '엑스좌표_값': 199817, '와이좌표_값': 456396, '시군구_코드': 11290, '행정동_코드': 11290640, '위도': 37.6071455432061, '경도': 126.99792749494841}
# {'_id': ObjectId('6194a480a04fa6007b691073'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000376, '상권_코드_명': '우이천로4다길', '엑스좌표_값': 203558, '와이좌표_값': 459512, '시군구_코드': 11320, '행정동_코드': 11320513, '위도': 37.63521344861366, '경도': 127.04031008537356}
# {'_id': ObjectId('6194a480a04fa6007b691074'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001292, '상권_코드_명': '이태원제일시장', '엑스좌표_값': 198921, '와이좌표_값': 448849, '시군구_코드': 11170, '행정동_코드': 11170660, '위도': 37.53914684239876, '경도': 126.98779125338027}
# {'_id': ObjectId('6194a480a04fa6007b691075'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001293, '상권_코드_명': '보광시장', '엑스좌표_값': 200033, '와이좌표_값': 447503, '시군구_코드': 11170, '행정동_코드': 11170700, '위도': 37.52701999855625, '경도': 127.00037333031572}
# {'_id': ObjectId('6194a480a04fa6007b691076'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001278, '상권_코드_명': '남평화시장', '엑스좌표_값': 200955, '와이좌표_값': 452181, '시군구_코드': 11140, '행정동_코드': 11140615, '위도': 37.56916822669786, '경도': 127.010810038063}
# {'_id': ObjectId('6194a480a04fa6007b691077'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001279, '상권_코드_명': '동평화시장', '엑스좌표_값': 201155, '와이좌표_값': 452190, '시군구_코드': 11140, '행정동_코드': 11140615, '위도': 37.56924908729413, '경도': 127.01307393450413}
# {'_id': ObjectId('6194a480a04fa6007b691078'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001280, '상권_코드_명': '제일평화시장', '엑스좌표_값': 201022, '와이좌표_값': 452093, '시군구_코드': 11140, '행정동_코드': 11140615, '위도': 37.568375278700614, '경도': 127.01156831600028}
# {'_id': ObjectId('6194a480a04fa6007b691079'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000300, '상권_코드_명': '종암로16길', '엑스좌표_값': 203263, '와이좌표_값': 455409, '시군구_코드': 11290, '행정동_코드': 11290705, '위도': 37.59824700224238, '경도': 127.03694960878664}
# {'_id': ObjectId('6194a480a04fa6007b69107a'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001281, '상권_코드_명': '청평화시장', '엑스좌표_값': 201326, '와이좌표_값': 452228, '시군구_코드': 11140, '행정동_코드': 11140615, '위도': 37.569591235352874, '경도': 127.01500962462404}
# {'_id': ObjectId('6194a480a04fa6007b69107b'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001282, '상권_코드_명': '약수시장', '엑스좌표_값': 200933, '와이좌표_값': 450362, '시군구_코드': 11140, '행정동_코드': 11140635, '위도': 37.552779117727084, '경도': 127.01055869791927}
# {'_id': ObjectId('6194a480a04fa6007b69107c'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001283, '상권_코드_명': '백학시장', '엑스좌표_값': 201714, '와이좌표_값': 451574, '시군구_코드': 11140, '행정동_코드': 11140650, '위도': 37.563698082212916, '경도': 127.019400052715}
# {'_id': ObjectId('6194a480a04fa6007b69107d'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001284, '상권_코드_명': '서울중앙시장', '엑스좌표_값': 201735, '와이좌표_값': 451936, '시군구_코드': 11140, '행정동_코드': 11140670, '위도': 37.566959648728094, '경도': 127.01963859917295}
# {'_id': ObjectId('6194a480a04fa6007b69107e'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001309, '상권_코드_명': '조양시장', '엑스좌표_값': 205964, '와이좌표_값': 448825, '시군구_코드': 11215, '행정동_코드': 11215847, '위도': 37.538911952569784, '경도': 127.06748167951677}
# {'_id': ObjectId('6194a480a04fa6007b69107f'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001368, '상권_코드_명': '연서시장', '엑스좌표_값': 193085, '와이좌표_값': 457778, '시군구_코드': 11380, '행정동_코드': 11380530, '위도': 37.619571231155106, '경도': 126.92167346415707}
# {'_id': ObjectId('6194a480a04fa6007b691080'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001369, '상권_코드_명': '갈현시장', '엑스좌표_값': 192709, '와이좌표_값': 458241, '시군구_코드': 11380, '행정동_코드': 11380551, '위도': 37.623739895187256, '경도': 126.91740988335779}
# {'_id': ObjectId('6194a480a04fa6007b691081'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001370, '상권_코드_명': '역촌중앙시장', '엑스좌표_값': 192603, '와이좌표_값': 457080, '시군구_코드': 11380, '행정동_코드': 11380552, '위도': 37.613278589249596, '경도': 126.91622088862053}
# {'_id': ObjectId('6194a480a04fa6007b691082'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001371, '상권_코드_명': '대조시장', '엑스좌표_값': 193542, '와이좌표_값': 456660, '시군구_코드': 11380, '행정동_코드': 11380570, '위도': 37.60950150921935, '경도': 126.92685978763448}
# {'_id': ObjectId('6194a480a04fa6007b691083'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001098, '상권_코드_명': '포스코사거리_1', '엑스좌표_값': 204775, '와이좌표_값': 445500, '시군구_코드': 11680, '행정동_코드': 11680590, '위도': 37.50896055541883, '경도': 127.05400674639628}
# {'_id': ObjectId('6194a480a04fa6007b691084'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001099, '상권_코드_명': '포스코사거리_2', '엑스좌표_값': 204973, '와이좌표_값': 445586, '시군구_코드': 11680, '행정동_코드': 11680580, '위도': 37.50973437396545, '경도': 127.05624676889406}
# {'_id': ObjectId('6194a480a04fa6007b691085'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001100, '상권_코드_명': '강남구 논현역_3', '엑스좌표_값': 201931, '와이좌표_값': 445848, '시군구_코드': 11680, '행정동_코드': 11680521, '위도': 37.51210637798919, '경도': 127.02184113245826}
# {'_id': ObjectId('6194a480a04fa6007b691086'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001101, '상권_코드_명': '선정릉역_2', '엑스좌표_값': 204085, '와이좌표_값': 445833, '시군구_코드': 11680, '행정동_코드': 11680590, '위도': 37.511964209812604, '경도': 127.04620448208236}
# {'_id': ObjectId('6194a480a04fa6007b691087'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001102, '상권_코드_명': '서울 강남구 학동역_1', '엑스좌표_값': 202606, '와이좌표_값': 445905, '시군구_코드': 11680, '행정동_코드': 11680521, '위도': 37.512618291870304, '경도': 127.02947611581212}
# {'_id': ObjectId('6194a480a04fa6007b691088'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001103, '상권_코드_명': '코엑스', '엑스좌표_값': 205283, '와이좌표_값': 445735, '시군구_코드': 11680, '행정동_코드': 11680580, '위도': 37.51107514837405, '경도': 127.05975407071885}
# {'_id': ObjectId('6194a480a04fa6007b691089'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001104, '상권_코드_명': '삼성역_3', '엑스좌표_값': 205648, '와이좌표_값': 445805, '시군구_코드': 11680, '행정동_코드': 11680580, '위도': 37.51170369047007, '경도': 127.06388298678927}
# {'_id': ObjectId('6194a480a04fa6007b69108a'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001055, '상권_코드_명': '서울 서초구 서초역', '엑스좌표_값': 200791, '와이좌표_값': 443762, '시군구_코드': 11650, '행정동_코드': 11650530, '위도': 37.49331307953432, '경도': 127.00894459146538}
# {'_id': ObjectId('6194a480a04fa6007b69108b'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001056, '상권_코드_명': '서울 송파구 가락시장역', '엑스좌표_값': 210540, '와이좌표_값': 443838, '시군구_코드': 11710, '행정동_코드': 11710620, '위도': 37.49393806173699, '경도': 127.11918680395776}
# {'_id': ObjectId('6194a480a04fa6007b69108c'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001027, '상권_코드_명': '가산디지털단지역_3', '엑스좌표_값': 189955, '와이좌표_값': 442117, '시군구_코드': 11545, '행정동_코드': 11545510, '위도': 37.47843725502126, '경도': 126.8864341433713}
# {'_id': ObjectId('6194a480a04fa6007b69108d'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001028, '상권_코드_명': '서울 관악구 서울대입구역_2', '엑스좌표_값': 196006, '와이좌표_값': 442715, '시군구_코드': 11620, '행정동_코드': 11620575, '위도': 37.48387123577071, '경도': 126.95484171774832}
# {'_id': ObjectId('6194a480a04fa6007b69108e'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001029, '상권_코드_명': '양재역_1', '엑스좌표_값': 202809, '와이좌표_값': 442502, '시군구_코드': 11650, '행정동_코드': 11650651, '위도': 37.48195644871718, '경도': 127.0317592337244}
# {'_id': ObjectId('6194a480a04fa6007b69108f'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001011, '상권_코드_명': '서울 금천구 시흥1동_4', '엑스좌표_값': 191286, '와이좌표_값': 439286, '시군구_코드': 11545, '행정동_코드': 11545670, '위도': 37.452943165976684, '경도': 126.90151548643851}
# {'_id': ObjectId('6194a480a04fa6007b691090'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001054, '상권_코드_명': '서울 강남구 대치역_2', '엑스좌표_값': 205280, '와이좌표_값': 443785, '시군구_코드': 11680, '행정동_코드': 11680600, '위도': 37.49350556247691, '경도': 127.05970614658726}
# {'_id': ObjectId('6194a480a04fa6007b691091'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001012, '상권_코드_명': '양재 화물트럭터미널앞_1', '엑스좌표_값': 203161, '와이좌표_값': 440282, '시군구_코드': 11650, '행정동_코드': 11650652, '위도': 37.46195288464275, '경도': 127.03572950785127}
# {'_id': ObjectId('6194a480a04fa6007b691092'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001013, '상권_코드_명': '양재 화물트럭터미널앞_2', '엑스좌표_값': 203269, '와이좌표_값': 440563, '시군구_코드': 11650, '행정동_코드': 11650652, '위도': 37.46448435173673, '경도': 127.0369515023419}
# {'_id': ObjectId('6194a480a04fa6007b691093'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001014, '상권_코드_명': '양재동 꽃시장', '엑스좌표_값': 203547, '와이좌표_값': 440820, '시군구_코드': 11650, '행정동_코드': 11650652, '위도': 37.466798926021674, '경도': 127.04009514194523}
# {'_id': ObjectId('6194a480a04fa6007b691094'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001015, '상권_코드_명': '서울 금천구 독산1동_1', '엑스좌표_값': 190842, '와이좌표_값': 441181, '시군구_코드': 11545, '행정동_코드': 11545610, '위도': 37.470013027610726, '경도': 126.89647392543884}
# {'_id': ObjectId('6194a480a04fa6007b691095'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001016, '상권_코드_명': '서울 관악구 대학동_1', '엑스좌표_값': 194671, '와이좌표_값': 441227, '시군구_코드': 11620, '행정동_코드': 11620735, '위도': 37.47045748675511, '경도': 126.9397582692801}
# {'_id': ObjectId('6194a480a04fa6007b691096'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000155, '상권_코드_명': '아차산로78길', '엑스좌표_값': 209529, '와이좌표_값': 449647, '시군구_코드': 11215, '행정동_코드': 11215810, '위도': 37.54628821661367, '경도': 127.10782968128034}
# {'_id': ObjectId('6194a480a04fa6007b691097'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000156, '상권_코드_명': '용마산로21길', '엑스좌표_값': 207516, '와이좌표_값': 451467, '시군구_코드': 11215, '행정동_코드': 11215750, '위도': 37.562704962308366, '경도': 127.08506933925977}
# {'_id': ObjectId('6194a480a04fa6007b691098'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000157, '상권_코드_명': '용마산로3길', '엑스좌표_값': 207500, '와이좌표_값': 450785, '시군구_코드': 11215, '행정동_코드': 11215750, '위도': 37.55656029984123, '경도': 127.0848812735163}
# {'_id': ObjectId('6194a480a04fa6007b691099'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000158, '상권_코드_명': '자양로11길', '엑스좌표_값': 207326, '와이좌표_값': 448272, '시군구_코드': 11215, '행정동_코드': 11215820, '위도': 37.53391961280386, '경도': 127.08288695723225}
# {'_id': ObjectId('6194a480a04fa6007b69109a'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000295, '상권_코드_명': '장월로1길', '엑스좌표_값': 203962, '와이좌표_값': 456285, '시군구_코드': 11290, '행정동_코드': 11290725, '위도': 37.606136933117284, '경도': 127.04486969357842}
# {'_id': ObjectId('6194a480a04fa6007b69109b'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000296, '상권_코드_명': '장위로50길', '엑스좌표_값': 205038, '와이좌표_값': 457231, '시군구_코드': 11290, '행정동_코드': 11290780, '위도': 37.61465502502365, '경도': 127.05706191208294}
# {'_id': ObjectId('6194a480a04fa6007b69109c'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000297, '상권_코드_명': '정릉로26길', '엑스좌표_값': 201022, '와이좌표_값': 456027, '시군구_코드': 11290, '행정동_코드': 11290630, '위도': 37.60382034084607, '경도': 127.01157380260076}
# {'_id': ObjectId('6194a480a04fa6007b69109d'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001277, '상권_코드_명': '방산종합시장', '엑스좌표_값': 200011, '와이좌표_값': 452055, '시군구_코드': 11140, '행정동_코드': 11140605, '위도': 37.56803346704921, '경도': 127.0001245116387}
# {'_id': ObjectId('6194a480a04fa6007b69109e'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001264, '상권_코드_명': '통인시장', '엑스좌표_값': 197342, '와이좌표_값': 453459, '시군구_코드': 11110, '행정동_코드': 11110515, '위도': 37.58067959801362, '경도': 126.96990837264661}
# {'_id': ObjectId('6194a480a04fa6007b69109f'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001265, '상권_코드_명': '광장시장', '엑스좌표_값': 199948, '와이좌표_값': 452270, '시군구_코드': 11110, '행정동_코드': 11110615, '위도': 37.569970606126326, '경도': 126.99941138428245}
# {'_id': ObjectId('6194a480a04fa6007b6910a0'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001266, '상권_코드_명': '동대문종합시장', '엑스좌표_값': 200715, '와이좌표_값': 452320, '시군구_코드': 11110, '행정동_코드': 11110630, '위도': 37.57042082785713, '경도': 127.00809351482725}
# {'_id': ObjectId('6194a480a04fa6007b6910a1'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001267, '상권_코드_명': '종로신진시장', '엑스좌표_값': 200468, '와이좌표_값': 452314, '시군구_코드': 11110, '행정동_코드': 11110630, '위도': 37.570366926707166, '경도': 127.00529756952639}
# {'_id': ObjectId('6194a480a04fa6007b6910a2'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001268, '상권_코드_명': '충신시장', '엑스좌표_값': 200505, '와이좌표_값': 452729, '시군구_코드': 11110, '행정동_코드': 11110630, '위도': 37.57410603671966, '경도': 127.00571668026423}
# {'_id': ObjectId('6194a480a04fa6007b6910a3'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001269, '상권_코드_명': '동문시장', '엑스좌표_값': 200983, '와이좌표_값': 452333, '시군구_코드': 11110, '행정동_코드': 11110670, '위도': 37.570537710296215, '경도': 127.01112718531732}
# {'_id': ObjectId('6194a480a04fa6007b6910a4'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001270, '상권_코드_명': '창신골목시장', '엑스좌표_값': 201018, '와이좌표_값': 452590, '시군구_코드': 11110, '행정동_코드': 11110680, '위도': 37.57285322980232, '경도': 127.0115237287406}
# {'_id': ObjectId('6194a480a04fa6007b6910a5'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001272, '상권_코드_명': '신설종합시장', '엑스좌표_값': 201854, '와이좌표_값': 452569, '시군구_코드': 11110, '행정동_코드': 11110710, '위도': 37.57266271778433, '경도': 127.02098716952338}
# {'_id': ObjectId('6194a480a04fa6007b6910a6'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001286, '상권_코드_명': '후암시장', '엑스좌표_값': 197904, '와이좌표_값': 450124, '시군구_코드': 11170, '행정동_코드': 11170510, '위도': 37.550632831653395, '경도': 126.97628039005014}
# {'_id': ObjectId('6194a480a04fa6007b6910a7'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001287, '상권_코드_명': '신흥시장', '엑스좌표_값': 198680, '와이좌표_값': 449527, '시군구_코드': 11170, '행정동_코드': 11170520, '위도': 37.54525530656243, '경도': 126.98506315071423}
# {'_id': ObjectId('6194a480a04fa6007b6910a8'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001289, '상권_코드_명': '용문전통시장', '엑스좌표_값': 196488, '와이좌표_값': 448561, '시군구_코드': 11170, '행정동_코드': 11170590, '위도': 37.53654590718111, '경도': 126.96026355135787}
# {'_id': ObjectId('6194a480a04fa6007b6910a9'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001290, '상권_코드_명': '이촌종합시장', '엑스좌표_값': 197769, '와이좌표_값': 446791, '시군구_코드': 11170, '행정동_코드': 11170630, '위도': 37.520602165174964, '경도': 126.97476277019915}
# {'_id': ObjectId('6194a480a04fa6007b6910aa'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001291, '상권_코드_명': '이태원시장', '엑스좌표_값': 199063, '와이좌표_값': 448266, '시군구_코드': 11170, '행정동_코드': 11170650, '위도': 37.53389416451648, '경도': 126.98939870878053}
# {'_id': ObjectId('6194a480a04fa6007b6910ab'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001092, '상권_코드_명': '강남구 논현역_1', '엑스좌표_값': 201940, '와이좌표_값': 445256, '시군구_코드': 11650, '행정동_코드': 11650560, '위도': 37.506772411794465, '경도': 127.02194136821261}
# {'_id': ObjectId('6194a480a04fa6007b6910ac'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001093, '상권_코드_명': '신천역', '엑스좌표_값': 207224, '와이좌표_값': 445640, '시군구_코드': 11710, '행정동_코드': 11710650, '위도': 37.510206048895434, '경도': 127.08170705738294}
# {'_id': ObjectId('6194a480a04fa6007b6910ad'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001094, '상권_코드_명': '선정릉역_1', '엑스좌표_값': 204141, '와이좌표_값': 445689, '시군구_코드': 11680, '행정동_코드': 11680590, '위도': 37.51066651445342, '경도': 127.04683707408867}
# {'_id': ObjectId('6194a480a04fa6007b6910ae'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001095, '상권_코드_명': '강남구 논현역_2', '엑스좌표_값': 202208, '와이좌표_값': 445400, '시군구_코드': 11680, '행정동_코드': 11680521, '위도': 37.50806925695847, '경도': 127.02497287577978}
# {'_id': ObjectId('6194a480a04fa6007b6910af'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001288, '상권_코드_명': '만리시장', '엑스좌표_값': 196790, '와이좌표_값': 450197, '시군구_코드': 11170, '행정동_코드': 11170555, '위도': 37.55128735486901, '경도': 126.96367337165762}
# {'_id': ObjectId('6194a480a04fa6007b6910b0'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001096, '상권_코드_명': '신도림역', '엑스좌표_값': 190279, '와이좌표_값': 445432, '시군구_코드': 11530, '행정동_코드': 11530510, '위도': 37.50830905050998, '경도': 126.89005341254958}
# {'_id': ObjectId('6194a480a04fa6007b6910b1'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001052, '상권_코드_명': '뱅뱅사거리_2', '엑스좌표_값': 202873, '와이좌표_값': 443583, '시군구_코드': 11680, '행정동_코드': 11680640, '위도': 37.491696148423806, '경도': 127.03248705054254}
# {'_id': ObjectId('6194a480a04fa6007b6910b2'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001053, '상권_코드_명': '서울 강남구 대치역_1', '엑스좌표_값': 205462, '와이좌표_값': 443761, '시군구_코드': 11680, '행정동_코드': 11680600, '위도': 37.493288262855124, '경도': 127.06176402022076}
# {'_id': ObjectId('6194a480a04fa6007b6910b3'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001022, '상권_코드_명': '관악구 사당역_2', '엑스좌표_값': 198281, '와이좌표_값': 442081, '시군구_코드': 11590, '행정동_코드': 11590620, '위도': 37.47816587022181, '경도': 126.98056555160662}
# {'_id': ObjectId('6194a480a04fa6007b6910b4'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001023, '상권_코드_명': '가산디지털단지역_2', '엑스좌표_값': 189388, '와이좌표_값': 442499, '시군구_코드': 11545, '행정동_코드': 11545510, '위도': 37.481872767274155, '경도': 126.88001831527892}
# {'_id': ObjectId('6194a480a04fa6007b6910b5'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001024, '상권_코드_명': '관악구 사당역_1', '엑스좌표_값': 198513, '와이좌표_값': 442082, '시군구_코드': 11650, '행정동_코드': 11650610, '위도': 37.47817528262151, '경도': 126.98318846514128}
# {'_id': ObjectId('6194a480a04fa6007b6910b6'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001025, '상권_코드_명': '서울 관악구 서울대입구역_1', '엑스좌표_값': 195788, '와이좌표_값': 442367, '시군구_코드': 11620, '행정동_코드': 11620595, '위도': 37.48073475833174, '경도': 126.95237888491067}
# {'_id': ObjectId('6194a480a04fa6007b6910b7'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001026, '상권_코드_명': '구로디지털단지역', '엑스좌표_값': 190126, '와이좌표_값': 442380, '시군구_코드': 11530, '행정동_코드': 11530595, '위도': 37.48080874716509, '경도': 126.88836389120875}
# {'_id': ObjectId('6194a480a04fa6007b6910b8'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001097, '상권_코드_명': '잠실역 롯데월드', '엑스좌표_값': 208671, '와이좌표_값': 445771, '시군구_코드': 11710, '행정동_코드': 11710680, '위도': 37.51137390833691, '경도': 127.09807487617543}
# {'_id': ObjectId('6194a480a04fa6007b6910b9'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001051, '상권_코드_명': '보라매공원', '엑스좌표_값': 193371, '와이좌표_값': 443527, '시군구_코드': 11590, '행정동_코드': 11590680, '위도': 37.49117227142047, '경도': 126.92504171914183}
# {'_id': ObjectId('6194a480a04fa6007b6910ba'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000067, '상권_코드_명': '원효로53길', '엑스좌표_값': 196681, '와이좌표_값': 448648, '시군구_코드': 11170, '행정동_코드': 11170590, '위도': 37.53733049201621, '경도': 126.962446852187}
# {'_id': ObjectId('6194a480a04fa6007b6910bb'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000068, '상권_코드_명': '원효로89길', '엑스좌표_값': 197234, '와이좌표_값': 449086, '시군구_코드': 11170, '행정동_코드': 11170560, '위도': 37.54127869587753, '경도': 126.96870217399656}
# {'_id': ObjectId('6194a480a04fa6007b6910bc'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000069, '상권_코드_명': '이촌로22길', '엑스좌표_값': 196081, '와이좌표_값': 447371, '시군구_코드': 11170, '행정동_코드': 11170640, '위도': 37.52582235495916, '경도': 126.9556649066854}
# {'_id': ObjectId('6194a480a04fa6007b6910bd'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000070, '상권_코드_명': '이태원로27길', '엑스좌표_값': 199453, '와이좌표_값': 448497, '시군구_코드': 11170, '행정동_코드': 11170650, '위도': 37.53597578998269, '경도': 126.9938110272278}
# {'_id': ObjectId('6194a480a04fa6007b6910be'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000152, '상권_코드_명': '아차산로51길', '엑스좌표_값': 207482, '와이좌표_값': 448936, '시군구_코드': 11215, '행정동_코드': 11215850, '위도': 37.53990099747857, '경도': 127.08465871524909}
# {'_id': ObjectId('6194a480a04fa6007b6910bf'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000153, '상권_코드_명': '아차산로55길', '엑스좌표_값': 207733, '와이좌표_값': 448875, '시군구_코드': 11215, '행정동_코드': 11215850, '위도': 37.53934931787935, '경도': 127.08749813117429}
# {'_id': ObjectId('6194a480a04fa6007b6910c0'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000154, '상권_코드_명': '아차산로65길', '엑스좌표_값': 208193, '와이좌표_값': 449251, '시군구_코드': 11215, '행정동_코드': 11215870, '위도': 37.54273310165684, '경도': 127.09270717418437}
# {'_id': ObjectId('6194a480a04fa6007b6910c1'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001300, '상권_코드_명': '화양제일골목시장', '엑스좌표_값': 206096, '와이좌표_값': 449274, '시군구_코드': 11215, '행정동_코드': 11215710, '위도': 37.54295657610216, '경도': 127.06897896366658}
# {'_id': ObjectId('6194a480a04fa6007b6910c2'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001301, '상권_코드_명': '중곡제일시장', '엑스좌표_값': 207176, '와이좌표_값': 451590, '시군구_코드': 11215, '행정동_코드': 11215740, '위도': 37.56381589690654, '경도': 127.08122227894687}
# {'_id': ObjectId('6194a480a04fa6007b6910c3'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001302, '상권_코드_명': '면곡골목시장', '엑스좌표_값': 207134, '와이좌표_값': 452395, '시군구_코드': 11215, '행정동_코드': 11215760, '위도': 37.571069232038916, '경도': 127.08075472787203}
# {'_id': ObjectId('6194a480a04fa6007b6910c4'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001303, '상권_코드_명': '신성골목시장', '엑스좌표_값': 207808, '와이좌표_값': 450932, '시군구_코드': 11215, '행정동_코드': 11215770, '위도': 37.557882207018466, '경도': 127.08836862482477}
# {'_id': ObjectId('6194a480a04fa6007b6910c5'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001304, '상권_코드_명': '자양골목시장', '엑스좌표_값': 207042, '와이좌표_값': 448309, '시군구_코드': 11215, '행정동_코드': 11215820, '위도': 37.53425519432588, '경도': 127.0796741157871}
# {'_id': ObjectId('6194a480a04fa6007b6910c6'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001305, '상권_코드_명': '자양종합시장', '엑스좌표_값': 206753, '와이좌표_값': 448042, '시군구_코드': 11215, '행정동_코드': 11215830, '위도': 37.531851684331734, '경도': 127.07640188035896}
# {'_id': ObjectId('6194a480a04fa6007b6910c7'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001306, '상권_코드_명': '노룬산골목시장', '엑스좌표_값': 205742, '와이좌표_값': 448568, '시군구_코드': 11215, '행정동_코드': 11215847, '위도': 37.53659779184103, '경도': 127.06496777853715}
# {'_id': ObjectId('6194a480a04fa6007b6910c8'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001307, '상권_코드_명': '능동로골목시장', '엑스좌표_값': 205899, '와이좌표_값': 448403, '시군구_코드': 11215, '행정동_코드': 11215840, '위도': 37.535110151175616, '경도': 127.06674282679104}
# {'_id': ObjectId('6194a480a04fa6007b6910c9'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001308, '상권_코드_명': '영동교골목시장', '엑스좌표_값': 205654, '와이좌표_값': 448727, '시군구_코드': 11215, '행정동_코드': 11215847, '위도': 37.53803092517618, '경도': 127.06397332818047}
# {'_id': ObjectId('6194a480a04fa6007b6910ca'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001273, '상권_코드_명': '남대문시장', '엑스좌표_값': 198091, '와이좌표_값': 451149, '시군구_코드': 11140, '행정동_코드': 11140540, '위도': 37.55986846331072, '경도': 126.97839392940769}
# {'_id': ObjectId('6194a480a04fa6007b6910cb'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001274, '상권_코드_명': '신중부시장', '엑스좌표_값': 200023, '와이좌표_값': 451785, '시군구_코드': 11140, '행정동_코드': 11140590, '위도': 37.56560077788206, '경도': 127.00026033405094}
# {'_id': ObjectId('6194a480a04fa6007b6910cc'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001275, '상권_코드_명': '인현시장', '엑스좌표_값': 199564, '와이좌표_값': 451525, '시군구_코드': 11140, '행정동_코드': 11140590, '위도': 37.56325808472952, '경도': 126.9950651264428}
# {'_id': ObjectId('6194a480a04fa6007b6910cd'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001276, '상권_코드_명': '평화시장', '엑스좌표_값': 200710, '와이좌표_값': 452148, '시군구_코드': 11140, '행정동_코드': 11140590, '위도': 37.56887111952541, '경도': 127.00803675030764}
# {'_id': ObjectId('6194a480a04fa6007b6910ce'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001069, '상권_코드_명': '은마아파트입구사거리_3', '엑스좌표_값': 205282, '와이좌표_값': 444402, '시군구_코드': 11680, '행정동_코드': 11680630, '위도': 37.49906475931724, '경도': 127.0597331901952}
# {'_id': ObjectId('6194a480a04fa6007b6910cf'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001070, '상권_코드_명': '은마아파트입구사거리_4', '엑스좌표_값': 205466, '와이좌표_값': 444479, '시군구_코드': 11680, '행정동_코드': 11680610, '위도': 37.49975746322555, '경도': 127.06181458398488}
# {'_id': ObjectId('6194a480a04fa6007b6910d0'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001071, '상권_코드_명': '서울 강남구 한티역', '엑스좌표_값': 204738, '와이좌표_값': 444303, '시군구_코드': 11680, '행정동_코드': 11680630, '위도': 37.49817571394421, '경도': 127.05358055707585}
# {'_id': ObjectId('6194a480a04fa6007b6910d1'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001165, '상권_코드_명': '서울 광진구 건대입구역_2', '엑스좌표_값': 206151, '와이좌표_값': 449134, '시군구_코드': 11215, '행정동_코드': 11215710, '위도': 37.54169481234147, '경도': 127.06960014021577}
# {'_id': ObjectId('6194a480a04fa6007b6910d2'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001166, '상권_코드_명': '서울 마포구 마포역_2', '엑스좌표_값': 195156, '와이좌표_값': 449005, '시군구_코드': 11440, '행정동_코드': 11440590, '위도': 37.54054031359572, '경도': 126.94518974329746}
# {'_id': ObjectId('6194a480a04fa6007b6910d3'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001167, '상권_코드_명': '서울 마포구 공덕역_1', '엑스좌표_값': 195722, '와이좌표_값': 449271, '시군구_코드': 11440, '행정동_코드': 11440565, '위도': 37.542939770927525, '경도': 126.95159252793033}
# {'_id': ObjectId('6194a480a04fa6007b6910d4'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001089, '상권_코드_명': '삼정역_1', '엑스좌표_값': 203222, '와이좌표_값': 445342, '시군구_코드': 11680, '행정동_코드': 11680640, '위도': 37.50754369288381, '경도': 127.03644114171418}
# {'_id': ObjectId('6194a480a04fa6007b6910d5'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001090, '상권_코드_명': '삼정역_2', '엑스좌표_값': 203114, '와이좌표_값': 445442, '시군구_코드': 11680, '행정동_코드': 11680531, '위도': 37.50844506812788, '경도': 127.03522007445697}
# {'_id': ObjectId('6194a480a04fa6007b6910d6'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001091, '상권_코드_명': '삼성역_2', '엑스좌표_값': 205759, '와이좌표_값': 445433, '시군구_코드': 11680, '행정동_코드': 11680610, '위도': 37.50835126987693, '경도': 127.06513556420268}
# {'_id': ObjectId('6194a480a04fa6007b6910d7'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000277, '상권_코드_명': '보문로32길', '엑스좌표_값': 201778, '와이좌표_값': 454576, '시군구_코드': 11290, '행정동_코드': 11290575, '위도': 37.590745808586, '경도': 127.0201317226878}
# {'_id': ObjectId('6194a480a04fa6007b6910d8'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000278, '상권_코드_명': '삼선교로10길', '엑스좌표_값': 200854, '와이좌표_값': 454139, '시군구_코드': 11290, '행정동_코드': 11290555, '위도': 37.58680979195958, '경도': 127.00966905845232}
# {'_id': ObjectId('6194a480a04fa6007b6910d9'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000279, '상권_코드_명': '삼선교로10다길', '엑스좌표_값': 200773, '와이좌표_값': 453904, '시군구_코드': 11290, '행정동_코드': 11290555, '위도': 37.58469252997415, '경도': 127.00875172189099}
# {'_id': ObjectId('6194a480a04fa6007b6910da'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000280, '상권_코드_명': '삼선교로16가길', '엑스좌표_값': 201020, '와이좌표_값': 453872, '시군구_코드': 11290, '행정동_코드': 11290555, '위도': 37.58440397169849, '경도': 127.01154815247764}
# {'_id': ObjectId('6194a480a04fa6007b6910db'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000064, '상권_코드_명': '우사단로4길', '엑스좌표_값': 199868, '와이좌표_값': 447913, '시군구_코드': 11170, '행정동_코드': 11170700, '위도': 37.53071409672035, '경도': 126.99850660509166}
# {'_id': ObjectId('6194a480a04fa6007b6910dc'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000065, '상권_코드_명': '원효로19길', '엑스좌표_값': 195898, '와이좌표_값': 448189, '시군구_코드': 11170, '행정동_코드': 11170570, '위도': 37.533191750440004, '경도': 126.95359008797688}
# {'_id': ObjectId('6194a480a04fa6007b6910dd'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000066, '상권_코드_명': '원효로41길', '엑스좌표_값': 196180, '와이좌표_값': 448370, '시군구_코드': 11170, '행정동_코드': 11170570, '위도': 37.53482377237657, '경도': 126.95677968602872}
# {'_id': ObjectId('6194a480a04fa6007b6910de'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001298, '상권_코드_명': '성동용답상가시장', '엑스좌표_값': 204625, '와이좌표_값': 451565, '시군구_코드': 11200, '행정동_코드': 11200790, '위도': 37.563606981029494, '경도': 127.05234838492093}
# {'_id': ObjectId('6194a480a04fa6007b6910df'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001311, '상권_코드_명': '동부청과시장', '엑스좌표_값': 203796, '와이좌표_값': 453091, '시군구_코드': 11230, '행정동_코드': 11230536, '위도': 37.57735995363058, '경도': 127.042973192155}
# {'_id': ObjectId('6194a480a04fa6007b6910e0'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001314, '상권_코드_명': '경동시장', '엑스좌표_값': 203447, '와이좌표_값': 453307, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 37.57930747265717, '경도': 127.03902330140541}
# {'_id': ObjectId('6194a480a04fa6007b6910e1'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001315, '상권_코드_명': '동서시장', '엑스좌표_값': 203658, '와이좌표_값': 453368, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 37.57985626500525, '경도': 127.0414123248943}
# {'_id': ObjectId('6194a480a04fa6007b6910e2'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001316, '상권_코드_명': '서울약령시장', '엑스좌표_값': 203313, '와이좌표_값': 453621, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 37.58213708424979, '경도': 127.03750771415709}
# {'_id': ObjectId('6194a480a04fa6007b6910e3'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001317, '상권_코드_명': '청량리농수산물시장', '엑스좌표_값': 203638, '와이좌표_값': 453503, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 37.58107268555848, '경도': 127.04118657439247}
# {'_id': ObjectId('6194a480a04fa6007b6910e4'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001318, '상권_코드_명': '청량리전통시장', '엑스좌표_값': 203766, '와이좌표_값': 453471, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 37.5807838531397, '경도': 127.04263552493434}
# {'_id': ObjectId('6194a480a04fa6007b6910e5'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001319, '상권_코드_명': '청량리종합시장', '엑스좌표_값': 203566, '와이좌표_값': 453322, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 37.57944216868575, '경도': 127.04037056666714}
# {'_id': ObjectId('6194a480a04fa6007b6910e6'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001320, '상권_코드_명': '전농로터리시장', '엑스좌표_값': 205011, '와이좌표_값': 453130, '시군구_코드': 11230, '행정동_코드': 11230560, '위도': 37.57770553283901, '경도': 127.05672804457532}
# {'_id': ObjectId('6194a480a04fa6007b6910e7'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001312, '상권_코드_명': '용두시장', '엑스좌표_값': 202629, '와이좌표_값': 453215, '시군구_코드': 11230, '행정동_코드': 11230536, '위도': 37.578481256301714, '경도': 127.02976243882634}
# {'_id': ObjectId('6194a480a04fa6007b6910e8'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001313, '상권_코드_명': '청량리수산시장', '엑스좌표_값': 203666, '와이좌표_값': 453187, '시군구_코드': 11230, '행정동_코드': 11230536, '위도': 37.57822543442258, '경도': 127.04150198792094}
# {'_id': ObjectId('6194a480a04fa6007b6910e9'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001321, '상권_코드_명': '답십리현대시장', '엑스좌표_값': 205255, '와이좌표_값': 451917, '시군구_코드': 11230, '행정동_코드': 11230610, '위도': 37.56677510875752, '경도': 127.0594816021787}
# {'_id': ObjectId('6194a480a04fa6007b6910ea'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001299, '상권_코드_명': '한아름시장', '엑스좌표_값': 206177, '와이좌표_값': 449338, '시군구_코드': 11215, '행정동_코드': 11215710, '위도': 37.54353267640729, '경도': 127.06989605257513}
# {'_id': ObjectId('6194a480a04fa6007b6910eb'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001085, '상권_코드_명': '서울 서초구 강남역', '엑스좌표_값': 202701, '와이좌표_값': 444730, '시군구_코드': 11680, '행정동_코드': 11680640, '위도': 37.50203121152806, '경도': 127.03054633381461}
# {'_id': ObjectId('6194a480a04fa6007b6910ec'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001086, '상권_코드_명': '고속터미널역', '엑스좌표_값': 200518, '와이좌표_값': 445031, '시군구_코드': 11650, '행정동_코드': 11650581, '위도': 37.50474704248736, '경도': 127.00585841327658}
# {'_id': ObjectId('6194a480a04fa6007b6910ed'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001087, '상권_코드_명': '서울 강남구 선릉역_2', '엑스좌표_값': 204007, '와이좌표_값': 445054, '시군구_코드': 11680, '행정동_코드': 11680640, '위도': 37.50494572617329, '경도': 127.04531799918914}
# {'_id': ObjectId('6194a480a04fa6007b6910ee'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001088, '상권_코드_명': '삼성역_1', '엑스좌표_값': 205337, '와이좌표_값': 445247, '시군구_코드': 11680, '행정동_코드': 11680610, '위도': 37.50667793699713, '경도': 127.06036130395252}
# {'_id': ObjectId('6194a480a04fa6007b6910ef'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001066, '상권_코드_명': '서울 강남구 강남역', '엑스좌표_값': 202696, '와이좌표_값': 444064, '시군구_코드': 11680, '행정동_코드': 11680640, '위도': 37.49603052520305, '경도': 127.03048734774165}
# {'_id': ObjectId('6194a480a04fa6007b6910f0'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001067, '상권_코드_명': '오류동역', '엑스좌표_값': 186098, '와이좌표_값': 444015, '시군구_코드': 11530, '행정동_코드': 11530770, '위도': 37.49548836626892, '경도': 126.84279231806514}
# {'_id': ObjectId('6194a480a04fa6007b6910f1'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001068, '상권_코드_명': '은마아파트입구사거리_2', '엑스좌표_값': 205514, '와이좌표_값': 444398, '시군구_코드': 11680, '행정동_코드': 11680610, '위도': 37.49902736333294, '경도': 127.06235680520315}
# {'_id': ObjectId('6194a480a04fa6007b6910f2'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000293, '상권_코드_명': '인촌로5길', '엑스좌표_값': 201816, '와이좌표_값': 454390, '시군구_코드': 11290, '행정동_코드': 11290600, '위도': 37.589069888712466, '경도': 127.02056152342301}
# {'_id': ObjectId('6194a480a04fa6007b6910f3'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000294, '상권_코드_명': '인촌로6길', '엑스좌표_값': 201886, '와이좌표_값': 453709, '시군구_코드': 11290, '행정동_코드': 11290610, '위도': 37.58293398628817, '경도': 127.02135234042038}
# {'_id': ObjectId('6194a480a04fa6007b6910f4'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000212, '상권_코드_명': '천호대로77길', '엑스좌표_값': 205537, '와이좌표_값': 451598, '시군구_코드': 11230, '행정동_코드': 11230650, '위도': 37.56389928147714, '경도': 127.06267116438009}
# {'_id': ObjectId('6194a480a04fa6007b6910f5'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000213, '상권_코드_명': '천호대로97길', '엑스좌표_값': 206223, '와이좌표_값': 451471, '시군구_코드': 11230, '행정동_코드': 11230650, '위도': 37.56275063990482, '경도': 127.07043465104928}
# {'_id': ObjectId('6194a480a04fa6007b6910f6'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000214, '상권_코드_명': '한천로14길', '엑스좌표_값': 205777, '와이좌표_값': 451945, '시군구_코드': 11230, '행정동_코드': 11230650, '위도': 37.56702426272566, '경도': 127.06539036288811}
# {'_id': ObjectId('6194a480a04fa6007b6910f7'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000215, '상권_코드_명': '한천로33길', '엑스좌표_값': 205926, '와이좌표_값': 453093, '시군구_코드': 11230, '행정동_코드': 11230570, '위도': 37.577366732991294, '경도': 127.06708618306541}
# {'_id': ObjectId('6194a480a04fa6007b6910f8'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000273, '상권_코드_명': '보국문로16길', '엑스좌표_값': 200903, '와이좌표_값': 456997, '시군구_코드': 11290, '행정동_코드': 11290650, '위도': 37.61256006404193, '경도': 127.01022736468003}
# {'_id': ObjectId('6194a480a04fa6007b6910f9'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000274, '상권_코드_명': '보문로13길', '엑스좌표_값': 201841, '와이좌표_값': 453388, '시군구_코드': 11290, '행정동_코드': 11290610, '위도': 37.58004188788442, '경도': 127.02084206689122}
# {'_id': ObjectId('6194a480a04fa6007b6910fa'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000370, '상권_코드_명': '방학로15길', '엑스좌표_값': 202133, '와이좌표_값': 462195, '시군구_코드': 11320, '행정동_코드': 11320710, '위도': 37.659391247274804, '경도': 127.02417349329981}
# {'_id': ObjectId('6194a480a04fa6007b6910fb'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000371, '상권_코드_명': '방학로5길', '엑스좌표_값': 203319, '와이좌표_값': 462234, '시군구_코드': 11320, '행정동_코드': 11320670, '위도': 37.6597391098479, '경도': 127.0376147199963}
# ...
# {'_id': ObjectId('6194a480a04fa6007b6915c2'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001239, '상권_코드_명': '디지털미디어시티', '엑스좌표_값': 190290, '와이좌표_값': 453427, '시군구_코드': 11440, '행정동_코드': 11440740, '위도': 37.580343931172585, '경도': 126.89007210424492}
# {'_id': ObjectId('6194a480a04fa6007b6915c3'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001240, '상권_코드_명': '혜화역 대학로_1', '엑스좌표_값': 200277, '와이좌표_값': 453642, '시군구_코드': 11110, '행정동_코드': 11110640, '위도': 37.58233221016945, '경도': 127.00313602901554}
# {'_id': ObjectId('6194a480a04fa6007b6915c4'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001459, '상권_코드_명': '신원시장', '엑스좌표_값': 193564, '와이좌표_값': 442580, '시군구_코드': 11620, '행정동_코드': 11620655, '위도': 37.48264109585288, '경도': 126.92723236679794}
# {'_id': ObjectId('6194a480a04fa6007b6915c5'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001392, '상권_코드_명': '동진시장', '엑스좌표_값': 193533, '와이좌표_값': 451424, '시군구_코드': 11440, '행정동_코드': 11440710, '위도': 37.562325492001655, '경도': 126.92680406595656}
# {'_id': ObjectId('6194a480a04fa6007b6915c6'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001393, '상권_코드_명': '마포농수산물시장', '엑스좌표_값': 190850, '와이좌표_값': 451572, '시군구_코드': 11440, '행정동_코드': 11440730, '위도': 37.56363623278709, '경도': 126.8964350575244}
# {'_id': ObjectId('6194a480a04fa6007b6915c7'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001379, '상권_코드_명': '인왕시장', '엑스좌표_값': 194990, '와이좌표_값': 454594, '시군구_코드': 11410, '행정동_코드': 11410640, '위도': 37.590896072693326, '경도': 126.94327326787227}
# {'_id': ObjectId('6194a480a04fa6007b6915c8'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001380, '상권_코드_명': '포방터시장', '엑스좌표_값': 195491, '와이좌표_값': 455485, '시군구_코드': 11410, '행정동_코드': 11410660, '위도': 37.59892649466034, '경도': 126.94894045405161}
# {'_id': ObjectId('6194a480a04fa6007b6915c9'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001381, '상권_코드_명': '모래내시장', '엑스좌표_값': 192532, '와이좌표_값': 452364, '시군구_코드': 11410, '행정동_코드': 11410690, '위도': 37.57078727706568, '경도': 126.9154648122609}
# {'_id': ObjectId('6194a480a04fa6007b6915ca'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001382, '상권_코드_명': '백련시장', '엑스좌표_값': 193208, '와이좌표_값': 453050, '시군구_코드': 11410, '행정동_코드': 11410700, '위도': 37.576973327344845, '경도': 126.92311053835193}
# {'_id': ObjectId('6194a480a04fa6007b6915cb'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001383, '상권_코드_명': '공덕시장', '엑스좌표_값': 195838, '와이좌표_값': 449448, '시군구_코드': 11440, '행정동_코드': 11440555, '위도': 37.54453507017073, '경도': 126.95290411590213}
# {'_id': ObjectId('6194a480a04fa6007b6915cc'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001384, '상권_코드_명': '마포시장', '엑스좌표_값': 195866, '와이좌표_값': 449517, '시군구_코드': 11440, '행정동_코드': 11440555, '위도': 37.54515688539801, '경도': 126.95322056654099}
# {'_id': ObjectId('6194a480a04fa6007b6915cd'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001385, '상권_코드_명': '아현시장', '엑스좌표_값': 196013, '와이좌표_값': 450782, '시군구_코드': 11440, '행정동_코드': 11440555, '위도': 37.556555158208674, '경도': 126.95487711502548}
# {'_id': ObjectId('6194a480a04fa6007b6915ce'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001386, '상권_코드_명': '신수시장', '엑스좌표_값': 194285, '와이좌표_값': 449529, '시군구_코드': 11440, '행정동_코드': 11440630, '위도': 37.545256562697425, '경도': 126.93533023436349}
# {'_id': ObjectId('6194a480a04fa6007b6915cf'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001387, '상권_코드_명': '서교시장', '엑스좌표_값': 193067, '와이좌표_값': 450433, '시군구_코드': 11440, '행정동_코드': 11440660, '위도': 37.55339322966758, '경도': 126.92153907019247}
# {'_id': ObjectId('6194a480a04fa6007b6915d0'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001388, '상권_코드_명': '영진시장', '엑스좌표_값': 192299, '와이좌표_값': 450437, '시군구_코드': 11440, '행정동_코드': 11440660, '위도': 37.55342317415335, '경도': 126.9128475622764}
# {'_id': ObjectId('6194a480a04fa6007b6915d1'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001389, '상권_코드_명': '합정시장', '엑스좌표_값': 192331, '와이좌표_값': 449862, '시군구_코드': 11440, '행정동_코드': 11440680, '위도': 37.54824270634102, '경도': 126.91321571394744}
# {'_id': ObjectId('6194a480a04fa6007b6915d2'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001390, '상권_코드_명': '망원시장', '엑스좌표_값': 191700, '와이좌표_값': 450757, '시군구_코드': 11440, '행정동_코드': 11440690, '위도': 37.556301164837045, '경도': 126.9060650512631}
# {'_id': ObjectId('6194a480a04fa6007b6915d3'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000074, '상권_코드_명': '청파로47나길', '엑스좌표_값': 197173, '와이좌표_값': 449736, '시군구_코드': 11170, '행정동_코드': 11170555, '위도': 37.54713500588048, '경도': 126.9680094448663}
# {'_id': ObjectId('6194a480a04fa6007b6915d4'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000075, '상권_코드_명': '청파로71길', '엑스좌표_값': 197088, '와이좌표_값': 449997, '시군구_코드': 11170, '행정동_코드': 11170555, '위도': 37.54948634768875, '경도': 126.96704654306637}
# {'_id': ObjectId('6194a480a04fa6007b6915d5'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000076, '상권_코드_명': '청파로73길', '엑스좌표_값': 197110, '와이좌표_값': 450285, '시군구_코드': 11170, '행정동_코드': 11170555, '위도': 37.552081291755876, '경도': 126.96729437074947}
# {'_id': ObjectId('6194a480a04fa6007b6915d6'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000159, '상권_코드_명': '자양로15길', '엑스좌표_값': 207186, '와이좌표_값': 448484, '시군구_코드': 11215, '행정동_코드': 11215820, '위도': 37.535830833660924, '경도': 127.08130506104884}
# {'_id': ObjectId('6194a480a04fa6007b6915d7'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000125, '상권_코드_명': '한림말3길', '엑스좌표_값': 201433, '와이좌표_값': 449279, '시군구_코드': 11200, '행정동_코드': 11200645, '위도': 37.543020659532004, '경도': 127.01621505009958}
# {'_id': ObjectId('6194a480a04fa6007b6915d8'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000126, '상권_코드_명': '한림말길', '엑스좌표_값': 201180, '와이좌표_값': 449048, '시군구_코드': 11200, '행정동_코드': 11200645, '위도': 37.54093970867538, '경도': 127.01335186835556}
# {'_id': ObjectId('6194a480a04fa6007b6915d9'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000127, '상권_코드_명': '광나루로12길', '엑스좌표_값': 206073, '와이좌표_값': 449751, '시군구_코드': 11215, '행정동_코드': 11215710, '위도': 37.5472544910565, '경도': 127.06872265367673}
# {'_id': ObjectId('6194a480a04fa6007b6915da'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001141, '상권_코드_명': '압구정 로데오거리_2', '엑스좌표_값': 203288, '와이좌표_값': 447403, '시군구_코드': 11680, '행정동_코드': 11680545, '위도': 37.52611313953564, '경도': 127.03719682412944}
# {'_id': ObjectId('6194a480a04fa6007b6915db'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001142, '상권_코드_명': '국회의사당역_1', '엑스좌표_값': 192692, '와이좌표_값': 447554, '시군구_코드': 11560, '행정동_코드': 11560540, '위도': 37.52745057202793, '경도': 126.91732383690497}
# {'_id': ObjectId('6194a480a04fa6007b6915dc'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001143, '상권_코드_명': '서울 용산구 신용산역', '엑스좌표_값': 197315, '와이좌표_값': 447811, '시군구_코드': 11170, '행정동_코드': 11170625, '위도': 37.5297911780406, '경도': 126.96962336458623}
# {'_id': ObjectId('6194a480a04fa6007b6915dd'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001144, '상권_코드_명': '국회의사당역_2', '엑스좌표_값': 192947, '와이좌표_값': 447754, '시군구_코드': 11560, '행정동_코드': 11560540, '위도': 37.529254558111724, '경도': 126.92020675631002}
# {'_id': ObjectId('6194a480a04fa6007b6915de'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001145, '상권_코드_명': '용산 전자상가_1', '엑스좌표_값': 196497, '와이좌표_값': 447798, '시군구_코드': 11170, '행정동_코드': 11170625, '위도': 37.52967130494357, '경도': 126.96036901949611}
# {'_id': ObjectId('6194a480a04fa6007b6915df'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001146, '상권_코드_명': '용산구청', '엑스좌표_값': 199141, '와이좌표_값': 448098, '시군구_코드': 11170, '행정동_코드': 11170650, '위도': 37.53238055868387, '경도': 126.99028140328255}
# {'_id': ObjectId('6194a480a04fa6007b6915e0'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001147, '상권_코드_명': '용산 전자상가_2', '엑스좌표_값': 196988, '와이좌표_값': 448177, '시군구_코드': 11170, '행정동_코드': 11170625, '위도': 37.53308783278587, '경도': 126.96592236399441}
# {'_id': ObjectId('6194a480a04fa6007b6915e1'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001148, '상권_코드_명': '목동사거리', '엑스좌표_값': 187986, '와이좌표_값': 448119, '시군구_코드': 11470, '행정동_코드': 11470540, '위도': 37.5324919471084, '경도': 126.8640752430311}
# {'_id': ObjectId('6194a480a04fa6007b6915e2'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001149, '상권_코드_명': '한남오거리', '엑스좌표_값': 200551, '와이좌표_값': 448182, '시군구_코드': 11170, '행정동_코드': 11170685, '위도': 37.5331376349698, '경도': 127.00623399409143}
# {'_id': ObjectId('6194a480a04fa6007b6915e3'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001241, '상권_코드_명': '혜화역 대학로_2', '엑스좌표_값': 199884, '와이좌표_값': 453809, '시군구_코드': 11110, '행정동_코드': 11110650, '위도': 37.58383690352655, '경도': 126.99868669065837}
# {'_id': ObjectId('6194a480a04fa6007b6915e4'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001242, '상권_코드_명': '혜화역 대학로_3', '엑스좌표_값': 200023, '와이좌표_값': 453715, '시군구_코드': 11110, '행정동_코드': 11110650, '위도': 37.58298997678076, '경도': 127.00026039459195}
# {'_id': ObjectId('6194a480a04fa6007b6915e5'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001243, '상권_코드_명': '서울 성북구 안암역', '엑스좌표_값': 202618, '와이좌표_값': 454030, '시군구_코드': 11290, '행정동_코드': 11290600, '위도': 37.58582438415557, '경도': 127.02964082093199}
# {'_id': ObjectId('6194a480a04fa6007b6915e6'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001244, '상권_코드_명': '경희대학교', '엑스좌표_값': 204609, '와이좌표_값': 454758, '시군구_코드': 11230, '행정동_코드': 11230710, '위도': 37.592375793905326, '경도': 127.0521873625993}
# {'_id': ObjectId('6194a480a04fa6007b6915e7'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001245, '상권_코드_명': '서울 성북구 성신여대입구역', '엑스좌표_값': 201566, '와이좌표_값': 454637, '시군구_코드': 11290, '행정동_코드': 11290575, '위도': 37.591295798803905, '경도': 127.01773144531104}
# {'_id': ObjectId('6194a480a04fa6007b6915e8'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001246, '상권_코드_명': '미아사거리_1', '엑스좌표_값': 202631, '와이좌표_값': 456413, '시군구_코드': 11290, '행정동_코드': 11290715, '위도': 37.60729496817233, '경도': 127.02979656631537}
# {'_id': ObjectId('6194a480a04fa6007b6915e9'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001204, '상권_코드_명': '서울 중구 을지로3가역_1', '엑스좌표_값': 199308, '와이좌표_값': 451766, '시군구_코드': 11140, '행정동_코드': 11140605, '위도': 37.56542932908629, '경도': 126.99216735868663}
# {'_id': ObjectId('6194a480a04fa6007b6915ea'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001205, '상권_코드_명': '동대문역사문화공원역', '엑스좌표_값': 200426, '와이좌표_값': 451788, '시군구_코드': 11140, '행정동_코드': 11140590, '위도': 37.56562770958554, '경도': 127.00482184111223}
# {'_id': ObjectId('6194a480a04fa6007b6915eb'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001157, '상권_코드_명': '서울 강동구 천호역_1', '엑스좌표_값': 211139, '와이좌표_값': 448643, '시군구_코드': 11740, '행정동_코드': 11740650, '위도': 37.537224158914064, '경도': 127.12603309416232}
# {'_id': ObjectId('6194a480a04fa6007b6915ec'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001391, '상권_코드_명': '망원월드컵시장', '엑스좌표_값': 191642, '와이좌표_값': 450960, '시군구_코드': 11440, '행정동_코드': 11440700, '위도': 37.55812966295797, '경도': 126.90540632714048}
# {'_id': ObjectId('6194a480a04fa6007b6915ed'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001403, '상권_코드_명': '신월7동골목시장', '엑스좌표_값': 185257, '와이좌표_값': 447058, '시군구_코드': 11470, '행정동_코드': 11470611, '위도': 37.52289278529112, '경도': 126.83322110262583}
# {'_id': ObjectId('6194a480a04fa6007b6915ee'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001404, '상권_코드_명': '신정제일시장', '엑스좌표_값': 187123, '와이좌표_값': 446835, '시군구_코드': 11470, '행정동_코드': 11470620, '위도': 37.52091147699331, '경도': 126.85433390357734}
# {'_id': ObjectId('6194a480a04fa6007b6915ef'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001405, '상권_코드_명': '신정2동골목시장', '엑스좌표_값': 189085, '와이좌표_값': 446859, '시군구_코드': 11470, '행정동_코드': 11470630, '위도': 37.52115300438805, '경도': 126.87652786415516}
# {'_id': ObjectId('6194a480a04fa6007b6915f0'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001406, '상권_코드_명': '신정3동골목시장', '엑스좌표_값': 187005, '와이좌표_값': 446592, '시군구_코드': 11470, '행정동_코드': 11470640, '위도': 37.518720392897634, '경도': 126.85300337322856}
# {'_id': ObjectId('6194a480a04fa6007b6915f1'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001394, '상권_코드_명': '목2동시장', '엑스좌표_값': 188801, '와이좌표_값': 449649, '시군구_코드': 11470, '행정동_코드': 11470520, '위도': 37.54628746759511, '경도': 126.87327269199903}
# {'_id': ObjectId('6194a480a04fa6007b6915f2'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001395, '상권_코드_명': '목3동시장', '엑스좌표_값': 188065, '와이좌표_값': 449908, '시군구_코드': 11470, '행정동_코드': 11470530, '위도': 37.5486118161891, '경도': 126.86493996412445}
# {'_id': ObjectId('6194a480a04fa6007b6915f3'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001271, '상권_코드_명': '동묘시장', '엑스좌표_값': 201645, '와이좌표_값': 452549, '시군구_코드': 11110, '행정동_코드': 11110710, '위도': 37.57248291567694, '경도': 127.01862125723245}
# {'_id': ObjectId('6194a480a04fa6007b6915f4'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001359, '상권_코드_명': '창동신창시장', '엑스좌표_값': 203266, '와이좌표_값': 460010, '시군구_코드': 11320, '행정동_코드': 11320512, '위도': 37.63970143730703, '경도': 127.0370041198399}
# {'_id': ObjectId('6194a480a04fa6007b6915f5'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001360, '상권_코드_명': '창동골목시장', '엑스좌표_값': 203458, '와이좌표_값': 459884, '시군구_코드': 11320, '행정동_코드': 11320513, '위도': 37.638565494331445, '경도': 127.03917890321948}
# {'_id': ObjectId('6194a480a04fa6007b6915f6'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001361, '상권_코드_명': '신도봉시장', '엑스좌표_값': 203671, '와이좌표_값': 463403, '시군구_코드': 11320, '행정동_코드': 11320521, '위도': 37.67027023397148, '경도': 127.04160986646488}
# {'_id': ObjectId('6194a480a04fa6007b6915f7'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000403, '상권_코드_명': '연서로21길', '엑스좌표_값': 192548, '와이좌표_값': 457302, '시군구_코드': 11380, '행정동_코드': 11380552, '위도': 37.61527833797514, '경도': 126.91559569338234}
# {'_id': ObjectId('6194a480a04fa6007b6915f8'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000404, '상권_코드_명': '연서로27길', '엑스좌표_값': 192672, '와이좌표_값': 457591, '시군구_코드': 11380, '행정동_코드': 11380552, '위도': 37.617883187574144, '경도': 126.9169972708041}
# {'_id': ObjectId('6194a480a04fa6007b6915f9'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000405, '상권_코드_명': '연서로28길', '엑스좌표_값': 193069, '와이좌표_값': 457405, '시군구_코드': 11380, '행정동_코드': 11380570, '위도': 37.6162104283088, '경도': 126.92149576504762}
# {'_id': ObjectId('6194a480a04fa6007b6915fa'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000406, '상권_코드_명': '연서로29길', '엑스좌표_값': 192727, '와이좌표_값': 457882, '시군구_코드': 11380, '행정동_코드': 11380551, '위도': 37.62050549616045, '경도': 126.91761735084197}
# {'_id': ObjectId('6194a480a04fa6007b6915fb'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000407, '상권_코드_명': '연서로33길', '엑스좌표_값': 193322, '와이좌표_값': 458034, '시군구_코드': 11380, '행정동_코드': 11380530, '위도': 37.621879508885414, '경도': 126.92435563537262}
# {'_id': ObjectId('6194a480a04fa6007b6915fc'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000425, '상권_코드_명': '증산로21길', '엑스좌표_값': 192270, '와이좌표_값': 455209, '시군구_코드': 11380, '행정동_코드': 11380631, '위도': 37.59641834662928, '경도': 126.91246905838028}
# {'_id': ObjectId('6194a480a04fa6007b6915fd'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000047, '상권_코드_명': '퇴계로56길', '엑스좌표_값': 200427, '와이좌표_값': 451429, '시군구_코드': 11140, '행정동_코드': 11140580, '위도': 37.562393132290616, '경도': 127.00483295102657}
# {'_id': ObjectId('6194a480a04fa6007b6915fe'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001150, '상권_코드_명': '서울 용산구 이태원역', '엑스좌표_값': 199532, '와이좌표_값': 448274, '시군구_코드': 11170, '행정동_코드': 11170650, '위도': 37.53396660171813, '경도': 126.99470500630214}
# {'_id': ObjectId('6194a480a04fa6007b6915ff'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001151, '상권_코드_명': '용산 전자상가_3', '엑스좌표_값': 196249, '와이좌표_값': 448167, '시군구_코드': 11170, '행정동_코드': 11170570, '위도': 37.53299502410429, '경도': 126.95756140332672}
# {'_id': ObjectId('6194a480a04fa6007b691600'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001152, '상권_코드_명': '서울 광진구 강변역', '엑스좌표_값': 208480, '와이좌표_값': 448480, '시군구_코드': 11215, '행정동_코드': 11215870, '위도': 37.53578380626318, '경도': 127.09594579196927}
# {'_id': ObjectId('6194a480a04fa6007b691601'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001153, '상권_코드_명': '당산역_1', '엑스좌표_값': 191112, '와이좌표_값': 448327, '시군구_코드': 11560, '행정동_코드': 11560620, '위도': 37.534401436510095, '경도': 126.89943980564207}
# {'_id': ObjectId('6194a480a04fa6007b691602'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001154, '상권_코드_명': '용산 전자상가_4', '엑스좌표_값': 196450, '와이좌표_값': 448406, '시군구_코드': 11170, '행정동_코드': 11170560, '위도': 37.53514921107346, '경도': 126.9598343502998}
# {'_id': ObjectId('6194a480a04fa6007b691603'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001155, '상권_코드_명': '용산 전자상가_5', '엑스좌표_값': 196870, '와이좌표_값': 448350, '시군구_코드': 11170, '행정동_코드': 11170560, '위도': 37.53464617134183, '경도': 126.96458658036106}
# {'_id': ObjectId('6194a480a04fa6007b691604'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001156, '상권_코드_명': '서울 강동구 길동역', '엑스좌표_값': 212214, '와이좌표_값': 448512, '시군구_코드': 11740, '행정동_코드': 11740685, '위도': 37.53603024424155, '경도': 127.13819405734606}
# {'_id': ObjectId('6194a480a04fa6007b691605'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001120, '상권_코드_명': '도산공원사거리_1', '엑스좌표_값': 202754, '와이좌표_값': 446796, '시군구_코드': 11680, '행정동_코드': 11680545, '위도': 37.52064580299694, '경도': 127.03115346079875}

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in c:\users\joach\anaconda3\lib\site-packages (from folium) (1.20.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\joach\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in c:\users\joach\anaconda3\lib\site-packages (from folium) (2.25.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\joach\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\joach\anaconda3\lib\site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joach\anaconda3\lib\site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\joach\anaconda3\lib\site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\joach\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1

# %%
import folium

# %%
m = folium.Map(location=[37.5335,126.9896], zoom_start=12)
from folium.plugins import MarkerCluster
marker_cluster = MarkerCluster().add_to(m)

for item in collection.find():
    folium.Marker(location=[item['위도'],item['경도']], popup=item['상권_코드_명'], icon=folium.Icon(color='red', icon='ok'), ).add_to(marker_cluster)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2cba829a5772415aa6e807b3747f1e27%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2cba829a5772415aa6e807b3747f1e27%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...
