# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
def read_files_spark(local_dir,header):
    df = spark.read.csv(local_dir,encoding='cp949',header=header)
    return df

# %%
from pyspark.sql import SparkSession
import databricks.koalas as ks

spark = SparkSession.builder.getOrCreate()
# Out:
# WARNING:root:Found numpy version "1.20.1" installed with pyspark version "2.4.8". Some functions will not work well with this combination of numpy version "1.20.1" and pyspark version "2.4.8". Please try to upgrade pyspark version to 3.1 or above, or downgrade numpy version to below 1.20.
# WARNING:root:'ARROW_PRE_0_15_IPC_FORMAT' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=0.15 and pyspark<3.0. Koalas will set it for you but it does not work if there is a Spark context already launched.
# WARNING:root:'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. Koalas will set it for you but it does not work if there is a Spark context already launched.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://host.docker.internal:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.8</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ----------------

# %% [markdown]
# ### 상권-영역 데이터 API호출 및 CSV생성

# %%
auth_key = '6f666551526a6f6132345a62664e58'
change_keys = {"TRDAR_SE_CD":"상권_구분_코드","TRDAR_SE_CD_NM":"상권_구분_코드_명","TRDAR_CD":"상권_코드","TRDAR_CD_NM":"상권_코드_명","XCNTS_VALUE":"엑스좌표_값","YDNTS_VALUE":"와이좌표_값","SIGNGU_CD":"시군구_코드","ADSTRD_CD":"행정동_코드","STDR_YM_CD":"기준_년월_코드"}

start, end  = 1, 1000
df = pd.DataFrame()
for i in range(2):
    url = f'http://openapi.seoul.go.kr:8088/{auth_key}/json/TbgisTrdarRelm/{start}/{end}/'
    res = requests.get(url)
    data = res.json()['TbgisTrdarRelm']['row']
    data = [{change_keys[k]:v for k,v in row.items()} for row in data]

    df = pd.concat([df,pd.json_normalize(data)])
            
    start += 1000
    end += 1000

df.to_csv("./상권-영역/서울시 우리마을가게 상권분석서비스(상권영역).csv", index=None, encoding='cp949')

# %%
df
# Out:
#     상권_구분_코드 상권_구분_코드_명    상권_코드       상권_코드_명  엑스좌표_값  와이좌표_값 시군구_코드  \
# 0          A       골목상권  1000275        보문로26길  201886  454183  11290
# 1          A       골목상권  1000276        보문로31길  201385  454290  11290
# 2          D       발달상권  1001045  동작구 총신대입구역_1  198304  442948  11590
# 3          D       발달상권  1001046  서울 관악구 신림역_4  193828  443001  11620
# 4          D       발달상권  1001047       뱅뱅사거리_1  202960  443242  11680
# ..       ...        ...      ...           ...     ...     ...    ...
# 491        D       발달상권  1001153         당산역_1  191112  448327  11560
# 492        D       발달상권  1001154     용산 전자상가_4  196450  448406  11170
# 493        D       발달상권  1001155     용산 전자상가_5  196870  448350  11170
# 494        D       발달상권  1001156    서울 강동구 길동역  212214  448512  11740
# 495        D       발달상권  1001120     도산공원사거리_1  202754  446796  11680
#
#        행정동_코드 기준_년월_코드
# 0    11290600   201810
# 1    11290555   201810
# 2    11590630   201810
# 3    11620695   201810
# 4    11680655   201810
# ..        ...      ...
# 491  11560620   201810
# 492  11170560   201810
# 493  11170560   201810
# 494  11740685   201810
# 495  11680545   201810
#
# [1496 rows x 9 columns]

# %% [markdown]
# ### 좌표 변환 모듈 설치 및 import

# %%
# !pip install pyproj
# Out:
# Requirement already satisfied: pyproj in c:\users\joach\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: certifi in c:\users\joach\anaconda3\lib\site-packages (from pyproj) (2020.12.5)

# %%
from pyproj import Transformer

# %% [markdown]
# #### 도로명 주소에서 위도,경도 좌표로 변환

# %%
# from UMTK to WSG84
transformer = Transformer.from_crs("epsg:5181", "epsg:4326")

# %%
DataFrame = df.copy()

long_list = []
lat_list = []

for idx, row in DataFrame.iterrows():
    x, y = row['엑스좌표_값'], row['와이좌표_값']
    latitude, longitude = transformer.transform(x, y)
    long_list.append(longitude)
    lat_list.append(latitude)

# %%
df['위도'] = lat_list
df['경도'] = long_list

# %%
df = df.drop(columns=['기준_년월_코드','상권_구분_코드'])

# %%
df
# Out:
#     상권_구분_코드_명    상권_코드       상권_코드_명  엑스좌표_값  와이좌표_값 시군구_코드    행정동_코드  \
# 0         골목상권  1000275        보문로26길  201886  454183  11290  11290600
# 1         골목상권  1000276        보문로31길  201385  454290  11290  11290555
# 2         발달상권  1001045  동작구 총신대입구역_1  198304  442948  11590  11590630
# 3         발달상권  1001046  서울 관악구 신림역_4  193828  443001  11620  11620695
# 4         발달상권  1001047       뱅뱅사거리_1  202960  443242  11680  11680655
# ..         ...      ...           ...     ...     ...    ...       ...
# 491       발달상권  1001153         당산역_1  191112  448327  11560  11560620
# 492       발달상권  1001154     용산 전자상가_4  196450  448406  11170  11170560
# 493       발달상권  1001155     용산 전자상가_5  196870  448350  11170  11170560
# 494       발달상권  1001156    서울 강동구 길동역  212214  448512  11740  11740685
# 495       발달상권  1001120     도산공원사거리_1  202754  446796  11680  11680545
#
#             위도          경도
# 0    35.281318  129.793627
# 1    35.276780  129.794647
# 2    35.251855  129.669211
# 3    35.211541  129.668472
# 4    35.293704  129.673816
# ..         ...         ...
# 491  35.185786  129.726082
# 492  35.233826  129.728557
# 493  35.237621  129.728069
# 494  35.375724  129.734495
# 495  35.290980  129.712783
#
# [1496 rows x 9 columns]

# %%
df.to_csv("./상권-영역/서울시 우리마을가게 상권분석서비스(상권영역)-위도,경도 추가.csv", index=None, encoding='cp949')

# %%
df = df.astype({"상권_구분_코드_명":str,"상권_코드":int,"상권_코드_명":str,"엑스좌표_값":int,"와이좌표_값":int,"시군구_코드":int,"행정동_코드":int,"위도":float,"경도":float})

# %%
df.dtypes
# Out:
# 상권_구분_코드_명     object
# 상권_코드           int32
# 상권_코드_명        object
# 엑스좌표_값          int32
# 와이좌표_값          int32
# 시군구_코드          int32
# 행정동_코드          int32
# 위도            float64
# 경도            float64
# dtype: object

# %%
import pymongo

# %%
connection = pymongo.MongoClient("mongodb+srv://user1:uZGuuMyRngM3izgG@cluster0.cu0c3.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
connection.list_database_names()
# Out:
# ['elice', 'admin', 'local']

# %%
db = connection.get_database("elice")

# %%
collection = db.get_collection("area_info")

# %%
df.to_dict('records')
# Out:
# [{'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000275,
#   '상권_코드_명': '보문로26길',
#   '엑스좌표_값': 201886,
#   '와이좌표_값': 454183,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290600,
#   '위도': 35.281317687486414,
#   '경도': 129.79362710633055},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000276,
#   '상권_코드_명': '보문로31길',
#   '엑스좌표_값': 201385,
#   '와이좌표_값': 454290,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290555,
#   '위도': 35.27678019592645,
#   '경도': 129.79464677864775},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001045,
#   '상권_코드_명': '동작구 총신대입구역_1',
#   '엑스좌표_값': 198304,
#   '와이좌표_값': 442948,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590630,
#   '위도': 35.2518546600379,
#   '경도': 129.66921104674586},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001046,
#   '상권_코드_명': '서울 관악구 신림역_4',
#   '엑스좌표_값': 193828,
#   '와이좌표_값': 443001,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620695,
#   '위도': 35.21154133987412,
#   '경도': 129.6684718345857},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001047,
#   '상권_코드_명': '뱅뱅사거리_1',
#   '엑스좌표_값': 202960,
#   '와이좌표_값': 443242,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680655,
#   '위도': 35.29370410909769,
#   '경도': 129.67381623988248},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001048,
#   '상권_코드_명': '뱅뱅사거리',
#   '엑스좌표_값': 202638,
#   '와이좌표_값': 443504,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650520,
#   '위도': 35.290741286663966,
#   '경도': 129.67659794379557},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001049,
#   '상권_코드_명': '개봉동 현대아파트 인근',
#   '엑스좌표_값': 187247,
#   '와이좌표_값': 443356,
#   '시군구_코드': 11530,
#   '행정동_코드': 11530760,
#   '위도': 35.15220177311876,
#   '경도': 129.67042619665293},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001050,
#   '상권_코드_명': '교대역_1',
#   '엑스좌표_값': 201023,
#   '와이좌표_값': 443482,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650530,
#   '위도': 35.27620589814781,
#   '경도': 129.67587757738818},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001260,
#   '상권_코드_명': '창동역',
#   '엑스좌표_값': 204324,
#   '와이좌표_값': 461465,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320514,
#   '위도': 35.30139054593065,
#   '경도': 129.8743486608515},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001261,
#   '상권_코드_명': '서울 노원구 노원역_1',
#   '엑스좌표_값': 205532,
#   '와이좌표_값': 461611,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350695,
#   '위도': 35.31222680475741,
#   '경도': 129.87633707045256},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001262,
#   '상권_코드_명': '서울 노원구 노원역_2',
#   '엑스좌표_값': 205198,
#   '와이좌표_값': 461669,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350695,
#   '위도': 35.309204978917144,
#   '경도': 129.8768674996572},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001263,
#   '상권_코드_명': '서울 노원구 노원역_3',
#   '엑스좌표_값': 205516,
#   '와이좌표_값': 461822,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350640,
#   '위도': 35.31202758695581,
#   '경도': 129.8786492378735},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001217,
#   '상권_코드_명': '서울 종로구 종로5가역_1',
#   '엑스좌표_값': 200123,
#   '와이좌표_값': 452320,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110630,
#   '위도': 35.265916665409335,
#   '경도': 129.77263169493617},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001255,
#   '상권_코드_명': '서울 은평구 연신내역_3',
#   '엑스좌표_값': 192979,
#   '와이좌표_값': 457903,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380530,
#   '위도': 35.20018228056756,
#   '경도': 129.83167710402108},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001259,
#   '상권_코드_명': '서울 강북구 수유역_3',
#   '엑스좌표_값': 202401,
#   '와이좌표_값': 460138,
#   '시군구_코드': 11305,
#   '행정동_코드': 11305630,
#   '위도': 35.28442515298064,
#   '경도': 129.8591675318602},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001310,
#   '상권_코드_명': '구의시장',
#   '엑스좌표_값': 207818,
#   '와이좌표_값': 449558,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215860,
#   '위도': 35.335886440963804,
#   '경도': 129.74465260591654},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001322,
#   '상권_코드_명': '동부시장',
#   '엑스좌표_값': 204647,
#   '와이좌표_값': 451975,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230600,
#   '위도': 35.306732341987754,
#   '경도': 129.77023269242687},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001323,
#   '상권_코드_명': '답십리시장',
#   '엑스좌표_값': 205141,
#   '와이좌표_값': 452679,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230610,
#   '위도': 35.31100220671458,
#   '경도': 129.77811659074976},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001324,
#   '상권_코드_명': '전곡시장',
#   '엑스좌표_값': 206080,
#   '와이좌표_값': 453173,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230660,
#   '위도': 35.31933087632621,
#   '경도': 129.7838321311872},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001325,
#   '상권_코드_명': '청량리청과물시장',
#   '엑스좌표_값': 203815,
#   '와이좌표_값': 453397,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 35.29888306945464,
#   '경도': 129.78559291703786},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001451,
#   '상권_코드_명': '사당시장',
#   '엑스좌표_값': 197801,
#   '와이좌표_값': 442618,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590650,
#   '위도': 35.24740570358293,
#   '경도': 129.66544057199204},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001468,
#   '상권_코드_명': '남부종합시장',
#   '엑스좌표_값': 198664,
#   '와이좌표_값': 443924,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650590,
#   '위도': 35.25485901530997,
#   '경도': 129.68003045461066},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001469,
#   '상권_코드_명': '양재시장',
#   '엑스좌표_값': 203388,
#   '와이좌표_값': 442737,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650651,
#   '위도': 35.29768020295667,
#   '경도': 129.6683970142627},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001407,
#   '상권_코드_명': '등마루시장',
#   '엑스좌표_값': 187644,
#   '와이좌표_값': 450807,
#   '시군구_코드': 11500,
#   '행정동_코드': 11500520,
#   '위도': 35.15394698111949,
#   '경도': 129.75222627438592},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001408,
#   '상권_코드_명': '신월중앙시장',
#   '엑스좌표_값': 186247,
#   '와이좌표_값': 451047,
#   '시군구_코드': 11500,
#   '행정동_코드': 11500535,
#   '위도': 35.14130971862605,
#   '경도': 129.75443304688392},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001450,
#   '상권_코드_명': '남성역골목시장',
#   '엑스좌표_값': 197564,
#   '와이좌표_값': 442672,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590650,
#   '위도': 35.24525876659679,
#   '경도': 129.66596335407291},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001042,
#   '상권_코드_명': '서울 서초구 남부터미널역_3',
#   '엑스좌표_값': 201432,
#   '와이좌표_값': 443037,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650510,
#   '위도': 35.27999641541479,
#   '경도': 129.67111274528494},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001043,
#   '상권_코드_명': '동작구 총신대입구역_2',
#   '엑스좌표_값': 198499,
#   '와이좌표_값': 442941,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650621,
#   '위도': 35.25361206764796,
#   '경도': 129.6691918072012},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001044,
#   '상권_코드_명': '양재역_3',
#   '엑스좌표_값': 202755,
#   '와이좌표_값': 443008,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650520,
#   '위도': 35.29191519632861,
#   '경도': 129.67118582471718},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001030,
#   '상권_코드_명': '양재역_2',
#   '엑스좌표_값': 203216,
#   '와이좌표_값': 442691,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650651,
#   '위도': 35.29614273737612,
#   '경도': 129.6678409682446},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001031,
#   '상권_코드_명': '서울 관악구 신림역_1',
#   '엑스좌표_값': 193706,
#   '와이좌표_값': 442615,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620645,
#   '위도': 35.21053620681941,
#   '경도': 129.66420121735118},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001032,
#   '상권_코드_명': '서울 관악구 신림역_2',
#   '엑스좌표_값': 193880,
#   '와이좌표_값': 442602,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620645,
#   '위도': 35.21210599946857,
#   '경도': 129.66410981412915},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001033,
#   '상권_코드_명': '서울 서초구 남부터미널역_1',
#   '엑스좌표_값': 201661,
#   '와이좌표_값': 442764,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650510,
#   '위도': 35.28212443889652,
#   '경도': 129.66818290344662},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000379,
#   '상권_코드_명': '동일로173가길',
#   '엑스좌표_값': 206395,
#   '와이좌표_값': 458052,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350595,
#   '위도': 35.32091993699389,
#   '경도': 129.83752154347852},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000380,
#   '상권_코드_명': '동일로192길',
#   '엑스좌표_값': 206671,
#   '와이좌표_값': 458471,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350595,
#   '위도': 35.323296376128624,
#   '경도': 129.84221080753187},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000381,
#   '상권_코드_명': '동일로242길',
#   '엑스좌표_값': 205175,
#   '와이좌표_값': 463916,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350630,
#   '위도': 35.30840789970422,
#   '경도': 129.90153617611315},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000071,
#   '상권_코드_명': '이태원로54길',
#   '엑스좌표_값': 200121,
#   '와이좌표_값': 448560,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170685,
#   '위도': 35.26683816279801,
#   '경도': 129.73135627259367},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000072,
#   '상권_코드_명': '장문로45길',
#   '엑스좌표_값': 200041,
#   '와이좌표_값': 447690,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170700,
#   '위도': 35.26633328589014,
#   '경도': 129.72178160728896},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000073,
#   '상권_코드_명': '청파로47길',
#   '엑스좌표_값': 197165,
#   '와이좌표_값': 449449,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170555,
#   '위도': 35.24000408650469,
#   '경도': 129.7402188551146},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001490,
#   '상권_코드_명': '길동복조리시장',
#   '엑스좌표_값': 212698,
#   '와이좌표_값': 448781,
#   '시군구_코드': 11740,
#   '행정동_코드': 11740685,
#   '위도': 35.38001468739503,
#   '경도': 129.73759942052172},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001332,
#   '상권_코드_명': '사가정시장',
#   '엑스좌표_값': 207989,
#   '와이좌표_값': 453527,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260575,
#   '위도': 35.3364272719127,
#   '경도': 129.78831107785217},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001333,
#   '상권_코드_명': '중화제일시장',
#   '엑스좌표_값': 206662,
#   '와이좌표_값': 456140,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260630,
#   '위도': 35.32381500732583,
#   '경도': 129.8166034825286},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001334,
#   '상권_코드_명': '태능시장',
#   '엑스좌표_값': 206759,
#   '와이좌표_값': 455413,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260610,
#   '위도': 35.32487416276388,
#   '경도': 129.80864794075535},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001335,
#   '상권_코드_명': '묵1동도깨비시장',
#   '엑스좌표_값': 207147,
#   '와이좌표_값': 457479,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260620,
#   '위도': 35.32783733222013,
#   '경도': 129.83146395539433},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001336,
#   '상권_코드_명': '우림골목시장',
#   '엑스좌표_값': 208659,
#   '와이좌표_값': 455348,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260655,
#   '위도': 35.34199547430626,
#   '경도': 129.80852607910472},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001337,
#   '상권_코드_명': '유영시장',
#   '엑스좌표_값': 208553,
#   '와이좌표_값': 454672,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260660,
#   '위도': 35.341213676124994,
#   '경도': 129.8010658507598},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001338,
#   '상권_코드_명': '돈암제일시장',
#   '엑스좌표_값': 201402,
#   '와이좌표_값': 454703,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290555,
#   '위도': 35.27682833556265,
#   '경도': 129.7991860956799},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001377,
#   '상권_코드_명': '영천시장',
#   '엑스좌표_값': 196581,
#   '와이좌표_값': 452325,
#   '시군구_코드': 11410,
#   '행정동_코드': 11410520,
#   '위도': 35.234027195899564,
#   '경도': 129.7716002275833},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001057,
#   '상권_코드_명': '교대역_2',
#   '엑스좌표_값': 201412,
#   '와이좌표_값': 443757,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650510,
#   '위도': 35.2796414070999,
#   '경도': 129.67901231732245},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001058,
#   '상권_코드_명': '역삼역_1',
#   '엑스좌표_값': 203292,
#   '와이좌표_값': 443852,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680640,
#   '위도': 35.29654489494053,
#   '경도': 129.68061370872556},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001059,
#   '상권_코드_명': '교대역_3',
#   '엑스좌표_값': 201065,
#   '와이좌표_값': 443865,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650530,
#   '위도': 35.2764908967652,
#   '경도': 129.68009513027172},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001060,
#   '상권_코드_명': '가락시장',
#   '엑스좌표_값': 210036,
#   '와이좌표_값': 443852,
#   '시군구_코드': 11710,
#   '행정동_코드': 11710631,
#   '위도': 35.357264146244965,
#   '경도': 129.6826203354508},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001061,
#   '상권_코드_명': '방배동카페골목',
#   '엑스좌표_값': 198796,
#   '와이좌표_값': 443913,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650590,
#   '위도': 35.25605016201411,
#   '경도': 129.67994886109093},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001062,
#   '상권_코드_명': '서울 강남구 강남역_1',
#   '엑스좌표_값': 202416,
#   '와이좌표_값': 443988,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650520,
#   '위도': 35.288624697300804,
#   '경도': 129.68184691694157},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001181,
#   '상권_코드_명': '서울 광진구 군자역',
#   '엑스좌표_값': 206935,
#   '와이좌표_값': 450796,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215730,
#   '위도': 35.32762710722659,
#   '경도': 129.75798389823967},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001123,
#   '상권_코드_명': '학동사거리_1',
#   '엑스좌표_값': 203226,
#   '와이좌표_값': 446892,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680531,
#   '위도': 35.295205621604545,
#   '경도': 129.71397872962572},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001017,
#   '상권_코드_명': '관악구 사당역_3',
#   '엑스좌표_값': 198317,
#   '와이좌표_값': 441788,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620630,
#   '위도': 35.25225207400083,
#   '경도': 129.65648245892592},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001018,
#   '상권_코드_명': '포이사거리_2',
#   '엑스좌표_값': 203907,
#   '와이좌표_값': 441907,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 35.30255400426024,
#   '경도': 129.65943462785015},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001019,
#   '상권_코드_명': '포이사거리_1',
#   '엑스좌표_값': 204078,
#   '와이좌표_값': 441953,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680690,
#   '위도': 35.30408250852673,
#   '경도': 129.65999027415296},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001020,
#   '상권_코드_명': '장지역',
#   '엑스좌표_값': 210795,
#   '와이좌표_값': 441986,
#   '시군구_코드': 11710,
#   '행정동_코드': 11710642,
#   '위도': 35.36455161587195,
#   '경도': 129.66233675996202},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001021,
#   '상권_코드_명': '가산디지털단지역_1',
#   '엑스좌표_값': 189789,
#   '와이좌표_값': 441401,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545510,
#   '위도': 35.17556055811718,
#   '경도': 129.64973659185608},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001038,
#   '상권_코드_명': '구로디지탈1단지',
#   '엑스좌표_값': 190721,
#   '와이좌표_값': 442712,
#   '시군구_코드': 11530,
#   '행정동_코드': 11530540,
#   '위도': 35.18363653224479,
#   '경도': 129.66438698592214},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001039,
#   '상권_코드_명': '서울 서초구 남부터미널역_2',
#   '엑스좌표_값': 201211,
#   '와이좌표_값': 442998,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650530,
#   '위도': 35.27801608090329,
#   '경도': 129.67061915598262},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001040,
#   '상권_코드_명': '서울 관악구 신림역_3',
#   '엑스좌표_값': 193679,
#   '와이좌표_값': 442896,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620695,
#   '위도': 35.21022518547817,
#   '경도': 129.66727600002056},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001041,
#   '상권_코드_명': '서울 강남구 수서역',
#   '엑스좌표_값': 209143,
#   '와이좌표_값': 443137,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680750,
#   '위도': 35.34939834469766,
#   '경도': 129.6744969897892},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000377,
#   '상권_코드_명': '해등로16길',
#   '엑스좌표_값': 203765,
#   '와이좌표_값': 461761,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320515,
#   '위도': 35.296281076664066,
#   '경도': 129.87742072405044},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000378,
#   '상권_코드_명': '공릉로58길',
#   '엑스좌표_값': 206529,
#   '와이좌표_값': 459618,
#   '시군구_코드': 11350,
#   '행정동_코드': 11350611,
#   '위도': 35.321721018439646,
#   '경도': 129.854764605295},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000298,
#   '상권_코드_명': '정릉로27길',
#   '엑스좌표_값': 201136,
#   '와이좌표_값': 456377,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290630,
#   '위도': 35.27400672292477,
#   '경도': 129.8174806051002},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000299,
#   '상권_코드_명': '정릉로8길',
#   '엑스좌표_값': 199817,
#   '와이좌표_값': 456396,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290640,
#   '위도': 35.26212755471531,
#   '경도': 129.81727775080935},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000376,
#   '상권_코드_명': '우이천로4다길',
#   '엑스좌표_값': 203558,
#   '와이좌표_값': 459512,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320513,
#   '위도': 35.29500308106362,
#   '경도': 129.85266046640393},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001292,
#   '상권_코드_명': '이태원제일시장',
#   '엑스좌표_값': 198921,
#   '와이좌표_값': 448849,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170660,
#   '위도': 35.25596266701823,
#   '경도': 129.7341656063076},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001293,
#   '상권_코드_명': '보광시장',
#   '엑스좌표_값': 200033,
#   '와이좌표_값': 447503,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170700,
#   '위도': 35.26630745513357,
#   '경도': 129.71972638209675},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001278,
#   '상권_코드_명': '남평화시장',
#   '엑스좌표_값': 200955,
#   '와이좌표_값': 452181,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140615,
#   '위도': 35.27344202711567,
#   '경도': 129.77136115987588},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001279,
#   '상권_코드_명': '동평화시장',
#   '엑스좌표_값': 201155,
#   '와이좌표_값': 452190,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140615,
#   '위도': 35.27524033235183,
#   '경도': 129.77152134497638},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001280,
#   '상권_코드_명': '제일평화시장',
#   '엑스좌표_값': 201022,
#   '와이좌표_값': 452093,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140615,
#   '위도': 35.27406736176077,
#   '경도': 129.770415639515},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000300,
#   '상권_코드_명': '종암로16길',
#   '엑스좌표_값': 203263,
#   '와이좌표_값': 455409,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290705,
#   '위도': 35.29340237856003,
#   '경도': 129.80751549846144},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001281,
#   '상권_코드_명': '청평화시장',
#   '엑스좌표_값': 201326,
#   '와이좌표_값': 452228,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140615,
#   '위도': 35.276770253813055,
#   '경도': 129.77199101635074},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001282,
#   '상권_코드_명': '약수시장',
#   '엑스좌표_값': 200933,
#   '와이좌표_값': 450362,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140635,
#   '위도': 35.273700100672144,
#   '경도': 129.75138503663428},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001283,
#   '상권_코드_명': '백학시장',
#   '엑스좌표_값': 201714,
#   '와이좌표_값': 451574,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140650,
#   '위도': 35.28042780657979,
#   '경도': 129.76492982456332},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001284,
#   '상권_코드_명': '서울중앙시장',
#   '엑스좌표_값': 201735,
#   '와이좌표_값': 451936,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140670,
#   '위도': 35.28052589316409,
#   '경도': 129.76891069765162},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001309,
#   '상권_코드_명': '조양시장',
#   '엑스좌표_값': 205964,
#   '와이좌표_값': 448825,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215847,
#   '위도': 35.31937751572191,
#   '경도': 129.73603633775812},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001368,
#   '상권_코드_명': '연서시장',
#   '엑스좌표_값': 193085,
#   '와이좌표_값': 457778,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380530,
#   '위도': 35.20116862356737,
#   '경도': 129.83033927459687},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001369,
#   '상권_코드_명': '갈현시장',
#   '엑스좌표_값': 192709,
#   '와이좌표_값': 458241,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380551,
#   '위도': 35.19766479901959,
#   '경도': 129.8352996361807},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001370,
#   '상권_코드_명': '역촌중앙시장',
#   '엑스좌표_값': 192603,
#   '와이좌표_값': 457080,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380552,
#   '위도': 35.197008225470206,
#   '경도': 129.82253345715955},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001371,
#   '상권_코드_명': '대조시장',
#   '엑스좌표_값': 193542,
#   '와이좌표_값': 456660,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380570,
#   '위도': 35.20556903029179,
#   '경도': 129.8182193992077},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001098,
#   '상권_코드_명': '포스코사거리_1',
#   '엑스좌표_값': 204775,
#   '와이좌표_값': 445500,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680590,
#   '위도': 35.30949411277275,
#   '경도': 129.69915568378062},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001099,
#   '상권_코드_명': '포스코사거리_2',
#   '엑스좌표_값': 204973,
#   '와이좌표_값': 445586,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680580,
#   '위도': 35.311255670826775,
#   '경도': 129.70015956073584},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001100,
#   '상권_코드_명': '강남구 논현역_3',
#   '엑스좌표_값': 201931,
#   '와이좌표_값': 445848,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680521,
#   '위도': 35.28380318412105,
#   '경도': 129.70212612761534},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001101,
#   '상권_코드_명': '선정릉역_2',
#   '엑스좌표_값': 204085,
#   '와이좌표_값': 445833,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680590,
#   '위도': 35.303200069422886,
#   '경도': 129.70260647108628},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001102,
#   '상권_코드_명': '서울 강남구 학동역_1',
#   '엑스좌표_값': 202606,
#   '와이좌표_값': 445905,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680521,
#   '위도': 35.28986645323011,
#   '경도': 129.70295412702146},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001103,
#   '상권_코드_명': '코엑스',
#   '엑스좌표_값': 205283,
#   '와이좌표_값': 445735,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680580,
#   '위도': 35.314010118924,
#   '경도': 129.70188904145442},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001104,
#   '상권_코드_명': '삼성역_3',
#   '엑스좌표_값': 205648,
#   '와이좌표_값': 445805,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680580,
#   '위도': 35.317279131374185,
#   '경도': 129.70276734876936},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001055,
#   '상권_코드_명': '서울 서초구 서초역',
#   '엑스좌표_값': 200791,
#   '와이좌표_값': 443762,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650530,
#   '위도': 35.2740489910039,
#   '경도': 129.67888296547972},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001056,
#   '상권_코드_명': '서울 송파구 가락시장역',
#   '엑스좌표_값': 210540,
#   '와이좌표_값': 443838,
#   '시군구_코드': 11710,
#   '행정동_코드': 11710620,
#   '위도': 35.36180527345262,
#   '경도': 129.68261666572502},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001027,
#   '상권_코드_명': '가산디지털단지역_3',
#   '엑스좌표_값': 189955,
#   '와이좌표_값': 442117,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545510,
#   '위도': 35.1768830641034,
#   '경도': 129.65763692703518},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001028,
#   '상권_코드_명': '서울 관악구 서울대입구역_2',
#   '엑스좌표_값': 196006,
#   '와이좌표_값': 442715,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620575,
#   '위도': 35.23122060829175,
#   '경도': 129.6659758900688},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001029,
#   '상권_코드_명': '양재역_1',
#   '엑스좌표_값': 202809,
#   '와이좌표_값': 442502,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650651,
#   '위도': 35.292524064365665,
#   '경도': 129.66564510675803},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001011,
#   '상권_코드_명': '서울 금천구 시흥1동_4',
#   '엑스좌표_값': 191286,
#   '와이좌표_값': 439286,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545670,
#   '위도': 35.18954513788101,
#   '경도': 129.62697710854482},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001054,
#   '상권_코드_명': '서울 강남구 대치역_2',
#   '엑스좌표_값': 205280,
#   '와이좌표_값': 443785,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680600,
#   '위도': 35.31446015061275,
#   '경도': 129.68046863907844},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001012,
#   '상권_코드_명': '양재 화물트럭터미널앞_1',
#   '엑스좌표_값': 203161,
#   '와이좌표_값': 440282,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 35.29622860423662,
#   '경도': 129.64136854272104},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001013,
#   '상권_코드_명': '양재 화물트럭터미널앞_2',
#   '엑스좌표_값': 203269,
#   '와이좌표_값': 440563,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 35.29713352977547,
#   '경도': 129.6444862393249},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001014,
#   '상권_코드_명': '양재동 꽃시장',
#   '엑스좌표_값': 203547,
#   '와이좌표_값': 440820,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 35.299574781318185,
#   '경도': 129.6473903040755},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001015,
#   '상권_코드_명': '서울 금천구 독산1동_1',
#   '엑스좌표_값': 190842,
#   '와이좌표_값': 441181,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545610,
#   '위도': 35.185094470004785,
#   '경도': 129.64763171297082},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001016,
#   '상권_코드_명': '서울 관악구 대학동_1',
#   '엑스좌표_값': 194671,
#   '와이좌표_값': 441227,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620735,
#   '위도': 35.21955926931652,
#   '경도': 129.64925635361973},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000155,
#   '상권_코드_명': '아차산로78길',
#   '엑스좌표_값': 209529,
#   '와이좌표_값': 449647,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215810,
#   '위도': 35.351268255250844,
#   '경도': 129.7461520400613},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000156,
#   '상권_코드_명': '용마산로21길',
#   '엑스좌표_값': 207516,
#   '와이좌표_값': 451467,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215750,
#   '위도': 35.3326892398711,
#   '경도': 129.76553347302763},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000157,
#   '상권_코드_명': '용마산로3길',
#   '엑스좌표_값': 207500,
#   '와이좌표_값': 450785,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215750,
#   '위도': 35.332716488127296,
#   '경도': 129.75803597112457},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000158,
#   '상권_코드_명': '자양로11길',
#   '엑스좌표_값': 207326,
#   '와이좌표_값': 448272,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215820,
#   '위도': 35.331777123900366,
#   '경도': 129.73037437163038},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000295,
#   '상권_코드_명': '장월로1길',
#   '엑스좌표_값': 203962,
#   '와이좌표_값': 456285,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290725,
#   '위도': 35.29947127624661,
#   '경도': 129.81735258639884},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000296,
#   '상권_코드_명': '장위로50길',
#   '엑스좌표_값': 205038,
#   '와이좌표_값': 457231,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290780,
#   '위도': 35.308915202802815,
#   '경도': 129.82807806283816},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000297,
#   '상권_코드_명': '정릉로26길',
#   '엑스좌표_값': 201022,
#   '와이좌표_값': 456027,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290630,
#   '위도': 35.273069923665155,
#   '경도': 129.81360286205037},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001277,
#   '상권_코드_명': '방산종합시장',
#   '엑스좌표_값': 200011,
#   '와이좌표_값': 452055,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140605,
#   '위도': 35.264975018549386,
#   '경도': 129.76968842060748},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001264,
#   '상권_코드_명': '통인시장',
#   '엑스좌표_값': 197342,
#   '와이좌표_값': 453459,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110515,
#   '위도': 35.24059255469835,
#   '경도': 129.78427760126246},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001265,
#   '상권_코드_명': '광장시장',
#   '엑스좌표_값': 199948,
#   '와이좌표_값': 452270,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110615,
#   '위도': 35.26435375038852,
#   '경도': 129.7720291382659},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001266,
#   '상권_코드_명': '동대문종합시장',
#   '엑스좌표_값': 200715,
#   '와이좌표_값': 452320,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110630,
#   '위도': 35.27124635299132,
#   '경도': 129.77281342780927},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001267,
#   '상권_코드_명': '종로신진시장',
#   '엑스좌표_값': 200468,
#   '와이좌표_값': 452314,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110630,
#   '위도': 35.2690241601325,
#   '경도': 129.77267173259858},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001268,
#   '상권_코드_명': '충신시장',
#   '엑스좌표_값': 200505,
#   '와이좌표_값': 452729,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110630,
#   '위도': 35.2692526981678,
#   '경도': 129.77723876419358},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001269,
#   '상권_코드_명': '동문시장',
#   '엑스좌표_값': 200983,
#   '와이좌표_값': 452333,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110670,
#   '위도': 35.27365584154558,
#   '경도': 129.77303843017143},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001270,
#   '상권_코드_명': '창신골목시장',
#   '엑스좌표_값': 201018,
#   '와이좌표_값': 452590,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110680,
#   '위도': 35.27390618908159,
#   '경도': 129.7758705638327},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001272,
#   '상권_코드_명': '신설종합시장',
#   '엑스좌표_값': 201854,
#   '와이좌표_값': 452569,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110710,
#   '위도': 35.28143783492525,
#   '경도': 129.77589702726877},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001286,
#   '상권_코드_명': '후암시장',
#   '엑스좌표_값': 197904,
#   '와이좌표_값': 450124,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170510,
#   '위도': 35.24648930394117,
#   '경도': 129.74785081063706},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001287,
#   '상권_코드_명': '신흥시장',
#   '엑스좌표_값': 198680,
#   '와이좌표_값': 449527,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170520,
#   '위도': 35.25362441877399,
#   '경도': 129.74153425935557},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001289,
#   '상권_코드_명': '용문전통시장',
#   '엑스좌표_값': 196488,
#   '와이좌표_값': 448561,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170590,
#   '위도': 35.234129307262755,
#   '경도': 129.7302695643642},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001290,
#   '상권_코드_명': '이촌종합시장',
#   '엑스좌표_값': 197769,
#   '와이좌표_값': 446791,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170630,
#   '위도': 35.24609948389949,
#   '경도': 129.71123089519756},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001291,
#   '상권_코드_명': '이태원시장',
#   '엑스좌표_값': 199063,
#   '와이좌표_값': 448266,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170650,
#   '위도': 35.25738564671735,
#   '경도': 129.7278093817276},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001092,
#   '상권_코드_명': '강남구 논현역_1',
#   '엑스좌표_값': 201940,
#   '와이좌표_값': 445256,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650560,
#   '위도': 35.28402934580508,
#   '경도': 129.69562854201934},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001093,
#   '상권_코드_명': '신천역',
#   '엑스좌표_값': 207224,
#   '와이좌표_값': 445640,
#   '시군구_코드': 11710,
#   '행정동_코드': 11710650,
#   '위도': 35.331508870474444,
#   '경도': 129.7014271804008},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001094,
#   '상권_코드_명': '선정릉역_1',
#   '엑스좌표_값': 204141,
#   '와이좌표_값': 445689,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680590,
#   '위도': 35.303739613699896,
#   '경도': 129.7010417196146},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001095,
#   '상권_코드_명': '강남구 논현역_2',
#   '엑스좌표_값': 202208,
#   '와이좌표_값': 445400,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680521,
#   '위도': 35.28640698528586,
#   '경도': 129.697289777809},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001288,
#   '상권_코드_명': '만리시장',
#   '엑스좌표_값': 196790,
#   '와이좌표_값': 450197,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170555,
#   '위도': 35.23644167142834,
#   '경도': 129.74831331356563},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001096,
#   '상권_코드_명': '신도림역',
#   '엑스좌표_값': 190279,
#   '와이좌표_값': 445432,
#   '시군구_코드': 11530,
#   '행정동_코드': 11530510,
#   '위도': 35.17899659993205,
#   '경도': 129.6940853304143},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001052,
#   '상권_코드_명': '뱅뱅사거리_2',
#   '엑스좌표_값': 202873,
#   '와이좌표_값': 443583,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680640,
#   '위도': 35.292837902581546,
#   '경도': 129.6775351922819},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001053,
#   '상권_코드_명': '서울 강남구 대치역_1',
#   '엑스좌표_값': 205462,
#   '와이좌표_값': 443761,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680600,
#   '위도': 35.31610463078747,
#   '경도': 129.6802591128468},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001022,
#   '상권_코드_명': '관악구 사당역_2',
#   '엑스좌표_값': 198281,
#   '와이좌표_값': 442081,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590620,
#   '위도': 35.251857249621864,
#   '경도': 129.65968791638485},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001023,
#   '상권_코드_명': '가산디지털단지역_2',
#   '엑스좌표_값': 189388,
#   '와이좌표_값': 442499,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545510,
#   '위도': 35.171685848224826,
#   '경도': 129.66165947430557},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001024,
#   '상권_코드_명': '관악구 사당역_1',
#   '엑스좌표_값': 198513,
#   '와이좌표_값': 442082,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650610,
#   '위도': 35.253945870990194,
#   '경도': 129.6597671725373},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001025,
#   '상권_코드_명': '서울 관악구 서울대입구역_1',
#   '엑스좌표_값': 195788,
#   '와이좌표_값': 442367,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620595,
#   '위도': 35.229341899421605,
#   '경도': 129.66209297950937},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001026,
#   '상권_코드_명': '구로디지털단지역',
#   '엑스좌표_값': 190126,
#   '와이좌표_값': 442380,
#   '시군구_코드': 11530,
#   '행정동_코드': 11530595,
#   '위도': 35.17835935948641,
#   '경도': 129.66057122370555},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001097,
#   '상권_코드_명': '잠실역 롯데월드',
#   '엑스좌표_값': 208671,
#   '와이좌표_값': 445771,
#   '시군구_코드': 11710,
#   '행정동_코드': 11710680,
#   '위도': 35.34450441363829,
#   '경도': 129.70330059041802},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001051,
#   '상권_코드_명': '보라매공원',
#   '엑스좌표_값': 193371,
#   '와이좌표_값': 443527,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590680,
#   '위도': 35.20729924869473,
#   '경도': 129.67410740172582},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000067,
#   '상권_코드_명': '원효로53길',
#   '엑스좌표_값': 196681,
#   '와이좌표_값': 448648,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170590,
#   '위도': 35.23584537399008,
#   '경도': 129.73128252150707},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000068,
#   '상권_코드_명': '원효로89길',
#   '엑스좌표_값': 197234,
#   '와이좌표_값': 449086,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170560,
#   '위도': 35.24071549557881,
#   '경도': 129.73625620295442},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000069,
#   '상권_코드_명': '이촌로22길',
#   '엑스좌표_값': 196081,
#   '와이좌표_값': 447371,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170640,
#   '위도': 35.23075901511085,
#   '경도': 129.71708908834304},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000070,
#   '상권_코드_명': '이태원로27길',
#   '엑스좌표_값': 199453,
#   '와이좌표_값': 448497,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170650,
#   '위도': 35.26083966245618,
#   '경도': 129.73046277127912},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000152,
#   '상권_코드_명': '아차산로51길',
#   '엑스좌표_값': 207482,
#   '와이좌표_값': 448936,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215850,
#   '위도': 35.333016501798056,
#   '경도': 129.7377166933069},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000153,
#   '상권_코드_명': '아차산로55길',
#   '엑스좌표_값': 207733,
#   '와이좌표_값': 448875,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215850,
#   '위도': 35.33529144645286,
#   '경도': 129.7371227650746},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000154,
#   '상권_코드_명': '아차산로65길',
#   '엑스좌표_값': 208193,
#   '와이좌표_값': 449251,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215870,
#   '위도': 35.33933914898443,
#   '경도': 129.74139375764958},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001300,
#   '상권_코드_명': '화양제일골목시장',
#   '엑스좌표_값': 206096,
#   '와이좌표_값': 449274,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215710,
#   '위도': 35.320454127759206,
#   '경도': 129.7410085657179},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001301,
#   '상권_코드_명': '중곡제일시장',
#   '엑스좌표_값': 207176,
#   '와이좌표_값': 451590,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215740,
#   '위도': 35.32959734449803,
#   '경도': 129.76678037875226},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001302,
#   '상권_코드_명': '면곡골목시장',
#   '엑스좌표_값': 207134,
#   '와이좌표_값': 452395,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215760,
#   '위도': 35.3290163696889,
#   '경도': 129.77561092565713},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001303,
#   '상권_코드_명': '신성골목시장',
#   '엑스좌표_값': 207808,
#   '와이좌표_값': 450932,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215770,
#   '위도': 35.335452484844545,
#   '경도': 129.7597452829071},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001304,
#   '상권_코드_명': '자양골목시장',
#   '엑스좌표_값': 207042,
#   '와이좌표_값': 448309,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215820,
#   '위도': 35.329211062273615,
#   '경도': 129.73069480735563},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001305,
#   '상권_코드_명': '자양종합시장',
#   '엑스좌표_값': 206753,
#   '와이좌표_값': 448042,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215830,
#   '위도': 35.32667543072771,
#   '경도': 129.7276740625718},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001306,
#   '상권_코드_명': '노룬산골목시장',
#   '엑스좌표_값': 205742,
#   '와이좌표_값': 448568,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215847,
#   '위도': 35.31744272683862,
#   '경도': 129.73314597594336},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001307,
#   '상권_코드_명': '능동로골목시장',
#   '엑스좌표_값': 205899,
#   '와이좌표_값': 448403,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215840,
#   '위도': 35.318897195718684,
#   '경도': 129.73138111049568},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001308,
#   '상권_코드_명': '영동교골목시장',
#   '엑스좌표_값': 205654,
#   '와이좌표_값': 448727,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215847,
#   '위도': 35.31661093800659,
#   '경도': 129.73486580242363},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001273,
#   '상권_코드_명': '남대문시장',
#   '엑스좌표_값': 198091,
#   '와이좌표_값': 451149,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140540,
#   '위도': 35.24791673574301,
#   '경도': 129.75915688709233},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001274,
#   '상권_코드_명': '신중부시장',
#   '엑스좌표_값': 200023,
#   '와이좌표_값': 451785,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140590,
#   '위도': 35.265150912569815,
#   '경도': 129.76672830346445},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001275,
#   '상권_코드_명': '인현시장',
#   '엑스좌표_값': 199564,
#   '와이좌표_값': 451525,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140590,
#   '위도': 35.261083846864985,
#   '경도': 129.76373384463312},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001276,
#   '상권_코드_명': '평화시장',
#   '엑스좌표_값': 200710,
#   '와이좌표_값': 452148,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140590,
#   '위도': 35.271244631311184,
#   '경도': 129.77092370880328},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001069,
#   '상권_코드_명': '은마아파트입구사거리_3',
#   '엑스좌표_값': 205282,
#   '와이좌표_값': 444402,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680630,
#   '위도': 35.31432762631478,
#   '경도': 129.6872466401112},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001070,
#   '상권_코드_명': '은마아파트입구사거리_4',
#   '엑스좌표_값': 205466,
#   '와이좌표_값': 444479,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680610,
#   '위도': 35.31596544254533,
#   '경도': 129.68814729596616},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001071,
#   '상권_코드_명': '서울 강남구 한티역',
#   '엑스좌표_값': 204738,
#   '와이좌표_값': 444303,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680630,
#   '위도': 35.309453935389776,
#   '경도': 129.68599714045206},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001165,
#   '상권_코드_명': '서울 광진구 건대입구역_2',
#   '엑스좌표_값': 206151,
#   '와이좌표_값': 449134,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215710,
#   '위도': 35.32098417252681,
#   '경도': 129.73948741341232},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001166,
#   '상권_코드_명': '서울 마포구 마포역_2',
#   '엑스좌표_값': 195156,
#   '와이좌표_값': 449005,
#   '시군구_코드': 11440,
#   '행정동_코드': 11440590,
#   '위도': 35.22202697113403,
#   '경도': 129.73473892394068},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001167,
#   '상권_코드_명': '서울 마포구 공덕역_1',
#   '엑스좌표_값': 195722,
#   '와이좌표_값': 449271,
#   '시군구_코드': 11440,
#   '행정동_코드': 11440565,
#   '위도': 35.22705676017181,
#   '경도': 129.73782862714285},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001089,
#   '상권_코드_명': '삼정역_1',
#   '엑스좌표_값': 203222,
#   '와이좌표_값': 445342,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680640,
#   '위도': 35.29555063130503,
#   '경도': 129.696955919001},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001090,
#   '상권_코드_명': '삼정역_2',
#   '엑스좌표_값': 203114,
#   '와이좌표_값': 445442,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680531,
#   '위도': 35.29455375702602,
#   '경도': 129.69802180367884},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001091,
#   '상권_코드_명': '삼성역_2',
#   '엑스좌표_값': 205759,
#   '와이좌표_값': 445433,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680610,
#   '위도': 35.31836983588858,
#   '경도': 129.6987142689684},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000277,
#   '상권_코드_명': '보문로32길',
#   '엑스좌표_값': 201778,
#   '와이좌표_값': 454576,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290575,
#   '위도': 35.28024560660041,
#   '경도': 129.7979083617395},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000278,
#   '상권_코드_명': '삼선교로10길',
#   '엑스좌표_값': 200854,
#   '와이좌표_값': 454139,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290555,
#   '위도': 35.27203808176614,
#   '경도': 129.79282481796463},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000279,
#   '상권_코드_명': '삼선교로10다길',
#   '엑스좌표_값': 200773,
#   '와이좌표_값': 453904,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290555,
#   '위도': 35.27136843239709,
#   '경도': 129.79022002289253},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000280,
#   '상권_코드_명': '삼선교로16가길',
#   '엑스좌표_값': 201020,
#   '와이좌표_값': 453872,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290555,
#   '위도': 35.27360020980494,
#   '경도': 129.7899450425903},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000064,
#   '상권_코드_명': '우사단로4길',
#   '엑스좌표_값': 199868,
#   '와이좌표_값': 447913,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170700,
#   '위도': 35.264720594474724,
#   '경도': 129.72417743904785},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000065,
#   '상권_코드_명': '원효로19길',
#   '엑스좌표_값': 195898,
#   '와이좌표_값': 448189,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170570,
#   '위도': 35.22890946067236,
#   '경도': 129.72600969351623},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000066,
#   '상권_코드_명': '원효로41길',
#   '엑스좌표_값': 196180,
#   '와이좌표_값': 448370,
#   '시군구_코드': 11170,
#   '행정동_코드': 11170570,
#   '위도': 35.2314036016077,
#   '경도': 129.7280807735675},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001298,
#   '상권_코드_명': '성동용답상가시장',
#   '엑스좌표_값': 204625,
#   '와이좌표_값': 451565,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200790,
#   '위도': 35.30663742192514,
#   '경도': 129.76572305932652},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001311,
#   '상권_코드_명': '동부청과시장',
#   '엑스좌표_값': 203796,
#   '와이좌표_값': 453091,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230536,
#   '위도': 35.29878942493234,
#   '경도': 129.78222673707597},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001314,
#   '상권_코드_명': '경동시장',
#   '엑스좌표_값': 203447,
#   '와이좌표_값': 453307,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 35.295592845977936,
#   '경도': 129.78449101795061},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001315,
#   '상권_코드_명': '동서시장',
#   '엑스좌표_값': 203658,
#   '와이좌표_값': 453368,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 35.29747698386693,
#   '경도': 129.7852259891783},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001316,
#   '상권_코드_명': '서울약령시장',
#   '엑스좌표_값': 203313,
#   '와이좌표_값': 453621,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 35.2943069946269,
#   '경도': 129.78789763959162},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001317,
#   '상권_코드_명': '청량리농수산물시장',
#   '엑스좌표_값': 203638,
#   '와이좌표_값': 453503,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 35.29726275556778,
#   '경도': 129.78670227725854},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001318,
#   '상권_코드_명': '청량리전통시장',
#   '엑스좌표_값': 203766,
#   '와이좌표_값': 453471,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 35.29842320366096,
#   '경도': 129.78639040869166},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001319,
#   '상권_코드_명': '청량리종합시장',
#   '엑스좌표_값': 203566,
#   '와이좌표_값': 453322,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230545,
#   '위도': 35.29666037437262,
#   '경도': 129.78469245818633},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001320,
#   '상권_코드_명': '전농로터리시장',
#   '엑스좌표_값': 205011,
#   '와이좌표_값': 453130,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230560,
#   '위도': 35.30971786948317,
#   '경도': 129.783029849268},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001312,
#   '상권_코드_명': '용두시장',
#   '엑스좌표_값': 202629,
#   '와이좌표_값': 453215,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230536,
#   '위도': 35.28825188064859,
#   '경도': 129.78322847628476},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001313,
#   '상권_코드_명': '청량리수산시장',
#   '엑스좌표_값': 203666,
#   '와이좌표_값': 453187,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230536,
#   '위도': 35.29759479606949,
#   '경도': 129.78324085156262},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001321,
#   '상권_코드_명': '답십리현대시장',
#   '엑스좌표_값': 205255,
#   '와이좌표_값': 451917,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230610,
#   '위도': 35.312220653266614,
#   '경도': 129.76978242261646},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001299,
#   '상권_코드_명': '한아름시장',
#   '엑스좌표_값': 206177,
#   '와이좌표_값': 449338,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215710,
#   '위도': 35.32116742050808,
#   '경도': 129.74173622456888},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001085,
#   '상권_코드_명': '서울 서초구 강남역',
#   '엑스좌표_값': 202701,
#   '와이좌표_값': 444730,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680640,
#   '위도': 35.29100962575201,
#   '경도': 129.69007972132297},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001086,
#   '상권_코드_명': '고속터미널역',
#   '엑스좌표_값': 200518,
#   '와이좌표_값': 445031,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650581,
#   '위도': 35.271281526323556,
#   '경도': 129.6927338648656},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001087,
#   '상권_코드_명': '서울 강남구 선릉역_2',
#   '엑스좌표_값': 204007,
#   '와이좌표_값': 445054,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680640,
#   '위도': 35.30268883178711,
#   '경도': 129.6940275597563},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001088,
#   '상권_코드_명': '삼성역_1',
#   '엑스좌표_값': 205337,
#   '와이좌표_값': 445247,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680610,
#   '위도': 35.31461603840511,
#   '경도': 129.6965448680288},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001066,
#   '상권_코드_명': '서울 강남구 강남역',
#   '엑스좌표_값': 202696,
#   '와이좌표_값': 444064,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680640,
#   '위도': 35.29112715658885,
#   '경도': 129.68276470376782},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001067,
#   '상권_코드_명': '오류동역',
#   '엑스좌표_값': 186098,
#   '와이좌표_값': 444015,
#   '시군구_코드': 11530,
#   '행정동_코드': 11530770,
#   '위도': 35.14169691515113,
#   '경도': 129.67731152206224},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001068,
#   '상권_코드_명': '은마아파트입구사거리_2',
#   '엑스좌표_값': 205514,
#   '와이좌표_값': 444398,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680610,
#   '위도': 35.31641739764689,
#   '경도': 129.68727184743318},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000293,
#   '상권_코드_명': '인촌로5길',
#   '엑스좌표_값': 201816,
#   '와이좌표_값': 454390,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290600,
#   '위도': 35.28063495659008,
#   '경도': 129.79587807266952},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000294,
#   '상권_코드_명': '인촌로6길',
#   '엑스좌표_값': 201886,
#   '와이좌표_값': 453709,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290610,
#   '위도': 35.28143784751819,
#   '경도': 129.78842305804267},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000212,
#   '상권_코드_명': '천호대로77길',
#   '엑스좌표_값': 205537,
#   '와이좌표_값': 451598,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230650,
#   '위도': 35.31483971414933,
#   '경도': 129.76636523357917},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000213,
#   '상권_코드_명': '천호대로97길',
#   '엑스좌표_값': 206223,
#   '와이좌표_값': 451471,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230650,
#   '위도': 35.32104758787499,
#   '경도': 129.765180687891},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000214,
#   '상권_코드_명': '한천로14길',
#   '엑스좌표_값': 205777,
#   '와이좌표_값': 451945,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230650,
#   '위도': 35.316913065916374,
#   '경도': 129.77025032598365},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000215,
#   '상권_코드_명': '한천로33길',
#   '엑스좌표_값': 205926,
#   '와이좌표_값': 453093,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230570,
#   '위도': 35.31796470440308,
#   '경도': 129.78290585787735},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000273,
#   '상권_코드_명': '보국문로16길',
#   '엑스좌표_값': 200903,
#   '와이좌표_값': 456997,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290650,
#   '위도': 35.27175033023407,
#   '경도': 129.82421392418493},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000274,
#   '상권_코드_명': '보문로13길',
#   '엑스좌표_값': 201841,
#   '와이좌표_값': 453388,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290610,
#   '위도': 35.28111397154034,
#   '경도': 129.78488489874496},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000370,
#   '상권_코드_명': '방학로15길',
#   '엑스좌표_값': 202133,
#   '와이좌표_값': 462195,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320710,
#   '위도': 35.28147630274588,
#   '경도': 129.88166501700624},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000371,
#   '상권_코드_명': '방학로5길',
#   '엑스좌표_값': 203319,
#   '와이좌표_값': 462234,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320670,
#   '위도': 35.29214243188853,
#   '경도': 129.88247187391644},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000372,
#   '상권_코드_명': '방학로6가길',
#   '엑스좌표_값': 203292,
#   '와이좌표_값': 462755,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320690,
#   '위도': 35.29176281069479,
#   '경도': 129.88818357882093},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000373,
#   '상권_코드_명': '삼양로144길',
#   '엑스좌표_값': 201226,
#   '와이좌표_값': 461253,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320660,
#   '위도': 35.27355753024368,
#   '경도': 129.87103512489887},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000374,
#   '상권_코드_명': '시루봉로23길',
#   '엑스좌표_값': 203746,
#   '와이좌표_값': 463694,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320521,
#   '위도': 35.295602822658815,
#   '경도': 129.89863907276847},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000369,
#   '상권_코드_명': '방학로10길',
#   '엑스좌표_값': 202981,
#   '와이좌표_값': 462736,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320700,
#   '위도': 35.28896819853783,
#   '경도': 129.8878754539783},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000375,
#   '상권_코드_명': '우이천로32길',
#   '엑스좌표_값': 202238,
#   '와이좌표_값': 461174,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320660,
#   '위도': 35.282688226754026,
#   '경도': 129.8704896322705},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001326,
#   '상권_코드_명': '회기시장',
#   '엑스좌표_값': 204908,
#   '와이좌표_값': 454618,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230710,
#   '위도': 35.30841310793409,
#   '경도': 129.79934029385777},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001327,
#   '상권_코드_명': '이경시장',
#   '엑스좌표_값': 205837,
#   '와이좌표_값': 455017,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230720,
#   '위도': 35.31667487840282,
#   '경도': 129.80401118636564},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001328,
#   '상권_코드_명': '이문제일시장',
#   '엑스좌표_값': 205511,
#   '와이좌표_값': 456110,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230750,
#   '위도': 35.31346087831912,
#   '경도': 129.8159144250765},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001329,
#   '상권_코드_명': '동부골목시장',
#   '엑스좌표_값': 206792,
#   '와이좌표_값': 454766,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260590,
#   '위도': 35.32533626475752,
#   '경도': 129.80155105738118},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001330,
#   '상권_코드_명': '동원시장',
#   '엑스좌표_값': 208013,
#   '와이좌표_값': 454486,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260565,
#   '위도': 35.33639967486436,
#   '경도': 129.79885449569335},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001331,
#   '상권_코드_명': '면목골목시장',
#   '엑스좌표_값': 207494,
#   '와이좌표_값': 453154,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260570,
#   '위도': 35.33206547498017,
#   '경도': 129.78406016302404},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001285,
#   '상권_코드_명': '합동(새벽)시장',
#   '엑스좌표_값': 197137,
#   '와이좌표_값': 451173,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140680,
#   '위도': 35.23932187308202,
#   '경도': 129.75912911009718},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001294,
#   '상권_코드_명': '마장축산물시장',
#   '엑스좌표_값': 203566,
#   '와이좌표_값': 452297,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200540,
#   '위도': 35.29691919916001,
#   '경도': 129.7734367305196},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001295,
#   '상권_코드_명': '행당시장',
#   '엑스좌표_값': 202951,
#   '와이좌표_값': 451270,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200560,
#   '위도': 35.29164070063594,
#   '경도': 129.76197064890243},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001296,
#   '상권_코드_명': '금남시장',
#   '엑스좌표_값': 201970,
#   '와이좌표_값': 449892,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200615,
#   '위도': 35.28315357215539,
#   '경도': 129.746540636302},
#  {'상권_구분_코드_명': '전통시장',
#   '상권_코드': 1001297,
#   '상권_코드_명': '뚝도시장',
#   '엑스좌표_값': 204817,
#   '와이좌표_값': 448747,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200670,
#   '위도': 35.30907039499842,
#   '경도': 129.73483162684352},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001115,
#   '상권_코드_명': '서울 강남구 강남구청역_2',
#   '엑스좌표_값': 203357,
#   '와이좌표_값': 446378,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680531,
#   '위도': 35.29651167061298,
#   '경도': 129.70837349923045},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001116,
#   '상권_코드_명': '영등포역_1',
#   '엑스좌표_값': 192076,
#   '와이좌표_값': 446422,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560535,
#   '위도': 35.194933721372045,
#   '경도': 129.7054783153695},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001117,
#   '상권_코드_명': '강남구 신사역_2',
#   '엑스좌표_값': 202085,
#   '와이좌표_값': 446380,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680521,
#   '위도': 35.28505897537019,
#   '경도': 129.70801374884385},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001118,
#   '상권_코드_명': '문래동 주민센터',
#   '엑스좌표_값': 191040,
#   '와이좌표_값': 446252,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560605,
#   '위도': 35.18564777910264,
#   '경도': 129.70330453037488},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001119,
#   '상권_코드_명': '영등포역_2',
#   '엑스좌표_값': 191929,
#   '와이좌표_값': 446538,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560535,
#   '위도': 35.19358176102039,
#   '경도': 129.70670668787008},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001082,
#   '상권_코드_명': '선릉역_2',
#   '엑스좌표_값': 204689,
#   '와이좌표_값': 444957,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680630,
#   '위도': 35.30885289031536,
#   '경도': 129.69316586045295},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001083,
#   '상권_코드_명': '서울 송파구 석촌역_2',
#   '엑스좌표_값': 209524,
#   '와이좌표_값': 445199,
#   '시군구_코드': 11710,
#   '행정동_코드': 11710580,
#   '위도': 35.35232473207748,
#   '경도': 129.69727070905262},
#  {'상권_구분_코드_명': '발달상권',
#   '상권_코드': 1001084,
#   '상권_코드_명': '서울 강남구 선릉역_1',
#   '엑스좌표_값': 204433,
#   '와이좌표_값': 445167,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680590,
#   '위도': 35.30649659969849,
#   '경도': 129.69539590848305},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000210,
#   '상권_코드_명': '천호대로17길',
#   '엑스좌표_값': 202858,
#   '와이좌표_값': 452970,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230536,
#   '위도': 35.29037542785892,
#   '경도': 129.78060892248342},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000211,
#   '상권_코드_명': '천호대로45길',
#   '엑스좌표_값': 203787,
#   '와이좌표_값': 452855,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230536,
#   '위도': 35.298768035939055,
#   '경도': 129.7796323410149},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000221,
#   '상권_코드_명': '휘경로3길',
#   '엑스좌표_값': 205568,
#   '와이좌표_값': 455328,
#   '시군구_코드': 11230,
#   '행정동_코드': 11230740,
#   '위도': 35.31417387958351,
#   '경도': 129.80734334103224},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000289,
#   '상권_코드_명': '인촌로17가길',
#   '엑스좌표_값': 202091,
#   '와이좌표_값': 454230,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290600,
#   '위도': 35.283151307222646,
#   '경도': 129.79420656753496},
# ...
#   '행정동_코드': 11290705,
#   '위도': 35.29224045884935,
#   '경도': 129.80982701850775},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000304,
#   '상권_코드_명': '종암로5길',
#   '엑스좌표_값': 203019,
#   '와이좌표_값': 454873,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290705,
#   '위도': 35.29134232236564,
#   '경도': 129.80155419547094},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000305,
#   '상권_코드_명': '지봉로20길',
#   '엑스좌표_값': 201697,
#   '와이좌표_값': 453727,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290610,
#   '위도': 35.27973177612614,
#   '경도': 129.78856230355413},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000309,
#   '상권_코드_명': '화랑로13길',
#   '엑스좌표_값': 203678,
#   '와이좌표_값': 456195,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290725,
#   '위도': 35.29693761086396,
#   '경도': 129.81627562836616},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000311,
#   '상권_코드_명': '화랑로19길',
#   '엑스좌표_값': 204416,
#   '와이좌표_값': 456562,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290770,
#   '위도': 35.30348742978578,
#   '경도': 129.8205363131656},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000312,
#   '상권_코드_명': '화랑로1길',
#   '엑스좌표_값': 202972,
#   '와이좌표_값': 456141,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290715,
#   '위도': 35.290595674169396,
#   '경도': 129.81546238084343},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000041,
#   '상권_코드_명': '장충단로8길',
#   '엑스좌표_값': 200741,
#   '와이좌표_값': 451402,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140580,
#   '위도': 35.27171115020948,
#   '경도': 129.76274369670267},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000042,
#   '상권_코드_명': '청구로17길',
#   '엑스좌표_값': 201034,
#   '와이좌표_값': 451013,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140625,
#   '위도': 35.27444653066139,
#   '경도': 129.7585627585519},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000043,
#   '상권_코드_명': '청구로1길',
#   '엑스좌표_값': 201360,
#   '와이좌표_값': 450951,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140645,
#   '위도': 35.27739702302898,
#   '경도': 129.75798166872377},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000310,
#   '상권_코드_명': '화랑로14길',
#   '엑스좌표_값': 203729,
#   '와이좌표_값': 455749,
#   '시군구_코드': 11290,
#   '행정동_코드': 11290725,
#   '위도': 35.29751076744021,
#   '경도': 129.81139403844315},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000389,
#   '상권_코드_명': '가좌로7길',
#   '엑스좌표_값': 192862,
#   '와이좌표_값': 453934,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380600,
#   '위도': 35.20013989848053,
#   '경도': 129.78810925400867},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000390,
#   '상권_코드_명': '갈현로1길',
#   '엑스좌표_값': 191901,
#   '와이좌표_값': 455542,
#   '시군구_코드': 11380,
#   '행정동_코드': 11380631,
#   '위도': 35.19108061955496,
#   '경도': 129.80544806686243},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000352,
#   '상권_코드_명': '노해로60길',
#   '엑스좌표_값': 203002,
#   '와이좌표_값': 461043,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320680,
#   '위도': 35.28959995850439,
#   '경도': 129.8692943002746},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000353,
#   '상권_코드_명': '노해로63다길',
#   '엑스좌표_값': 204014,
#   '와이좌표_값': 461657,
#   '시군구_코드': 11320,
#   '행정동_코드': 11320515,
#   '위도': 35.29854975940974,
#   '경도': 129.8763581595058},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000529,
#   '상권_코드_명': '목동중앙서로7길',
#   '엑스좌표_값': 188084,
#   '와이좌표_값': 448328,
#   '시군구_코드': 11470,
#   '행정동_코드': 11470540,
#   '위도': 35.158523190481056,
#   '경도': 129.72518272632834},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000530,
#   '상권_코드_명': '목동중앙서로8가길',
#   '엑스좌표_값': 188068,
#   '와이좌표_값': 447995,
#   '시군구_코드': 11470,
#   '행정동_코드': 11470540,
#   '위도': 35.15846125911834,
#   '경도': 129.7215272113699},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000531,
#   '상권_코드_명': '신목로2길',
#   '엑스좌표_값': 189014,
#   '와이좌표_값': 446703,
#   '시군구_코드': 11470,
#   '행정동_코드': 11470630,
#   '위도': 35.16729615593912,
#   '경도': 129.7076452406503},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000118,
#   '상권_코드_명': '왕십리로26길',
#   '엑스좌표_값': 202889,
#   '와이좌표_값': 451635,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200535,
#   '위도': 35.290990867654315,
#   '경도': 129.76595957878519},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000095,
#   '상권_코드_명': '마조로16길',
#   '엑스좌표_값': 203961,
#   '와이좌표_값': 451778,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200540,
#   '위도': 35.30060597707613,
#   '경도': 129.76785861202202},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000096,
#   '상권_코드_명': '마조로1길',
#   '엑스좌표_값': 203530,
#   '와이좌표_값': 451337,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200550,
#   '위도': 35.296836558398596,
#   '경도': 129.76288362709178},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000097,
#   '상권_코드_명': '매봉길',
#   '엑스좌표_값': 201211,
#   '와이좌표_값': 449778,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200645,
#   '위도': 35.27634869611915,
#   '경도': 129.74505817353668},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000098,
#   '상권_코드_명': '무수막길',
#   '엑스좌표_값': 201844,
#   '와이좌표_값': 450369,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200615,
#   '위도': 35.2819000823848,
#   '경도': 129.7517395107047},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000099,
#   '상권_코드_명': '무학로6길',
#   '엑스좌표_값': 202959,
#   '와이좌표_값': 451797,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200535,
#   '위도': 35.29158034602165,
#   '경도': 129.7677598920778},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000100,
#   '상권_코드_명': '무학봉28길',
#   '엑스좌표_값': 202825,
#   '와이좌표_값': 451396,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200520,
#   '위도': 35.29047471178516,
#   '경도': 129.76331563035686},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000101,
#   '상권_코드_명': '무학봉길',
#   '엑스좌표_값': 202542,
#   '와이좌표_값': 451232,
#   '시군구_코드': 11200,
#   '행정동_코드': 11200520,
#   '위도': 35.28796804722171,
#   '경도': 129.76142823841957},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000678,
#   '상권_코드_명': '시흥대로62가길',
#   '엑스좌표_값': 191516,
#   '와이좌표_값': 439656,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545670,
#   '위도': 35.191527906749315,
#   '경도': 129.63110211497295},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000679,
#   '상권_코드_명': '시흥대로63길',
#   '엑스좌표_값': 190993,
#   '와이좌표_값': 439529,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545670,
#   '위도': 35.18684907408841,
#   '경도': 129.6295573071706},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000714,
#   '상권_코드_명': '신길로17길',
#   '엑스좌표_값': 191729,
#   '와이좌표_값': 444251,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560670,
#   '위도': 35.19233948522645,
#   '경도': 129.681563409213},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000715,
#   '상권_코드_명': '신길로39길',
#   '엑스좌표_값': 191864,
#   '와이좌표_값': 445355,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560650,
#   '위도': 35.193286049713976,
#   '경도': 129.69371216973374},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000716,
#   '상권_코드_명': '신길로42가길',
#   '엑스좌표_값': 192439,
#   '와이좌표_값': 445537,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560630,
#   '위도': 35.19841863385675,
#   '경도': 129.6958795093071},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000717,
#   '상권_코드_명': '신길로42길',
#   '엑스좌표_값': 192317,
#   '와이좌표_값': 445241,
#   '시군구_코드': 11560,
#   '행정동_코드': 11560660,
#   '위도': 35.19739248942457,
#   '경도': 129.69259649107912},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000808,
#   '상권_코드_명': '법원단지9길',
#   '엑스좌표_값': 193119,
#   '와이좌표_값': 441729,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620775,
#   '위도': 35.20546460432619,
#   '경도': 129.65430906881286},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000812,
#   '상권_코드_명': '봉천로33길',
#   '엑스좌표_값': 195052,
#   '와이좌표_값': 442764,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620605,
#   '위도': 35.22261921793544,
#   '경도': 129.66623238407573},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000813,
#   '상권_코드_명': '서림7길',
#   '엑스좌표_값': 194723,
#   '와이좌표_값': 441441,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620665,
#   '위도': 35.2199760277544,
#   '경도': 129.65161959034398},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000814,
#   '상권_코드_명': '승방길',
#   '엑스좌표_값': 198228,
#   '와이좌표_값': 441524,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620630,
#   '위도': 35.25151435956477,
#   '경도': 129.65355857754602},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000928,
#   '상권_코드_명': '선릉로18길',
#   '엑스좌표_값': 205444,
#   '와이좌표_값': 442663,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680670,
#   '위도': 35.316209500392986,
#   '경도': 129.6681924907926},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000929,
#   '상권_코드_명': '압구정로2길',
#   '엑스좌표_값': 201728,
#   '와이좌표_값': 446846,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680510,
#   '위도': 35.281730065225155,
#   '경도': 129.7130232442288},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000930,
#   '상권_코드_명': '언주로81길',
#   '엑스좌표_값': 203657,
#   '와이좌표_값': 444381,
#   '시군구_코드': 11680,
#   '행정동_코드': 11680650,
#   '위도': 35.299702167216005,
#   '경도': 129.6865318875731},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000499,
#   '상권_코드_명': '월드컵로16길',
#   '엑스좌표_값': 192138,
#   '와이좌표_값': 450868,
#   '시군구_코드': 11440,
#   '행정동_코드': 11440660,
#   '위도': 35.19439187497839,
#   '경도': 129.75426024829716},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000867,
#   '상권_코드_명': '사평대로26길',
#   '엑스좌표_값': 199919,
#   '와이좌표_값': 444457,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650581,
#   '위도': 35.2660286211696,
#   '경도': 129.68625399870234},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000868,
#   '상권_코드_명': '사평대로57길',
#   '엑스좌표_값': 201876,
#   '와이좌표_값': 445325,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650560,
#   '위도': 35.2834362303245,
#   '경도': 129.6963670614291},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000869,
#   '상권_코드_명': '서초대로15길',
#   '엑스좌표_값': 199030,
#   '와이좌표_값': 443314,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650621,
#   '위도': 35.258302547436166,
#   '경도': 129.67344308280067},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000552,
#   '상권_코드_명': '가로공원로76가길',
#   '엑스좌표_값': 185909,
#   '와이좌표_값': 448257,
#   '시군구_코드': 11500,
#   '행정동_코드': 11500540,
#   '위도': 35.13895832084003,
#   '경도': 129.72375126972702},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000553,
#   '상권_코드_명': '가로공원로80길',
#   '엑스좌표_값': 185846,
#   '와이좌표_값': 448560,
#   '시군구_코드': 11500,
#   '행정동_코드': 11500540,
#   '위도': 35.138316362531214,
#   '경도': 129.7270533559091},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000624,
#   '상권_코드_명': '고척로52길',
#   '엑스좌표_값': 187266,
#   '와이좌표_값': 444683,
#   '시군구_코드': 11530,
#   '행정동_코드': 11530720,
#   '위도': 35.15205111815073,
#   '경도': 129.68497924605705},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000006,
#   '상권_코드_명': '북촌로11길',
#   '엑스좌표_값': 198602,
#   '와이좌표_값': 453529,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110600,
#   '위도': 35.25191838074168,
#   '경도': 129.78543397113714},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000007,
#   '상권_코드_명': '북촌로5길',
#   '엑스좌표_값': 198383,
#   '와이좌표_값': 453422,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110540,
#   '위도': 35.24997381517753,
#   '경도': 129.78419217278193},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000137,
#   '상권_코드_명': '능동로13길',
#   '엑스좌표_값': 206086,
#   '와이좌표_값': 449515,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215710,
#   '위도': 35.32030401142421,
#   '경도': 129.74365284283525},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000138,
#   '상권_코드_명': '능동로19길',
#   '엑스좌표_값': 206369,
#   '와이좌표_값': 449653,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215710,
#   '위도': 35.32281742269581,
#   '경도': 129.74525491362223},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000139,
#   '상권_코드_명': '능동로34길',
#   '엑스좌표_값': 207316,
#   '와이좌표_값': 450510,
#   '시군구_코드': 11215,
#   '행정동_코드': 11215780,
#   '위도': 35.3311288948329,
#   '경도': 129.7549584919757},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000231,
#   '상권_코드_명': '동일로123길',
#   '엑스좌표_값': 206965,
#   '와이좌표_값': 455458,
#   '시군구_코드': 11260,
#   '행정동_코드': 11260610,
#   '위도': 35.32671718193834,
#   '경도': 129.8092064572793},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000831,
#   '상권_코드_명': '조원중앙로2길',
#   '엑스좌표_값': 191933,
#   '와이좌표_값': 442499,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620725,
#   '위도': 35.19460053415138,
#   '경도': 129.66240720878184},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000832,
#   '상권_코드_명': '중앙길',
#   '엑스좌표_값': 195647,
#   '와이좌표_값': 442864,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620615,
#   '위도': 35.227952233939995,
#   '경도': 129.66750504688525},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000833,
#   '상권_코드_명': '청룡8길',
#   '엑스좌표_값': 194960,
#   '와이좌표_값': 442335,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620595,
#   '위도': 35.22189452523969,
#   '경도': 129.66149822242048},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000809,
#   '상권_코드_명': '법원단지길',
#   '엑스좌표_값': 192885,
#   '와이좌표_값': 441644,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620775,
#   '위도': 35.203378157525655,
#   '경도': 129.6533080359931},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000810,
#   '상권_코드_명': '복은길',
#   '엑스좌표_값': 194616,
#   '와이좌표_값': 441668,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620665,
#   '위도': 35.218958003955095,
#   '경도': 129.65407884590152},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000855,
#   '상권_코드_명': '동광로39길',
#   '엑스좌표_값': 199980,
#   '와이좌표_값': 444218,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650581,
#   '위도': 35.26663610008766,
#   '경도': 129.68364840075097},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000856,
#   '상권_코드_명': '동산로10길',
#   '엑스좌표_값': 204021,
#   '와이좌표_값': 441216,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 35.303747192194294,
#   '경도': 129.65187881051148},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000857,
#   '상권_코드_명': '동산로19길',
#   '엑스좌표_값': 204097,
#   '와이좌표_값': 441586,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 35.304342231103554,
#   '경도': 129.6559649996761},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000858,
#   '상권_코드_명': '방배천로4안길',
#   '엑스좌표_값': 198534,
#   '와이좌표_값': 442403,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650610,
#   '위도': 35.254057399337455,
#   '경도': 129.66329681300613},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000859,
#   '상권_코드_명': '마방로2길',
#   '엑스좌표_값': 203516,
#   '와이좌표_값': 441384,
#   '시군구_코드': 11650,
#   '행정동_코드': 11650652,
#   '위도': 35.2991598253147,
#   '경도': 129.65357544952764},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000549,
#   '상권_코드_명': '지양로7길',
#   '엑스좌표_값': 185169,
#   '와이좌표_값': 446879,
#   '시군구_코드': 11470,
#   '행정동_코드': 11470611,
#   '위도': 35.132634488820926,
#   '경도': 129.70842678971877},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000500,
#   '상권_코드_명': '월드컵로19길',
#   '엑스좌표_값': 191895,
#   '와이좌표_값': 450786,
#   '시군구_코드': 11440,
#   '행정동_코드': 11440690,
#   '위도': 35.19222458568012,
#   '경도': 129.75328703308153},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000576,
#   '상권_코드_명': '공항대로55길',
#   '엑스좌표_값': 187636,
#   '와이좌표_값': 450546,
#   '시군구_코드': 11500,
#   '행정동_코드': 11500520,
#   '위도': 35.15393996293251,
#   '경도': 129.74936270573326},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000577,
#   '상권_코드_명': '공항대로59길',
#   '엑스좌표_값': 187993,
#   '와이좌표_값': 450371,
#   '시군구_코드': 11500,
#   '행정동_코드': 11500520,
#   '위도': 35.157197658518214,
#   '경도': 129.74755245396355},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000674,
#   '상권_코드_명': '시흥대로150길',
#   '엑스좌표_값': 191260,
#   '와이좌표_값': 441898,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545630,
#   '위도': 35.18868580094736,
#   '경도': 129.65561779621214},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000675,
#   '상권_코드_명': '시흥대로153길',
#   '엑스좌표_값': 190698,
#   '와이좌표_값': 441839,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545510,
#   '위도': 35.18363983266031,
#   '경도': 129.65480600406852},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000676,
#   '상권_코드_명': '시흥대로22길',
#   '엑스좌표_값': 191610,
#   '와이좌표_값': 437964,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545690,
#   '위도': 35.192776352590364,
#   '경도': 129.6125705832095},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000677,
#   '상권_코드_명': '시흥대로36길',
#   '엑스좌표_값': 191609,
#   '와이좌표_값': 438262,
#   '시군구_코드': 11545,
#   '행정동_코드': 11545690,
#   '위도': 35.19269674109883,
#   '경도': 129.61583895796406},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000821,
#   '상권_코드_명': '신림로65길',
#   '엑스좌표_값': 193516,
#   '와이좌표_값': 442877,
#   '시군구_코드': 11620,
#   '행정동_코드': 11620695,
#   '위도': 35.208762172439194,
#   '경도': 129.6670195323977},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000008,
#   '상권_코드_명': '북촌로5나길',
#   '엑스좌표_값': 198500,
#   '와이좌표_값': 454026,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110540,
#   '위도': 35.25087433118325,
#   '경도': 129.79085707404963},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000009,
#   '상권_코드_명': '삼청로5길',
#   '엑스좌표_값': 198284,
#   '와이좌표_값': 453968,
#   '시군구_코드': 11110,
#   '행정동_코드': 11110540,
#   '위도': 35.24894442790417,
#   '경도': 129.79015385082727},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000762,
#   '상권_코드_명': '서달로10길',
#   '엑스좌표_값': 196733,
#   '와이좌표_값': 444897,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590605,
#   '위도': 35.237236078203054,
#   '경도': 129.69013575757745},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000763,
#   '상권_코드_명': '서달로14길',
#   '엑스좌표_값': 196881,
#   '와이좌표_값': 445277,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590605,
#   '위도': 35.23847577164157,
#   '경도': 129.69434996022005},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000764,
#   '상권_코드_명': '서달로15길',
#   '엑스좌표_값': 196677,
#   '와이좌표_값': 445447,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590605,
#   '위도': 35.23659748877896,
#   '경도': 129.6961547301058},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000765,
#   '상권_코드_명': '서달로8가길',
#   '엑스좌표_값': 196640,
#   '와이좌표_값': 445137,
#   '시군구_코드': 11590,
#   '행정동_코드': 11590605,
#   '위도': 35.236340144663515,
#   '경도': 129.69274181532495},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000326,
#   '상권_코드_명': '도봉로99길',
#   '엑스좌표_값': 202431,
#   '와이좌표_값': 460456,
#   '시군구_코드': 11305,
#   '행정동_코드': 11305630,
#   '위도': 35.28461258013546,
#   '경도': 129.86266828710066},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000327,
#   '상권_코드_명': '삼각산로28길',
#   '엑스좌표_값': 201827,
#   '와이좌표_값': 459865,
#   '시군구_코드': 11305,
#   '행정동_코드': 11305630,
#   '위도': 35.279328761395256,
#   '경도': 129.85598873270553},
#  {'상권_구분_코드_명': '골목상권',
#   '상권_코드': 1000037,
#   '상권_코드_명': '동호로20길',
#   '엑스좌표_값': 200833,
#   '와이좌표_값': 451152,
#   '시군구_코드': 11140,
#   '행정동_코드': 11140580,
#   '위도': 35.2726021087966,
#   '경도': 129.76002731813279},
#  ...]

# %%
collection.insert_many(df.to_dict('records'))

# %%
for item in collection.find():
    print(item)
# Out:
# {'_id': ObjectId('61947fd243c0ec72518a26eb'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000275, '상권_코드_명': '보문로26길', '엑스좌표_값': 201886, '와이좌표_값': 454183, '시군구_코드': 11290, '행정동_코드': 11290600, '위도': 35.281317687486414, '경도': 129.79362710633055}
# {'_id': ObjectId('61947fd243c0ec72518a26ec'), '상권_구분_코드_명': '골목상권', '상권_코드': 1
), '상권_구분_코드_명': '전통시장', '상권_코드': 1001281, '상권_코드_명': '청평화시장', '엑스좌표_값': 201326, '와이좌표_값': 452228, '시군구_코드': 11140, '행정동_코드': 11140615, '위도': 35.276770253813055, '경도': 129.77199101635074}
# {'_id': ObjectId('61947fd243c0ec72518a2738'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001282, '상권_코드_명': '약수시장', '엑스좌표_값': 200933, '와이좌표_값': 450362, '시군구_코드': 11140, '행정동_코드': 11140635, '위도': 35.273700100672144, '경도': 129.75138503663428}
# {'_id': ObjectId('61947fd243c0ec72518a2739'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001283, '상권_코드_명': '백학시장', '엑스좌표_값': 201714, '와이좌표_값': 451574, '시군구_코드': 11140, '행정동_코드': 11140650, '위도': 35.28042780657979, '경도': 129.76492982456332}
# {'_id': ObjectId('61947fd243c0ec72518a273a'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001284, '상권_코드_명': '서울중앙시장', '엑스좌표_값': 201735, '와이좌표_값': 451936, '시군구_코드': 11140, '행정동_코드': 11140670, '위도': 35.28052589316409, '경도': 129.76891069765162}
# {'_id': ObjectId('61947fd243c0ec72518a273b'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001309, '상권_코드_명': '조양시장', '엑스좌표_값': 205964, '와이좌표_값': 448825, '시군구_코드': 11215, '행정동_코드': 11215847, '위도': 35.31937751572191, '경도': 129.73603633775812}
# {'_id': ObjectId('61947fd243c0ec72518a273c'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001368, '상권_코드_명': '연서시장', '엑스좌표_값': 193085, '와이좌표_값': 457778, '시군구_코드': 11380, '행정동_코드': 11380530, '위도': 35.20116862356737, '경도': 129.83033927459687}
# {'_id': ObjectId('61947fd243c0ec72518a273d'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001369, '상권_코드_명': '갈현시장', '엑스좌표_값': 192709, '와이좌표_값': 458241, '시군구_코드': 11380, '행정동_코드': 11380551, '위도': 35.19766479901959, '경도': 129.8352996361807}
# {'_id': ObjectId('61947fd243c0ec72518a273e'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001370, '상권_코드_명': '역촌중앙시장', '엑스좌표_값': 192603, '와이좌표_값': 457080, '시군구_코드': 11380, '행정동_코드': 11380552, '위도': 35.197008225470206, '경도': 129.82253345715955}
# {'_id': ObjectId('61947fd243c0ec72518a273f'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001371, '상권_코드_명': '대조시장', '엑스좌표_값': 193542, '와이좌표_값': 456660, '시군구_코드': 11380, '행정동_코드': 11380570, '위도': 35.20556903029179, '경도': 129.8182193992077}
# {'_id': ObjectId('61947fd243c0ec72518a2740'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001098, '상권_코드_명': '포스코사거리_1', '엑스좌표_값': 204775, '와이좌표_값': 445500, '시군구_코드': 11680, '행정동_코드': 11680590, '위도': 35.30949411277275, '경도': 129.69915568378062}
# {'_id': ObjectId('61947fd243c0ec72518a2741'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001099, '상권_코드_명': '포스코사거리_2', '엑스좌표_값': 204973, '와이좌표_값': 445586, '시군구_코드': 11680, '행정동_코드': 11680580, '위도': 35.311255670826775, '경도': 129.70015956073584}
# {'_id': ObjectId('61947fd243c0ec72518a2742'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001100, '상권_코드_명': '강남구 논현역_3', '엑스좌표_값': 201931, '와이좌표_값': 445848, '시군구_코드': 11680, '행정동_코드': 11680521, '위도': 35.28380318412105, '경도': 129.70212612761534}
# {'_id': ObjectId('61947fd243c0ec72518a2743'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001101, '상권_코드_명': '선정릉역_2', '엑스좌표_값': 204085, '와이좌표_값': 445833, '시군구_코드': 11680, '행정동_코드': 11680590, '위도': 35.303200069422886, '경도': 129.70260647108628}
# {'_id': ObjectId('61947fd243c0ec72518a2744'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001102, '상권_코드_명': '서울 강남구 학동역_1', '엑스좌표_값': 202606, '와이좌표_값': 445905, '시군구_코드': 11680, '행정동_코드': 11680521, '위도': 35.28986645323011, '경도': 129.70295412702146}
# {'_id': ObjectId('61947fd243c0ec72518a2745'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001103, '상권_코드_명': '코엑스', '엑스좌표_값': 205283, '와이좌표_값': 445735, '시군구_코드': 11680, '행정동_코드': 11680580, '위도': 35.314010118924, '경도': 129.70188904145442}
# {'_id': ObjectId('61947fd243c0ec72518a2746'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001104, '상권_코드_명': '삼성역_3', '엑스좌표_값': 205648, '와이좌표_값': 445805, '시군구_코드': 11680, '행정동_코드': 11680580, '위도': 35.317279131374185, '경도': 129.70276734876936}
# {'_id': ObjectId('61947fd243c0ec72518a2747'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001055, '상권_코드_명': '서울 서초구 서초역', '엑스좌표_값': 200791, '와이좌표_값': 443762, '시군구_코드': 11650, '행정동_코드': 11650530, '위도': 35.2740489910039, '경도': 129.67888296547972}
# {'_id': ObjectId('61947fd243c0ec72518a2748'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001056, '상권_코드_명': '서울 송파구 가락시장역', '엑스좌표_값': 210540, '와이좌표_값': 443838, '시군구_코드': 11710, '행정동_코드': 11710620, '위도': 35.36180527345262, '경도': 129.68261666572502}
# {'_id': ObjectId('61947fd243c0ec72518a2749'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001027, '상권_코드_명': '가산디지털단지역_3', '엑스좌표_값': 189955, '와이좌표_값': 442117, '시군구_코드': 11545, '행정동_코드': 11545510, '위도': 35.1768830641034, '경도': 129.65763692703518}
# {'_id': ObjectId('61947fd243c0ec72518a274a'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001028, '상권_코드_명': '서울 관악구 서울대입구역_2', '엑스좌표_값': 196006, '와이좌표_값': 442715, '시군구_코드': 11620, '행정동_코드': 11620575, '위도': 35.23122060829175, '경도': 129.6659758900688}
# {'_id': ObjectId('61947fd243c0ec72518a274b'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001029, '상권_코드_명': '양재역_1', '엑스좌표_값': 202809, '와이좌표_값': 442502, '시군구_코드': 11650, '행정동_코드': 11650651, '위도': 35.292524064365665, '경도': 129.66564510675803}
# {'_id': ObjectId('61947fd243c0ec72518a274c'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001011, '상권_코드_명': '서울 금천구 시흥1동_4', '엑스좌표_값': 191286, '와이좌표_값': 439286, '시군구_코드': 11545, '행정동_코드': 11545670, '위도': 35.18954513788101, '경도': 129.62697710854482}
# {'_id': ObjectId('61947fd243c0ec72518a274d'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001054, '상권_코드_명': '서울 강남구 대치역_2', '엑스좌표_값': 205280, '와이좌표_값': 443785, '시군구_코드': 11680, '행정동_코드': 11680600, '위도': 35.31446015061275, '경도': 129.68046863907844}
# {'_id': ObjectId('61947fd243c0ec72518a274e'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001012, '상권_코드_명': '양재 화물트럭터미널앞_1', '엑스좌표_값': 203161, '와이좌표_값': 440282, '시군구_코드': 11650, '행정동_코드': 11650652, '위도': 35.29622860423662, '경도': 129.64136854272104}
# {'_id': ObjectId('61947fd243c0ec72518a274f'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001013, '상권_코드_명': '양재 화물트럭터미널앞_2', '엑스좌표_값': 203269, '와이좌표_값': 440563, '시군구_코드': 11650, '행정동_코드': 11650652, '위도': 35.29713352977547, '경도': 129.6444862393249}
# {'_id': ObjectId('61947fd243c0ec72518a2750'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001014, '상권_코드_명': '양재동 꽃시장', '엑스좌표_값': 203547, '와이좌표_값': 440820, '시군구_코드': 11650, '행정동_코드': 11650652, '위도': 35.299574781318185, '경도': 129.6473903040755}
# {'_id': ObjectId('61947fd243c0ec72518a2751'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001015, '상권_코드_명': '서울 금천구 독산1동_1', '엑스좌표_값': 190842, '와이좌표_값': 441181, '시군구_코드': 11545, '행정동_코드': 11545610, '위도': 35.185094470004785, '경도': 129.64763171297082}
# {'_id': ObjectId('61947fd243c0ec72518a2752'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001016, '상권_코드_명': '서울 관악구 대학동_1', '엑스좌표_값': 194671, '와이좌표_값': 441227, '시군구_코드': 11620, '행정동_코드': 11620735, '위도': 35.21955926931652, '경도': 129.64925635361973}
# {'_id': ObjectId('61947fd243c0ec72518a2753'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000155, '상권_코드_명': '아차산로78길', '엑스좌표_값': 209529, '와이좌표_값': 449647, '시군구_코드': 11215, '행정동_코드': 11215810, '위도': 35.351268255250844, '경도': 129.7461520400613}
# {'_id': ObjectId('61947fd243c0ec72518a2754'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000156, '상권_코드_명': '용마산로21길', '엑스좌표_값': 207516, '와이좌표_값': 451467, '시군구_코드': 11215, '행정동_코드': 11215750, '위도': 35.3326892398711, '경도': 129.76553347302763}
# {'_id': ObjectId('61947fd243c0ec72518a2755'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000157, '상권_코드_명': '용마산로3길', '엑스좌표_값': 207500, '와이좌표_값': 450785, '시군구_코드': 11215, '행정동_코드': 11215750, '위도': 35.332716488127296, '경도': 129.75803597112457}
# {'_id': ObjectId('61947fd243c0ec72518a2756'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000158, '상권_코드_명': '자양로11길', '엑스좌표_값': 207326, '와이좌표_값': 448272, '시군구_코드': 11215, '행정동_코드': 11215820, '위도': 35.331777123900366, '경도': 129.73037437163038}
# {'_id': ObjectId('61947fd243c0ec72518a2757'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000295, '상권_코드_명': '장월로1길', '엑스좌표_값': 203962, '와이좌표_값': 456285, '시군구_코드': 11290, '행정동_코드': 11290725, '위도': 35.29947127624661, '경도': 129.81735258639884}
# {'_id': ObjectId('61947fd243c0ec72518a2758'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000296, '상권_코드_명': '장위로50길', '엑스좌표_값': 205038, '와이좌표_값': 457231, '시군구_코드': 11290, '행정동_코드': 11290780, '위도': 35.308915202802815, '경도': 129.82807806283816}
# {'_id': ObjectId('61947fd243c0ec72518a2759'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000297, '상권_코드_명': '정릉로26길', '엑스좌표_값': 201022, '와이좌표_값': 456027, '시군구_코드': 11290, '행정동_코드': 11290630, '위도': 35.273069923665155, '경도': 129.81360286205037}
# {'_id': ObjectId('61947fd243c0ec72518a275a'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001277, '상권_코드_명': '방산종합시장', '엑스좌표_값': 200011, '와이좌표_값': 452055, '시군구_코드': 11140, '행정동_코드': 11140605, '위도': 35.264975018549386, '경도': 129.76968842060748}
# {'_id': ObjectId('61947fd243c0ec72518a275b'), '상권_구분_코드_명': '전통시장', '상권_코드': 1
'시군구_코드': 11215, '행정동_코드': 11215710, '위도': 35.32098417252681, '경도': 129.73948741341232}
# {'_id': ObjectId('61947fd243c0ec72518a278f'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001166, '상권_코드_명': '서울 마포구 마포역_2', '엑스좌표_값': 195156, '와이좌표_값': 449005, '시군구_코드': 11440, '행정동_코드': 11440590, '위도': 35.22202697113403, '경도': 129.73473892394068}
# {'_id': ObjectId('61947fd243c0ec72518a2790'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001167, '상권_코드_명': '서울 마포구 공덕역_1', '엑스좌표_값': 195722, '와이좌표_값': 449271, '시군구_코드': 11440, '행정동_코드': 11440565, '위도': 35.22705676017181, '경도': 129.73782862714285}
# {'_id': ObjectId('61947fd243c0ec72518a2791'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001089, '상권_코드_명': '삼정역_1', '엑스좌표_값': 203222, '와이좌표_값': 445342, '시군구_코드': 11680, '행정동_코드': 11680640, '위도': 35.29555063130503, '경도': 129.696955919001}
# {'_id': ObjectId('61947fd243c0ec72518a2792'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001090, '상권_코드_명': '삼정역_2', '엑스좌표_값': 203114, '와이좌표_값': 445442, '시군구_코드': 11680, '행정동_코드': 11680531, '위도': 35.29455375702602, '경도': 129.69802180367884}
# {'_id': ObjectId('61947fd243c0ec72518a2793'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001091, '상권_코드_명': '삼성역_2', '엑스좌표_값': 205759, '와이좌표_값': 445433, '시군구_코드': 11680, '행정동_코드': 11680610, '위도': 35.31836983588858, '경도': 129.6987142689684}
# {'_id': ObjectId('61947fd243c0ec72518a2794'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000277, '상권_코드_명': '보문로32길', '엑스좌표_값': 201778, '와이좌표_값': 454576, '시군구_코드': 11290, '행정동_코드': 11290575, '위도': 35.28024560660041, '경도': 129.7979083617395}
# {'_id': ObjectId('61947fd243c0ec72518a2795'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000278, '상권_코드_명': '삼선교로10길', '엑스좌표_값': 200854, '와이좌표_값': 454139, '시군구_코드': 11290, '행정동_코드': 11290555, '위도': 35.27203808176614, '경도': 129.79282481796463}
# {'_id': ObjectId('61947fd243c0ec72518a2796'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000279, '상권_코드_명': '삼선교로10다길', '엑스좌표_값': 200773, '와이좌표_값': 453904, '시군구_코드': 11290, '행정동_코드': 11290555, '위도': 35.27136843239709, '경도': 129.79022002289253}
# {'_id': ObjectId('61947fd243c0ec72518a2797'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000280, '상권_코드_명': '삼선교로16가길', '엑스좌표_값': 201020, '와이좌표_값': 453872, '시군구_코드': 11290, '행정동_코드': 11290555, '위도': 35.27360020980494, '경도': 129.7899450425903}
# {'_id': ObjectId('61947fd243c0ec72518a2798'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000064, '상권_코드_명': '우사단로4길', '엑스좌표_값': 199868, '와이좌표_값': 447913, '시군구_코드': 11170, '행정동_코드': 11170700, '위도': 35.264720594474724, '경도': 129.72417743904785}
# {'_id': ObjectId('61947fd243c0ec72518a2799'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000065, '상권_코드_명': '원효로19길', '엑스좌표_값': 195898, '와이좌표_값': 448189, '시군구_코드': 11170, '행정동_코드': 11170570, '위도': 35.22890946067236, '경도': 129.72600969351623}
# {'_id': ObjectId('61947fd243c0ec72518a279a'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000066, '상권_코드_명': '원효로41길', '엑스좌표_값': 196180, '와이좌표_값': 448370, '시군구_코드': 11170, '행정동_코드': 11170570, '위도': 35.2314036016077, '경도': 129.7280807735675}
# {'_id': ObjectId('61947fd243c0ec72518a279b'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001298, '상권_코드_명': '성동용답상가시장', '엑스좌표_값': 204625, '와이좌표_값': 451565, '시군구_코드': 11200, '행정동_코드': 11200790, '위도': 35.30663742192514, '경도': 129.76572305932652}
# {'_id': ObjectId('61947fd243c0ec72518a279c'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001311, '상권_코드_명': '동부청과시장', '엑스좌표_값': 203796, '와이좌표_값': 453091, '시군구_코드': 11230, '행정동_코드': 11230536, '위도': 35.29878942493234, '경도': 129.78222673707597}
# {'_id': ObjectId('61947fd243c0ec72518a279d'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001314, '상권_코드_명': '경동시장', '엑스좌표_값': 203447, '와이좌표_값': 453307, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 35.295592845977936, '경도': 129.78449101795061}
# {'_id': ObjectId('61947fd243c0ec72518a279e'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001315, '상권_코드_명': '동서시장', '엑스좌표_값': 203658, '와이좌표_값': 453368, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 35.29747698386693, '경도': 129.7852259891783}
# {'_id': ObjectId('61947fd243c0ec72518a279f'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001316, '상권_코드_명': '서울약령시장', '엑스좌표_값': 203313, '와이좌표_값': 453621, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 35.2943069946269, '경도': 129.78789763959162}
# {'_id': ObjectId('61947fd243c0ec72518a27a0'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001317, '상권_코드_명': '청량리농수산물시장', '엑스좌표_값': 203638, '와이좌표_값': 453503, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 35.29726275556778, '경도': 129.78670227725854}
# {'_id': ObjectId('61947fd243c0ec72518a27a1'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001318, '상권_코드_명': '청량리전통시장', '엑스좌표_값': 203766, '와이좌표_값': 453471, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 35.29842320366096, '경도': 129.78639040869166}
# {'_id': ObjectId('61947fd243c0ec72518a27a2'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001319, '상권_코드_명': '청량리종합시장', '엑스좌표_값': 203566, '와이좌표_값': 453322, '시군구_코드': 11230, '행정동_코드': 11230545, '위도': 35.29666037437262, '경도': 129.78469245818633}
# {'_id': ObjectId('61947fd243c0ec72518a27a3'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001320, '상권_코드_명': '전농로터리시장', '엑스좌표_값': 205011, '와이좌표_값': 453130, '시군구_코드': 11230, '행정동_코드': 11230560, '위도': 35.30971786948317, '경도': 129.783029849268}
# {'_id': ObjectId('61947fd243c0ec72518a27a4'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001312, '상권_코드_명': '용두시장', '엑스좌표_값': 202629, '와이좌표_값': 453215, '시군구_코드': 11230, '행정동_코드': 11230536, '위도': 35.28825188064859, '경도': 129.78322847628476}
# {'_id': ObjectId('61947fd243c0ec72518a27a5'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001313, '상권_코드_명': '청량리수산시장', '엑스좌표_값': 203666, '와이좌표_값': 453187, '시군구_코드': 11230, '행정동_코드': 11230536, '위도': 35.29759479606949, '경도': 129.78324085156262}
# {'_id': ObjectId('61947fd243c0ec72518a27a6'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001321, '상권_코드_명': '답십리현대시장', '엑스좌표_값': 205255, '와이좌표_값': 451917, '시군구_코드': 11230, '행정동_코드': 11230610, '위도': 35.312220653266614, '경도': 129.76978242261646}
# {'_id': ObjectId('61947fd243c0ec72518a27a7'), '상권_구분_코드_명': '전통시장', '상권_코드': 1001299, '상권_코드_명': '한아름시장', '엑스좌표_값': 206177, '와이좌표_값': 449338, '시군구_코드': 11215, '행정동_코드': 11215710, '위도': 35.32116742050808, '경도': 129.74173622456888}
# {'_id': ObjectId('61947fd243c0ec72518a27a8'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001085, '상권_코드_명': '서울 서초구 강남역', '엑스좌표_값': 202701, '와이좌표_값': 444730, '시군구_코드': 11680, '행정동_코드': 11680640, '위도': 35.29100962575201, '경도': 129.69007972132297}
# {'_id': ObjectId('61947fd243c0ec72518a27a9'), '상권_구분_코드_명': '발달상권', '상권_코드': 1
), '상권_구분_코드_명': '골목상권', '상권_코드': 1000406, '상권_코드_명': '연서로29길', '엑스좌표_값': 192727, '와이좌표_값': 457882, '시군구_코드': 11380, '행정동_코드': 11380551, '위도': 35.19791904024636, '경도': 129.83136799021963}
# {'_id': ObjectId('61947fd243c0ec72518a2cb8'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000407, '상권_코드_명': '연서로33길', '엑스좌표_값': 193322, '와이좌표_값': 458034, '시군구_코드': 11380, '행정동_코드': 11380530, '위도': 35.20323649898307, '경도': 129.83322119175023}
# {'_id': ObjectId('61947fd243c0ec72518a2cb9'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000425, '상권_코드_명': '증산로21길', '엑스좌표_값': 192270, '와이좌표_값': 455209, '시군구_코드': 11380, '행정동_코드': 11380631, '위도': 35.19448723988326, '경도': 129.80191029024672}
# {'_id': ObjectId('61947fd243c0ec72518a2cba'), '상권_구분_코드_명': '골목상권', '상권_코드': 1000047, '상권_코드_명': '퇴계로56길', '엑스좌표_값': 200427, '와이좌표_값': 451429, '시군구_코드': 11140, '행정동_코드': 11140580, '위도': 35.26887745861209, '경도': 129.76294404152728}
# {'_id': ObjectId('61947fd243c0ec72518a2cbb'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001150, '상권_코드_명': '서울 용산구 이태원역', '엑스좌표_값': 199532, '와이좌표_값': 448274, '시군구_코드': 11170, '행정동_코드': 11170650, '위도': 35.26160616795089, '경도': 129.72803879702755}
# {'_id': ObjectId('61947fd243c0ec72518a2cbc'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001151, '상권_코드_명': '용산 전자상가_3', '엑스좌표_값': 196249, '와이좌표_값': 448167, '시군구_코드': 11170, '행정동_코드': 11170570, '위도': 35.23207504573457, '경도': 129.72587407782007}
# {'_id': ObjectId('61947fd243c0ec72518a2cbd'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001152, '상권_코드_명': '서울 광진구 강변역', '엑스좌표_값': 208480, '와이좌표_값': 448480, '시군구_코드': 11215, '행정동_코드': 11215870, '위도': 35.34211497610137, '경도': 129.73300958215725}
# {'_id': ObjectId('61947fd243c0ec72518a2cbe'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001153, '상권_코드_명': '당산역_1', '엑스좌표_값': 191112, '와이좌표_값': 448327, '시군구_코드': 11560, '행정동_코드': 11560620, '위도': 35.18578558290609, '경도': 129.7260822724152}
# {'_id': ObjectId('61947fd243c0ec72518a2cbf'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001154, '상권_코드_명': '용산 전자상가_4', '엑스좌표_값': 196450, '와이좌표_값': 448406, '시군구_코드': 11170, '행정동_코드': 11170560, '위도': 35.23382556598436, '경도': 129.72855725216283}
# {'_id': ObjectId('61947fd243c0ec72518a2cc0'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001155, '상권_코드_명': '용산 전자상가_5', '엑스좌표_값': 196870, '와이좌표_값': 448350, '시군구_코드': 11170, '행정동_코드': 11170560, '위도': 35.237620786895214, '경도': 129.72806945466297}
# {'_id': ObjectId('61947fd243c0ec72518a2cc1'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001156, '상권_코드_명': '서울 강동구 길동역', '엑스좌표_값': 212214, '와이좌표_값': 448512, '시군구_코드': 11740, '행정동_코드': 11740685, '위도': 35.37572425973575, '경도': 129.7344952107566}
# {'_id': ObjectId('61947fd243c0ec72518a2cc2'), '상권_구분_코드_명': '발달상권', '상권_코드': 1001120, '상권_코드_명': '도산공원사거리_1', '엑스좌표_값': 202754, '와이좌표_값': 446796, '시군구_코드': 11680, '행정동_코드': 11680545, '위도': 35.290979748325356, '경도': 129.71278259951788}
